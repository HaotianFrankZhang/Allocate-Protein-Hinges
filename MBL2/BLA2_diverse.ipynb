# %%
from numpy import *
# from matplotlib.pyplot import *
# import os
# ion()

# find hinges
def splitHinge(vals, sites, block):
    # split hinges
    currBlock = 1
    index = 0
    isStart = False
    newSites = []
    newVals = []

    for val in vals:
        if block[index] == currBlock and not isStart:
            isStart = True
            currSites = [sites[index]]
            currValLists = [vals[index]]
        elif block[index] == currBlock and isStart:
            currSites.append(sites[index])
            currValLists.append(vals[index])
        else:
            currBlock += 1
            isStart = True
            newSites.append(currSites)
            newVals.append(currValLists)
            currSites = [sites[index]]
            currValLists = [vals[index]]
        if currBlock == block[-1] and index == len(vals) - 1:
            newSites.append(currSites)
            newVals.append(currValLists)
        index += 1
    # print newSites, newVals
    return newSites, newVals


def mini(a, b):
    if a > b:
        return a
    else:
        return b


def checkIfCrossBase(currVal, currSite, currEigenVec):
    identify = sort(currVal)
    ifRemain = True
    if identify[0] < 0 and identify[-1] > 0:
        ifRemain = True
    else:
        maxSite = max(currSite)
        minSite = min(currSite)
        # print (identify)
        if identify[0] >= 0 and identify[-1] >= 0:
            if currEigenVec[max(0, minSite - 1)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 1)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 2)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 3)] < 0:
                ifRemain = True
            else:
                ifRemain = False
        elif identify[0] <= 0 and identify[-1] <= 0:
            # print (len(currEigenVec))
            # print (currEigenVec[239])

            if currEigenVec[max(0, minSite - 1)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 1))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 2))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 3))] > 0:
                ifRemain = True
            else:
                ifRemain = False

        else:
            print(identify[0], identify[-1])
            print("Check!")
    return ifRemain


def oneModeHinge(currEigenVec, thereshold=20):
    range = ((1 / float(len(currEigenVec))) ** 0.5) / thereshold
    # print (range)
    # print range
    sites = []
    vals = []
    block = []

    index = 0
    blockID = 1
    for item in currEigenVec:
        if item <= range and item >= -range:
            vals.append(item)
            if len(sites) >= 1 and abs(sites[-1] - index) > 1:
                blockID += 1
            sites.append(index)
            block.append(blockID)
        index += 1

    newSites, newVals = splitHinge(vals, sites, block)

    filtSites = []
    filtVals = []

    index = 0
    for item in newSites:
        currSite = newSites[index]
        currVal = newVals[index]
        if checkIfCrossBase(currVal, currSite, currEigenVec):
            filtSites.append(currSite)
            filtVals.append(currVal)
        index += 1

    return filtSites, filtVals


def getValue(currList):
    newList = []
    for item in currList:
        newList.append(float(item))
    return newList


def readModes(fileName):
    allModes = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.strip()
            line = line.split('\t')
            currMode = line[0]
            currVal = line[1:]
            allModes[currMode] = getValue(currVal)
    return allModes


def flattenData(arrayTwoD):
    flat = []
    for item in arrayTwoD:
        for each in item:
            flat.append(each)
    return flat

def cleanStr(currStr):
    return currStr.strip('\'')

def readFile(fileName):
    data = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.replace('\n', '')
            line = line.strip()
            line = line.split('\t')
            currPDB = line[0]
            currDrug = line[1]
            currChain = line[2:]
            if currPDB not in data.keys():
                data[currPDB] = {}
            if currDrug not in data[currPDB].keys():
                data[currPDB][currDrug] = []
            for each in currChain:
                data[currPDB][currDrug].append(cleanStr(each))
    return data

# contribution of mode of motions
def getContribution(eigenVals, mode):
    allContribution = sqrt(sum(1 / eigenVals))
    currModeContribution = eigenVals[:mode]
    currContribution = sqrt(sum(1 / currModeContribution))
    return currContribution / allContribution

def getModesGivenThreshold(eigenVals, thereshold):
    contribution = 0
    mode = 0
    while contribution <= thereshold:
        mode += 1
        contribution = getContribution(eigenVals, mode)
    return mode

def writeBinding(fileName, pdb_ids):
    with open(fileName, 'w') as wf:
        for item in pdb_ids:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')


from prody import *
def getModes(currPDB, eachChain, length = 0.7, rmsd = 1.0, Z = 10):    
    # if not os.path.exists('./Results/' + currPath):
    #     os.mkdir('./Results/' + currPath)
    dali_rec = searchDali(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len = length, cutoff_rmsd = rmsd, cutoff_Z = Z)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    
    ags = parsePDB(pdb_ids, subset='ca')
    dali_ens = buildPDBEnsemble(ags, mapping=mappings, seqid=20)
    gnms = calcEnsembleENMs(dali_ens, model='GNM', trim='reduce', n_modes=None)
    eigVals = gnms.getEigvals()
    averageEigVals = eigVals[0]

    eigVects = gnms.getEigvecs()
    averageEigVects = mean(eigVects, axis=0)
    return averageEigVals, averageEigVects, pdb_ids, gnms, averageEigVects

            
def getDali_info(currPDB, eachChain, rmsd = 2.5, length = 0.9):
    dali_rec = searchDali(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len=length, cutoff_rmsd=rmsd)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    return pdb_ids, mappings

def getHinges(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge


def getHinges_modes(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def get3Hinges_bandwidth(averageEigVects, bandWidths = [15, 16, 17]):
    currHinge = []
    for i in range(3):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidths[i])
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
def oneModeHinge_update(values, thereshold=20):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    # print (regions)
    
    FinalRegions = []
    for region in regions:
        # print ('before filtering', region)
        if len(region) >= 5:
            # print ('previous region', region)
            pos = [index for index in region if values[index] > 0]
            neg = [index for index in region if values[index] < 0]
            pos.sort(key=lambda x: values[x])
            neg.sort(key=lambda x: values[x], reverse=True)
            n = int(len(region) / 4) + 1
            region = pos[:n] + neg[:n]
            # print (region, neg, pos)
        elif 3 <= len(region) <= 4:
            if values[region[0]-1] * values[region[-1]+1] > 0:
                continue  # Skip this region if adjacent values outside the band have the same sign
        # print ('after filtering',region)      
            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    # print ('Final regions', FinalRegions)
    
    flat = flattenData(FinalRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return FinalRegions, final_values

def getHinges2(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

def getHinges_modes2(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

# %%
# Experiment to evaluate performance of hypergeometric p values
from scipy.stats import hypergeom
def ORA(M, N, n, k):
    total = 0
    totalLength = N
    binding = M
    hinge = n
    overlap = k
    
    for i in range(overlap):
        total += hypergeom.pmf(i, totalLength, binding, hinge)
    return 1 - total


import os
def writeIDs(path, idList):
    # Check whether the specified path exists or not
    isExist = os.path.exists(path)
    if not isExist:

       # Create a new directory because it does not exist
       os.makedirs(path)
       print("The new directory is created!")
    
    with open(path + '/ids_diverse.txt', 'w') as wf:
        for item in idList:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')

# %%
def writeNumbers(path, numbers):
    with open(path, 'w') as wf:
        for item in numbers:
            wf.write(str(item) + '\n')

def merge_overlapping_lists(lists):
    sorted_lists = sorted(lists, key=lambda x: x[0])  # Sort lists based on the first element
    merged_lists = [sorted_lists[0]]
    
    for current in sorted_lists[1:]:
        previous = merged_lists[-1]
        # Check if the current list overlaps with the previous one
        if current[0] <= previous[-1]:
            # Merge overlapping lists by updating the last list in merged_lists
            merged_lists[-1] = list(range(min(previous[0], current[0]), max(previous[-1], current[-1])+1))
        else:
            merged_lists.append(current)
    return merged_lists

# %% [markdown]
# # Method3

# %%
def trimEnds(values, lists):
    begining = 4
    ends = len(values) - 5
    isInclude = True
    for item in lists:
        if item < begining or item > ends:
            isInclude = False
    return isInclude

def splitRegions(currlist):
    sortList = sort(currlist)
    
    region_list = []
    currRegion = []
    previous = -1
    for item in sortList:
        if item - previous == 1:
            currRegion.append(item)
            previous = item
        else:
            if currRegion != []:
                region_list.append(currRegion)
            currRegion = [item]
            previous = item
    
    if currRegion not in region_list:
        region_list.append(currRegion)
    return region_list
        
def extendRegions(crossovers, values, thereshold):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    return regions

def mergeRegions(lists, max_gap=2, min_length=5):
    merged = [lists[0]]  # Start with the first list

    for next_list in lists[1:]:
        # Check if the next list starts within max_gap+1 of the last element of the current last list in 'merged'
        if next_list[0] - merged[-1][-1] <= max_gap + 1:
            # Merge the lists by extending the last list in 'merged' with the elements of 'next_list'
            merged[-1].extend(next_list)
        else:
            # If it doesn't meet the merge criteria, just append the list as a new one
            merged.append(next_list)

    # Filter merged lists to ensure they meet the min_length requirement after removing duplicates and sort them
    # Keep unmerged lists as they are
    final_list = []
    for sublist in merged:
        unique_sublist = sorted(set(sublist))  # Remove duplicates and sort
        if len(unique_sublist) >= min_length or unique_sublist == sublist:  # Check length or unchanged list
            final_list.append(unique_sublist)
        else:
            # For lists that were attempted to merge but didn't meet the length requirement,
            # revert to individual elements as separate lists
            final_list.extend([[item] for item in unique_sublist])

    # print (final_list)
    finals = []
    for item in final_list:
        if len(item) < min_length:
            finals += splitRegions(item)
        else:
            finals.append(item)
    
    return finals

# Function to trim similar sign values from start
def trim_start(lst, index):
    if len(lst) == 1:
        return lst, index
    if not lst:
        return [], []
    start_sign = lst[0] >= 0
    for i in range(1, len(lst)):
        if (lst[i] >= 0) != start_sign:
            return lst[i-1:], index[i-1:]
    return [], []

# Function to trim similar sign values from end
def trim_end(lst, index):
    if len(lst) == 1:
        return lst, index
    
    if not lst:
        return [], []
    lst = lst[::-1]  # Reverse the list for ease of use
    index = index[::-1]
    end_sign = lst[0] >= 0
    for i in range(1, len(lst)):
        if (lst[i] >= 0) != end_sign:
            return lst[i-1:][::-1], index[i-1:][::-1]  # Reverse the list again to restore original order
    return [], []

def trimRegions(region, values):
    newRegion = []
    for eachIndex in region:
        currValues = [values[x] for x in eachIndex]
        # print (eachIndex, currValues)
        # Apply the trimming functions
        trimmed_start, trimmed_index = trim_start(currValues, eachIndex)
        # print (trimmed_index)
        trimmed_end, trimmed_index = trim_end(trimmed_start, trimmed_index)
        newRegion.append(trimmed_index)
    return newRegion

def findSmallestPairs(index_list, value_list):
    # Initialize variables to store the smallest sum and corresponding indices
    smallest_sum = float('inf')  # Set it to infinity initially
    smallest_pair = None

    # Iterate through the value list to find adjacent index pairs with the smallest sum of absolute values
    for i in range(len(value_list) - 1):  # -1 because we are looking at pairs
        current_sum = abs(value_list[i]) + abs(value_list[i + 1])
        if current_sum < smallest_sum:
            smallest_sum = current_sum
            smallest_pair = [index_list[i], index_list[i + 1]]
    return smallest_pair

def find_cross_points(Final_test, crossovers, values):
    crossoverPoints_pairs = []
    for item in Final_test:
        if item in crossovers and item - 1 in Final_test:
            crossoverPoints_pairs.append([item - 1, item])
    
    # print ('cross_pairs', crossoverPoints_pairs)
    # filtering_pairs = mergeRegions(crossoverPoints_pairs, max_gap=0, min_length=3)
    # currNumber = len(filtering_pairs) * 2
    # print ('filtering_pairs', crossoverPoints_pairs)
    
    bestPairs = crossoverPoints_pairs[0]
    bestScore = abs(values[bestPairs[0]]) + abs(values[bestPairs[1]])
    if len(crossoverPoints_pairs) <= 1:
        return bestPairs
    else:
        for item in crossoverPoints_pairs[1:]:
            currScore = abs(values[item[0]]) + abs(values[item[1]])
            # print ('item, score', item, currScore)
            if currScore <= bestScore:
                bestPairs = item
                bestScore = currScore
    
    # print ('filtered', bestPairs)
    return bestPairs

def filteringCriteria(Final, values, crossovers):
    FinalRegions = []
    for region in Final:
        # print ('before filtering', region)
        if len(region) >= 5:
            allPairs = find_cross_points(region, crossovers, values)
            currRegion = allPairs
            
            # print ('allPairs', allPairs)
            pos = [index for index in region if values[index] > 0]
            neg = [index for index in region if values[index] < 0]
            pos.sort(key=lambda x: values[x])
            neg.sort(key=lambda x: values[x], reverse=True)
            extra = round((len(region) - 2) / 4 + 0.00001)
            
            # rest = pos[1:] + neg[1:]
            # restValues = [values[res] for res in rest]
            # combined_list = sorted(zip(rest, restValues), key=lambda x: abs(x[1]))
            rest = []
            for item in region:
                if item not in currRegion:
                    rest.append(item)
            restValues = [values[res] for res in rest]   
            combined_list = sorted(zip(rest, restValues), key=lambda x: abs(x[1]))
            
            # Extract the sorted indexes from the combined list
            sorted_indexes = [index for index, value in combined_list]
            
            region = currRegion + sorted_indexes[:extra]
            # print (region)
            
        elif 3 <= len(region) <= 4:
            region = find_cross_points(region, crossovers, values)
            # print (region)
            # if values[region[0]-1] * values[region[-1]+1] > 0:
            #     continue  # Skip this region if adjacent values outside the band have the same sign
        # print ('after filtering',region)      
            
        
        # print ('after filtering',region)      
        elif len(region) == 1:
            continue
            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    return FinalRegions

# %%
def oneModeHinge_update2(values, hinges, thereshold=20):
    # band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    regions = extendRegions(crossovers, values, thereshold)
    # print ('extend Regions', regions)
    
    # merge regions and hinges
    flat = sort(list(set(flattenData(regions) + hinges)))
    Final = splitRegions(flat)
    # print ('before merging', Final)
    Final = mergeRegions(Final, max_gap=2, min_length=5)
    # print ('Final is', Final)
    # trim Regions
    trimmedFinal = trimRegions(Final, values)
    # print ('after trimming', trimmedFinal)
    
    FinalRegions = filteringCriteria(trimmedFinal, values, crossovers)
    # print ('after filtering', FinalRegions)
    
    # remove frist and last several residues as hinges
    updateRegions = []
    for currReg in FinalRegions:
        if trimEnds(values, currReg):
            updateRegions.append(currReg)
    
    # print (updateRegions)
        
    flat = flattenData(updateRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return updateRegions, final_values

# %%
def getHinges_modes3(averageEigVects, mode, hinges, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update2(averageEigVects[:, mode], hinges, thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def getHinges3(averageEigVects, currNumModes, hinges, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update2(averageEigVects[:, i], hinges[i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
# remove first and last hinges for each chain
def filterTwoEnds(hinges, chainLength = [[0, 551], [552, 956]], trimmingLength = 15):
    FilteringIndex = []
    for item in chainLength:
        # print (item)
        FilteringIndex += list(range(item[0], item[0] + trimmingLength))
        FilteringIndex += list(range(item[1] - trimmingLength + 1, item[1] + 1))  
    updateHinges = []
    for item in hinges:
        if item not in FilteringIndex:
            updateHinges.append(item)
    
    return updateHinges

# %%
def writeAllData(path, curr):
    with open(path, 'w') as wf:
        for row in curr:
            for col in row:
                if col == 0.0:
                    wf.write('' + '\t')
                else:
                    wf.write(str(col) + '\t')
            wf.write('\n')

# %% [markdown]
# # Diverse ensemble

# %%
currPDB = '4c1h'
eachChain = 'A'

# pdb_ids, mappings = getDali_info(currPDB, eachChain, cutoff_len=0.7, cutoff_rmsd=1.0, cutoff_Z=10)
averageEigVals, averageEigVects, ids, gnms, averageEigVects = getModes(currPDB, eachChain, length=0.95, rmsd=1, Z=10)
# Out:
# @> Submitted Dali search for PDB "4c1hA".
# @> http://ekhidna2.biocenter.helsinki.fi/barcosel/tmp//4c1hA/
# @> Dali results were fetched in 0.2s.
# @> Obtained 1907 PDB chains from Dali for 4c1hA.
# @> 1220 PDBs have been filtered out from 1907 Dali hits (remaining: 687).
# @> Retrieving 4c1hA... [  0%]
# # of similar structures is found from Dali 687
# @> 687 PDBs were parsed in 176.97s.
# @> Mapping 2y8bA_ca to the reference... [  4%] 12s@> WARNING
# the number of residues in the map_dict (226 residues) is inconsistent with Chain A from 2y8bA_ca (225 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5lcfA_ca to the reference... [  9%] 11s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5le1A_ca to the reference... [ 12%] 11s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5naiA_ca to the reference... [ 21%] 10s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4axhA_ca to the reference... [ 97%] 1s @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 2yheC_ca to the reference... [ 97%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 2yheB_ca to the reference... [ 97%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4av7A_ca to the reference... [ 97%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4av7C_ca to the reference... [ 97%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 2cg2A_ca to the reference... [ 97%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 2yheE_ca to the reference... [ 97%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 2yheD_ca to the reference... [ 98%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4av7D_ca to the reference... [ 98%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4nurB_ca to the reference... [ 98%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4av7E_ca to the reference... [ 98%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 2cfzA_ca to the reference... [ 98%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4nurA_ca to the reference... [ 98%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 6ao1D_ca to the reference... [ 98%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 2yheA_ca to the reference... [ 99%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5ajlB_ca to the reference... [ 99%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4axhB_ca to the reference... [ 99%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4av7B_ca to the reference... [ 99%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 2yheF_ca to the reference... [ 99%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4av7F_ca to the reference... [ 99%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Starting iterative superposition:
# @> Step #1: RMSD difference = 1.4382e+00
# @> Step #2: RMSD difference = 1.3862e-02
# @> Step #3: RMSD difference = 3.6416e-04
# @> Step #4: RMSD difference = 1.3964e-05
# @> Iterative superposition completed in 0.59s.
# @> Final superposition to calculate transformations.
# @> Superposition completed in 0.15 seconds.
# @> Ensemble (663 conformations) were built in 14.41s.
# @> WARNING 24 structures cannot be mapped.
# @> WARNING last 12 modes for 208 modes from MaskedGNM 4c1hA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 12 modes for 208 modes from MaskedGNM 2m5dA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 12 modes for 208 modes from MaskedGNM 2m5cA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 1znbA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 3znbA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 3znbB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 11 modes for 208 modes from MaskedGNM 2bmiB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 1a7tA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 1a7tB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 2bmiA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 6xfrB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 2znbB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 1znbB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 4znbB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 4znbA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 1hlkB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6xfrA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 11 modes for 208 modes from MaskedGNM 1a8tB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 1hlkA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 1kr3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 11 modes for 208 modes from MaskedGNM 1a8tA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 2znbA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 1kr3B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6lfdD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6jv4C_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6lfdC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6jv4B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6lf4B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6lf4D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6t5kC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6lf4C_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6lfdB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6lfdA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4d1tA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6lf4A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4d1vA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 5acsB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 6t5lA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 2y87A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 2y8aA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 4d1wA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4d1uA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5mmdF_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5n58B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 2ynwA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 2yntB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 5n58A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 2yntA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6zynB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 6v61A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6jn6B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 5mmdE_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 8i52A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 5acsA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 7yrpB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 2ynuA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6kw1B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4nq2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4pvoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4pvtA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 5lcaA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dv1B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6zyoB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6kw1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5acpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 1ko3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4c1dA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6zynA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 6v71A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5lchA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6hf5A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4zejB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5a87A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 2ynvA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4zejA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dueB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6jn6A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4ua4A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 2yntC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5k48B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 8a4mA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5mxqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5acqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 5acrA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6dd0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4wd6A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5o7nA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 2yz3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5k48A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 7afxB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dubA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 6v54A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7yhbA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5nhzA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6sp7E_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 6v5mA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7ovhA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 2ynvB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5lm6B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5ni0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6ew3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dv1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5ni0E_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7afxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7oveA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6tgiA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4ua4B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5y6dB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6jv4D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6tmbB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5n5iA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6dd1B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 6tgiB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 7pp0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7duzB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 6kxoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5o7nB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7ovfA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 7yrpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4uwpB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6dd0B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5mm9B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5yd7B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5yd7A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6tm9A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dz1B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5acxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4bz3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4uwoB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4uwsB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4pvtB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6tmaB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4c1dB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6dd1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4c1eA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 6o5tB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 2whgA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6sp7A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7duxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 6v1pA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5mxrA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6rpnB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6zyoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6jv4A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6ew3B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4c1eB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7a60A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 7uydB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7uyaA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 2ynwB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 6o5tA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6kznB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 2wrsA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 6zgmA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6v3qB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4pvoB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5y6dA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5n55C_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7duzA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hxoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5nhzB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 7uydA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5acwA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5actA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5fqcA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7a60B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7cjlB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7up2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5y6dC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7yhbB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6tmaA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 2whgB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4bz3B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6tmbA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hy2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 2yz3B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5mm9A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dueA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6v3qA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7du1B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5n5hA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7duyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7du1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6yrpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5n4tB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hxpB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7yhcE_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 3l6nA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 2wrsB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hydA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7yhcH_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7yhcA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hy1B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7a5zA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6kxoB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5n4sA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hxuA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7yhcD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6j8rA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dv0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hxoB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5acxB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5n55A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7uybA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dz1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5fqcB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5n5gA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5y6eB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5lm6A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dyzA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5n55B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dubB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5y6eA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7yhcF_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5y6dD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hx5B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hxvB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6mh0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7chvA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7yhcC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5a87B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6rpnA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 7afyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5acwB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6y6jA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 4wd6B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6op7A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5n4sB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5n4tA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5ypkG_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hxwA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7yhcG_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7uycA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7cjlA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hxwB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hx5A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 5acpB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hxpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5lscA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hy1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8i52D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dz0B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6kznA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4fr7A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5lscB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hxuB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4uwrB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6mgzA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6tmcA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 8hxvA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 8b1zB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7yhcB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7yhdA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6mgzB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6v1pB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4tzfA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 6ovzB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 6v73A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 1m2xC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 3spuC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6lj1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6op6A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5ypmH_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5yplA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4u4lB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 6 modes for 208 modes from MaskedGNM 7ayjA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 4fsbB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6ogoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 1ko2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dz0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6tgdB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6c89A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 4fsbA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dyyB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6q30A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5ypmE_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5ypkC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5ypiF_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6tgdA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 1m2xB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4rbsA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6xciA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6c6iA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7dyyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 8skoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 8b20A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 5acqB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6c89D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 7uoyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 6mgyB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 7vqjB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 3spuD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5ypiC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5ypmD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5acvA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5acvB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5ypkD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5ypnA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5yplB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 5acuA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 4tzeB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 6c6iB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 6lizA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 7up3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5ypiD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 6mgyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6efjA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 8skoB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6d1bA_ca reduced has been discarded because at least one conformation has only 208 modes
# ...
# @> WARNING last 8 modes for 208 modes from MaskedGNM 3q6xA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6kxiA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5zgtB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 4eyfA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 7up1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5zguB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4rl2B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 3srxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6cacA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 6zysA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5zh1B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5zgeB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 8hy6B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5zgqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4hkyB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4eylB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4hl2B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 7ct2D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6ex7A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4h0dB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4hl2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5o2fB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ewaB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 3q6xB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4u4lD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5zgrA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5zgvB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5zgeA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 6zyrA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 6 modes for 208 modes from MaskedGNM 5k4kA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 6cacC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7wzuC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 6rmfA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 5k4mA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6jkbA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 5k4nA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7wzuA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7wzuD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 4u4lC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 5jqjA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 4c1fA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 6jkaB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 3sblA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 5k4kK_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 4c1gA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ewaA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 6ol8A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7yh9D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 5zgpB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ev8A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 8jaoB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7yh9A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7wzuB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 7 modes for 208 modes from MaskedGNM 8gpcB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ev8B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7dtnC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 8jaoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 5nbkA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ev6A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7dtnA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7yh9E_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6kzlA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6ol8B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7dtnD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7dtmB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 8hybA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 1jjtA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6jkbB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 1jjeB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4rl2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 1wuoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5o2fA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 6v70A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7dtmC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 1wuoC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7dtnB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7dtmD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 1wuoD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 4uamB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5y5bA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 1wuoB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 1jjtB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 7yh9F_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 1jjeA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 6jedA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ev6B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 6lblA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 6jkaC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 3pg4A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ev8C_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 1wupC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 3rkjA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 4gyqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 3rkjB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 1wupD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 3rkkA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 4gyqB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 3rkkB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 4gyqC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 4gyqD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ndeB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4gyuA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 6cqsA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ndbA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ls3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 2fhxB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 4bp0C_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ndbB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 4bp0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 2fhxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 1 modes for 208 modes from MaskedGNM 5ndeA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> all GNM modes were calculated for each of the 663 conformations in 23.90s.
# @> 208 modes across 663 modesets were matched in 6.08s.

# %%
writeIDs('./Binding', ids)
# Out:
# The new directory is created!

# %%
currNumModes = getModesGivenThreshold(averageEigVals, 0.33)
currNumModes
# Out:
# 3

# %%
bindings = ['48', '97', '100', '101', '104', '107', '108', '2199', '200', '201', '202', '215', '216', '217', '218', '224', '225', '226', '232', '233', '234', '235', '241', '242', '245', '326']

binding = [int(x) for x in bindings]

# %%
Hinges_2 = getHinges(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges(averageEigVects, 3, 20)

Hinges_4 = getHinges(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges(averageEigVects, 3, 15)

# %%
protein_length = 447

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 42
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 38 5 0.2787847912334618
# # of hinge sites for first 3 modes, overlap, hyper score 38 5 0.2787847912334618
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 48 6 0.2881632604181592
# # of hinge sites for first 3 modes, overlap, hyper score 48 6 0.2881632604181592

# %%
Badren = parsePDB('4c1h', subset='calpha')
calphas = Badren.select('calpha and chain A')
gnm = GNM('b-adren')
gnm.buildKirchhoff(calphas)
gnm.calcModes(n_modes=None)
Hinge0 = calcHinges(gnm[0])
Hinge1 = calcHinges(gnm[1])
Hinge2 = calcHinges(gnm[2])
# Out:
# @> Connecting wwPDB FTP server RCSB PDB (USA).
# @> 4c1h downloaded (4c1h.pdb.gz)
# @> PDB download via FTP completed (1 downloaded, 0 failed).
# @> 221 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> Secondary structures were assigned to 137 residues.
# @> Kirchhoff was built in 0.02s.
# @> 220 modes were calculated in 0.03s.

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 42
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 83 10 0.23365896982905376
# # of hinge sites for 3 modes, overlap, hyper score 83 10 0.23365896982905376
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 91 11 0.21258253478128197
# # of hinge sites for 3 modes, overlap, hyper score 91 11 0.21258253478128197

# %% [markdown]
# ## writeResults

# %%
# write MSFs
averageEigVals
modes = [0, 1]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)
len(MSF)
# Out:
# 578

# %%
values_array = np.array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = np.argsort(values_array)

if not os.path.exists('./Data'):
    os.mkdir('./Data')

writeNumbers('./Data/RMSF_minimum.txt', indices)

# %%
curr = zeros((len(MSF), 7))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]

for each in binding:
    curr[each, 0] = each

# %%
modes = [0, 1]
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    currList = sort(list(set(list(currHinge) + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
curr = list(curr)
def writeAllData(path, curr):
    with open(path, 'w') as wf:
        for row in curr:
            for col in row:
                if col == 0.0:
                    wf.write('' + '\t')
                else:
                    wf.write(str(col) + '\t')
            wf.write('\n')
                
writeAllData('./Data/ALB_Method1.txt', curr)

# %% [markdown]
# ## Method 2

# %%
bindings = [64,68,69,89,116,117,118,119,120,179,198,200,201,205,207,208,209,210,240]

binding = [x - 37 for x in bindings]

# %%
Hinges_2 = getHinges2(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges2(averageEigVects, 3, 20)

Hinges_4 = getHinges2(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges2(averageEigVects, 3, 15)

# %%
Hinges_2 = filterTwoEnds(Hinges_2, [[0, 221]], 10)
Hinges_3 = filterTwoEnds(Hinges_3, [[0, 221]], 10)
Hinges_4 = filterTwoEnds(Hinges_4, [[0, 221]], 10)
Hinges_5 = filterTwoEnds(Hinges_5, [[0, 221]], 10)

# %%
protein_length = 222

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 19
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 57 9 0.027743789068260805
# # of hinge sites for first 3 modes, overlap, hyper score 57 9 0.027743789068260805
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 54 7 0.14700026298620417
# # of hinge sites for first 3 modes, overlap, hyper score 54 7 0.14700026298620417

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

Hinges_sep2 = filterTwoEnds(Hinges_sep2, [[0, 348]], 15)
Hinges_sep3 = filterTwoEnds(Hinges_sep3, [[0, 348]], 15)
Hinges_sep4 = filterTwoEnds(Hinges_sep4, [[0, 348]], 15)
Hinges_sep5 = filterTwoEnds(Hinges_sep5, [[0, 348]], 15)

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 19
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 67 10 0.02783312693937534
# # of hinge sites for 3 modes, overlap, hyper score 67 10 0.02783312693937534
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 66 8 0.16492930355895585
# # of hinge sites for 3 modes, overlap, hyper score 66 8 0.16492930355895585

# %% [markdown]
# ## writeResults

# %%
# write MSFs
averageEigVals
modes = [0, 1]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)

# %%
curr = zeros((len(MSF), 7))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]

for each in binding:
    curr[each, 0] = each

# %%
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=15)
    currList = sort(list(set(list(currHinge) + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
writeAllData('./Data/ALB_Method2.txt', curr)

# %% [markdown]
# # method3

# %%
Hinges_2 = getHinges3(averageEigVects, currNumModes, [Hinge0, Hinge1, Hinge2], 20)
Hinges_3 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 20)

Hinges_4 = getHinges3(averageEigVects, currNumModes, [Hinge0, Hinge1, Hinge2], 15)
Hinges_5 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 15)

# %%
Hinges_2 = getHinges3(averageEigVects, currNumModes, [[], [], []], 20)
Hinges_3 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 20)

Hinges_4 = getHinges3(averageEigVects, currNumModes, [[], [], []], 15)
Hinges_5 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 15)

# %%
Hinges_2 = filterTwoEnds(Hinges_2, [[0, 221]], 10)
Hinges_3 = filterTwoEnds(Hinges_3, [[0, 221]], 10)
Hinges_4 = filterTwoEnds(Hinges_4, [[0, 221]], 10)
Hinges_5 = filterTwoEnds(Hinges_5, [[0, 221]], 10)

# %%
protein_length = 222

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 19
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 49 9 0.009562988146268658
# # of hinge sites for first 3 modes, overlap, hyper score 49 9 0.009562988146268658
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 49 9 0.009562988146268658
# # of hinge sites for first 3 modes, overlap, hyper score 49 9 0.009562988146268658

# %% [markdown]
# ## write data

# %%
# write MSFs
# averageEigVals
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)

# %%
values_array = array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = argsort(values_array)

if not os.path.exists('./Data'):
    os.mkdir('./Data')

writeNumbers('./Data/RMSF_minimum_diverse.txt', indices)

# %%
includeModes = 3
size = includeModes * 2 + 1 + 2 

curr = zeros((len(MSF), size))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]
curr[:, 5] = averageEigVects[:, 2]

for each in binding:
    curr[each, 0] = each

# %%
row, col = averageEigVects.shape
hinges = [Hinge0, Hinge1, Hinge2]
for mode in modes:
    currHinge = getHinges_modes3(averageEigVects, mode, hinges[mode], bandWidth=15)
    currHinge = filterTwoEnds(currHinge, [[0, 221]], 10)
    
    currList = sort(list(set(list(currHinge)))) # + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

writeAllData('./Data/BLA2_Method2_diverse.txt', curr)

# %% [markdown]
# # Write Modes

# %%
# write MSFs
# averageEigVals
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / EigVals[mode]
    MSF.append(currMSF)

# %%
writeModesAsBfactors(0, eigenVects)
writeModesAsBfactors(1, eigenVects)

# %% [markdown]
# # Plot graphs

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import math
import numpy as np

def format_significant(value, pos):
    if abs(value) <= 0.01:
        return "0.00"
    else:
        order_of_magnitude = math.floor(math.log10(abs(value)))
        round_digits = -order_of_magnitude + 1
        formatted_number = round(value, round_digits)
        str_format = "{:." + str(round_digits) + "f}"
        return str_format.format(formatted_number)

# %%
def plotSingleGraph(mode, averageEigVects, gnms, binding, Hinge):
    fig, ax = plt.subplots(figsize=(15, 10))   # Adjust size as per requirement
    
    plt.sca(ax)  # Set current axis to 'ax'
    
    # Increase font sizes
    plt.rc('xtick', labelsize=40)
    plt.rc('ytick', labelsize=50)
    plt.rcParams.update({'font.size': 50})

    # plot mode of motion
    showSignatureMode(gnms[:, mode], linewidth=3)

    # Hinges within band
    # method1
    # currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    # method2
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=20)
    
    
    HingeY = [averageEigVects[item, mode] for item in currHinge]
    print ('Hinge residue with wide bands', currHinge)
    plt.plot(currHinge, HingeY, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # extraHinges for local loops
    updateHinge = [item for item in Hinge if item not in currHinge]
    HingeY_local = [averageEigVects[item, mode] for item in updateHinge]
    print ('local loop motion', updateHinge)
    plt.plot(updateHinge, HingeY_local, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # plot binding sites
    bindingY = [averageEigVects[item, mode] for item in binding]
    plt.plot(binding, bindingY, 'r*', markersize=18)
    print ('current bindings are', binding)
    plt.title('Mode ' + str(mode + 1), fontweight="bold")

    # plot overlaps
    allHinge = updateHinge + currHinge
    overlaps = [item for item in binding if item in allHinge]
    overlapsY = [averageEigVects[item, mode] for item in overlaps]
    print ('current hits are', overlaps)
    plt.plot(overlaps, overlapsY, 'mD', markersize=18)

    print('# of overlaps finding from current mode is', len(overlaps))
    
    # Set y-ticks to have 4-5 values with equal spacing
    y_min, y_max = ax.get_ylim()
    ax.set_yticks(np.linspace(y_min * 0.9, y_max, 5))  # Adjust the number 5 if you want a different number of y-ticks
    ax.yaxis.set_major_formatter(FuncFormatter(format_significant)) 
    
    plt.tight_layout()
    plt.savefig('./MAPK14_method2_mode' + str(mode + 1) + '.png', dpi=500)

# %%
modes = 0 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, Hinge0)
# Out:
# Hinge residue with wide bands [333, 334, 335]
# local loop motion [338, 341, 344, 371]
# current bindings are [385, 386, 387, 523, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 408, 536, 538, 539, 542, 424, 425, 427, 428, 429, 432, 433, 443, 444, 445, 318, 447, 448, 321, 322, 451, 325, 203, 204, 207, 208, 341, 344, 345, 474, 475, 476, 477, 479, 480, 482, 483, 484, 381, 382, 383]
# current hits are [341, 344]
# # of overlaps finding from current mode is 2

# %%
modes = 1 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, Hinge1)
# Out:
# Hinge residue with wide bands [396, 397, 398, 399, 423, 424, 192, 193, 454, 455, 456, 457, 465, 466, 467, 486, 487, 238, 239, 250, 251]
# local loop motion [195, 237, 279, 402, 421, 459, 460]
# current bindings are [385, 386, 387, 523, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 408, 536, 538, 539, 542, 424, 425, 427, 428, 429, 432, 433, 443, 444, 445, 318, 447, 448, 321, 322, 451, 325, 203, 204, 207, 208, 341, 344, 345, 474, 475, 476, 477, 479, 480, 482, 483, 484, 381, 382, 383]
# current hits are [396, 397, 398, 399, 402, 424]
# # of overlaps finding from current mode is 6

# %%
def plotSingleGraph_method3(mode, averageEigVects, gnms, binding, Hinge):
    fig, ax = plt.subplots(figsize=(20, 10))   # Adjust size as per requirement
    
    plt.sca(ax)  # Set current axis to 'ax'
    
    # Increase font sizes
    plt.rc('xtick', labelsize=40)
    plt.rc('ytick', labelsize=50)
    plt.rcParams.update({'font.size': 50})

    # plot mode of motion
    showSignatureMode(gnms[:, mode], linewidth=3)

    # Hinges within band
    # method3
    currHinge = getHinges_modes3(averageEigVects, mode, Hinge, bandWidth = 15)
    currHinge = filterTwoEnds(currHinge, [[0, 221]], 10)
    
    HingeY = [averageEigVects[item, mode] for item in currHinge]
    print ('Hinge residue with wide bands', currHinge, len(currHinge))
    plt.plot(currHinge, HingeY, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # extraHinges for local loops
    # updateHinge = [item for item in Hinge if item not in currHinge]
    # HingeY_local = [averageEigVects[item, mode] for item in updateHinge]
    # print ('local loop motion', updateHinge)
    # plt.plot(updateHinge, HingeY_local, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # plot binding sites
    bindingY = [averageEigVects[item, mode] for item in binding]
    plt.plot(binding, bindingY, 'r*', markersize=18)
    print ('current bindings are', binding)
    plt.title('Mode ' + str(mode + 1), fontweight="bold")

    # plot overlaps
    allHinge = currHinge
    overlaps = [item for item in binding if item in allHinge]
    overlapsY = [averageEigVects[item, mode] for item in overlaps]
    print ('current hits are', overlaps)
    plt.plot(overlaps, overlapsY, 'mD', markersize=18)

    print('# of overlaps finding from current mode is', len(overlaps))
    
    # Set y-ticks to have 4-5 values with equal spacing
    y_min, y_max = ax.get_ylim()
    ax.set_yticks(np.linspace(y_min * 0.9, y_max, 5))  # Adjust the number 5 if you want a different number of y-ticks
    ax.yaxis.set_major_formatter(FuncFormatter(format_significant)) 
    
    plt.tight_layout()
    plt.savefig('./BLA2_diverse_Merging_method2_mode' + str(mode + 1) + '.png', dpi=500)

# %%
curr = [131, 100, 132, 102, 106, 107, 79, 80, 118, 119, 125, 126]
curr = [x + 37 for x in curr]
print (sort(curr))
# Out:
# [116 117 137 139 143 144 155 156 162 163 168 169]

# %%
modes = 0 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [131, 100, 132, 102, 106, 107, 79, 80, 118, 119, 125, 126] 12
# current bindings are [27, 31, 32, 52, 79, 80, 81, 82, 83, 142, 161, 163, 164, 168, 170, 171, 172, 173, 203]
# current hits are [79, 80]
# # of overlaps finding from current mode is 2

# %%
curr = [35, 36, 137, 10, 11, 138, 146, 51, 52, 21, 22, 83, 84, 147, 157, 158]
curr = [x + 37 for x in curr]
print (sort(curr))
# Out:
# [ 47  48  58  59  72  73  88  89 120 121 174 175 183 184 194 195]

# %%
modes = 1 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [35, 36, 137, 10, 11, 138, 146, 51, 52, 21, 22, 83, 84, 147, 157, 158] 16
# current bindings are [27, 31, 32, 52, 79, 80, 81, 82, 83, 142, 161, 163, 164, 168, 170, 171, 172, 173, 203]
# current hits are [52, 83]
# # of overlaps finding from current mode is 2

# %%
curr = [134, 135, 148, 149, 24, 25, 31, 32, 160, 161, 171, 172, 48, 49, 183, 184, 185, 58, 59, 73, 74, 125, 126]
curr = [x + 37 for x in curr]
print (sort(curr))
# Out:
# [ 61  62  68  69  85  86  95  96 110 111 162 163 171 172 185 186 197 198
#  208 209 220 221 222]

# %%
modes = 2 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [134, 135, 148, 149, 24, 25, 31, 32, 160, 161, 171, 172, 48, 49, 183, 184, 185, 58, 59, 73, 74, 125, 126] 23
# current bindings are [27, 31, 32, 52, 79, 80, 81, 82, 83, 142, 161, 163, 164, 168, 170, 171, 172, 173, 203]
# current hits are [31, 32, 161, 171, 172]
# # of overlaps finding from current mode is 5

# %% [markdown]
# # Write Modes

# %%
len(averageEigVects[:, 0])
# Out:
# 349

# %%
mode = 2

# %%
residue = []
new_b_factor = []

for item in averageEigVects[:, mode]:
    new_b_factor.append(item)

# %%
resiIndex = [x for x in range(3, 450)]
chain = ['A' for x in range(3, 450)]

# %%
with open('./structure_demo/CYP51_b_diverse_mode' + str(mode + 1) + '.txt', 'w') as wf:
    for i in range(len(resiIndex)):
        # print (chain[i])
        wf.write(chain[i] + ', ' + str(resiIndex[i]) + ', ' + str(new_b_factor[i]) + '\n')
