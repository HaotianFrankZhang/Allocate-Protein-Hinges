# %%
from numpy import *
# from matplotlib.pyplot import *
# import os
# ion()

# find hinges
def splitHinge(vals, sites, block):
    # split hinges
    currBlock = 1
    index = 0
    isStart = False
    newSites = []
    newVals = []

    for val in vals:
        if block[index] == currBlock and not isStart:
            isStart = True
            currSites = [sites[index]]
            currValLists = [vals[index]]
        elif block[index] == currBlock and isStart:
            currSites.append(sites[index])
            currValLists.append(vals[index])
        else:
            currBlock += 1
            isStart = True
            newSites.append(currSites)
            newVals.append(currValLists)
            currSites = [sites[index]]
            currValLists = [vals[index]]
        if currBlock == block[-1] and index == len(vals) - 1:
            newSites.append(currSites)
            newVals.append(currValLists)
        index += 1
    # print newSites, newVals
    return newSites, newVals


def mini(a, b):
    if a > b:
        return a
    else:
        return b


def checkIfCrossBase(currVal, currSite, currEigenVec):
    identify = sort(currVal)
    ifRemain = True
    if identify[0] < 0 and identify[-1] > 0:
        ifRemain = True
    else:
        maxSite = max(currSite)
        minSite = min(currSite)
        # print (identify)
        if identify[0] >= 0 and identify[-1] >= 0:
            if currEigenVec[max(0, minSite - 1)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 1)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 2)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 3)] < 0:
                ifRemain = True
            else:
                ifRemain = False
        elif identify[0] <= 0 and identify[-1] <= 0:
            # print (len(currEigenVec))
            # print (currEigenVec[239])

            if currEigenVec[max(0, minSite - 1)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 1))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 2))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 3))] > 0:
                ifRemain = True
            else:
                ifRemain = False

        else:
            print(identify[0], identify[-1])
            print("Check!")
    return ifRemain


def oneModeHinge(currEigenVec, thereshold=20):
    range = ((1 / float(len(currEigenVec))) ** 0.5) / thereshold
    # print (range)
    # print range
    sites = []
    vals = []
    block = []

    index = 0
    blockID = 1
    for item in currEigenVec:
        if item <= range and item >= -range:
            vals.append(item)
            if len(sites) >= 1 and abs(sites[-1] - index) > 1:
                blockID += 1
            sites.append(index)
            block.append(blockID)
        index += 1

    newSites, newVals = splitHinge(vals, sites, block)

    filtSites = []
    filtVals = []

    index = 0
    for item in newSites:
        currSite = newSites[index]
        currVal = newVals[index]
        if checkIfCrossBase(currVal, currSite, currEigenVec):
            filtSites.append(currSite)
            filtVals.append(currVal)
        index += 1

    return filtSites, filtVals


def getValue(currList):
    newList = []
    for item in currList:
        newList.append(float(item))
    return newList


def readModes(fileName):
    allModes = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.strip()
            line = line.split('\t')
            currMode = line[0]
            currVal = line[1:]
            allModes[currMode] = getValue(currVal)
    return allModes


def flattenData(arrayTwoD):
    flat = []
    for item in arrayTwoD:
        for each in item:
            flat.append(each)
    return flat

def cleanStr(currStr):
    return currStr.strip('\'')

def readFile(fileName):
    data = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.replace('\n', '')
            line = line.strip()
            line = line.split('\t')
            currPDB = line[0]
            currDrug = line[1]
            currChain = line[2:]
            if currPDB not in data.keys():
                data[currPDB] = {}
            if currDrug not in data[currPDB].keys():
                data[currPDB][currDrug] = []
            for each in currChain:
                data[currPDB][currDrug].append(cleanStr(each))
    return data

# contribution of mode of motions
def getContribution(eigenVals, mode):
    allContribution = sqrt(sum(1 / eigenVals))
    currModeContribution = eigenVals[:mode]
    currContribution = sqrt(sum(1 / currModeContribution))
    return currContribution / allContribution

def getModesGivenThreshold(eigenVals, thereshold):
    contribution = 0
    mode = 0
    while contribution <= thereshold:
        mode += 1
        contribution = getContribution(eigenVals, mode)
    return mode

def writeBinding(fileName, pdb_ids):
    with open(fileName, 'w') as wf:
        for item in pdb_ids:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')


from prody import *
def getModes(currPDB, eachChain, length = 0.7, rmsd = 1.0, Z = 10):    
    # if not os.path.exists('./Results/' + currPath):
    #     os.mkdir('./Results/' + currPath)
    dali_rec = searchDali(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len = length, cutoff_rmsd = rmsd, cutoff_Z = Z)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    
    ags = parsePDB(pdb_ids, subset='ca')
    dali_ens = buildPDBEnsemble(ags, mapping=mappings, seqid=20)
    gnms = calcEnsembleENMs(dali_ens, model='GNM', trim='reduce', n_modes=None)
    eigVals = gnms.getEigvals()
    averageEigVals = eigVals[0]

    eigVects = gnms.getEigvecs()
    averageEigVects = mean(eigVects, axis=0)
    return averageEigVals, averageEigVects, pdb_ids, gnms, averageEigVects

            
def getDali_info(currPDB, eachChain, rmsd = 2.5, length = 0.9):
    dali_rec = searchDali(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len=length, cutoff_rmsd=rmsd)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    return pdb_ids, mappings

def getHinges(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge


def getHinges_modes(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def get3Hinges_bandwidth(averageEigVects, bandWidths = [15, 16, 17]):
    currHinge = []
    for i in range(3):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidths[i])
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
def oneModeHinge_update(values, thereshold=20):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    # print (regions)
    
    FinalRegions = []
    for region in regions:
        # print ('before filtering', region)
        if len(region) >= 4:
            # print ('if continuous', values[region[0]-1] * values[region[-1]+1])
            if values[region[0]-1] * values[region[-1]+1] > 0:
                continue  
            else:
                # print ('previous region', region)
                pos = [index for index in region if values[index] > 0]
                neg = [index for index in region if values[index] < 0]
                pos.sort(key=lambda x: values[x])
                neg.sort(key=lambda x: values[x], reverse=True)
                n = int(len(region) / 4) + 1
                region = pos[:n] + neg[:n]
            # print (region, neg, pos)
        elif  len(region) == 3:  
            if values[region[0]-1] * values[region[-1]+1] > 0:
                continue  # Skip this region if adjacent values outside the band have the same sign
            else:
                region = find_cross_points(region, crossovers, values)

            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    # print ('Final regions', FinalRegions)
    
    flat = flattenData(FinalRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return FinalRegions, final_values

def getHinges2(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

def getHinges_modes2(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

# %%
# Experiment to evaluate performance of hypergeometric p values
from scipy.stats import hypergeom
def ORA(M, N, n, k):
    total = 0
    totalLength = N
    binding = M
    hinge = n
    overlap = k
    
    for i in range(overlap):
        total += hypergeom.pmf(i, totalLength, binding, hinge)
    return 1 - total


import os
def writeIDs(path, idList):
    # Check whether the specified path exists or not
    isExist = os.path.exists(path)
    if not isExist:

       # Create a new directory because it does not exist
       os.makedirs(path)
       print("The new directory is created!")
    
    with open(path + '/ids_diverse.txt', 'w') as wf:
        for item in idList:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')

# %%
def writeNumbers(path, numbers):
    with open(path, 'w') as wf:
        for item in numbers:
            wf.write(str(item) + '\n')

def merge_overlapping_lists(lists):
    sorted_lists = sorted(lists, key=lambda x: x[0])  # Sort lists based on the first element
    merged_lists = [sorted_lists[0]]
    
    for current in sorted_lists[1:]:
        previous = merged_lists[-1]
        # Check if the current list overlaps with the previous one
        if current[0] <= previous[-1]:
            # Merge overlapping lists by updating the last list in merged_lists
            merged_lists[-1] = list(range(min(previous[0], current[0]), max(previous[-1], current[-1])+1))
        else:
            merged_lists.append(current)
    return merged_lists

# %% [markdown]
# # Method3

# %%
def trimEnds(values, lists):
    begining = 4
    ends = len(values) - 5
    isInclude = True
    for item in lists:
        if item < begining or item > ends:
            isInclude = False
    return isInclude

def splitRegions(currlist):
    sortList = sort(currlist)
    
    region_list = []
    currRegion = []
    previous = -1
    for item in sortList:
        if item - previous == 1:
            currRegion.append(item)
            previous = item
        else:
            if currRegion != []:
                region_list.append(currRegion)
            currRegion = [item]
            previous = item
    
    if currRegion not in region_list:
        region_list.append(currRegion)
    return region_list
        
def extendRegions(crossovers, values, thereshold):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    return regions

def mergeRegions(lists, max_gap=2, min_length=5):
    merged = [lists[0]]  # Start with the first list

    for next_list in lists[1:]:
        # Check if the next list starts within max_gap+1 of the last element of the current last list in 'merged'
        if next_list[0] - merged[-1][-1] <= max_gap + 1:
            # Merge the lists by extending the last list in 'merged' with the elements of 'next_list'
            merged[-1].extend(next_list)
        else:
            # If it doesn't meet the merge criteria, just append the list as a new one
            merged.append(next_list)

    # Filter merged lists to ensure they meet the min_length requirement after removing duplicates and sort them
    # Keep unmerged lists as they are
    final_list = []
    for sublist in merged:
        unique_sublist = sorted(set(sublist))  # Remove duplicates and sort
        if len(unique_sublist) >= min_length or unique_sublist == sublist:  # Check length or unchanged list
            final_list.append(unique_sublist)
        else:
            # For lists that were attempted to merge but didn't meet the length requirement,
            # revert to individual elements as separate lists
            final_list.extend([[item] for item in unique_sublist])

    # print (final_list)
    finals = []
    for item in final_list:
        if len(item) < min_length:
            finals += splitRegions(item)
        else:
            finals.append(item)
    
    return finals

# Function to trim similar sign values from start
def trim_start(lst, index):
    if len(lst) == 1:
        return lst, index
    if not lst:
        return [], []
    start_sign = lst[0] >= 0
    for i in range(1, len(lst)):
        if (lst[i] >= 0) != start_sign:
            return lst[i-1:], index[i-1:]
    return [], []

# Function to trim similar sign values from end
def trim_end(lst, index):
    if len(lst) == 1:
        return lst, index
    
    if not lst:
        return [], []
    lst = lst[::-1]  # Reverse the list for ease of use
    index = index[::-1]
    end_sign = lst[0] >= 0
    for i in range(1, len(lst)):
        if (lst[i] >= 0) != end_sign:
            return lst[i-1:][::-1], index[i-1:][::-1]  # Reverse the list again to restore original order
    return [], []

def trimRegions(region, values):
    newRegion = []
    for eachIndex in region:
        currValues = [values[x] for x in eachIndex]
        # print (eachIndex, currValues)
        # Apply the trimming functions
        trimmed_start, trimmed_index = trim_start(currValues, eachIndex)
        # print (trimmed_index)
        trimmed_end, trimmed_index = trim_end(trimmed_start, trimmed_index)
        newRegion.append(trimmed_index)
    return newRegion

def findSmallestPairs(index_list, value_list):
    # Initialize variables to store the smallest sum and corresponding indices
    smallest_sum = float('inf')  # Set it to infinity initially
    smallest_pair = None

    # Iterate through the value list to find adjacent index pairs with the smallest sum of absolute values
    for i in range(len(value_list) - 1):  # -1 because we are looking at pairs
        current_sum = abs(value_list[i]) + abs(value_list[i + 1])
        if current_sum < smallest_sum:
            smallest_sum = current_sum
            smallest_pair = [index_list[i], index_list[i + 1]]
    return smallest_pair

def find_cross_points(Final_test, crossovers, values):
    crossoverPoints_pairs = []
    for item in Final_test:
        if item in crossovers and item - 1 in Final_test:
            crossoverPoints_pairs.append([item - 1, item])
    
    # print ('cross_pairs', crossoverPoints_pairs)
    # filtering_pairs = mergeRegions(crossoverPoints_pairs, max_gap=0, min_length=3)
    # currNumber = len(filtering_pairs) * 2
    # print ('filtering_pairs', crossoverPoints_pairs)
    
    bestPairs = crossoverPoints_pairs[0]
    bestScore = abs(values[bestPairs[0]]) + abs(values[bestPairs[1]])
    if len(crossoverPoints_pairs) <= 1:
        return bestPairs
    else:
        for item in crossoverPoints_pairs[1:]:
            currScore = abs(values[item[0]]) + abs(values[item[1]])
            # print ('item, score', item, currScore)
            if currScore <= bestScore:
                bestPairs = item
                bestScore = currScore
    
    # print ('filtered', bestPairs)
    return bestPairs

def filteringCriteria(Final, values, crossovers):
    FinalRegions = []
    for region in Final:
        # print ('before filtering', region)
        if len(region) >= 4:
            if len(region) == 4:
                if values[region[0]-1] * values[region[-1]+1] > 0:
                    continue  
            
            # print ('allPairs', allPairs)
            pos = [index for index in region if values[index] > 0]
            neg = [index for index in region if values[index] < 0]
            pos.sort(key=lambda x: values[x])
            neg.sort(key=lambda x: values[x], reverse=True)
            extra = round((len(region) - 2) / 4 + 0.00001)
            
            # rest = pos[1:] + neg[1:]
            # restValues = [values[res] for res in rest]
            # combined_list = sorted(zip(rest, restValues), key=lambda x: abs(x[1]))
            rest = []
            for item in region:
                if item not in currRegion:
                    rest.append(item)
            restValues = [values[res] for res in rest]   
            combined_list = sorted(zip(rest, restValues), key=lambda x: abs(x[1]))
            
            # Extract the sorted indexes from the combined list
            sorted_indexes = [index for index, value in combined_list]
            
            region = currRegion + sorted_indexes[:extra]
            # print (region)
            
        elif  len(region) == 3:  
            if values[region[0]-1] * values[region[-1]+1] > 0:
                continue  # Skip this region if adjacent values outside the band have the same sign
            else:
                region = find_cross_points(region, crossovers, values)
            
        
        # print ('after filtering',region)      
        elif len(region) == 1:
            continue
            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    return FinalRegions

# %%
def oneModeHinge_update2(values, hinges, thereshold=20):
    # band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    regions = extendRegions(crossovers, values, thereshold)
    # print ('extend Regions', regions)
    
    # merge regions and hinges
    flat = sort(list(set(flattenData(regions) + hinges)))
    Final = splitRegions(flat)
    # print ('before merging', Final)
    Final = mergeRegions(Final, max_gap=2, min_length=5)
    # print ('Final is', Final)
    # trim Regions
    trimmedFinal = trimRegions(Final, values)
    # print ('after trimming', trimmedFinal)
    
    FinalRegions = filteringCriteria(trimmedFinal, values, crossovers)
    # print ('after filtering', FinalRegions)
    
    # remove frist and last several residues as hinges
    updateRegions = []
    for currReg in FinalRegions:
        if trimEnds(values, currReg):
            updateRegions.append(currReg)
    
    # print (updateRegions)
        
    flat = flattenData(updateRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return updateRegions, final_values

# %%
def getHinges_modes3(averageEigVects, mode, hinges, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update2(averageEigVects[:, mode], hinges, thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def getHinges3(averageEigVects, currNumModes, hinges, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update2(averageEigVects[:, i], hinges[i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
# remove first and last hinges for each chain
def filterTwoEnds(hinges, chainLength = [[0, 551], [552, 956]], trimmingLength = 15):
    FilteringIndex = []
    for item in chainLength:
        # print (item)
        FilteringIndex += list(range(item[0], item[0] + trimmingLength))
        FilteringIndex += list(range(item[1] - trimmingLength + 1, item[1] + 1))  
    updateHinges = []
    for item in hinges:
        if item not in FilteringIndex:
            updateHinges.append(item)
    
    return updateHinges

# %% [markdown]
# # Diverse ensemble

# %%
currPDB = '6f78'
eachChain = 'A'

# pdb_ids, mappings = getDali_info(currPDB, eachChain, cutoff_len=0.7, cutoff_rmsd=1.0, cutoff_Z=10)
averageEigVals, averageEigVects, ids, gnms, averageEigVects = getModes(currPDB, eachChain, length=0.95, rmsd=1, Z=10)
# Out:
# @> Submitted Dali search for PDB "6f78A".
# @> http://ekhidna2.biocenter.helsinki.fi/barcosel/tmp//6f78A/
# @> Dali results were fetched in 0.2s.
# @> Obtained 5026 PDB chains from Dali for 6f78A.
# @> 4764 PDBs have been filtered out from 5026 Dali hits (remaining: 262).
# @> Retrieving 6f78A... [  0%]
# # of similar structures is found from Dali 262
# @> Retrieving 2pznA... [ 12%] 121s@> WARNING SEQADV for chain A: database sequence reference not found (2PZN:321)
# @> Retrieving 3t42A... [ 14%] 120s@> WARNING SEQADV for chain A: database sequence reference not found (3T42:303)
# @> Retrieving 1t41A... [ 30%] 93s @> WARNING SEQADV for chain A: database sequence reference not found (1T41:290)
# @> 262 PDBs were parsed in 119.93s.
# @> Mapping 3ln3A_ca to the reference... [  0%]@> WARNING
# the number of residues in the map_dict (319 residues) is inconsistent with Chain A from 3ln3A_ca (291 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 1ah3A_ca to the reference... [ 51%] 4s@> WARNING
# the number of residues in the map_dict (315 residues) is inconsistent with Chain A from 1ah3A_ca (314 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 1ah4A_ca to the reference... [ 62%] 3s@> WARNING
# the number of residues in the map_dict (315 residues) is inconsistent with Chain A from 1ah4A_ca (314 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 1ekoA_ca to the reference... [ 66%] 3s@> WARNING
# the number of residues in the map_dict (315 residues) is inconsistent with Chain A from 1ekoA_ca (314 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4wevX_ca to the reference... [ 67%] 3s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 4wevX_ca (301 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 2pf8A_ca to the reference... [ 69%] 3s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain A from 2pf8A_ca (313 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4xzlX_ca to the reference... [ 70%] 2s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 4xzlX_ca (302 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5liuX_ca to the reference... [ 71%] 2s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5liuX_ca (302 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4iccX_ca to the reference... [ 74%] 2s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 4iccX_ca (301 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5liyX_ca to the reference... [ 75%] 2s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5liyX_ca (307 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5lixX_ca to the reference... [ 75%] 2s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5lixX_ca (301 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5liwX_ca to the reference... [ 76%] 2s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5liwX_ca (307 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5likX_ca to the reference... [ 76%] 2s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5likX_ca (302 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5m2fX_ca to the reference... [ 77%] 2s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5m2fX_ca (299 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4xzmX_ca to the reference... [ 79%] 2s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 4xzmX_ca (298 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4xznX_ca to the reference... [ 79%] 2s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 4xznX_ca (299 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Starting iterative superposition:
# @> Step #1: RMSD difference = 1.0466e+00
# @> Step #2: RMSD difference = 3.7278e-03
# @> Step #3: RMSD difference = 9.0957e-05
# @> Iterative superposition completed in 0.17s.
# @> Final superposition to calculate transformations.
# @> Superposition completed in 0.06 seconds.
# @> Ensemble (246 conformations) were built in 6.78s.
# @> WARNING 16 structures cannot be mapped.
# @> WARNING last 16 modes for 301 modes from MaskedGNM 6f78A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 13 modes for 301 modes from MaskedGNM 2he8B_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 9 modes for 301 modes from MaskedGNM 2he8A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 13 modes for 301 modes from MaskedGNM 3fjnB_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 13 modes for 301 modes from MaskedGNM 2he5B_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 13 modes for 301 modes from MaskedGNM 2he5A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 1afsA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 1afsB_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 9 modes for 301 modes from MaskedGNM 2he5D_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 3fjnA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 9 modes for 301 modes from MaskedGNM 2he5C_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4rpqA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 8fh6A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4qx4A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4xzhA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2hv5A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 10 modes for 301 modes from MaskedGNM 6m7kA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2pdlA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 8b3nA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 5ou0A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 4ys1A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2pdfA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4q7bA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3bcjA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4igsA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 5oujA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3u2cA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2pdhA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2j8tA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2fzbA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2dv0A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2pdqA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2pznA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 4puuA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 6t5gA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1pwlA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3t42A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2pdpA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 4nkcA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4prtA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 5oukA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2pdkA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2pdjA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4prrA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1x98A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2pduA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2pdnA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2pdgA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 6t27A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 6tufA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3q67B_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2acqA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3q67A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2agtA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3mc5A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 8auuA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1x97A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1pwmA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 6xumA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2pd5A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2nvcA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 8b34A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3rx2A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2nvdA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3m0iA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2ikhA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2pdmA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2f2kA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 4puwA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3lenA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 8aqpA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2pd9A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1x96A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 8fh9A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2ikgA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2fz9A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 8fh5A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4qbxA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3m64A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1t41A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 5ha7B_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2pdcA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3dn5A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 4pr4A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3mb9A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 5ha7A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1z8aA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3v35A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 6y1pA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4lb4A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2ikjA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 8fh7A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3q65B_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 4yu1A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 6txpA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2ineA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 6sywA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 6td8A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3rx3A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3q65A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3s3gA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 6f81A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2pevA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3p2vA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1z89A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2pdyA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3rx4A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4gcaA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2pdwA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2pdbA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2hvoA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4lb3A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 8bjlA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2fz8A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 8ae9A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1el3A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 6f82A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 4qr6A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4lbsA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2duxA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4lbrA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 4jirA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 6t7qA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3v36A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 8fh8A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2duzA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4lazA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 6f84A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4lauA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 10 modes for 301 modes from MaskedGNM 6f7rA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2iq0A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2acuA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 9 modes for 301 modes from MaskedGNM 6y03A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 8a4nA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 8b66A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3ghuA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3ghtA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2hvnA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3m4hA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 1ah0A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 1t40A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 6t3pA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2pdiA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2iqdA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4xziA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3ghsA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2isfA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 2r24A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 2fzdA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2is7A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3ghrA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 1adsA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 1ef3B_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1ef3A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2inzA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4xzhB_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1az1A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2acrA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 2acsA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3lboA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3g5eA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 10 modes for 301 modes from MaskedGNM 4qxiA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 8b3rA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 9 modes for 301 modes from MaskedGNM 6f8oA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 6 modes for 301 modes from MaskedGNM 2ipwA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 6tucA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 1z3nA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 9 modes for 301 modes from MaskedGNM 2qxwA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 2pdxA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4ga8A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 8aqgA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 9 modes for 301 modes from MaskedGNM 3oncA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 1us0A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 3lqgA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 10 modes for 301 modes from MaskedGNM 1c9wA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 9 modes for 301 modes from MaskedGNM 3lepA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 7 modes for 301 modes from MaskedGNM 2i17A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 1az2A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 3ld5A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 3onbA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 3lz3A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 7 modes for 301 modes from MaskedGNM 2i16A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 3lz5A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 3lqlA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 7 modes for 301 modes from MaskedGNM 2ikiA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 10 modes for 301 modes from MaskedGNM 1frbA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 1zuaX_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4gabA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4jiiX_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4jihA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 4gq0A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3qkzA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 4gqgA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 3o3rA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3o3rB_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 4i5xA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 3qkzB_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 11 modes for 301 modes from MaskedGNM 5y7nA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 10 modes for 301 modes from MaskedGNM 1hqtA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 12 modes for 301 modes from MaskedGNM 1ieiA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 7 modes for 301 modes from MaskedGNM 3h4gA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 9 modes for 301 modes from MaskedGNM 5ketA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 3fx4A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 9 modes for 301 modes from MaskedGNM 3cv7A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 2pfhA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 8 modes for 301 modes from MaskedGNM 4gacA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 5 modes for 301 modes from MaskedGNM 1xgdA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1r38A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1r38B_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1k8cC_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 4 modes for 301 modes from MaskedGNM 1k8cB_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 4 modes for 301 modes from MaskedGNM 1r38D_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1r38C_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 7 modes for 301 modes from MaskedGNM 5zcmA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1k8cD_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 2 modes for 301 modes from MaskedGNM 1ye6C_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1mi3A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1ye6D_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1sm9A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 4 modes for 301 modes from MaskedGNM 1sm9D_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1sm9B_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 1 modes for 301 modes from MaskedGNM 1ye6A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1k8cA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1sm9C_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1mi3D_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1mi3B_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 4 modes for 301 modes from MaskedGNM 1z9aA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1ye6B_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 5z6tA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 5 modes for 301 modes from MaskedGNM 1z9aC_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 4 modes for 301 modes from MaskedGNM 1z9aB_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1z9aD_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 1 modes for 301 modes from MaskedGNM 3h7uA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 1mi3C_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 5 modes for 301 modes from MaskedGNM 1ye4B_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 4 modes for 301 modes from MaskedGNM 1ye4D_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 4 modes for 301 modes from MaskedGNM 1ye4A_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 4 modes for 301 modes from MaskedGNM 1ye4C_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 2 modes for 301 modes from MaskedGNM 5z6uA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 3 modes for 301 modes from MaskedGNM 5zciB_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 2 modes for 301 modes from MaskedGNM 5z6uB_ca reduced has been discarded because at least one conformation has only 301 modes
# @> WARNING last 4 modes for 301 modes from MaskedGNM 5zciA_ca reduced has been discarded because at least one conformation has only 301 modes
# @> all GNM modes were calculated for each of the 246 conformations in 13.06s.
# @> 301 modes across 246 modesets were matched in 4.18s.

# %%
writeIDs('./Binding', ids)

# %%
currNumModes = getModesGivenThreshold(averageEigVals, 0.33)
currNumModes
# Out:
# 3

# %%
bindings =  ['14', '15', '16', '19', '107', '143', '194', '195', '196', '197', '198', '199', '200', '246', '247', '250', '251', '254', '257', '258', '259', '285']

binding = [int(x) for x in bindings]

binding = ['18', '21', '25', '48', '49', '50', '52', '53', '80', '112', '113', '114', '210', '211', '221', '300', '301', '305', '307', '312']

# binding = ['18', '21', '48', '49', '50', '53', '80', '112', '113', '114', '221', '223', '300', '305', '307', '312']

binding = [int(x) for x in binding]

# %%
Hinges_2 = getHinges(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges(averageEigVects, 3, 20)

Hinges_4 = getHinges(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges(averageEigVects, 3, 15)

# %%
Hinges_2 = filterTwoEnds(Hinges_2, chainLength = [[0, 317]])
Hinges_3 = filterTwoEnds(Hinges_3, chainLength = [[0, 317]])
Hinges_4 = filterTwoEnds(Hinges_4, chainLength = [[0, 317]])
Hinges_5 = filterTwoEnds(Hinges_5, chainLength = [[0, 317]])

# %%
protein_length = 318

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 20
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 27 0 1
# # of hinge sites for first 3 modes, overlap, hyper score 27 0 1
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 33 1 0.8960215909260487
# # of hinge sites for first 3 modes, overlap, hyper score 33 1 0.8960215909260487

# %%
Badren = parsePDB('6f78', subset='calpha')
calphas = Badren.select('calpha and chain A')
gnm = GNM('b-adren')
gnm.buildKirchhoff(calphas)
gnm.calcModes(n_modes=None)
Hinge0 = calcHinges(gnm[0])
Hinge1 = calcHinges(gnm[1])
Hinge2 = calcHinges(gnm[2])
# Out:
# @> Connecting wwPDB FTP server RCSB PDB (USA).
# @> 6f78 downloaded (6f78.pdb.gz)
# @> PDB download via FTP completed (1 downloaded, 0 failed).
# @> 636 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> Secondary structures were assigned to 406 residues.
# @> Kirchhoff was built in 0.02s.
# @> 317 modes were calculated in 0.04s.

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 20
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 56 4 0.48156372365241706
# # of hinge sites for 3 modes, overlap, hyper score 56 4 0.48156372365241706
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 61 4 0.5569357818214666
# # of hinge sites for 3 modes, overlap, hyper score 61 4 0.5569357818214666

# %% [markdown]
# ## writeResults

# %%
# write MSFs
averageEigVals
modes = [0, 1]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)
len(MSF)
# Out:
# 578

# %%
values_array = np.array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = np.argsort(values_array)

if not os.path.exists('./Data'):
    os.mkdir('./Data')

writeNumbers('./Data/RMSF_minimum.txt', indices)

# %%
curr = zeros((len(MSF), 7))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]

for each in binding:
    curr[each, 0] = each

# %%
modes = [0, 1]
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    currList = sort(list(set(list(currHinge) + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
# curr = list(curr)
def writeAllData(path, curr):
    with open(path, 'w') as wf:
        for row in curr:
            for col in row:
                if col == 0.0:
                    wf.write('' + '\t')
                else:
                    wf.write(str(col) + '\t')
            wf.write('\n')

# %%
writeAllData('./Data/ALB_Method1.txt', curr)

# %% [markdown]
# ## Method 2

# %%
binding = ['18', '21', '48', '49', '50', '80', '112', '113', '114', '210', '211', '221', '300', '301', '313']

binding = [int(x) for x in binding]

# %%
binding = ['18', '21', '48', '49', '50', '52', '80', '111', '112', '113', '114', '161', '210', '211', '300', '301', '305', '313']

binding = [int(x) for x in binding]

# %%
Hinges_2 = getHinges2(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges2(averageEigVects, 3, 20)

Hinges_4 = getHinges2(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges2(averageEigVects, 3, 15)

# %%
Hinges_2 = filterTwoEnds(Hinges_2, [[0, 318]], 15)
Hinges_3 = filterTwoEnds(Hinges_3, [[0, 318]], 15)
Hinges_4 = filterTwoEnds(Hinges_4, [[0, 318]], 15)
Hinges_5 = filterTwoEnds(Hinges_5, [[0, 318]], 15)

# %%
Hinges_4 = getHinges2(averageEigVects, currNumModes, 15)
# Out:
# before filtering [2, 3]
# before filtering [9, 10]
# before filtering [20, 21]
# before filtering [23, 24]
# before filtering [44, 45]
# before filtering [53, 54, 55, 56, 57]
# if continuous -6.0313606996791335e-05
# before filtering [69, 70, 71]
# before filtering [73, 74]
# before filtering [184, 185]
# before filtering [194, 195, 196, 197, 198]
# if continuous -0.0004246478125610305
# before filtering [206, 207]
# before filtering [300, 301]
# before filtering [79, 80]
# before filtering [88, 89]
# before filtering [109, 110]
# before filtering [144, 145]
# before filtering [158, 159]
# before filtering [177, 178, 179, 180, 181, 182]
# if continuous 0.00017302522505815887
# before filtering [259, 260, 261]
# before filtering [276, 277]
# before filtering [13, 14]
# before filtering [73, 74]
# before filtering [79, 80]
# before filtering [84, 85, 86]
# before filtering [87, 88, 89]
# before filtering [91, 92, 93]
# before filtering [94, 95]
# before filtering [102, 103]
# before filtering [113, 114]
# before filtering [136, 137]
# before filtering [210, 211, 212, 213]
# if continuous -0.00029657376209768455
# before filtering [250, 251]
# before filtering [262, 263]
# before filtering [280, 281, 282]
# before filtering [296, 297, 298, 299]
# if continuous -0.0001865195037031057
# before filtering [311, 312]

# %%
protein_length = 318

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 18
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 60 8 0.00935485533037883
# # of hinge sites for first 3 modes, overlap, hyper score 60 8 0.00935485533037883
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 60 8 0.00935485533037883
# # of hinge sites for first 3 modes, overlap, hyper score 60 8 0.00935485533037883

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

Hinges_2 = filterTwoEnds(Hinges_2, [[0, 318]], 15)
Hinges_3 = filterTwoEnds(Hinges_3, [[0, 318]], 15)
Hinges_4 = filterTwoEnds(Hinges_4, [[0, 318]], 15)
Hinges_5 = filterTwoEnds(Hinges_5, [[0, 318]], 15)

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 18
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 86 9 0.027957391181392288
# # of hinge sites for 3 modes, overlap, hyper score 86 9 0.027957391181392288
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 86 9 0.027957391181392288
# # of hinge sites for 3 modes, overlap, hyper score 86 9 0.027957391181392288

# %% [markdown]
# ## writeResults

# %%
# write MSFs
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)
len(MSF)
# Out:
# 318

# %%
values_array = np.array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = np.argsort(values_array)

if not os.path.exists('./Data'):
    os.mkdir('./Data')

writeNumbers('./Data/RMSF_minimum_diverse.txt', indices)

# %%
includeModes = 3
size = includeModes * 2 + 1 + 2 

curr = zeros((len(MSF), size))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]
curr[:, 5] = averageEigVects[:, 2]

for each in binding:
    curr[each, 0] = each

# %%
modes = [0, 1, 2]
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=15)
    currHinge = filterTwoEnds(currHinge, [[0, 318]], 15)
    currList = sort(list(set(list(currHinge)))) # + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
writeAllData('./Data/ARK3C1_diverse_Method2_update.txt', curr)

# %% [markdown]
# # method3

# %%
Hinges_2 = getHinges3(averageEigVects, currNumModes, [[], [], []], 20)
Hinges_3 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 20)

Hinges_4 = getHinges3(averageEigVects, currNumModes, [[], [], []], 15)
Hinges_5 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 15)

# %%
protein_length = 303

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 24
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 68 3 0.9380415451085422
# # of hinge sites for first 3 modes, overlap, hyper score 68 3 0.9380415451085422
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 68 3 0.9380415451085422
# # of hinge sites for first 3 modes, overlap, hyper score 68 3 0.9380415451085422

# %% [markdown]
# # Write Modes

# %%
def writeModesAsBfactors(mode, eigenVects):
    residue = []
    new_b_factor = []
    chain = 'A'

    resiIndex = 4
    for item in eigenVects[:, mode]:
        resiIndex += 1
        residue.append(resiIndex)
        new_b_factor.append(item)

    with open('./Structure_demo/ALB_b_mode' + str(mode + 1) + '.txt', 'w') as wf:
        for i in range(len(residue)):
            wf.write(chain + ', ' + str(residue[i]) + ', ' + str(new_b_factor[i]) + '\n')

# %%
writeModesAsBfactors(0, eigenVects)
writeModesAsBfactors(1, eigenVects)

# %% [markdown]
# # Plot graphs

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import math
import numpy as np

def format_significant(value, pos):
    if abs(value) <= 0.01:
        return "0.00"
    else:
        order_of_magnitude = math.floor(math.log10(abs(value)))
        round_digits = -order_of_magnitude + 1
        formatted_number = round(value, round_digits)
        str_format = "{:." + str(round_digits) + "f}"
        return str_format.format(formatted_number)

# %%
def plotSingleGraph(mode, averageEigVects, gnms, binding, Hinge):
    fig, ax = plt.subplots(figsize=(20, 10))   # Adjust size as per requirement
    
    plt.sca(ax)  # Set current axis to 'ax'
    
    # Increase font sizes
    plt.rc('xtick', labelsize=40)
    plt.rc('ytick', labelsize=50)
    plt.rcParams.update({'font.size': 50})

    # plot mode of motion
    showSignatureMode(gnms[:, mode], linewidth=3)

    # Hinges within band
    # method1
    # currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    # method2
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=15)
    currHinge = filterTwoEnds(currHinge, [[0, 318]], 15)
    
    
    HingeY = [averageEigVects[item, mode] for item in currHinge]
    print ('Hinge residue with wide bands', currHinge)
    plt.plot(currHinge, HingeY, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # extraHinges for local loops
    updateHinge = [item for item in Hinge if item not in currHinge]
    HingeY_local = [averageEigVects[item, mode] for item in updateHinge]
    print ('local loop motion', updateHinge)
    plt.plot(updateHinge, HingeY_local, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # plot binding sites
    bindingY = [averageEigVects[item, mode] for item in binding]
    plt.plot(binding, bindingY, 'r*', markersize=18)
    print ('current bindings are', binding)
    plt.title('Mode ' + str(mode + 1), fontweight="bold")

    # plot overlaps
    allHinge = updateHinge + currHinge
    overlaps = [item for item in binding if item in allHinge]
    overlapsY = [averageEigVects[item, mode] for item in overlaps]
    print ('current hits are', overlaps)
    plt.plot(overlaps, overlapsY, 'mD', markersize=18)

    print('# of overlaps finding from current mode is', len(overlaps))
    
    # Set y-ticks to have 4-5 values with equal spacing
    y_min, y_max = ax.get_ylim()
    ax.set_yticks(np.linspace(y_min * 0.9, y_max, 5))  # Adjust the number 5 if you want a different number of y-ticks
    ax.yaxis.set_major_formatter(FuncFormatter(format_significant)) 
    
    plt.tight_layout()
    plt.savefig('./AKR1C3_diverse_update_method2_mode' + str(mode + 1) + '.png', dpi=500)

# %%
modes = 0 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [20, 21, 23, 24, 44, 45, 300, 301, 53, 54, 56, 185, 57, 184, 194, 195, 197, 198, 73, 74, 206, 207]
# local loop motion []
# current bindings are [18, 21, 48, 49, 50, 52, 80, 111, 112, 113, 114, 161, 210, 211, 300, 301, 305, 313]
# current hits are [21, 300, 301]
# # of overlaps finding from current mode is 3

# %%
modes = 1 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [259, 260, 109, 110, 79, 80, 144, 145, 276, 277, 88, 89, 158, 159]
# local loop motion []
# current bindings are [18, 21, 48, 49, 50, 52, 80, 111, 112, 113, 114, 161, 210, 211, 300, 301, 305, 313]
# current hits are [80]
# # of overlaps finding from current mode is 1

# %%
modes = 2 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [262, 263, 136, 137, 280, 281, 296, 297, 298, 299, 73, 74, 79, 80, 210, 211, 212, 85, 86, 213, 94, 95, 102, 103, 113, 114, 250, 251]
# local loop motion []
# current bindings are [18, 21, 48, 49, 50, 52, 80, 111, 112, 113, 114, 161, 210, 211, 300, 301, 305, 313]
# current hits are [80, 113, 114, 210, 211]
# # of overlaps finding from current mode is 5

# %% [markdown]
# # Write modes

# %%
len(averageEigVects[:, 0])
# Out:
# 318

# %%
mode = 2

# %%
residue = []
new_b_factor = []

for item in averageEigVects[:, mode]:
    new_b_factor.append(item)

# %%
residue = []
new_b_factor = []

for item in averageEigVects[:, mode]:
    new_b_factor.append(item)

# %%
resiIndex = [x for x in range(6, 324)]
chain = ['A' for x in range(6, 324)]

# %%
with open('./structure_demo/AKR1C3_b_diverse_mode' + str(mode + 1) + '.txt', 'w') as wf:
    for i in range(len(resiIndex)):
        # print (chain[i])
        wf.write(chain[i] + ', ' + str(resiIndex[i]) + ', ' + str(new_b_factor[i]) + '\n')
