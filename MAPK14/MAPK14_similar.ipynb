# %%
# -*- coding: utf-8 -*-
"""This module defines functions for Dali searching Protein Data Bank."""

import re
import numpy as np
from prody.atomic import Atomic, AtomGroup, AtomMap
from prody.proteins.pdbfile import _getPDBid
from prody.measure import getRMSD, getTransformation
from prody.utilities import checkCoords, checkWeights, createStringIO
from prody import LOGGER, PY3K
from prody import parsePDB, writePDBStream
# if PY3K:
    # import urllib.parse as urllib
    # import urllib.request as urllib2
# else:
    # import urllib
    # import urllib2
from prody.ensemble import Ensemble
from prody.ensemble import PDBEnsemble
import os

__all__ = ['DaliRecord', 'searchDali', 
           'daliFilterMultimer', 'daliFilterMultimers']

def searchDal(pdb, chain=None, subset='fullPDB', daliURL=None, **kwargs):
    """Search Dali server with input of PDB ID (or local PDB file) and chain ID.
    Dali server: http://ekhidna2.biocenter.helsinki.fi/dali/
    
    :arg pdb: PDB code or local PDB file for the protein to be searched

    :arg chain: chain identifier (only one chain can be assigned for PDB)
    :type chain: str

    :arg subset: fullPDB, PDB25, PDB50, PDB90
    :type subset: str
    """
    
    import requests
    
    LOGGER.timeit('_dali')
    # timeout = 120
    timeout = kwargs.pop('timeout', 120)
    
    if daliURL is None:
        daliURL = "http://ekhidna2.biocenter.helsinki.fi/cgi-bin/sans/dump.cgi"
    
    if isinstance(pdb, Atomic):
        atoms = pdb
        chain_set = set(atoms.getChids())
        if chain and not chain in chain_set:
            raise ValueError('input structure (%s) does not have chain %s'%(atoms.getTitle(), chain))
        
        if len(chain_set) > 1:
            if not chain:
                raise TypeError('the structure (%s) contains more than one chain, therefore a chain identifier '
                                'needs to be specified'%pdb.getTitle())
            atoms = atoms.select('chain '+chain)
        else:
            chain = chain_set.pop()
            
        stream = createStringIO()
        writePDBStream(stream, atoms)
        data = stream.getvalue()
        stream.close()
        files = {"file1" : data}

        pdbId = atoms.getTitle()
        pdb_chain = ''
        dali_title = 'Title_'+pdbId+chain
    elif isinstance(pdb, str):
        if os.path.isfile(pdb):
            atoms = parsePDB(pdb)
            chain_set = set(atoms.getChids())
            # pdbId = "s001"
            filename = os.path.basename(pdb)
            filename, ext = os.path.splitext(filename)
            if ext.lower() == '.gz':
                filename2, ext2 = os.path.splitext(filename)
                if ext2.lower() == '.pdb':
                    filename = filename2
            pdbId = filename
            if chain and not chain in chain_set:
                raise ValueError('input PDB file does not have chain ' + chain)
            
            if len(chain_set) > 1:
                if not chain:
                    raise TypeError('PDB file (%s) contains more than one chain, therefore a chain identifier '
                                    'needs to be specified'%pdb)
                atoms = atoms.select('chain '+chain)
                #local_temp_pdb = pdbId+chain+'.pdb'
                #local_temp_pdb = 's001'+chain+'.pdb'
                stream = createStringIO()
                writePDBStream(stream, atoms)
                data = stream.getvalue()
                stream.close()
            else:
                data = open(pdb, "rb")
                chain = chain_set.pop()
            files = {"file1" : data}
            # case: multiple chains.             apply fetch ? multiple times?
            pdb_chain = ''
            dali_title = 'Title_' + pdbId + chain
        else:
            pdbId, ch = _getPDBid(pdb)
            if not chain:
                chain = ch
            if not chain:
                raise TypeError('a chain identifier is needed for the search')
            pdb_chain = pdbId + chain
            dali_title = 'Title_' + pdb_chain
            files = ''
    parameters = { 'cd1' : pdb_chain, 'method': 'search', 'title': dali_title, 'address': '' }
    # enc_params = urllib.urlencode(parameters).encode('utf-8')
    # request = urllib2.Request(daliURL, enc_params)
    request = requests.post(daliURL, parameters, files=files)
    try_error = 3
    while try_error >= 0:
        try:
            # url = urllib2.urlopen(request).url
            url = request.url
            break
        except:
            try_error -= 1
            if try_error >= 0:
                LOGGER.sleep(2, '. Connection error happened. Trying to reconnect...')
                continue
            else:
                # url = urllib2.urlopen(request).url
                url = request.url
                break
    if url.split('.')[-1].lower() in ['html', 'php']:
        # print('test -1: '+url)
        url = url.replace(url.split('/')[-1], '')
    LOGGER.debug('Submitted Dali search for PDB "{0}{1}".'.format(pdbId, chain))
    LOGGER.info(url)
    LOGGER.clear()
    
    return DaliRecor(url, pdbId, chain, subset=subset, timeout=timeout, **kwargs)
    

class DaliRecor(object):

    """A class to store results from Dali PDB search."""

    def __init__(self, url, pdbId, chain, subset='fullPDB', localFile=False, **kwargs):
        """Instantiate a DaliRecord object instance.

        :arg url: url of Dali results page or local dali results file
        :arg pdbId: PDB code for searched protein
        :arg chain: chain identifier (only one chain can be assigned for PDB)
        :arg subset: fullPDB, PDB25, PDB50, PDB90. Ignored if localFile=True (url is a local file)
        :arg localFile: whether provided url is a path for a local dali results file
        """

        self._url = url
        self._pdbId = pdbId
        self._chain = chain
        subset = subset.upper()
        if subset == "FULLPDB" or subset not in ["PDB25", "PDB50", "PDB90"]:
            self._subset = ""
        else:
            self._subset = "-"+subset[3:]
        timeout = kwargs.pop('timeout', 120)

        self._title = pdbId + '-' + chain
        self._alignPDB = None
        self._filterDict = None
        self._max_index = None
        self.fetch(self._url, localFile=localFile, timeout=timeout, **kwargs)

    def fetch(self, url=None, localFile=False, **kwargs):
        """Get Dali record from url or file.

        :arg url: url of Dali results page or local dali results file
            If None then the url already associated with the DaliRecord object is used.
        :type url: str

        :arg localFile: whether provided url is a path for a local dali results file
        :type localFile: bool

        :arg timeout: amount of time until the query times out in seconds
            default value is 120
        :type timeout: int

        :arg localfolder: folder in which to find the local file
            default is the current folder
        :type localfolder: str
        """
        if localFile:
            dali_file = open(url, 'r')
            data = dali_file.read()
            dali_file.close()
        else:
            import requests
            
            if url == None:
                url = self._url
            
            sleep = 2
            timeout = kwargs.pop('timeout', 120)
            LOGGER.timeit('_dali')
            log_message = ''
            try_error = 3
            while True:
                LOGGER.write('Connecting to Dali for search results...')
                LOGGER.clear()
                try:
                    # html = urllib2.urlopen(url).read()
                    html = requests.get(url).content
                except:
                    try_error -= 1
                    if try_error >= 0:
                        LOGGER.sleep(2, '. Connection error happened. Trying to reconnect...')
                        continue
                    else:
                        # html = urllib2.urlopen(url).read()
                        html = requests.get(url).content
                if PY3K:
                    html = html.decode()
                if html.find('Status: Queued') > -1:
                    log_message = '(Dali search is queued)...'
                elif html.find('Status: Running') > -1:
                    log_message = '(Dali search is running)...'
                elif html.find('Your job') == -1 and html.find('.txt') > -1:
                    break
                elif html.find('ERROR:') > -1:
                    LOGGER.warn(': Dali search reported an ERROR!')
                    self.isSuccess = False
                    return False
                sleep = 20 if int(sleep * 1.5) >= 20 else int(sleep * 1.5)
                if LOGGER.timing('_dali') > timeout:
                    LOGGER.warn(': Dali search has timed out. \nThe results can be obtained later using the fetch() method.')
                    self.isSuccess = False
                    return False
                LOGGER.sleep(int(sleep), 'to reconnect to Dali '+log_message)
                LOGGER.clear()
            LOGGER.clear()
            LOGGER.report('Dali results were fetched in %.1fs.', '_dali')
            lines = html.strip().split('\n')
            file_name = re.search('=.+-90\\.txt', html).group()[1:]
            file_name = file_name[:-7]
            # LOGGER.info(url+file_name+self._subset+'.txt')
            # data = urllib2.urlopen(url+file_name+self._subset+'.txt').read()
            data = requests.get(url+file_name+self._subset+'.txt').content
            if PY3K:
                data = data.decode()
            localfolder = kwargs.pop('localfolder', '.')

            if file_name.lower().startswith('s001'):
                temp_name = self._pdbId + self._chain
            else:
                temp_name = file_name
            temp_name += self._subset + '_dali.txt'
            if localfolder != '.' and not os.path.exists(localfolder):
                os.mkdir(localfolder)
            with open(localfolder+os.sep+temp_name, "w") as file_temp: file_temp.write(html + '\n' + url+file_name+self._subset+'.txt' + '\n' + data)
            # with open(temp_name, "a+") as file_temp: file_temp.write(url+file_name + '\n' + data)
        data_list = data.strip().split('# ')
        # No:  Chain   Z    rmsd lali nres  %id PDB  Description -> data_list[3]
        # Structural equivalences -> data_list[4]
        # Translation-rotation matrices -> data_list[5]
        map_temp_dict = dict()
        lines = data_list[4].strip().split('\n')
        self._lines_4 = lines
        mapping_temp = np.genfromtxt(lines[1:], delimiter = (4,1,14,6,2,4,4,5,2,4,4,3,5,4,3,5,6,3,5,4,3,5,28), 
                                     usecols = [0,3,5,7,9,12,15,15,18,21], dtype='|i4')
        # [0,3,5,7,9,12,15,15,18,21] -> [index, residue_a, residue_b, residue_i_a, residue_i_b, resid_a, resid_b, resid_i_a, resid_i_b]
        for map_i in mapping_temp:
            if not map_i[0] in map_temp_dict:
                map_temp_dict[map_i[0]] = [[map_i[1], map_i[2], map_i[3], map_i[4]]]
            else:
                map_temp_dict[map_i[0]].append([map_i[1], map_i[2], map_i[3], map_i[4]])
        self._max_index = max(mapping_temp[:,2])
        self._mapping = map_temp_dict
        self._data = data_list[3]
        lines = data_list[3].strip().split('\n')
        # daliInfo = np.genfromtxt(lines[1:], delimiter = (4,3,6,5,5,5,6,5,57), usecols = [0,2,3,4,5,6,7,8], 
                                # dtype=[('id', '<i4'), ('pdb_chain', '|S6'), ('Z', '<f4'), ('rmsd', '<f4'), 
                                # ('len_align', '<i4'), ('nres', '<i4'), ('identity', '<i4'), ('title', '|S70')])
        daliInfo = np.genfromtxt(lines[1:], delimiter = (4,3,6,5,5,5,6,5,57), usecols = [0,2,3,4,5,6,7,8], 
                                dtype=[('id', '<i4'), ('pdb_chain', '|U6'), ('Z', '<f4'), ('rmsd', '<f4'), 
                                ('len_align', '<i4'), ('nres', '<i4'), ('identity', '<i4'), ('title', '|U70')])
        if daliInfo.ndim == 0:
            daliInfo = np.array([daliInfo])
        pdbListAll = []
        self._daliInfo = daliInfo
        dali_temp_dict = dict()
        for temp in self._daliInfo:
            temp_dict = dict()
            pdb_chain = temp[1].strip()[0:6]
            # U6 and U70 were used as the dtype for np.genfromtext -> unicode string were used in daliInfo 
            # if PY3K:
                # pdb_chain = pdb_chain.decode()
            pdb_chain = str(pdb_chain)
            temp_dict['pdbId'] = pdbid = pdb_chain[0:4].lower()
            temp_dict['chainId'] = chid = pdb_chain[5:6]
            temp_dict['pdb_chain'] = pdb_chain = pdbid + chid
            temp_dict['Z'] = temp[2]
            temp_dict['rmsd'] = temp[3]
            temp_dict['len_align'] = temp[4]
            temp_dict['nres'] = temp[5]
            temp_dict['identity'] = temp[6]
            temp_dict['mapping'] = (np.array(map_temp_dict[temp[0]])-1).tolist()
            temp_dict['map_ref'] = [x for map_i in (np.array(map_temp_dict[temp[0]])-1).tolist() for x in range(map_i[0], map_i[1]+1)]
            temp_dict['map_sel'] = [x for map_i in (np.array(map_temp_dict[temp[0]])-1).tolist() for x in range(map_i[2], map_i[3]+1)]
            dali_temp_dict[pdb_chain] = temp_dict
            pdbListAll.append(pdb_chain)
        self._pdbListAll = tuple(pdbListAll)
        self._pdbList = self._pdbListAll
        self._alignPDB = dali_temp_dict
        LOGGER.info('Obtained ' + str(len(pdbListAll)) + ' PDB chains from Dali for '+self._pdbId+self._chain+'.')
        self.isSuccess = True
        return True
        
    def getPDBs(self, filtered=True):
        """Returns PDB list (filters may be applied)"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')
        
        if filtered:
            return self._pdbList
        return self._pdbListAll
        
    def getHits(self):
        """Returns the dictionary associated with the DaliRecord"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')

        return self._alignPDB
        
    def getFilterList(self):
        """Returns a list of PDB IDs and chains for the entries that were filtered out"""
        
        filterDict = self._filterDict
        if filterDict is None:
            raise ValueError('You cannot obtain the list of filtered out entries before doing any filtering.')

        temp_str = ', '.join([str(len(filterDict['len'])), str(len(filterDict['rmsd'])), 
                            str(len(filterDict['Z'])), str(len(filterDict['identity']))])
        LOGGER.info('Filtered out [' + temp_str + '] for [length, RMSD, Z, identity]')
        return self._filterList

    
    def getMapping(self, key):
        """Get mapping for a particular entry in the DaliRecord"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')
            return None
        
        try:
            info = self._alignPDB[key]
            mapping = [info['map_ref'], info['map_sel']]
        except KeyError:
            return None
        return mapping

    def getMappings(self):
        """Get all mappings in the DaliRecord"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')
            return None

        map_dict = {}
        for key in self._alignPDB:
            info = self._alignPDB[key]
            mapping = [info['map_ref'], info['map_sel']]
            map_dict[key] = mapping
        return map_dict

    mappings = property(getMappings)

    def filter(self, cutoff_len=None, cutoff_rmsd=None, cutoff_Z=None, cutoff_identity=None):
        """Filters out PDBs from the PDBList and returns the PDB list.
        PDBs that satisfy any of the following criterion will be filtered out.
        (1) Length of aligned residues < cutoff_len (must be an integer or a float between 0 and 1);
        (2) RMSD < cutoff_rmsd (must be a positive number);
        (3) Z score < cutoff_Z (must be a positive number);
        (4) Identity > cutoff_identity (must be an integer or a float between 0 and 1).
        """
        if self._max_index is None:
            LOGGER.warn('DaliRecord has no data. Please use the fetch() method.')
            return None

        if cutoff_len == None:
            # cutoff_len = int(0.8*self._max_index)
            cutoff_len = 0.00000001
        elif not isinstance(cutoff_len, (float, int)):
            raise TypeError('cutoff_len must be a float or an integer')
        elif cutoff_len <= 1 and cutoff_len > 0:
            cutoff_len = int(cutoff_len*self._max_index)
        elif cutoff_len <= self._max_index and cutoff_len > 0:
            cutoff_len = int(cutoff_len)
        else:
            raise ValueError('cutoff_len must be a float between 0 and 1, or an int not greater than the max length')
            
        if cutoff_rmsd == None:
            cutoff_rmsd = 1000
        elif not isinstance(cutoff_rmsd, (float, int)):
            raise TypeError('cutoff_rmsd must be a float or an integer')
        elif cutoff_rmsd >= 0:
            cutoff_rmsd = float(cutoff_rmsd)
        else:
            raise ValueError('cutoff_rmsd must be a number not less than 0')
            
        if cutoff_Z == None:
            cutoff_Z = 0
        elif not isinstance(cutoff_Z, (float, int)):
            raise TypeError('cutoff_Z must be a float or an integer')
        elif cutoff_Z >= 0:
            cutoff_Z = float(cutoff_Z)
        else:
            raise ValueError('cutoff_Z must be a number not less than 0')
            
        if cutoff_identity == None or cutoff_identity == 0:
            cutoff_identity = 0
        elif not isinstance(cutoff_identity, (float, int)):
            raise TypeError('cutoff_identity must be a float or an integer')
        elif cutoff_identity <= 1 and cutoff_identity > 0:
            cutoff_identity = float(cutoff_identity*100)
        elif cutoff_identity <= 100 and cutoff_identity > 0:
            cutoff_identity = float(cutoff_identity)
        else:
            raise ValueError('cutoff_identity must be a float between 0 and 1, or a number between 0 and 100')
            
        # debug:
        # print('cutoff_len: ' + str(cutoff_len) + ', ' + 'cutoff_rmsd: ' + str(cutoff_rmsd) + ', ' + 'cutoff_Z: ' + str(cutoff_Z) + ', ' + 'cutoff_identity: ' + str(cutoff_identity))
        
        daliInfo = self._alignPDB
        if daliInfo is None:
            raise ValueError("Dali Record does not have any data yet. Please run fetch.")

        pdbListAll = self._pdbListAll
        missing_ind_dict = dict()
        ref_indices_set = set(range(self._max_index))
        filterListLen = []
        filterListRMSD = []
        filterListZ = []
        filterListIdentity = []
        
        RMSDs = []
        
        # keep the first PDB (query PDB)
        for pdb_chain in pdbListAll[1:]:
            temp_dict = daliInfo[pdb_chain]
            # print ('currRMSD', temp_dict['rmsd'])
            # filter: len_align, identity, rmsd, Z
            RMSDs.append(temp_dict['rmsd'])
            if temp_dict['len_align'] < cutoff_len:
                # print('Filter out ' + pdb_chain + ', len_align: ' + str(temp_dict['len_align']))
                filterListLen.append(pdb_chain)
                continue
            if temp_dict['rmsd'] > cutoff_rmsd:
                # print('Filter out ' + pdb_chain + ', rmsd: ' + str(temp_dict['rmsd']))
                filterListRMSD.append(pdb_chain)
                # print ('currRMSD', temp_dict['rmsd'])
                # print(pdb_chain)
                continue
            if temp_dict['Z'] < cutoff_Z:
                # print('Filter out ' + pdb_chain + ', Z: ' + str(temp_dict['Z']))
                filterListZ.append(pdb_chain)
                continue
            if temp_dict['identity'] < cutoff_identity:
                # print('Filter out ' + pdb_chain + ', identity: ' + str(temp_dict['identity']))
                filterListIdentity.append(pdb_chain)
                continue
            temp_diff = list(ref_indices_set - set(temp_dict['map_ref']))
            for diff_i in temp_diff:
                if not diff_i in missing_ind_dict:
                    missing_ind_dict[diff_i] = 1
                else:
                    missing_ind_dict[diff_i] += 1
        self._missing_ind_dict = missing_ind_dict
        
        filterList = filterListLen + filterListRMSD + filterListZ + filterListIdentity
        filterDict = {'len': filterListLen, 'rmsd': filterListRMSD, 'Z': filterListZ, 'identity': filterListIdentity}
        self._filterList = filterList
        self._filterDict = filterDict
        self._pdbList = [self._pdbListAll[0]] + [item for item in self._pdbListAll[1:] if not item in filterList]
        LOGGER.info(str(len(filterList)) + ' PDBs have been filtered out from '+str(len(pdbListAll))+' Dali hits (remaining: '+str(len(pdbListAll)-len(filterList))+').')
        
        filterRMSD = []
        diverseRMSD = []
        for item in RMSDs:
            if item < cutoff_rmsd:
                filterRMSD.append(item)
            if item > 1.0:
                diverseRMSD.append(item)
        
        print ('RMSD less than ', cutoff_rmsd, mean(filterRMSD), std(filterRMSD))
        print ('RMSD greater than 1A ', mean(diverseRMSD), std(diverseRMSD))
        
        return self._pdbList
    
    def getTitle(self):
        """Return the title of the record"""

        return self._title

def daliFilterMultimer(atoms, dali_rec, n_chains=None):
    """
    Filters multimers to only include chains with Dali mappings.

    :arg atoms: the multimer to be filtered
    :type atoms: :class:`.Atomic`

    :arg dali_rec: the DaliRecord object with which to filter chains
    :type dali_rec: :class:`.DaliRecord`
    """
    if not isinstance(atoms, Atomic):
        raise TypeError("atoms should be an Atomic object")

    if not isinstance(dali_rec, DaliRecord):
        raise TypeError("dali_rec should be a DaliRecord")
    try:
        keys = dali_rec._alignPDB
    except:
        raise AttributeError("Dali Record does not have any data yet. Please run fetch.")

    numChains = 0
    atommap = None
    for i, chain in enumerate(atoms.iterChains()):
        m = dali_rec.getMapping(chain.getTitle()[:4] + chain.getChid())
        if m is not None:
            numChains += 1
            if atommap is None:
                atommap = chain
            else:
                atommap += chain

    if n_chains is None or numChains == n_chains:
        return atommap
    else:
        return None

def daliFilterMultimers(structures, dali_rec, n_chains=None):
    """A wrapper for daliFilterMultimer to apply to multiple structures.
    """
    dali_ags = []
    for entry in structures:
        result = daliFilterMultimer(entry, dali_rec, n_chains)
        if result is not None:
            dali_ags.append(result)
    return dali_ags

# %%
from numpy import *
from matplotlib.pyplot import *
# import os
ion()

# find hinges
def splitHinge(vals, sites, block):
    # split hinges
    currBlock = 1
    index = 0
    isStart = False
    newSites = []
    newVals = []

    for val in vals:
        if block[index] == currBlock and not isStart:
            isStart = True
            currSites = [sites[index]]
            currValLists = [vals[index]]
        elif block[index] == currBlock and isStart:
            currSites.append(sites[index])
            currValLists.append(vals[index])
        else:
            currBlock += 1
            isStart = True
            newSites.append(currSites)
            newVals.append(currValLists)
            currSites = [sites[index]]
            currValLists = [vals[index]]
        if currBlock == block[-1] and index == len(vals) - 1:
            newSites.append(currSites)
            newVals.append(currValLists)
        index += 1
    # print newSites, newVals
    return newSites, newVals


def mini(a, b):
    if a > b:
        return a
    else:
        return b


def checkIfCrossBase(currVal, currSite, currEigenVec):
    identify = sort(currVal)
    ifRemain = True
    if identify[0] < 0 and identify[-1] > 0:
        ifRemain = True
    else:
        maxSite = max(currSite)
        minSite = min(currSite)
        # print (identify)
        if identify[0] >= 0 and identify[-1] >= 0:
            if currEigenVec[max(0, minSite - 1)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 1)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 2)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 3)] < 0:
                ifRemain = True
            else:
                ifRemain = False
        elif identify[0] <= 0 and identify[-1] <= 0:
            # print (len(currEigenVec))
            # print (currEigenVec[239])

            if currEigenVec[max(0, minSite - 1)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 1))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 2))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 3))] > 0:
                ifRemain = True
            else:
                ifRemain = False

        else:
            print(identify[0], identify[-1])
            print("Check!")
    return ifRemain


def oneModeHinge(currEigenVec, thereshold=20):
    range = ((1 / float(len(currEigenVec))) ** 0.5) / thereshold
    # print (range)
    # print range
    sites = []
    vals = []
    block = []

    index = 0
    blockID = 1
    for item in currEigenVec:
        if item <= range and item >= -range:
            vals.append(item)
            if len(sites) >= 1 and abs(sites[-1] - index) > 1:
                blockID += 1
            sites.append(index)
            block.append(blockID)
        index += 1

    newSites, newVals = splitHinge(vals, sites, block)

    filtSites = []
    filtVals = []

    index = 0
    for item in newSites:
        currSite = newSites[index]
        currVal = newVals[index]
        if checkIfCrossBase(currVal, currSite, currEigenVec):
            filtSites.append(currSite)
            filtVals.append(currVal)
        index += 1

    return filtSites, filtVals

def oneModeHinge_update(values, thereshold=20):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    # print (regions)
    
    FinalRegions = []
    for region in regions:
        # print ('before filtering', region)
        if len(region) >= 5:
            # print ('previous region', region)
            pos = [index for index in region if values[index] > 0]
            neg = [index for index in region if values[index] < 0]
            pos.sort(key=lambda x: values[x])
            neg.sort(key=lambda x: values[x], reverse=True)
            n = int(len(region) / 4) + 1
            region = pos[:n] + neg[:n]
            # print (region, neg, pos)
        elif 3 <= len(region) <= 4:
            if values[region[0]-1] * values[region[-1]+1] > 0:
                continue  # Skip this region if adjacent values outside the band have the same sign
        # print ('after filtering',region)      
            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    # print ('Final regions', FinalRegions)
    
    flat = flattenData(FinalRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return FinalRegions, final_values

def getValue(currList):
    newList = []
    for item in currList:
        newList.append(float(item))
    return newList


def readModes(fileName):
    allModes = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.strip()
            line = line.split('\t')
            currMode = line[0]
            currVal = line[1:]
            allModes[currMode] = getValue(currVal)
    return allModes


def flattenData(arrayTwoD):
    flat = []
    for item in arrayTwoD:
        for each in item:
            flat.append(each)
    return flat

def cleanStr(currStr):
    return currStr.strip('\'')

def readFile(fileName):
    data = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.replace('\n', '')
            line = line.strip()
            line = line.split('\t')
            currPDB = line[0]
            currDrug = line[1]
            currChain = line[2:]
            if currPDB not in data.keys():
                data[currPDB] = {}
            if currDrug not in data[currPDB].keys():
                data[currPDB][currDrug] = []
            for each in currChain:
                data[currPDB][currDrug].append(cleanStr(each))
    return data

# contribution of mode of motions
def getContribution(eigenVals, mode):
    allContribution = np.sqrt(np.sum(1 / eigenVals))
    currModeContribution = eigenVals[:mode]
    currContribution = np.sqrt(np.sum(1 / currModeContribution))
    return currContribution / allContribution

def getModesGivenThreshold(eigenVals, thereshold):
    contribution = 0
    mode = 0
    while contribution <= thereshold:
        mode += 1
        contribution = getContribution(eigenVals, mode)
    return mode

def writeBinding(fileName, pdb_ids):
    with open(fileName, 'w') as wf:
        for item in pdb_ids:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')


from prody import *
def getModes(currPDB, eachChain, length = 0.7, rmsd = 1.0, Z = 10):    
    # if not os.path.exists('./Results/' + currPath):
    #     os.mkdir('./Results/' + currPath)
    dali_rec = searchDal(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len = length, cutoff_rmsd = rmsd, cutoff_Z = Z)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    
    ags = parsePDB(pdb_ids, subset='ca')
    dali_ens = buildPDBEnsemble(ags, mapping=mappings, seqid=20)
    gnms = calcEnsembleENMs(dali_ens, model='GNM', trim='reduce', n_modes=None)
    eigVals = gnms.getEigvals()
    averageEigVals = mean(eigVals, axis=0)

    eigVects = gnms.getEigvecs()
    averageEigVects = mean(eigVects, axis=0)
    return averageEigVals, averageEigVects, pdb_ids, gnms, averageEigVects

            
def getDali_info(currPDB, eachChain, rmsd = 2.5, length = 0.9):
    dali_rec = searchDali(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len=length, cutoff_rmsd=rmsd)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    return pdb_ids, mappings

def getHinges(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

def getHinges2(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

def getHinges_modes(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def getHinges_modes2(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge


def get3Hinges_bandwidth(averageEigVects, bandWidths = [15, 16, 17]):
    currHinge = []
    for i in range(3):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidths[i])
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
# Experiment to evaluate performance of hypergeometric p values
from scipy.stats import hypergeom
def ORA(M, N, n, k):
    total = 0
    totalLength = N
    binding = M
    hinge = n
    overlap = k
    
    for i in range(overlap):
        total += hypergeom.pmf(i, totalLength, binding, hinge)
    return 1 - total

import os
def writeIDs(path, idList):
    # Check whether the specified path exists or not
    isExist = os.path.exists(path)
    if not isExist:

       # Create a new directory because it does not exist
       os.makedirs(path)
       print("The new directory is created!")
    
    with open(path + '/ids.txt', 'w') as wf:
        for item in idList:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')

# %%
def screenIDs(ids):
    newIDs = []
    for item in ids:
        newIDs.append(item[:4])
    return newIDs

# filter transmembrane protein
def filterHinges(Hinges_2, ContinueThreshold = 50, HingeCutoff = 10):
    newHinges = []
    currItem = []
    for item in Hinges_2:
        if currItem == [] or currItem[-1] == item - 1:
            currItem.append(item)
        else:
            newHinges.append(currItem)
            currItem = []

    filteredItem = []
    for item in newHinges:
        if len(item) <= ContinueThreshold:
            filteredItem += item
        else:
            filteredItem += item[:HingeCutoff]
            filteredItem += item[-HingeCutoff:]
    return filteredItem

# %%
def writeNumbers(path, numbers):
    with open(path, 'w') as wf:
        for item in numbers:
            wf.write(str(item) + '\n')

def merge_overlapping_lists(lists):
    sorted_lists = sorted(lists, key=lambda x: x[0])  # Sort lists based on the first element
    merged_lists = [sorted_lists[0]]
    
    for current in sorted_lists[1:]:
        previous = merged_lists[-1]
        # Check if the current list overlaps with the previous one
        if current[0] <= previous[-1]:
            # Merge overlapping lists by updating the last list in merged_lists
            merged_lists[-1] = list(range(min(previous[0], current[0]), max(previous[-1], current[-1])+1))
        else:
            merged_lists.append(current)
    return merged_lists

# %%
def writeAllData(path, curr):
    with open(path, 'w') as wf:
        for row in curr:
            for col in row:
                if col == 0.0:
                    wf.write('' + '\t')
                else:
                    wf.write(str(col) + '\t')
            wf.write('\n')

# %% [markdown]
# # Similar ensemble

# %%
# p38
currPDB = '6sot'
eachChain = 'A'

# pdb_ids, mappings = getDali_info(currPDB, eachChain, cutoff_len=0.7, cutoff_rmsd=1.0, cutoff_Z=10)
averageEigVals, averageEigVects, ids, gnms, averageEigVects = getModes(currPDB, eachChain, length=0.8, rmsd=2, Z=10)
# Out:
# @> Submitted Dali search for PDB "6sotA".
# @> http://ekhidna2.biocenter.helsinki.fi/barcosel/tmp//6sotA//
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> Dali results were fetched in 36.6s.
# @> Obtained 2167 PDB chains from Dali for 6sotA.
# @> 1755 PDBs have been filtered out from 2167 Dali hits (remaining: 412).
# @> Retrieving 6sotA... [  0%]
# RMSD less than  2.0 1.1575377 0.43552193
# RMSD greater than 1A  2.5507903 0.6495281
# # of similar structures is found from Dali 412
# @> 412 PDBs were parsed in 96.32s.
# @> Starting iterative superposition:
# @> Step #1: RMSD difference = 8.2827e-01
# @> Step #2: RMSD difference = 5.0915e-03
# @> Step #3: RMSD difference = 1.7101e-04
# @> Step #4: RMSD difference = 6.2735e-06
# @> Iterative superposition completed in 0.40s.
# @> Final superposition to calculate transformations.
# @> Superposition completed in 0.10 seconds.
# @> Ensemble (412 conformations) were built in 11.28s.
# @> WARNING last 38 modes for 303 modes from MaskedGNM 6sotA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 6soiA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 6so4A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r92A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9jA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r95A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5ra4A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9cA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 6so1A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9pA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 5r9hA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 6sodA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5ra2A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 5r9mA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9eA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9fA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 5r90A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9wA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r96A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 5r91A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9xA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 6so2A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 5r9lA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9gA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 5r94A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 5r9bA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5ra5A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r8xA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 5ra0A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9vA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 35 modes for 303 modes from MaskedGNM 5r9nA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r93A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r98A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9sA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r8vA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r8wA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5ra6A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9oA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9aA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 5r9dA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9zA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9qA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1w84A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 5r99A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r9rA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5ra1A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 5ra3A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1wboA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 5r9tA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 5r9yA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 35 modes for 303 modes from MaskedGNM 6souA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 33 modes for 303 modes from MaskedGNM 5r9iA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 2zb0A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 5r8yA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5ra9A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3d83A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1w7hA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 3fmjA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1p38A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r8uA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5etcA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3flzA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 1di9A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1wbvA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1r3cA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 2zazA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 5r9uA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 1oz1A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5mz3A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 33 modes for 303 modes from MaskedGNM 5uojA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3mptA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 5ra8A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1wbwA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3fmhA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3flyA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1bl6A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1bmkA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5ra7A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3gfeA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1wbnA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1wbtA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r8zA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1a9uA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1ouyA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1bl7A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1wbsA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 1m7qA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 1r39A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 34 modes for 303 modes from MaskedGNM 5r9kA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 1oukA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 3e93A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1yqjA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 2zb1A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3iphA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1w83A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 34 modes for 303 modes from MaskedGNM 3fsfA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3nnuA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5xyyA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5r97A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3kq7A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3u8wA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3gc7A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3nnwA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5etiA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 3flqA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 3flwA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 3fmkA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 33 modes for 303 modes from MaskedGNM 3fmlA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 34 modes for 303 modes from MaskedGNM 3fmnA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 31 modes for 303 modes from MaskedGNM 5xyxA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 32 modes for 303 modes from MaskedGNM 1wfcA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 3flsA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3e92A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3nnvA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 2gfsA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3itzA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 33 modes for 303 modes from MaskedGNM 3ha8A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1w82A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3d7zA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 34 modes for 303 modes from MaskedGNM 3flnC_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3s3iA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3dt1A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 3fmmA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 31 modes for 303 modes from MaskedGNM 1lezA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 32 modes for 303 modes from MaskedGNM 3fi4A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3p4kA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 35 modes for 303 modes from MaskedGNM 3hrbA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 34 modes for 303 modes from MaskedGNM 3mw1A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 3fknA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1oveA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 37 modes for 303 modes from MaskedGNM 3fkoA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 5etfA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 1lewA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 34 modes for 303 modes from MaskedGNM 3fskA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 34 modes for 303 modes from MaskedGNM 3fklA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 2i0hA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 32 modes for 303 modes from MaskedGNM 3fl4A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 2y8oA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 1zzlA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3rinA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 2yixA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 2okrA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 33 modes for 303 modes from MaskedGNM 3lhjA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4ka3A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 2onlB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 2onlA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 3fc1X_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 4looA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 2okrD_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 2balA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 7pvuA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 2bakA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 4a9yA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 3newA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 4f9yA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4eh2A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 4eh3A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 4r3cA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4f9wA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 5n64A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4dliA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3nwwA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 3hllA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 4ewqA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 22 modes for 303 modes from MaskedGNM 5n67A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3rocA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 6hwuA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 2ghmA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3hl7A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 2lgcA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 6qyxA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 6sfkA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 6y4xA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 5n66A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 3gcqA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 4eh6A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 3kf7A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 1ywrA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 2rg6A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3zyaA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3ds6C_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 2ghlA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 4aa4A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 4e5aX_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 5n68A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3mh3A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 4dljA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3tg1A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 4eh8A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 5etaA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 4e6cA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 3mpaA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 5etaB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 5n65A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 3mh0A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 4zthA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 3hv3A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 3k3jA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 5n63A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 5omgA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3gcuA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3p79A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3hucA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3mh1A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 3lfaA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4eh9A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 32 modes for 303 modes from MaskedGNM 4aa5A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 3ocgA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 4kinB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3k3iA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 6sfjA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 22 modes for 303 modes from MaskedGNM 4eh5A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 32 modes for 303 modes from MaskedGNM 3ds6A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 3hv6A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 6y4tA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 6y4uA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 3uvqA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 1zyjA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 6y4wA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 6y7zA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 3mh2A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 6y4vA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 5o8uA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 4fa2A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 22 modes for 303 modes from MaskedGNM 4aa0A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 22 modes for 303 modes from MaskedGNM 2ewaA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3o8tA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3hv5A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 3oc1A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 2qd9A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 6y85A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3hv4A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 4ehvA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 7pvuB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3p78A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4eh4A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 6y81A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 1kv1A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3zsgA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 3mgyA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3py3A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3gcuB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 3iw8A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 6y7yA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 6hwvA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 7be4A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3p7bA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 6y8hA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 3hvcA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 35 modes for 303 modes from MaskedGNM 4aacA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 6hwtA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 6y7xA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3zs5A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 6y80A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 3bv2A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 6sovA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3o8pA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 21 modes for 303 modes from MaskedGNM 2npqA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 5larA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 6y7wA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 6splA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4eh7A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 6qe1A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 6anlA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 32 modes for 303 modes from MaskedGNM 3ds6B_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 3hegA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4kiqB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 6qdzA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3hv5B_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3p5kA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 6ycwA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 4lopB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 32 modes for 303 modes from MaskedGNM 3qudA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 4kinC_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3hv4B_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 6y70A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4kiqC_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 31 modes for 303 modes from MaskedGNM 6sp9A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 19 modes for 303 modes from MaskedGNM 4e6aA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 6yk7A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4kipA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 3mvmB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 3ds6D_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 6zwrA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 6y82A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 6sfoA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 3hp5A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3hv7A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 8efjA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3bx5A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4lopC_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 21 modes for 303 modes from MaskedGNM 4geoA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 21 modes for 303 modes from MaskedGNM 2fsmX_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4kiqD_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 32 modes for 303 modes from MaskedGNM 3queA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 5omhA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 2rg5A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 2fslX_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3hp2A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3nnxA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3p7cA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 19 modes for 303 modes from MaskedGNM 4e5bA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 22 modes for 303 modes from MaskedGNM 5o8vA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4kinA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 4kipB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 5o90A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 38 modes for 303 modes from MaskedGNM 4loqA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 2gtnA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3objA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3mvlA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3gcvA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3p7aA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3lfeA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 6m9lA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3o8uA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3l8sA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 2ozaB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 3pg3A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 4loqC_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 3lfcA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 3bv3A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 1zz2A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 6ycuA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4kiqA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 5mtxA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 6sfiA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 3gcsA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3uvpA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3iw6A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 4e8aA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3iw7A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 5wjjA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 6y6vA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 3gcpA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3iw5A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 2puuA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 7be5A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 3obgA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3mvmA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 32 modes for 303 modes from MaskedGNM 2gtmA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3mvlB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 4tyhB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 1yw2A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 21 modes for 303 modes from MaskedGNM 2yiwA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 21 modes for 303 modes from MaskedGNM 2yisA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 5ml5A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 3hecA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 3ctqA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 22 modes for 303 modes from MaskedGNM 3zshA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 7bdqA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 2fstX_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 6zwpA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 6y6wA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 22 modes for 303 modes from MaskedGNM 2baqA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 7bdoA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 3lfbA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 2fsoX_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3hubA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 21 modes for 303 modes from MaskedGNM 6ohdA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 6yjcA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 3lfdA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 3zsiA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 22 modes for 303 modes from MaskedGNM 5mtyA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 3c5uA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 4kinD_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 19 modes for 303 modes from MaskedGNM 1kv2A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 6m95A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 27 modes for 303 modes from MaskedGNM 3lffA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 3gi3A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 21 modes for 303 modes from MaskedGNM 5tcoA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 4ynoA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 3odzX_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 18 modes for 303 modes from MaskedGNM 3l8xA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 3oefX_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 36 modes for 303 modes from MaskedGNM 6tcaD_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 29 modes for 303 modes from MaskedGNM 5ekoA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 35 modes for 303 modes from MaskedGNM 6tcaB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 3s4qA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 22 modes for 303 modes from MaskedGNM 2bajA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 30 modes for 303 modes from MaskedGNM 4l8mA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 28 modes for 303 modes from MaskedGNM 4eymA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 25 modes for 303 modes from MaskedGNM 3gc9B_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 35 modes for 303 modes from MaskedGNM 6tcaF_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 5eknA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 26 modes for 303 modes from MaskedGNM 4eyjA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 3gp0A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 3uvrA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 14 modes for 303 modes from MaskedGNM 6unaA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 24 modes for 303 modes from MaskedGNM 4ic8B_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 3zu7A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 21 modes for 303 modes from MaskedGNM 4h39A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 15 modes for 303 modes from MaskedGNM 6unaB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 22 modes for 303 modes from MaskedGNM 4h3bC_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 21 modes for 303 modes from MaskedGNM 4h3bA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 23 modes for 303 modes from MaskedGNM 4h36A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 15 modes for 303 modes from MaskedGNM 4mygB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 15 modes for 303 modes from MaskedGNM 4mygA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 20 modes for 303 modes from MaskedGNM 3npcA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 19 modes for 303 modes from MaskedGNM 3npcB_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 21 modes for 303 modes from MaskedGNM 3ptgA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 16 modes for 303 modes from MaskedGNM 3zuvC_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 16 modes for 303 modes from MaskedGNM 3zuvA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 16 modes for 303 modes from MaskedGNM 2erkA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 10 modes for 303 modes from MaskedGNM 4hysA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 11 modes for 303 modes from MaskedGNM 5byyA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 10 modes for 303 modes from MaskedGNM 4hyuA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 10 modes for 303 modes from MaskedGNM 4izyA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 9 modes for 303 modes from MaskedGNM 4g1wA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 6 modes for 303 modes from MaskedGNM 4e73A_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 5 modes for 303 modes from MaskedGNM 1ukhA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> WARNING last 10 modes for 303 modes from MaskedGNM 1ukiA_ca reduced has been discarded because at least one conformation has only 303 modes
# @> all GNM modes were calculated for each of the 412 conformations in 24.44s.
# @> 303 modes across 412 modesets were matched in 7.54s.

# %%
ids
# Out:
# ['6sotA',
#  '5r92A',
#  '6soiA',
#  '6so4A',
#  '5r95A',
#  '5r9jA',
#  '5ra4A',
#  '5r9cA',
#  '6sodA',
#  '5r9hA',
#  '6so1A',
#  '5r9pA',
#  '5ra2A',
#  '5r9mA',
#  '5r9eA',
#  '5r90A',
#  '5r9fA',
#  '5r9wA',
#  '5r9xA',
#  '6so2A',
#  '5r91A',
#  '5r96A',
#  '5r9lA',
#  '5r9gA',
#  '5r94A',
#  '5ra5A',
#  '5r9bA',
#  '5r8xA',
#  '5ra0A',
#  '5r9nA',
#  '5r9vA',
#  '5r93A',
#  '5r8wA',
#  '5r98A',
#  '5r9sA',
#  '5r8vA',
#  '5r9oA',
#  '5r9dA',
#  '5ra6A',
#  '5r9aA',
#  '5r9zA',
#  '5r9qA',
#  '5r9rA',
#  '1w84A',
#  '5r99A',
#  '5ra1A',
#  '5ra3A',
#  '1wboA',
#  '5r9tA',
#  '5r9yA',
#  '6souA',
#  '5r9iA',
#  '2zb0A',
#  '5ra9A',
#  '5r8yA',
#  '3fmjA',
#  '3d83A',
#  '1w7hA',
#  '1p38A',
#  '5r8uA',
#  '5etcA',
#  '3flzA',
#  '1wbvA',
#  '1di9A',
#  '1r3cA',
#  '2zazA',
#  '5r9uA',
#  '1oz1A',
#  '5uojA',
#  '5mz3A',
#  '3mptA',
#  '5ra8A',
#  '3fmhA',
#  '1bmkA',
#  '1bl6A',
#  '1wbwA',
#  '3flyA',
#  '5ra7A',
#  '1wbnA',
#  '1wbtA',
#  '3gfeA',
#  '5r8zA',
#  '1a9uA',
#  '1bl7A',
#  '1ouyA',
#  '1wbsA',
#  '1m7qA',
#  '1r39A',
#  '5r9kA',
#  '2zb1A',
#  '3iphA',
#  '1yqjA',
#  '1w83A',
#  '1oukA',
#  '3e93A',
#  '3fsfA',
#  '3nnuA',
#  '5xyyA',
#  '5r97A',
#  '3u8wA',
#  '3gc7A',
#  '3kq7A',
#  '3nnwA',
#  '5etiA',
#  '3flqA',
#  '3fmnA',
#  '3fmkA',
#  '3fmlA',
#  '3flwA',
#  '1wfcA',
#  '3flsA',
#  '5xyxA',
#  '3e92A',
#  '3nnvA',
#  '2gfsA',
#  '3flnC',
#  '1w82A',
#  '3ha8A',
#  '3d7zA',
#  '3itzA',
#  '3s3iA',
#  '3fmmA',
#  '3dt1A',
#  '3hrbA',
#  '3fi4A',
#  '3p4kA',
#  '1lezA',
#  '3fknA',
#  '3mw1A',
#  '1oveA',
#  '3fkoA',
#  '3fskA',
#  '1lewA',
#  '5etfA',
#  '3fklA',
#  '2i0hA',
#  '3fl4A',
#  '2y8oA',
#  '1zzlA',
#  '2yixA',
#  '3rinA',
#  '2okrA',
#  '3lhjA',
#  '4ka3A',
#  '2onlB',
#  '2onlA',
#  '2okrD',
#  '3fc1X',
#  '4looA',
#  '2balA',
#  '7pvuA',
#  '4a9yA',
#  '2bakA',
#  '3newA',
#  '4eh2A',
#  '4f9yA',
#  '4eh3A',
#  '4r3cA',
#  '4dliA',
#  '3nwwA',
#  '5n64A',
#  '4f9wA',
#  '3hl7A',
#  '2ghmA',
#  '2lgcA',
#  '3hllA',
#  '3rocA',
#  '4ewqA',
#  '6hwuA',
#  '5n67A',
#  '6sfkA',
#  '6qyxA',
#  '5n66A',
#  '4eh6A',
#  '3gcqA',
#  '3kf7A',
#  '6y4xA',
#  '3ds6C',
#  '4e5aX',
#  '4aa4A',
#  '3zyaA',
#  '1ywrA',
#  '5n68A',
#  '2rg6A',
#  '2ghlA',
#  '5etaA',
#  '4e6cA',
#  '3tg1A',
#  '4dljA',
#  '4eh8A',
#  '3mh3A',
#  '3mh0A',
#  '3mpaA',
#  '3k3jA',
#  '3hv3A',
#  '4zthA',
#  '5etaB',
#  '5n65A',
#  '5omgA',
#  '3p79A',
#  '3hucA',
#  '4eh9A',
#  '3lfaA',
#  '5n63A',
#  '3gcuA',
#  '3mh1A',
#  '3uvqA',
#  '3hv6A',
#  '3ds6A',
#  '1zyjA',
#  '6y4tA',
#  '4aa5A',
#  '4kinB',
#  '3k3iA',
#  '4eh5A',
#  '3ocgA',
#  '6y4wA',
#  '6y4uA',
#  '6sfjA',
#  '2ewaA',
#  '3o8tA',
#  '4aa0A',
#  '5o8uA',
#  '3hv5A',
#  '6y7zA',
#  '4fa2A',
#  '6y4vA',
#  '3mh2A',
#  '3oc1A',
#  '7pvuB',
#  '4ehvA',
#  '3p78A',
#  '2qd9A',
#  '3hv4A',
#  '3zsgA',
#  '4eh4A',
#  '3mgyA',
#  '6y81A',
#  '1kv1A',
#  '6y85A',
#  '6y7xA',
#  '6y7yA',
#  '3py3A',
#  '6sovA',
#  '3hvcA',
#  '4aacA',
#  '6hwtA',
#  '3p7bA',
#  '3gcuB',
#  '3iw8A',
#  '6y80A',
#  '6y8hA',
#  '3bv2A',
#  '7be4A',
#  '3zs5A',
#  '6hwvA',
#  '2npqA',
#  '3ds6B',
#  '3p5kA',
#  '3hegA',
#  '4eh7A',
#  '5larA',
#  '6y7wA',
#  '6ycwA',
#  '4kiqB',
#  '6qe1A',
#  '6splA',
#  '6anlA',
#  '6qdzA',
#  '3hv5B',
#  '3o8pA',
#  '4lopB',
#  '3qudA',
#  '3hv4B',
#  '6zwrA',
#  '3hp5A',
#  '4kinC',
#  '4kipA',
#  '6y82A',
#  '6y70A',
#  '4kiqC',
#  '6sfoA',
#  '6sp9A',
#  '4e6aA',
#  '3mvmB',
#  '3ds6D',
#  '6yk7A',
#  '2fslX',
#  '8efjA',
#  '2fsmX',
#  '5omhA',
#  '4lopC',
#  '3hv7A',
#  '4kiqD',
#  '2rg5A',
#  '3queA',
#  '3bx5A',
#  '4geoA',
#  '5o8vA',
#  '3hp2A',
#  '4e5bA',
#  '5o90A',
#  '3nnxA',
#  '4kinA',
#  '3p7cA',
#  '4kipB',
#  '2gtnA',
#  '3gcvA',
#  '3mvlA',
#  '3objA',
#  '4loqA',
#  '3o8uA',
#  '3p7aA',
#  '6m9lA',
#  '3l8sA',
#  '2ozaB',
#  '3pg3A',
#  '3lfeA',
#  '4loqC',
#  '3lfcA',
#  '3bv3A',
#  '6ycuA',
#  '1zz2A',
#  '5mtxA',
#  '4kiqA',
#  '3gcsA',
#  '6sfiA',
#  '3iw6A',
#  '4e8aA',
#  '3uvpA',
#  '3mvmA',
#  '7be5A',
#  '3iw7A',
#  '3obgA',
#  '6y6vA',
#  '3gcpA',
#  '2puuA',
#  '3iw5A',
#  '5wjjA',
#  '2gtmA',
#  '4tyhB',
#  '3mvlB',
#  '1yw2A',
#  '5ml5A',
#  '2yiwA',
#  '3hecA',
#  '2yisA',
#  '7bdqA',
#  '3ctqA',
#  '3zshA',
#  '2fstX',
#  '2baqA',
#  '2fsoX',
#  '7bdoA',
#  '6zwpA',
#  '3lfbA',
#  '6y6wA',
#  '5mtyA',
#  '6ohdA',
#  '3zsiA',
#  '6yjcA',
#  '3hubA',
#  '3lfdA',
#  '3c5uA',
#  '4kinD',
#  '1kv2A',
#  '3lffA',
#  '3gi3A',
#  '6m95A',
#  '4ynoA',
#  '3odzX',
#  '5tcoA',
#  '3l8xA',
#  '3oefX',
#  '6tcaD',
#  '5ekoA',
#  '3s4qA',
#  '6tcaB',
#  '4l8mA',
#  '2bajA',
#  '4eymA',
#  '6tcaF',
#  '3gc9B',
#  '5eknA',
#  '4eyjA',
#  '3gp0A',
#  '6unaA',
#  '3uvrA',
#  '4ic8B',
#  '3zu7A',
#  '4h39A',
#  '4h3bC',
#  '4h3bA',
#  '6unaB',
#  '4h36A',
#  '4mygA',
#  '4mygB',
#  '3npcA',
#  '3npcB',
#  '3ptgA',
#  '3zuvC',
#  '3zuvA',
#  '2erkA',
#  '4hysA',
#  '5byyA',
#  '4hyuA',
#  '4izyA',
#  '4g1wA',
#  '4e73A',
#  '1ukhA',
#  '1ukiA',
#  '6rfoA']

# %%
writeIDs('./Binding', ids)

# %%
currNumModes = getModesGivenThreshold(averageEigVals, 0.33)
currNumModes
# Out:
# 1

# %%
binding2 = [98, 27, 255, 103, 104, 100, 196, 161, 45, 197, 65, 26, 101, 46, 47, 69, 254, 252, 162, 256, 32, 78, 102, 99, 253]

# binding = ['25', '28', '31', '44', '45', '46', '64', '68', '77', '97', '98', '99', '100', '101', '102', '103', '104', '105', '149', '159', '160', '161', '162']


binding = ['25', '28', '31', '44', '45', '46', '64', '68', '77', '97', '98', '99', '100', '101', '102', '103', '104', '105', '149', '159', '160', '161', '163']

# writeNumbers('./Data/binding_residues_index.txt', binding)

binding = [int(x) for x in binding]

# %%
sort(binding2)
# Out:
# array([ 26,  27,  32,  45,  46,  47,  65,  69,  78,  98,  99, 100, 101,
#        102, 103, 104, 161, 162, 196, 197, 252, 253, 254, 255, 256])

# %%
len(binding2)
# Out:
# 25

# %%
sort(binding)
# Out:
# array([ 25,  28,  31,  44,  45,  46,  64,  68,  77,  97,  98,  99, 100,
#        101, 102, 103, 104, 105, 149, 159, 160, 161, 163])

# %%
Hinges_2 = getHinges(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges(averageEigVects, 3, 20)

Hinges_4 = getHinges(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges(averageEigVects, 3, 15)

# %%
overlaps_2 = len(binding2) + len(Hinges_2) - len(set(binding2 + Hinges_2))
overlaps_3 = len(binding2) + len(Hinges_3) - len(set(binding2 + Hinges_3))
overlaps_4 = len(binding2) + len(Hinges_4) - len(set(binding2 + Hinges_4))
overlaps_5 = len(binding2) + len(Hinges_5) - len(set(binding2 + Hinges_5))


HyperScore_2 = ORA(len(binding2), 341, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding2), 341, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding2), 341, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding2), 341, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 23
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 3 1 0.20476718962050855
# # of hinge sites for first 3 modes, overlap, hyper score 48 7 0.04546912616711274
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 3 1 0.20476718962050855
# # of hinge sites for first 3 modes, overlap, hyper score 66 9 0.033029360603519464

# %%
ubi = parsePDB('6sot', subset='calpha')
calphas = ubi.select('calpha and chain A')
gnm = GNM('P38')
gnm.buildKirchhoff(calphas)
gnm.calcModes(n_modes=None)
eigenVals = gnm.getEigvals()
eigenVects = gnm.getEigvecs()
Hinge0 = calcHinges(gnm[0])
Hinge1 = calcHinges(gnm[1])
Hinge2 = calcHinges(gnm[2])

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

overlaps_sep2 = len(binding2) + len(Hinges_sep2) - len(set(binding2 + Hinges_sep2))
overlaps_sep3 = len(binding2) + len(Hinges_sep3) - len(set(binding2 + Hinges_sep3))
overlaps_sep4 = len(binding2) + len(Hinges_sep4) - len(set(binding2 + Hinges_sep4))
overlaps_sep5 = len(binding2) + len(Hinges_sep5) - len(set(binding2 + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding2), 341, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding2), 341, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding2), 341, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding2), 341, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 23
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 7 3 0.01006289331260124
# # of hinge sites for 3 modes, overlap, hyper score 70 10 0.016702969942724244
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 7 3 0.01006289331260124
# # of hinge sites for 3 modes, overlap, hyper score 84 12 0.007221527676289807

# %% [markdown]
# ### write hinges

# %%
averageEigVects.shape
# Out:
# (342, 303)

# %%
currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
currList = sort(list(set(list(currHinge) + list(calcHinges(gnm[mode])))))

writingList = []

row, col = averageEigVects.shape
for i in range(row):
    if i in currList:
        writingList.append('1')
    else:
        writingList.append('')
print (len(writingList))
# Out:
# 342

# %%
writeNumbers('./Data/hinge_method1.txt', Hinges_sep5)

modes = [0, 1, 2]
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    currList = sort(list(set(list(currHinge) + list(calcHinges(gnm[mode])))))

    print (mode, len(currList))
    writingList = []

    for i in range(row):
        if i in currList:
            writingList.append('1')
        else:
            writingList.append('0')
    writeNumbers('./Data/hinge' + '_mode' + str(mode + 1) + '_method1.txt', writingList)
# Out:
# 0 7
# 1 26
# 2 57

# %% [markdown]
# ## method 2

# %%
Hinges_2 = getHinges2(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges2(averageEigVects, 2, 20)

Hinges_4 = getHinges2(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges2(averageEigVects, 2, 15)

# %%
overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))


HyperScore_2 = ORA(len(binding), 341, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), 341, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), 341, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), 341, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 23
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 12 7 1.5663255664710718e-06
# # of hinge sites for first 3 modes, overlap, hyper score 33 9 7.856015859353249e-05
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 12 7 1.5663255664710718e-06
# # of hinge sites for first 3 modes, overlap, hyper score 40 10 6.098889896333226e-05

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), 341, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), 341, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), 341, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), 341, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 23
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 13 7 3.250063571269557e-06
# # of hinge sites for 3 modes, overlap, hyper score 58 11 0.0003663213779097063
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 13 7 3.250063571269557e-06
# # of hinge sites for 3 modes, overlap, hyper score 64 12 0.00018173019846134952

# %%
AverageEigVals1 = gnms.getEigvals()[0]
AverageEigVals2 = mean(gnms.getEigvals(), axis=0)
proteinLength = 341

# %%
currHinge = Hinges_4

# %%
Segment = int(proteinLength / 5)
print ('mark Index are', 0, Segment, Segment*2, Segment*3, Segment*4, proteinLength - 1)
# Out:
# mark Index are 0 68 136 204 272 340

# %%
# Labels = ['5', '120', '235', '350', '465', '582']

# %%
import matplotlib.patches as patches
fig, ax = plt.subplots(figsize=(20, 10))   # Adjust size as per requirement
plt.sca(ax)  # Set current axis to 'ax'
    
# Increase font sizes
plt.rc('xtick', labelsize=55)
plt.rc('ytick', labelsize=50)
plt.rcParams.update({'font.size': 70})

# calcMSF
modes = [0]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / AverageEigVals2[mode]
    MSF.append(currMSF)

plt.plot(MSF, color='black', linewidth=4, alpha=0.88)    

HingeY = [MSF[item] for item in currHinge]
plt.plot(currHinge, HingeY, color=(0.2, 1, 0.1), marker='o', linestyle='', markersize=25)
print ('# of hinges', len(HingeY))

# plot binding sites
bindingY = [MSF[item] for item in binding]
plt.plot(binding, bindingY, 'r*', markersize=30)
print ('# of bindings sites', len(binding))

# plot overlaps
allHinge = currHinge
overlaps = [item for item in binding if item in allHinge]
overlapsY = [MSF[item] for item in overlaps]
plt.plot(overlaps, overlapsY, 'mD', markersize=25)

print ('# of hits are', len(overlaps))

# Hide y labels
plt.gca().yaxis.set_visible(False)

# Hide top, right, and left spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)


# Set x-axis labels and title with Arial font
# plt.title('Mitogen-activated Protein Kinase 14')
xticks([0, Segment, Segment*2, Segment*3, Segment*4, proteinLength - 1], Labels)

plt.savefig('./MAPK14_MSF.png', dpi=500)
# Out:
# # of hinges 12
# # of bindings sites 23
# # of hits are 7

# %%
averageEigVals
# Out:
# array([ 0.29739962,  0.97182294,  1.22242077,  4.34517518,  2.00903868,
#         2.80839028,  3.57218026,  2.71060205,  3.79650595,  7.18384265,
#         5.87951858,  3.46965874,  3.99354367,  4.47384225,  4.42079442,
#         4.65578307,  5.09991294,  4.9159634 ,  5.31209487,  5.37192468,
#         5.89706262,  6.13632981,  7.08972674,  7.35390865,  7.57640386,
#         7.21284774,  7.59280038, 18.14768689,  8.980835  ,  8.54756045,
#         7.59379268, 16.38167595,  8.09657219,  8.41478006,  8.57069497,
#         8.93405253,  8.32931388,  8.91216001,  8.55512429,  9.09297817,
#         9.40848157,  9.51263552,  9.43032461,  9.7849675 ,  9.73057691,
#         9.60028865,  9.97082145,  9.53451145, 12.59448499, 11.18783089,
#        10.88020583,  9.87211876, 10.6385969 , 10.52249736, 10.13906705,
#        10.48373657, 11.16750458, 10.2963605 , 10.30846789, 10.61046141,
#        10.11637744, 10.4761355 , 11.15829032, 11.00801186, 10.84978722,
#        10.88552497, 11.93083183, 11.21634496, 11.34298123, 11.71915283,
#        11.22428802, 11.55931445, 11.97654552, 11.8559836 , 11.91278586,
#        11.46460902, 11.68988288, 11.89208973, 11.73559468, 12.81473192,
#        13.00433408, 11.95542939, 12.42809544, 12.3712592 , 12.02923749,
#        12.53904829, 12.1515989 , 12.14860277, 12.97395309, 13.06292815,
#        13.38753014, 12.73559699, 12.15540439, 12.93896349, 12.23355547,
#        13.09368867, 12.86350137, 12.90658304, 12.7776691 , 13.00610537,
#        13.4000612 , 13.5904004 , 13.48209857, 13.80088437, 13.44085492,
#        13.47270794, 14.56307022, 13.76790162, 13.96240563, 13.93003824,
#        14.15472726, 13.97033073, 13.95032004, 14.49854676, 14.40945972,
#        13.7906536 , 14.08975743, 14.05761942, 14.35793368, 14.43644843,
#        14.18199155, 14.55921598, 14.40360949, 14.80320685, 14.68812469,
#        15.02333992, 15.0604996 , 14.72051346, 14.61335115, 14.69939739,
#        14.82606596, 14.79016016, 14.92071349, 15.14373723, 14.46111684,
#        15.27629433, 15.08263294, 15.11748528, 15.52368051, 15.16262934,
#        15.3197046 , 15.39777494, 15.63923219, 15.71407414, 15.62683905,
#        15.43357833, 15.75777315, 15.47455298, 15.8755742 , 16.10643523,
#        15.69717248, 16.0743351 , 16.01373585, 15.94326998, 15.82104782,
#        16.20106883, 15.84948256, 15.95938273, 16.64299032, 16.24950849,
#        15.94502985, 16.46209019, 16.63831368, 16.8048452 , 16.79150058,
#        16.89429737, 16.46156014, 16.78131438, 16.38544268, 16.84788038,
#        16.78297591, 16.6919482 , 17.10344883, 16.82758293, 17.05435911,
#        16.25281362, 15.68856614, 17.56750409, 17.48912368, 17.35881991,
#        17.7566716 , 17.39455384, 17.49433416, 17.54288147, 17.5930445 ,
#        17.91649459, 17.78952984, 17.76456772, 17.9362765 , 17.68280996,
#        17.983336  , 17.76510747, 18.02919064, 18.22252323, 18.23127851,
#        18.11796947, 17.9535242 , 18.43647048, 18.42305767, 18.44556238,
#        18.7675557 , 18.14085445, 18.44004173, 18.60583272, 18.58704566,
#        19.00473251, 18.85870247, 19.00609818, 18.72969699, 19.01114704,
#        19.28219805, 19.23150118, 18.86142565, 19.22117348, 19.07266446,
#        19.28473943, 19.33359105, 19.56806067, 19.61860659, 19.74675314,
#        19.44152437, 19.58701952, 19.43242948, 19.79978214, 19.90920709,
#        19.55812491, 19.97044007, 20.21389267, 20.73948667, 19.93126664,
#        19.99920682, 20.37637612, 20.22128441, 20.61880524, 19.90282514,
#        20.38561767, 20.19480052, 20.33339906, 21.43660728, 20.72897755,
#        20.4855023 , 21.06106337, 21.22058293, 21.02130458, 21.33660122,
#        20.90346202, 21.27262309, 19.19423122, 21.13801668, 21.34170362,
#        22.03129532, 21.2803406 , 21.84291576, 21.40552315, 21.84327691,
#        21.58122412, 21.87794491, 21.6696198 , 21.49490423, 22.3702122 ,
#        21.46882463, 21.93328671, 23.03025811, 22.57805971, 22.51467839,
#        22.75063325, 22.5669034 , 22.30633824, 22.48042638, 22.61605932,
#        22.65213056, 23.10733198, 23.04423568, 22.94247865, 22.37496096,
#        22.75180941, 23.00149468, 23.0584867 , 22.89043226, 23.14478388,
#        23.32035038, 23.25080347, 23.42088552, 23.7039134 , 23.46410227,
#        23.35152322, 22.91038565, 24.28667652, 23.79551749, 23.70931238,
#        24.04097761, 24.40001752, 23.90855748, 24.10515695, 24.0538561 ,
#        24.44037456, 24.71095961, 24.39180473, 24.21582264, 24.68414634,
#        24.5611877 , 24.64598519, 24.79705563])

# %% [markdown]
# ### write hinges

# %%
# write MSFs
# averageEigVals
modes = [0]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)
len(MSF)
# Out:
# 342

# %%
includeModes = 1
size = includeModes * 2 + 1 + 2 

curr = zeros((len(MSF), size))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
# curr[:, 3] = averageEigVects[:, 1]
# curr[:, 5] = averageEigVects[:, 2]

for each in binding:
    curr[each, 0] = each

# %%
modes = [0]
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=15)
    # currHinge = filterTwoEnds(currHinge, chainLength = [[0, 550], [551, 1104]])
    currList = sort(list(set(list(currHinge)))) # + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
writeAllData('./Data/MAPK14_Method2_update.txt', curr)

# %% [markdown]
# # StoreData

# %%
# write modes
writeNumbers('./Data/mode1.txt', averageEigVects[:, 0])
writeNumbers('./Data/mode2.txt', averageEigVects[:, 1])
writeNumbers('./Data/mode3.txt', averageEigVects[:, 2])

# %%
# write MSFs
averageEigVals
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)
           
writeNumbers('./Data/MSF_mode123.txt', MSF)
writeNumbers('./Data/RMSF_mode123.txt', sqrt(MSF))

# %%
# RMSF minimum
values_array = np.array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = np.argsort(values_array)

writeNumbers('./Data/RMSF_minimum.txt', indices)

# %% [markdown]
# # Plot graph

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import math
import numpy as np

def format_significant(value, pos):
    if abs(value) <= 0.01:
        return "0.00"
    else:
        order_of_magnitude = math.floor(math.log10(abs(value)))
        round_digits = -order_of_magnitude + 1
        formatted_number = round(value, round_digits)
        str_format = "{:." + str(round_digits) + "f}"
        return str_format.format(formatted_number)

# %% [markdown]
# # Plot single graph

# %%
def plotSingleGraph(mode, averageEigVects, gnms, binding, Hinge):
    fig, ax = plt.subplots(figsize=(20, 10))   # Adjust size as per requirement
    
    plt.sca(ax)  # Set current axis to 'ax'
    
    # Increase font sizes
    plt.rc('xtick', labelsize=40)
    plt.rc('ytick', labelsize=50)
    plt.rcParams.update({'font.size': 50})

    # plot mode of motion
    showSignatureMode(gnms[:, mode], linewidth=3)

    # Hinges within band
    # method1
    # currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    # method2
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=20)
    
    
    HingeY = [averageEigVects[item, mode] for item in currHinge]
    print ('Hinge residue with wide bands', currHinge)
    plt.plot(currHinge, HingeY, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # extraHinges for local loops
    updateHinge = [item for item in Hinge if item not in currHinge]
    HingeY_local = [averageEigVects[item, mode] for item in updateHinge]
    print ('local loop motion', updateHinge)
    plt.plot(updateHinge, HingeY_local, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # plot binding sites
    bindingY = [averageEigVects[item, mode] for item in binding]
    plt.plot(binding, bindingY, 'r*', markersize=18)
    print ('current bindings are', binding)
    plt.title('Mode ' + str(mode + 1), fontweight="bold")

    # plot overlaps
    allHinge = updateHinge + currHinge
    overlaps = [item for item in binding if item in allHinge]
    overlapsY = [averageEigVects[item, mode] for item in overlaps]
    print ('current hits are', overlaps)
    plt.plot(overlaps, overlapsY, 'mD', markersize=18)

    print('# of overlaps finding from current mode is', len(overlaps))
    
    # Set y-ticks to have 4-5 values with equal spacing
    y_min, y_max = ax.get_ylim()
    ax.set_yticks(np.linspace(y_min * 0.9, y_max, 5))  # Adjust the number 5 if you want a different number of y-ticks
    ax.yaxis.set_major_formatter(FuncFormatter(format_significant)) 
    
    plt.tight_layout()
    plt.savefig('./MAPK14_method2Merging_mode' + str(mode + 1) + '.png', dpi=500)

# %%
modes = 0 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [160, 161, 163, 103, 72, 73, 104, 76, 77, 309, 310, 159]
# local loop motion []
# current bindings are [25, 28, 31, 44, 45, 46, 64, 68, 77, 97, 98, 99, 100, 101, 102, 103, 104, 105, 149, 159, 160, 161, 163]
# current hits are [77, 103, 104, 159, 160, 161, 163]
# # of overlaps finding from current mode is 7

# %%
modes = 1 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [258, 259, 278, 279, 283, 284, 162, 163, 189, 190, 319, 62, 63, 320, 80, 81, 338, 211, 212, 339, 98, 99]
# local loop motion []
# current bindings are [25, 28, 31, 44, 45, 46, 64, 68, 77, 97, 98, 99, 100, 101, 102, 103, 104, 105, 149, 159, 160, 161, 163]
# current hits are [98, 99, 163]
# # of overlaps finding from current mode is 3

# %%
modes = 2 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [256, 255, 140, 141, 279, 280, 158, 159, 289, 290, 163, 164, 47, 48, 303, 178, 179, 180, 304, 193, 194, 195, 196, 74, 75, 77, 78, 81, 82, 83, 84, 95, 96, 228, 229, 125, 126, 127]
# local loop motion []
# current bindings are [25, 28, 31, 44, 45, 46, 64, 68, 77, 97, 98, 99, 100, 101, 102, 103, 104, 105, 149, 159, 160, 161, 163]
# current hits are [77, 159, 163]
# # of overlaps finding from current mode is 3

# %%
ORA(len(binding), 341, 56, 4)
# Out:
# 0.5410738796757333

# %% [markdown]
# # Write Modes

# %%
len(averageEigVects[:, 0])
# Out:
# 342

# %%
mode = 2
writePDB('./structure_demo/MAPK14_mode' + str(mode) + '.pdb', calphas, beta=eigenVects[:, mode])
# Out:
# './structure_demo/MAPK14_mode2.pdb'

# %%
residue = []
new_b_factor = []
chain = 'A'

resiIndex = 0
for item in eigenVects[:, mode]:
    resiIndex += 1
    residue.append(resiIndex)
    new_b_factor.append(item)

# %%
with open('./structure_demo/DHFR_b_mode' + str(mode + 1) + '.txt', 'w') as wf:
    for i in range(len(residue)):
        wf.write(chain + ', ' + str(residue[i]) + ', ' + str(new_b_factor[i]) + '\n')

# %%
# !pwd
# Out:
# /data/frank/Desktop/Hinges_Figures_all/MAPK14
