# %%
from numpy import *
# from matplotlib.pyplot import *
# import os
# ion()

# find hinges
def splitHinge(vals, sites, block):
    # split hinges
    currBlock = 1
    index = 0
    isStart = False
    newSites = []
    newVals = []

    for val in vals:
        if block[index] == currBlock and not isStart:
            isStart = True
            currSites = [sites[index]]
            currValLists = [vals[index]]
        elif block[index] == currBlock and isStart:
            currSites.append(sites[index])
            currValLists.append(vals[index])
        else:
            currBlock += 1
            isStart = True
            newSites.append(currSites)
            newVals.append(currValLists)
            currSites = [sites[index]]
            currValLists = [vals[index]]
        if currBlock == block[-1] and index == len(vals) - 1:
            newSites.append(currSites)
            newVals.append(currValLists)
        index += 1
    # print newSites, newVals
    return newSites, newVals


def mini(a, b):
    if a > b:
        return a
    else:
        return b


def checkIfCrossBase(currVal, currSite, currEigenVec):
    identify = sort(currVal)
    ifRemain = True
    if identify[0] < 0 and identify[-1] > 0:
        ifRemain = True
    else:
        maxSite = max(currSite)
        minSite = min(currSite)
        # print (identify)
        if identify[0] >= 0 and identify[-1] >= 0:
            if currEigenVec[max(0, minSite - 1)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 1)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 2)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 3)] < 0:
                ifRemain = True
            else:
                ifRemain = False
        elif identify[0] <= 0 and identify[-1] <= 0:
            # print (len(currEigenVec))
            # print (currEigenVec[239])

            if currEigenVec[max(0, minSite - 1)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 1))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 2))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 3))] > 0:
                ifRemain = True
            else:
                ifRemain = False

        else:
            print(identify[0], identify[-1])
            print("Check!")
    return ifRemain


def oneModeHinge(currEigenVec, thereshold=20):
    range = ((1 / float(len(currEigenVec))) ** 0.5) / thereshold
    # print (range)
    # print range
    sites = []
    vals = []
    block = []

    index = 0
    blockID = 1
    for item in currEigenVec:
        if item <= range and item >= -range:
            vals.append(item)
            if len(sites) >= 1 and abs(sites[-1] - index) > 1:
                blockID += 1
            sites.append(index)
            block.append(blockID)
        index += 1

    newSites, newVals = splitHinge(vals, sites, block)

    filtSites = []
    filtVals = []

    index = 0
    for item in newSites:
        currSite = newSites[index]
        currVal = newVals[index]
        if checkIfCrossBase(currVal, currSite, currEigenVec):
            filtSites.append(currSite)
            filtVals.append(currVal)
        index += 1

    return filtSites, filtVals


def getValue(currList):
    newList = []
    for item in currList:
        newList.append(float(item))
    return newList


def readModes(fileName):
    allModes = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.strip()
            line = line.split('\t')
            currMode = line[0]
            currVal = line[1:]
            allModes[currMode] = getValue(currVal)
    return allModes


def flattenData(arrayTwoD):
    flat = []
    for item in arrayTwoD:
        for each in item:
            flat.append(each)
    return flat

def cleanStr(currStr):
    return currStr.strip('\'')

def readFile(fileName):
    data = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.replace('\n', '')
            line = line.strip()
            line = line.split('\t')
            currPDB = line[0]
            currDrug = line[1]
            currChain = line[2:]
            if currPDB not in data.keys():
                data[currPDB] = {}
            if currDrug not in data[currPDB].keys():
                data[currPDB][currDrug] = []
            for each in currChain:
                data[currPDB][currDrug].append(cleanStr(each))
    return data

# contribution of mode of motions
def getContribution(eigenVals, mode):
    allContribution = sqrt(sum(1 / eigenVals))
    currModeContribution = eigenVals[:mode]
    currContribution = sqrt(sum(1 / currModeContribution))
    return currContribution / allContribution

def getModesGivenThreshold(eigenVals, thereshold):
    contribution = 0
    mode = 0
    while contribution <= thereshold:
        mode += 1
        contribution = getContribution(eigenVals, mode)
    return mode

def writeBinding(fileName, pdb_ids):
    with open(fileName, 'w') as wf:
        for item in pdb_ids:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')


from prody import *
def getModes(currPDB, eachChain, length = 0.7, rmsd = 1.0, Z = 10):    
    # if not os.path.exists('./Results/' + currPath):
    #     os.mkdir('./Results/' + currPath)
    dali_rec = searchDali(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len = length, cutoff_rmsd = rmsd, cutoff_Z = Z)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    try:
        ags = parsePDB(pdb_ids, subset='ca')
    except EOFError:
        pass
    dali_ens = buildPDBEnsemble(ags, mapping=mappings, seqid=20)
    gnms = calcEnsembleENMs(dali_ens, model='GNM', trim='reduce', n_modes=None)
    eigVals = gnms.getEigvals()
    averageEigVals = eigVals[0]

    eigVects = gnms.getEigvecs()
    averageEigVects = mean(eigVects, axis=0)
    return averageEigVals, averageEigVects, pdb_ids, gnms, averageEigVects

            
def getDali_info(currPDB, eachChain, rmsd = 2.5, length = 0.9):
    dali_rec = searchDali(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len=length, cutoff_rmsd=rmsd)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    return pdb_ids, mappings

def getHinges(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge


def getHinges_modes(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def get3Hinges_bandwidth(averageEigVects, bandWidths = [15, 16, 17]):
    currHinge = []
    for i in range(3):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidths[i])
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
def oneModeHinge_update(values, thereshold=20):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    # print (regions)
    
    FinalRegions = []
    for region in regions:
        # print ('before filtering', region)
        if len(region) >= 5:
            # print ('previous region', region)
            pos = [index for index in region if values[index] > 0]
            neg = [index for index in region if values[index] < 0]
            pos.sort(key=lambda x: values[x])
            neg.sort(key=lambda x: values[x], reverse=True)
            n = int(len(region) / 4) + 1
            region = pos[:n] + neg[:n]
            # print (region, neg, pos)
        elif 3 <= len(region) <= 4:
            if values[region[0]-1] * values[region[-1]+1] > 0:
                continue  # Skip this region if adjacent values outside the band have the same sign
        # print ('after filtering',region)      
            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    # print ('Final regions', FinalRegions)
    
    flat = flattenData(FinalRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return FinalRegions, final_values

def getHinges2(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

def getHinges_modes2(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

# %%
# Experiment to evaluate performance of hypergeometric p values
from scipy.stats import hypergeom
def ORA(M, N, n, k):
    total = 0
    totalLength = N
    binding = M
    hinge = n
    overlap = k
    
    for i in range(overlap):
        total += hypergeom.pmf(i, totalLength, binding, hinge)
    return 1 - total


import os
def writeIDs(path, idList):
    # Check whether the specified path exists or not
    isExist = os.path.exists(path)
    if not isExist:

       # Create a new directory because it does not exist
       os.makedirs(path)
       print("The new directory is created!")
    
    with open(path + '/ids_diverse.txt', 'w') as wf:
        for item in idList:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')

# %%
def writeNumbers(path, numbers):
    with open(path, 'w') as wf:
        for item in numbers:
            wf.write(str(item) + '\n')

def merge_overlapping_lists(lists):
    sorted_lists = sorted(lists, key=lambda x: x[0])  # Sort lists based on the first element
    merged_lists = [sorted_lists[0]]
    
    for current in sorted_lists[1:]:
        previous = merged_lists[-1]
        # Check if the current list overlaps with the previous one
        if current[0] <= previous[-1]:
            # Merge overlapping lists by updating the last list in merged_lists
            merged_lists[-1] = list(range(min(previous[0], current[0]), max(previous[-1], current[-1])+1))
        else:
            merged_lists.append(current)
    return merged_lists

# %% [markdown]
# # Method3

# %%
def trimEnds(values, lists):
    begining = 4
    ends = len(values) - 5
    isInclude = True
    for item in lists:
        if item < begining or item > ends:
            isInclude = False
    return isInclude

def splitRegions(currlist):
    sortList = sort(currlist)
    
    region_list = []
    currRegion = []
    previous = -1
    for item in sortList:
        if item - previous == 1:
            currRegion.append(item)
            previous = item
        else:
            if currRegion != []:
                region_list.append(currRegion)
            currRegion = [item]
            previous = item
    
    if currRegion not in region_list:
        region_list.append(currRegion)
    return region_list
        
def extendRegions(crossovers, values, thereshold):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    return regions

def mergeRegions(lists, max_gap=2, min_length=5):
    merged = [lists[0]]  # Start with the first list

    for next_list in lists[1:]:
        # Check if the next list starts within max_gap+1 of the last element of the current last list in 'merged'
        if next_list[0] - merged[-1][-1] <= max_gap + 1:
            # Merge the lists by extending the last list in 'merged' with the elements of 'next_list'
            merged[-1].extend(next_list)
        else:
            # If it doesn't meet the merge criteria, just append the list as a new one
            merged.append(next_list)

    # Filter merged lists to ensure they meet the min_length requirement after removing duplicates and sort them
    # Keep unmerged lists as they are
    final_list = []
    for sublist in merged:
        unique_sublist = sorted(set(sublist))  # Remove duplicates and sort
        if len(unique_sublist) >= min_length or unique_sublist == sublist:  # Check length or unchanged list
            final_list.append(unique_sublist)
        else:
            # For lists that were attempted to merge but didn't meet the length requirement,
            # revert to individual elements as separate lists
            final_list.extend([[item] for item in unique_sublist])

    # print (final_list)
    finals = []
    for item in final_list:
        if len(item) < min_length:
            finals += splitRegions(item)
        else:
            finals.append(item)
    
    return finals

# Function to trim similar sign values from start
def trim_start(lst, index):
    if len(lst) == 1:
        return lst, index
    if not lst:
        return [], []
    start_sign = lst[0] >= 0
    for i in range(1, len(lst)):
        if (lst[i] >= 0) != start_sign:
            return lst[i-1:], index[i-1:]
    return [], []

# Function to trim similar sign values from end
def trim_end(lst, index):
    if len(lst) == 1:
        return lst, index
    
    if not lst:
        return [], []
    lst = lst[::-1]  # Reverse the list for ease of use
    index = index[::-1]
    end_sign = lst[0] >= 0
    for i in range(1, len(lst)):
        if (lst[i] >= 0) != end_sign:
            return lst[i-1:][::-1], index[i-1:][::-1]  # Reverse the list again to restore original order
    return [], []

def trimRegions(region, values):
    newRegion = []
    for eachIndex in region:
        currValues = [values[x] for x in eachIndex]
        # print (eachIndex, currValues)
        # Apply the trimming functions
        trimmed_start, trimmed_index = trim_start(currValues, eachIndex)
        # print (trimmed_index)
        trimmed_end, trimmed_index = trim_end(trimmed_start, trimmed_index)
        newRegion.append(trimmed_index)
    return newRegion

def findSmallestPairs(index_list, value_list):
    # Initialize variables to store the smallest sum and corresponding indices
    smallest_sum = float('inf')  # Set it to infinity initially
    smallest_pair = None

    # Iterate through the value list to find adjacent index pairs with the smallest sum of absolute values
    for i in range(len(value_list) - 1):  # -1 because we are looking at pairs
        current_sum = abs(value_list[i]) + abs(value_list[i + 1])
        if current_sum < smallest_sum:
            smallest_sum = current_sum
            smallest_pair = [index_list[i], index_list[i + 1]]
    return smallest_pair

def find_cross_points(Final_test, crossovers, values):
    crossoverPoints_pairs = []
    for item in Final_test:
        if item in crossovers and item - 1 in Final_test:
            crossoverPoints_pairs.append([item - 1, item])
    
    # print ('cross_pairs', crossoverPoints_pairs)
    # filtering_pairs = mergeRegions(crossoverPoints_pairs, max_gap=0, min_length=3)
    # currNumber = len(filtering_pairs) * 2
    # print ('filtering_pairs', crossoverPoints_pairs)
    
    bestPairs = crossoverPoints_pairs[0]
    bestScore = abs(values[bestPairs[0]]) + abs(values[bestPairs[1]])
    if len(crossoverPoints_pairs) <= 1:
        return bestPairs
    else:
        for item in crossoverPoints_pairs[1:]:
            currScore = abs(values[item[0]]) + abs(values[item[1]])
            # print ('item, score', item, currScore)
            if currScore <= bestScore:
                bestPairs = item
                bestScore = currScore
    
    # print ('filtered', bestPairs)
    return bestPairs

def filteringCriteria(Final, values, crossovers):
    FinalRegions = []
    for region in Final:
        # print ('before filtering', region)
        if len(region) >= 5:
            allPairs = find_cross_points(region, crossovers, values)
            currRegion = allPairs
            
            # print ('allPairs', allPairs)
            pos = [index for index in region if values[index] > 0]
            neg = [index for index in region if values[index] < 0]
            pos.sort(key=lambda x: values[x])
            neg.sort(key=lambda x: values[x], reverse=True)
            extra = round((len(region) - 2) / 4 + 0.00001)
            
            # rest = pos[1:] + neg[1:]
            # restValues = [values[res] for res in rest]
            # combined_list = sorted(zip(rest, restValues), key=lambda x: abs(x[1]))
            rest = []
            for item in region:
                if item not in currRegion:
                    rest.append(item)
            restValues = [values[res] for res in rest]   
            combined_list = sorted(zip(rest, restValues), key=lambda x: abs(x[1]))
            
            # Extract the sorted indexes from the combined list
            sorted_indexes = [index for index, value in combined_list]
            
            region = currRegion + sorted_indexes[:extra]
            # print (region)
            
        elif 3 <= len(region) <= 4:
            region = find_cross_points(region, crossovers, values)
            # print (region)
            # if values[region[0]-1] * values[region[-1]+1] > 0:
            #     continue  # Skip this region if adjacent values outside the band have the same sign
        # print ('after filtering',region)      
            
        
        # print ('after filtering',region)      
        elif len(region) == 1:
            continue
            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    return FinalRegions

# %%
def oneModeHinge_update2(values, hinges, thereshold=20):
    # band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    regions = extendRegions(crossovers, values, thereshold)
    # print ('extend Regions', regions)
    
    # merge regions and hinges
    flat = sort(list(set(flattenData(regions) + hinges)))
    Final = splitRegions(flat)
    # print ('before merging', Final)
    Final = mergeRegions(Final, max_gap=2, min_length=5)
    # print ('Final is', Final)
    # trim Regions
    trimmedFinal = trimRegions(Final, values)
    # print ('after trimming', trimmedFinal)
    
    FinalRegions = filteringCriteria(trimmedFinal, values, crossovers)
    # print ('after filtering', FinalRegions)
    
    # remove frist and last several residues as hinges
    updateRegions = []
    for currReg in FinalRegions:
        if trimEnds(values, currReg):
            updateRegions.append(currReg)
    
    # print (updateRegions)
        
    flat = flattenData(updateRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return updateRegions, final_values

# %%
def getHinges_modes3(averageEigVects, mode, hinges, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update2(averageEigVects[:, mode], hinges, thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def getHinges3(averageEigVects, currNumModes, hinges, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update2(averageEigVects[:, i], hinges[i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
# remove first and last hinges for each chain
def filterTwoEnds(hinges, chainLength = [[0, 551], [552, 956]], trimmingLength = 15):
    FilteringIndex = []
    for item in chainLength:
        # print (item)
        FilteringIndex += list(range(item[0], item[0] + trimmingLength))
        FilteringIndex += list(range(item[1] - trimmingLength + 1, item[1] + 1))  
    updateHinges = []
    for item in hinges:
        if item not in FilteringIndex:
            updateHinges.append(item)
    
    return updateHinges

# %%
def writeAllData(path, curr):
    with open(path, 'w') as wf:
        for row in curr:
            for col in row:
                if col == 0.0:
                    wf.write('' + '\t')
                else:
                    wf.write(str(col) + '\t')
            wf.write('\n')

# %% [markdown]
# # Diverse ensemble

# %%
currPDB = '3v7j'
eachChain = 'A'

# pdb_ids, mappings = getDali_info(currPDB, eachChain, cutoff_len=0.7, cutoff_rmsd=1.0, cutoff_Z=10)
averageEigVals, averageEigVects, ids, gnms, averageEigVects = getModes(currPDB, eachChain, length=0.95, rmsd=1, Z=10)
# Out:
# @> Submitted Dali search for PDB "3v7jA".
# @> http://ekhidna2.biocenter.helsinki.fi/barcosel/tmp//3v7jA//
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> Dali results were fetched in 76.1s.
# @> Obtained 1462 PDB chains from Dali for 3v7jA.
# @> 832 PDBs have been filtered out from 1462 Dali hits (remaining: 630).
# @> Retrieving 3v7jA... [  0%]
# # of similar structures is found from Dali 630
# @> 630 PDBs were parsed in 162.78s.
# @> Mapping 7m4iA_ca to the reference... [ 66%] 6s @> WARNING
# the number of residues in the map_dict (318 residues) is inconsistent with Chain A from 7m4iA_ca (317 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5iikA_ca to the reference... [ 69%] 5s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5iioM_ca to the reference... [ 73%] 5s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 6widA_ca to the reference... [ 78%] 4s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5tygA_ca to the reference... [ 79%] 4s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 6wicA_ca to the reference... [ 81%] 4s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 6ipmA_ca to the reference... [ 82%] 3s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5tyeA_ca to the reference... [ 86%] 3s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4i29A_ca to the reference... [ 98%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 6go5A_ca to the reference... [ 99%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Starting iterative superposition:
# @> Step #1: RMSD difference = 3.9822e+00
# @> Step #2: RMSD difference = 3.1418e-02
# @> Step #3: RMSD difference = 7.8868e-04
# @> Step #4: RMSD difference = 2.1016e-05
# @> Iterative superposition completed in 0.59s.
# @> Final superposition to calculate transformations.
# @> Superposition completed in 0.15 seconds.
# @> Ensemble (620 conformations) were built in 17.30s.
# @> WARNING 10 structures cannot be mapped.
# @> WARNING last 17 modes for 309 modes from MaskedGNM 3v7jA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3oguA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9ickA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icwA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icxA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9iclA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7ictA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icvA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7iciA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icmA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icoA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icmA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqpA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7ichA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icqA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7iceA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icqA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7ickA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icgA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icnA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqiA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8iccA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icmA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icuA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icsA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8iczA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icqA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9ictA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icrA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icnA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqnA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icoA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icsA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icfA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9ichA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8ickA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icnA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icvA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqgA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqeA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqbA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icuA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqoA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 3rjeA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqfA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqcA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8iciA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icrA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7iclA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icrA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icfA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icpA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqtA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8iclA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3rjgA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icfA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icsA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3rjjA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icxA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icbA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icpA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqrA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 4gxiA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icgA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icgA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icvA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqkA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8iceA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqlA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icbA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8ichA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4r63A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icuA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqmA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqsA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1tv9A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icpA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9iccA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8ictA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 7s9kA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 13 modes for 309 modes from MaskedGNM 5v1hA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icjA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4r64A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9icyA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icoA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 3iscA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 7s9nA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icyA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 6clyA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 7s9jA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5j0xA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 3isbA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5tzvA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 4tupA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5dbaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 6diaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 5j0rA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4o5cA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 5j0qA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 2i9gA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icjA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqdA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5dbbA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 5j0sA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqqA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 7icjA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5j0oA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 13 modes for 309 modes from MaskedGNM 1zjmA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 5j0tA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5db9A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5hhhA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6n2rA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4ymmA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 5j0wA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5dbcA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 13 modes for 309 modes from MaskedGNM 5j0vA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1tvaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4rq7A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 12 modes for 309 modes from MaskedGNM 4f5nA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqhA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 4p2hA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 8icwA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9iciA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 13 modes for 309 modes from MaskedGNM 5j0uA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4f5rA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 7s9lA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 7mz0A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 10 modes for 309 modes from MaskedGNM 5v1gA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 10 modes for 309 modes from MaskedGNM 5bomA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5db7A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 10 modes for 309 modes from MaskedGNM 6mr8A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1zqjA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 5j0yA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 12 modes for 309 modes from MaskedGNM 4kluA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 12 modes for 309 modes from MaskedGNM 6mr7A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 13 modes for 309 modes from MaskedGNM 4pheA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 5j0pA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 9 modes for 309 modes from MaskedGNM 4m2yA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 6e3rA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5db8A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 7s9mA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4o5eA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4r66A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 2p66A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4turA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4yn4A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 7s9oA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 13 modes for 309 modes from MaskedGNM 4ny8A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 4o9mA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 7mz3A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 11 modes for 309 modes from MaskedGNM 4f5oA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 11 modes for 309 modes from MaskedGNM 4mf2A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 6cubA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 6u2oA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 4nlnA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4pgyA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 4pgqA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 9iceA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 4f5pA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4ymnA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 13 modes for 309 modes from MaskedGNM 4nlzA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5db6A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 12 modes for 309 modes from MaskedGNM 6uokA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 12 modes for 309 modes from MaskedGNM 7rbfA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 11 modes for 309 modes from MaskedGNM 4mfaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4m9gA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 6e3xA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 9 modes for 309 modes from MaskedGNM 4ub2A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 11 modes for 309 modes from MaskedGNM 4mffA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 6pkzA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4ppxA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 6 modes for 309 modes from MaskedGNM 5u8hA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 1huzB_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 6ph5A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 8 modes for 309 modes from MaskedGNM 4mfcA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 7mz4A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1bpxA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 11 modes for 309 modes from MaskedGNM 4nm2A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5hhiA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 7mz8A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 1huoB_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 7 modes for 309 modes from MaskedGNM 4ub1A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3uxpA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4m9hA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 8 modes for 309 modes from MaskedGNM 5u8iA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 6cuaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 1huoA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 4rq1A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 5 modes for 309 modes from MaskedGNM 5u8gA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 9 modes for 309 modes from MaskedGNM 5v1jA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 1huzA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 7rbnA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 6crhA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 6 modes for 309 modes from MaskedGNM 4mf8A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 11 modes for 309 modes from MaskedGNM 5u2tA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 5 modes for 309 modes from MaskedGNM 7rbeA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 1bpzA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 1mq2A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4z6dA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 13 modes for 309 modes from MaskedGNM 5u2sA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 9 modes for 309 modes from MaskedGNM 7rboA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3uxpB_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 11 modes for 309 modes from MaskedGNM 6nktA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4m47A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 7 modes for 309 modes from MaskedGNM 5tbaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 7s9qA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 4phdA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4phaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3c2mA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 4klqA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 13 modes for 309 modes from MaskedGNM 7rbgA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4tusA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 4klsA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 4lvsA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 4m9lA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3isdA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 14 modes for 309 modes from MaskedGNM 2bpgB_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3c2lA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 5vryA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4kltA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 7k97A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3jpqA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5vs0A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 2fmsA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4r65A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3jptA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5vrxA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4rq4A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5wnyA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5v1pA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4jwmA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3mbyA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6ctnA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6ctoA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5wo0A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6ctiA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6cr9A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6cr3A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3jppA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 4rq8A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4docA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 6u6bA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6cpqA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5vezA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3tfrA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3tfsA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4ubbA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4doaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4do9A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3jpoA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6cr8A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4dobA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6cr4A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4ubcA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4rt2A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3jpnA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5v1oA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6nl0A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6nkzA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5ugoA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 2pxiA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6w2mA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4rq3A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 2isoA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5j2cA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4ymoA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4ub4A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6uolA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4uayA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5j2gA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6ctkA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6uokF_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5v1rA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5j2eA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 6 modes for 309 modes from MaskedGNM 4gxkA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3jpsA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 12 modes for 309 modes from MaskedGNM 5vrzA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6nksA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 4rq2A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6cr6A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5vs3A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5v1iA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6e3wA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4rt3A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6nkxA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6uomA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 17 modes for 309 modes from MaskedGNM 5vs4A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4uawA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5j2fA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5j29A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 7mz2A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6ctlA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3jprA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 4uazA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5j2dA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5j2jA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6nkyA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5eozA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5j2hA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6nkuA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3rjiA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 2ispA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 6crcA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 2fmqA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4tuqA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3gdxA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6cr5A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 15 modes for 309 modes from MaskedGNM 5vrwA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6e3vA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 6bemA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 5vs1A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 3rjkA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4rpyA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4rq5A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 16 modes for 309 modes from MaskedGNM 4klfA_ca reduced has been discarded because at least one conformation has only 309 modes
# ...
# @> WARNING last 2 modes for 309 modes from MaskedGNM 4k4hI_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 7m0dA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 3c5gB_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 3c5gA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 2bcrA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 3hx0F_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 4k4hE_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 3hx0A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 4k4gE_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 7m0dB_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 4k4hM_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 4k4iE_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 4k4iM_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 5cwrA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 4k4gM_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 3hx0P_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 7ktjA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 4lzdA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 7ksyA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 7ktkA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 6ipgA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6vf3A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 6aehA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 5tyuA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6vfbA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 7co8A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 7ktcA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 7ktmA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 7kteA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6vfcA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6iphA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 7co6A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 6ak6A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6aecA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6vf8A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 5txzA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 7kswA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 6vf1A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 5vzaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 4yd1A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6vf5A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 6p1tA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 6ipiA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 5vzgA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 5vz7A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 6akhA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6p1rA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 5tywA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 5tycA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 5tyfA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 7co9A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 7ktaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6vfaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6p1oA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 5vzeA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 5vz8A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6ipeA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 7kt1A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 5tybA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 6ak9A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 7coaA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6ak5A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 6p1pA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 4m04A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 5vzcA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 7kstA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 5vzhA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 7codA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 5vz9A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 5vzbA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 7kssA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 7kt0A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 6p1wA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 5txxA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 5vziA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 6ipkA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 2ihmA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 2ihmB_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 6go3A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 4qzhA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 4qz8A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 4qzgA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 6go7A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 5 modes for 309 modes from MaskedGNM 4qzcA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 4qzeA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4i2fA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 4qzfA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 6go5B_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4qziA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4i2gA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 5 modes for 309 modes from MaskedGNM 4i2cA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 5 modes for 309 modes from MaskedGNM 4i2bA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 4qzdA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 2 modes for 309 modes from MaskedGNM 5d46A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 4i28A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4iquA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 5d4bB_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4qz9A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4iqwA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 4i2hA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 5d49A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 4i2eA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 4i2jA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 4iqtA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 5 modes for 309 modes from MaskedGNM 4i2aA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 1jmsA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 4iqvA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 6go4A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 1 modes for 309 modes from MaskedGNM 1kdhA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 3 modes for 309 modes from MaskedGNM 6go6A_ca reduced has been discarded because at least one conformation has only 309 modes
# @> WARNING last 4 modes for 309 modes from MaskedGNM 1kejA_ca reduced has been discarded because at least one conformation has only 309 modes
# @> all GNM modes were calculated for each of the 620 conformations in 42.96s.
# @> 309 modes across 620 modesets were matched in 9.53s.

# %%
writeIDs('./POLB_3v7j', ids)

# %%
currNumModes = getModesGivenThreshold(averageEigVals, 0.33)
currNumModes
# Out:
# 1

# %%
binding = [19,20,21,22,23,24,26,72,76,78,79,82,83,96,98,99,100,101,172,173,175,176,177,178,181,252,253,255,256,257,258,259,260,321,322,323,324,430,431,432,433,434]

binding = [x - 3 for x in binding]

# %%
Hinges_2 = getHinges(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges(averageEigVects, 3, 20)

Hinges_4 = getHinges(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges(averageEigVects, 3, 15)

# %%
protein_length = 447

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 42
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 38 5 0.2787847912334618
# # of hinge sites for first 3 modes, overlap, hyper score 38 5 0.2787847912334618
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 48 6 0.2881632604181592
# # of hinge sites for first 3 modes, overlap, hyper score 48 6 0.2881632604181592

# %%
Badren = parsePDB('1ea1', subset='calpha')
calphas = Badren.select('calpha and chain A')
gnm = GNM('b-adren')
gnm.buildKirchhoff(calphas)
gnm.calcModes(n_modes=None)
Hinge0 = calcHinges(gnm[0])
Hinge1 = calcHinges(gnm[1])
Hinge2 = calcHinges(gnm[2])
# Out:
# @> Connecting wwPDB FTP server RCSB PDB (USA).
# @> 1ea1 downloaded (1ea1.pdb.gz)
# @> PDB download via FTP completed (1 downloaded, 0 failed).
# @> 447 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> Secondary structures were assigned to 308 residues.
# @> Kirchhoff was built in 0.02s.
# @> 446 modes were calculated in 0.08s.

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 42
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 83 10 0.23365896982905376
# # of hinge sites for 3 modes, overlap, hyper score 83 10 0.23365896982905376
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 91 11 0.21258253478128197
# # of hinge sites for 3 modes, overlap, hyper score 91 11 0.21258253478128197

# %% [markdown]
# ## writeResults

# %%
# write MSFs
averageEigVals
modes = [0, 1]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)
len(MSF)
# Out:
# 578

# %%
values_array = np.array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = np.argsort(values_array)

if not os.path.exists('./Data'):
    os.mkdir('./Data')

writeNumbers('./Data/RMSF_minimum.txt', indices)

# %%
curr = zeros((len(MSF), 7))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]

for each in binding:
    curr[each, 0] = each

# %%
modes = [0, 1]
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    currList = sort(list(set(list(currHinge) + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
curr = list(curr)
def writeAllData(path, curr):
    with open(path, 'w') as wf:
        for row in curr:
            for col in row:
                if col == 0.0:
                    wf.write('' + '\t')
                else:
                    wf.write(str(col) + '\t')
            wf.write('\n')
                
writeAllData('./Data/ALB_Method1.txt', curr)

# %% [markdown]
# ## Method 2

# %%
binding = [149,178,179,180,183,188,189,190,192,256,258,271,272,273,295]

binding = [x - 9 for x in binding]

# %%
Hinges_2 = getHinges2(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges2(averageEigVects, 3, 20)

Hinges_4 = getHinges2(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges2(averageEigVects, 3, 15)

# %%
sort(Hinges_5)
# Out:
# array([ 11,  12,  13,  14,  15,  24,  25,  28,  29,  75,  76,  77,  78,
#        132, 133, 134, 136, 137, 138, 139, 168, 169, 175, 176, 184, 185,
#        186, 188, 196, 197, 250, 251, 254, 255, 256, 257, 262, 263, 264,
#        265])

# %%
Hinges_2 = filterTwoEnds(Hinges_2, [[0, 311]], 15)
Hinges_3 = filterTwoEnds(Hinges_3, [[0, 311]], 15)
Hinges_4 = filterTwoEnds(Hinges_4, [[0, 311]], 15)
Hinges_5 = filterTwoEnds(Hinges_5, [[0, 311]], 15)

# %%
protein_length = 326

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 15
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 3 0 1
# # of hinge sites for first 3 modes, overlap, hyper score 38 4 0.08331108134624321
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 3 0 1
# # of hinge sites for first 3 modes, overlap, hyper score 40 4 0.09736098413583938

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 42
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 105 14 0.08539804066791223
# # of hinge sites for 3 modes, overlap, hyper score 105 14 0.08539804066791223
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 106 14 0.09144399268404058
# # of hinge sites for 3 modes, overlap, hyper score 106 14 0.09144399268404058

# %% [markdown]
# ## writeResults

# %%
# write MSFs
averageEigVals
modes = [0, 1]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)

# %%
curr = zeros((len(MSF), 7))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]

for each in binding:
    curr[each, 0] = each

# %%
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=15)
    currList = sort(list(set(list(currHinge) + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
writeAllData('./Data/ALB_Method2.txt', curr)

# %% [markdown]
# # method3

# %%
Hinges_2 = getHinges3(averageEigVects, currNumModes, [Hinge0, Hinge1, Hinge2], 20)
Hinges_3 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 20)

Hinges_4 = getHinges3(averageEigVects, currNumModes, [Hinge0, Hinge1, Hinge2], 15)
Hinges_5 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 15)

# %%
Hinges_2 = getHinges3(averageEigVects, currNumModes, [[], [], []], 20)
Hinges_3 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 20)

Hinges_4 = getHinges3(averageEigVects, currNumModes, [[], [], []], 15)
Hinges_5 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 15)

# %%
Hinges_2 = filterTwoEnds(Hinges_2, [[0, 446]], 15)
Hinges_3 = filterTwoEnds(Hinges_3, [[0, 446]], 15)
Hinges_4 = filterTwoEnds(Hinges_4, [[0, 446]], 15)
Hinges_5 = filterTwoEnds(Hinges_5, [[0, 446]], 15)

# %%
protein_length = 447

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 42
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 60 12 0.005044416216170355
# # of hinge sites for first 3 modes, overlap, hyper score 60 12 0.005044416216170355
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 60 12 0.005044416216170355
# # of hinge sites for first 3 modes, overlap, hyper score 60 12 0.005044416216170355

# %% [markdown]
# ## write data

# %%
# write MSFs
# averageEigVals
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)

# %%
values_array = np.array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = np.argsort(values_array)

if not os.path.exists('./Data'):
    os.mkdir('./Data')

writeNumbers('./Data/RMSF_minimum_diverse.txt', indices)

# %%
includeModes = 3
size = includeModes * 2 + 1 + 2 

curr = zeros((len(MSF), size))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]
curr[:, 5] = averageEigVects[:, 2]

for each in binding:
    curr[each, 0] = each

# %%
row, col = averageEigVects.shape
hinges = [Hinge0, Hinge1, Hinge2]
for mode in modes:
    currHinge = getHinges_modes3(averageEigVects, mode, hinges[mode], bandWidth=15)
    currHinge = filterTwoEnds(currHinge, [[0, 446]], 15)
    
    currList = sort(list(set(list(currHinge)))) # + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

writeAllData('./Data/CYP51_Method2_diverse.txt', curr)

# %% [markdown]
# # Write Modes

# %%
# write MSFs
# averageEigVals
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / EigVals[mode]
    MSF.append(currMSF)

# %%
writeModesAsBfactors(0, eigenVects)
writeModesAsBfactors(1, eigenVects)

# %% [markdown]
# # Plot graphs

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import math
import numpy as np

def format_significant(value, pos):
    if abs(value) <= 0.01:
        return "0.00"
    else:
        order_of_magnitude = math.floor(math.log10(abs(value)))
        round_digits = -order_of_magnitude + 1
        formatted_number = round(value, round_digits)
        str_format = "{:." + str(round_digits) + "f}"
        return str_format.format(formatted_number)

# %%
def plotSingleGraph(mode, averageEigVects, gnms, binding, Hinge):
    fig, ax = plt.subplots(figsize=(15, 10))   # Adjust size as per requirement
    
    plt.sca(ax)  # Set current axis to 'ax'
    
    # Increase font sizes
    plt.rc('xtick', labelsize=40)
    plt.rc('ytick', labelsize=50)
    plt.rcParams.update({'font.size': 50})

    # plot mode of motion
    showSignatureMode(gnms[:, mode], linewidth=3)

    # Hinges within band
    # method1
    # currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    # method2
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=20)
    
    
    HingeY = [averageEigVects[item, mode] for item in currHinge]
    print ('Hinge residue with wide bands', currHinge)
    plt.plot(currHinge, HingeY, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # extraHinges for local loops
    updateHinge = [item for item in Hinge if item not in currHinge]
    HingeY_local = [averageEigVects[item, mode] for item in updateHinge]
    print ('local loop motion', updateHinge)
    plt.plot(updateHinge, HingeY_local, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # plot binding sites
    bindingY = [averageEigVects[item, mode] for item in binding]
    plt.plot(binding, bindingY, 'r*', markersize=18)
    print ('current bindings are', binding)
    plt.title('Mode ' + str(mode + 1), fontweight="bold")

    # plot overlaps
    allHinge = updateHinge + currHinge
    overlaps = [item for item in binding if item in allHinge]
    overlapsY = [averageEigVects[item, mode] for item in overlaps]
    print ('current hits are', overlaps)
    plt.plot(overlaps, overlapsY, 'mD', markersize=18)

    print('# of overlaps finding from current mode is', len(overlaps))
    
    # Set y-ticks to have 4-5 values with equal spacing
    y_min, y_max = ax.get_ylim()
    ax.set_yticks(np.linspace(y_min * 0.9, y_max, 5))  # Adjust the number 5 if you want a different number of y-ticks
    ax.yaxis.set_major_formatter(FuncFormatter(format_significant)) 
    
    plt.tight_layout()
    plt.savefig('./MAPK14_method2_mode' + str(mode + 1) + '.png', dpi=500)

# %%
modes = 0 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, Hinge0)
# Out:
# Hinge residue with wide bands [333, 334, 335]
# local loop motion [338, 341, 344, 371]
# current bindings are [385, 386, 387, 523, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 408, 536, 538, 539, 542, 424, 425, 427, 428, 429, 432, 433, 443, 444, 445, 318, 447, 448, 321, 322, 451, 325, 203, 204, 207, 208, 341, 344, 345, 474, 475, 476, 477, 479, 480, 482, 483, 484, 381, 382, 383]
# current hits are [341, 344]
# # of overlaps finding from current mode is 2

# %%
modes = 1 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, Hinge1)
# Out:
# Hinge residue with wide bands [396, 397, 398, 399, 423, 424, 192, 193, 454, 455, 456, 457, 465, 466, 467, 486, 487, 238, 239, 250, 251]
# local loop motion [195, 237, 279, 402, 421, 459, 460]
# current bindings are [385, 386, 387, 523, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 408, 536, 538, 539, 542, 424, 425, 427, 428, 429, 432, 433, 443, 444, 445, 318, 447, 448, 321, 322, 451, 325, 203, 204, 207, 208, 341, 344, 345, 474, 475, 476, 477, 479, 480, 482, 483, 484, 381, 382, 383]
# current hits are [396, 397, 398, 399, 402, 424]
# # of overlaps finding from current mode is 6

# %%
def plotSingleGraph_method3(mode, averageEigVects, gnms, binding, Hinge):
    fig, ax = plt.subplots(figsize=(15, 10))   # Adjust size as per requirement
    
    plt.sca(ax)  # Set current axis to 'ax'
    
    # Increase font sizes
    plt.rc('xtick', labelsize=40)
    plt.rc('ytick', labelsize=50)
    plt.rcParams.update({'font.size': 50})

    # plot mode of motion
    showSignatureMode(gnms[:, mode], linewidth=3)

    # Hinges within band
    # method3
    currHinge = getHinges_modes3(averageEigVects, mode, Hinge, bandWidth = 15)
    currHinge = filterTwoEnds(currHinge, [[0, 446]], 15)
    
    HingeY = [averageEigVects[item, mode] for item in currHinge]
    print ('Hinge residue with wide bands', currHinge)
    plt.plot(currHinge, HingeY, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # extraHinges for local loops
    # updateHinge = [item for item in Hinge if item not in currHinge]
    # HingeY_local = [averageEigVects[item, mode] for item in updateHinge]
    # print ('local loop motion', updateHinge)
    # plt.plot(updateHinge, HingeY_local, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # plot binding sites
    bindingY = [averageEigVects[item, mode] for item in binding]
    plt.plot(binding, bindingY, 'r*', markersize=18)
    print ('current bindings are', binding)
    plt.title('Mode ' + str(mode + 1), fontweight="bold")

    # plot overlaps
    allHinge = currHinge
    overlaps = [item for item in binding if item in allHinge]
    overlapsY = [averageEigVects[item, mode] for item in overlaps]
    print ('current hits are', overlaps)
    plt.plot(overlaps, overlapsY, 'mD', markersize=18)

    print('# of overlaps finding from current mode is', len(overlaps))
    
    # Set y-ticks to have 4-5 values with equal spacing
    y_min, y_max = ax.get_ylim()
    ax.set_yticks(np.linspace(y_min * 0.9, y_max, 5))  # Adjust the number 5 if you want a different number of y-ticks
    ax.yaxis.set_major_formatter(FuncFormatter(format_significant)) 
    
    plt.tight_layout()
    plt.savefig('./CYP51_diverse_method2_mode' + str(mode + 1) + '.png', dpi=500)

# %%
modes = 0 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [391, 392, 423, 74, 75, 424, 175, 176, 306, 307, 180, 308]
# current bindings are [16, 17, 18, 19, 20, 21, 23, 69, 73, 75, 76, 79, 80, 93, 95, 96, 97, 98, 169, 170, 172, 173, 174, 175, 178, 249, 250, 252, 253, 254, 255, 256, 257, 318, 319, 320, 321, 427, 428, 429, 430, 431]
# current hits are [75, 175]
# # of overlaps finding from current mode is 2

# %%
modes = 1 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [320, 384, 385, 102, 103, 392, 393, 428, 429, 145, 147, 148, 345, 346, 253, 254, 319]
# current bindings are [16, 17, 18, 19, 20, 21, 23, 69, 73, 75, 76, 79, 80, 93, 95, 96, 97, 98, 169, 170, 172, 173, 174, 175, 178, 249, 250, 252, 253, 254, 255, 256, 257, 318, 319, 320, 321, 427, 428, 429, 430, 431]
# current hits are [253, 254, 319, 320, 428, 429]
# # of overlaps finding from current mode is 6

# %%
modes = 2 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [265, 266, 144, 145, 146, 273, 274, 404, 405, 407, 24, 25, 26, 155, 156, 39, 40, 46, 47, 318, 319, 68, 69, 201, 202, 89, 90, 96, 97, 115, 116, 245, 246, 247]
# current bindings are [16, 17, 18, 19, 20, 21, 23, 69, 73, 75, 76, 79, 80, 93, 95, 96, 97, 98, 169, 170, 172, 173, 174, 175, 178, 249, 250, 252, 253, 254, 255, 256, 257, 318, 319, 320, 321, 427, 428, 429, 430, 431]
# current hits are [69, 96, 97, 318, 319]
# # of overlaps finding from current mode is 5

# %% [markdown]
# # Write Modes

# %%
len(averageEigVects[:, 0])
# Out:
# 447

# %%
mode = 2

# %%
residue = []
new_b_factor = []

for item in averageEigVects[:, mode]:
    new_b_factor.append(item)

# %%
resiIndex = [x for x in range(3, 450)]
chain = ['A' for x in range(3, 450)]

# %%
with open('./structure_demo/CYP51_b_diverse_mode' + str(mode + 1) + '.txt', 'w') as wf:
    for i in range(len(resiIndex)):
        # print (chain[i])
        wf.write(chain[i] + ', ' + str(resiIndex[i]) + ', ' + str(new_b_factor[i]) + '\n')
