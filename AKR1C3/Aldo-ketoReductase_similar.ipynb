# %%
# -*- coding: utf-8 -*-
"""This module defines functions for Dali searching Protein Data Bank."""

import re
import numpy as np
from prody.atomic import Atomic, AtomGroup, AtomMap
from prody.proteins.pdbfile import _getPDBid
from prody.measure import getRMSD, getTransformation
from prody.utilities import checkCoords, checkWeights, createStringIO
from prody import LOGGER, PY3K
from prody import parsePDB, writePDBStream
# if PY3K:
    # import urllib.parse as urllib
    # import urllib.request as urllib2
# else:
    # import urllib
    # import urllib2
from prody.ensemble import Ensemble
from prody.ensemble import PDBEnsemble
import os

__all__ = ['DaliRecord', 'searchDali', 
           'daliFilterMultimer', 'daliFilterMultimers']

def searchDal(pdb, chain=None, subset='fullPDB', daliURL=None, **kwargs):
    """Search Dali server with input of PDB ID (or local PDB file) and chain ID.
    Dali server: http://ekhidna2.biocenter.helsinki.fi/dali/
    
    :arg pdb: PDB code or local PDB file for the protein to be searched

    :arg chain: chain identifier (only one chain can be assigned for PDB)
    :type chain: str

    :arg subset: fullPDB, PDB25, PDB50, PDB90
    :type subset: str
    """
    
    import requests
    
    LOGGER.timeit('_dali')
    # timeout = 120
    timeout = kwargs.pop('timeout', 120)
    
    if daliURL is None:
        daliURL = "http://ekhidna2.biocenter.helsinki.fi/cgi-bin/sans/dump.cgi"
    
    if isinstance(pdb, Atomic):
        atoms = pdb
        chain_set = set(atoms.getChids())
        if chain and not chain in chain_set:
            raise ValueError('input structure (%s) does not have chain %s'%(atoms.getTitle(), chain))
        
        if len(chain_set) > 1:
            if not chain:
                raise TypeError('the structure (%s) contains more than one chain, therefore a chain identifier '
                                'needs to be specified'%pdb.getTitle())
            atoms = atoms.select('chain '+chain)
        else:
            chain = chain_set.pop()
            
        stream = createStringIO()
        writePDBStream(stream, atoms)
        data = stream.getvalue()
        stream.close()
        files = {"file1" : data}

        pdbId = atoms.getTitle()
        pdb_chain = ''
        dali_title = 'Title_'+pdbId+chain
    elif isinstance(pdb, str):
        if os.path.isfile(pdb):
            atoms = parsePDB(pdb)
            chain_set = set(atoms.getChids())
            # pdbId = "s001"
            filename = os.path.basename(pdb)
            filename, ext = os.path.splitext(filename)
            if ext.lower() == '.gz':
                filename2, ext2 = os.path.splitext(filename)
                if ext2.lower() == '.pdb':
                    filename = filename2
            pdbId = filename
            if chain and not chain in chain_set:
                raise ValueError('input PDB file does not have chain ' + chain)
            
            if len(chain_set) > 1:
                if not chain:
                    raise TypeError('PDB file (%s) contains more than one chain, therefore a chain identifier '
                                    'needs to be specified'%pdb)
                atoms = atoms.select('chain '+chain)
                #local_temp_pdb = pdbId+chain+'.pdb'
                #local_temp_pdb = 's001'+chain+'.pdb'
                stream = createStringIO()
                writePDBStream(stream, atoms)
                data = stream.getvalue()
                stream.close()
            else:
                data = open(pdb, "rb")
                chain = chain_set.pop()
            files = {"file1" : data}
            # case: multiple chains.             apply fetch ? multiple times?
            pdb_chain = ''
            dali_title = 'Title_' + pdbId + chain
        else:
            pdbId, ch = _getPDBid(pdb)
            if not chain:
                chain = ch
            if not chain:
                raise TypeError('a chain identifier is needed for the search')
            pdb_chain = pdbId + chain
            dali_title = 'Title_' + pdb_chain
            files = ''
    parameters = { 'cd1' : pdb_chain, 'method': 'search', 'title': dali_title, 'address': '' }
    # enc_params = urllib.urlencode(parameters).encode('utf-8')
    # request = urllib2.Request(daliURL, enc_params)
    request = requests.post(daliURL, parameters, files=files)
    try_error = 3
    while try_error >= 0:
        try:
            # url = urllib2.urlopen(request).url
            url = request.url
            break
        except:
            try_error -= 1
            if try_error >= 0:
                LOGGER.sleep(2, '. Connection error happened. Trying to reconnect...')
                continue
            else:
                # url = urllib2.urlopen(request).url
                url = request.url
                break
    if url.split('.')[-1].lower() in ['html', 'php']:
        # print('test -1: '+url)
        url = url.replace(url.split('/')[-1], '')
    LOGGER.debug('Submitted Dali search for PDB "{0}{1}".'.format(pdbId, chain))
    LOGGER.info(url)
    LOGGER.clear()
    
    return DaliRecor(url, pdbId, chain, subset=subset, timeout=timeout, **kwargs)
    

class DaliRecor(object):

    """A class to store results from Dali PDB search."""

    def __init__(self, url, pdbId, chain, subset='fullPDB', localFile=False, **kwargs):
        """Instantiate a DaliRecord object instance.

        :arg url: url of Dali results page or local dali results file
        :arg pdbId: PDB code for searched protein
        :arg chain: chain identifier (only one chain can be assigned for PDB)
        :arg subset: fullPDB, PDB25, PDB50, PDB90. Ignored if localFile=True (url is a local file)
        :arg localFile: whether provided url is a path for a local dali results file
        """

        self._url = url
        self._pdbId = pdbId
        self._chain = chain
        subset = subset.upper()
        if subset == "FULLPDB" or subset not in ["PDB25", "PDB50", "PDB90"]:
            self._subset = ""
        else:
            self._subset = "-"+subset[3:]
        timeout = kwargs.pop('timeout', 120)

        self._title = pdbId + '-' + chain
        self._alignPDB = None
        self._filterDict = None
        self._max_index = None
        self.fetch(self._url, localFile=localFile, timeout=timeout, **kwargs)

    def fetch(self, url=None, localFile=False, **kwargs):
        """Get Dali record from url or file.

        :arg url: url of Dali results page or local dali results file
            If None then the url already associated with the DaliRecord object is used.
        :type url: str

        :arg localFile: whether provided url is a path for a local dali results file
        :type localFile: bool

        :arg timeout: amount of time until the query times out in seconds
            default value is 120
        :type timeout: int

        :arg localfolder: folder in which to find the local file
            default is the current folder
        :type localfolder: str
        """
        if localFile:
            dali_file = open(url, 'r')
            data = dali_file.read()
            dali_file.close()
        else:
            import requests
            
            if url == None:
                url = self._url
            
            sleep = 2
            timeout = kwargs.pop('timeout', 120)
            LOGGER.timeit('_dali')
            log_message = ''
            try_error = 3
            while True:
                LOGGER.write('Connecting to Dali for search results...')
                LOGGER.clear()
                try:
                    # html = urllib2.urlopen(url).read()
                    html = requests.get(url).content
                except:
                    try_error -= 1
                    if try_error >= 0:
                        LOGGER.sleep(2, '. Connection error happened. Trying to reconnect...')
                        continue
                    else:
                        # html = urllib2.urlopen(url).read()
                        html = requests.get(url).content
                if PY3K:
                    html = html.decode()
                if html.find('Status: Queued') > -1:
                    log_message = '(Dali search is queued)...'
                elif html.find('Status: Running') > -1:
                    log_message = '(Dali search is running)...'
                elif html.find('Your job') == -1 and html.find('.txt') > -1:
                    break
                elif html.find('ERROR:') > -1:
                    LOGGER.warn(': Dali search reported an ERROR!')
                    self.isSuccess = False
                    return False
                sleep = 20 if int(sleep * 1.5) >= 20 else int(sleep * 1.5)
                if LOGGER.timing('_dali') > timeout:
                    LOGGER.warn(': Dali search has timed out. \nThe results can be obtained later using the fetch() method.')
                    self.isSuccess = False
                    return False
                LOGGER.sleep(int(sleep), 'to reconnect to Dali '+log_message)
                LOGGER.clear()
            LOGGER.clear()
            LOGGER.report('Dali results were fetched in %.1fs.', '_dali')
            lines = html.strip().split('\n')
            file_name = re.search('=.+-90\\.txt', html).group()[1:]
            file_name = file_name[:-7]
            # LOGGER.info(url+file_name+self._subset+'.txt')
            # data = urllib2.urlopen(url+file_name+self._subset+'.txt').read()
            data = requests.get(url+file_name+self._subset+'.txt').content
            if PY3K:
                data = data.decode()
            localfolder = kwargs.pop('localfolder', '.')

            if file_name.lower().startswith('s001'):
                temp_name = self._pdbId + self._chain
            else:
                temp_name = file_name
            temp_name += self._subset + '_dali.txt'
            if localfolder != '.' and not os.path.exists(localfolder):
                os.mkdir(localfolder)
            with open(localfolder+os.sep+temp_name, "w") as file_temp: file_temp.write(html + '\n' + url+file_name+self._subset+'.txt' + '\n' + data)
            # with open(temp_name, "a+") as file_temp: file_temp.write(url+file_name + '\n' + data)
        data_list = data.strip().split('# ')
        # No:  Chain   Z    rmsd lali nres  %id PDB  Description -> data_list[3]
        # Structural equivalences -> data_list[4]
        # Translation-rotation matrices -> data_list[5]
        map_temp_dict = dict()
        lines = data_list[4].strip().split('\n')
        self._lines_4 = lines
        mapping_temp = np.genfromtxt(lines[1:], delimiter = (4,1,14,6,2,4,4,5,2,4,4,3,5,4,3,5,6,3,5,4,3,5,28), 
                                     usecols = [0,3,5,7,9,12,15,15,18,21], dtype='|i4')
        # [0,3,5,7,9,12,15,15,18,21] -> [index, residue_a, residue_b, residue_i_a, residue_i_b, resid_a, resid_b, resid_i_a, resid_i_b]
        for map_i in mapping_temp:
            if not map_i[0] in map_temp_dict:
                map_temp_dict[map_i[0]] = [[map_i[1], map_i[2], map_i[3], map_i[4]]]
            else:
                map_temp_dict[map_i[0]].append([map_i[1], map_i[2], map_i[3], map_i[4]])
        self._max_index = max(mapping_temp[:,2])
        self._mapping = map_temp_dict
        self._data = data_list[3]
        lines = data_list[3].strip().split('\n')
        # daliInfo = np.genfromtxt(lines[1:], delimiter = (4,3,6,5,5,5,6,5,57), usecols = [0,2,3,4,5,6,7,8], 
                                # dtype=[('id', '<i4'), ('pdb_chain', '|S6'), ('Z', '<f4'), ('rmsd', '<f4'), 
                                # ('len_align', '<i4'), ('nres', '<i4'), ('identity', '<i4'), ('title', '|S70')])
        daliInfo = np.genfromtxt(lines[1:], delimiter = (4,3,6,5,5,5,6,5,57), usecols = [0,2,3,4,5,6,7,8], 
                                dtype=[('id', '<i4'), ('pdb_chain', '|U6'), ('Z', '<f4'), ('rmsd', '<f4'), 
                                ('len_align', '<i4'), ('nres', '<i4'), ('identity', '<i4'), ('title', '|U70')])
        if daliInfo.ndim == 0:
            daliInfo = np.array([daliInfo])
        pdbListAll = []
        self._daliInfo = daliInfo
        dali_temp_dict = dict()
        for temp in self._daliInfo:
            temp_dict = dict()
            pdb_chain = temp[1].strip()[0:6]
            # U6 and U70 were used as the dtype for np.genfromtext -> unicode string were used in daliInfo 
            # if PY3K:
                # pdb_chain = pdb_chain.decode()
            pdb_chain = str(pdb_chain)
            temp_dict['pdbId'] = pdbid = pdb_chain[0:4].lower()
            temp_dict['chainId'] = chid = pdb_chain[5:6]
            temp_dict['pdb_chain'] = pdb_chain = pdbid + chid
            temp_dict['Z'] = temp[2]
            temp_dict['rmsd'] = temp[3]
            temp_dict['len_align'] = temp[4]
            temp_dict['nres'] = temp[5]
            temp_dict['identity'] = temp[6]
            temp_dict['mapping'] = (np.array(map_temp_dict[temp[0]])-1).tolist()
            temp_dict['map_ref'] = [x for map_i in (np.array(map_temp_dict[temp[0]])-1).tolist() for x in range(map_i[0], map_i[1]+1)]
            temp_dict['map_sel'] = [x for map_i in (np.array(map_temp_dict[temp[0]])-1).tolist() for x in range(map_i[2], map_i[3]+1)]
            dali_temp_dict[pdb_chain] = temp_dict
            pdbListAll.append(pdb_chain)
        self._pdbListAll = tuple(pdbListAll)
        self._pdbList = self._pdbListAll
        self._alignPDB = dali_temp_dict
        LOGGER.info('Obtained ' + str(len(pdbListAll)) + ' PDB chains from Dali for '+self._pdbId+self._chain+'.')
        self.isSuccess = True
        return True
        
    def getPDBs(self, filtered=True):
        """Returns PDB list (filters may be applied)"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')
        
        if filtered:
            return self._pdbList
        return self._pdbListAll
        
    def getHits(self):
        """Returns the dictionary associated with the DaliRecord"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')

        return self._alignPDB
        
    def getFilterList(self):
        """Returns a list of PDB IDs and chains for the entries that were filtered out"""
        
        filterDict = self._filterDict
        if filterDict is None:
            raise ValueError('You cannot obtain the list of filtered out entries before doing any filtering.')

        temp_str = ', '.join([str(len(filterDict['len'])), str(len(filterDict['rmsd'])), 
                            str(len(filterDict['Z'])), str(len(filterDict['identity']))])
        LOGGER.info('Filtered out [' + temp_str + '] for [length, RMSD, Z, identity]')
        return self._filterList

    
    def getMapping(self, key):
        """Get mapping for a particular entry in the DaliRecord"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')
            return None
        
        try:
            info = self._alignPDB[key]
            mapping = [info['map_ref'], info['map_sel']]
        except KeyError:
            return None
        return mapping

    def getMappings(self):
        """Get all mappings in the DaliRecord"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')
            return None

        map_dict = {}
        for key in self._alignPDB:
            info = self._alignPDB[key]
            mapping = [info['map_ref'], info['map_sel']]
            map_dict[key] = mapping
        return map_dict

    mappings = property(getMappings)

    def filter(self, cutoff_len=None, cutoff_rmsd=None, cutoff_Z=None, cutoff_identity=None):
        """Filters out PDBs from the PDBList and returns the PDB list.
        PDBs that satisfy any of the following criterion will be filtered out.
        (1) Length of aligned residues < cutoff_len (must be an integer or a float between 0 and 1);
        (2) RMSD < cutoff_rmsd (must be a positive number);
        (3) Z score < cutoff_Z (must be a positive number);
        (4) Identity > cutoff_identity (must be an integer or a float between 0 and 1).
        """
        if self._max_index is None:
            LOGGER.warn('DaliRecord has no data. Please use the fetch() method.')
            return None

        if cutoff_len == None:
            # cutoff_len = int(0.8*self._max_index)
            cutoff_len = 0.00000001
        elif not isinstance(cutoff_len, (float, int)):
            raise TypeError('cutoff_len must be a float or an integer')
        elif cutoff_len <= 1 and cutoff_len > 0:
            cutoff_len = int(cutoff_len*self._max_index)
        elif cutoff_len <= self._max_index and cutoff_len > 0:
            cutoff_len = int(cutoff_len)
        else:
            raise ValueError('cutoff_len must be a float between 0 and 1, or an int not greater than the max length')
            
        if cutoff_rmsd == None:
            cutoff_rmsd = 1000
        elif not isinstance(cutoff_rmsd, (float, int)):
            raise TypeError('cutoff_rmsd must be a float or an integer')
        elif cutoff_rmsd >= 0:
            cutoff_rmsd = float(cutoff_rmsd)
        else:
            raise ValueError('cutoff_rmsd must be a number not less than 0')
            
        if cutoff_Z == None:
            cutoff_Z = 0
        elif not isinstance(cutoff_Z, (float, int)):
            raise TypeError('cutoff_Z must be a float or an integer')
        elif cutoff_Z >= 0:
            cutoff_Z = float(cutoff_Z)
        else:
            raise ValueError('cutoff_Z must be a number not less than 0')
            
        if cutoff_identity == None or cutoff_identity == 0:
            cutoff_identity = 0
        elif not isinstance(cutoff_identity, (float, int)):
            raise TypeError('cutoff_identity must be a float or an integer')
        elif cutoff_identity <= 1 and cutoff_identity > 0:
            cutoff_identity = float(cutoff_identity*100)
        elif cutoff_identity <= 100 and cutoff_identity > 0:
            cutoff_identity = float(cutoff_identity)
        else:
            raise ValueError('cutoff_identity must be a float between 0 and 1, or a number between 0 and 100')
            
        # debug:
        # print('cutoff_len: ' + str(cutoff_len) + ', ' + 'cutoff_rmsd: ' + str(cutoff_rmsd) + ', ' + 'cutoff_Z: ' + str(cutoff_Z) + ', ' + 'cutoff_identity: ' + str(cutoff_identity))
        
        daliInfo = self._alignPDB
        if daliInfo is None:
            raise ValueError("Dali Record does not have any data yet. Please run fetch.")

        pdbListAll = self._pdbListAll
        missing_ind_dict = dict()
        ref_indices_set = set(range(self._max_index))
        filterListLen = []
        filterListRMSD = []
        filterListZ = []
        filterListIdentity = []
        
        RMSDs = []
        
        # keep the first PDB (query PDB)
        for pdb_chain in pdbListAll[1:]:
            temp_dict = daliInfo[pdb_chain]
            # print ('currRMSD', temp_dict['rmsd'])
            # filter: len_align, identity, rmsd, Z
            RMSDs.append(temp_dict['rmsd'])
            if temp_dict['len_align'] < cutoff_len:
                # print('Filter out ' + pdb_chain + ', len_align: ' + str(temp_dict['len_align']))
                filterListLen.append(pdb_chain)
                continue
            if temp_dict['rmsd'] > cutoff_rmsd:
                # print('Filter out ' + pdb_chain + ', rmsd: ' + str(temp_dict['rmsd']))
                filterListRMSD.append(pdb_chain)
                # print ('currRMSD', temp_dict['rmsd'])
                # print(pdb_chain)
                continue
            if temp_dict['Z'] < cutoff_Z:
                # print('Filter out ' + pdb_chain + ', Z: ' + str(temp_dict['Z']))
                filterListZ.append(pdb_chain)
                continue
            if temp_dict['identity'] < cutoff_identity:
                # print('Filter out ' + pdb_chain + ', identity: ' + str(temp_dict['identity']))
                filterListIdentity.append(pdb_chain)
                continue
            temp_diff = list(ref_indices_set - set(temp_dict['map_ref']))
            for diff_i in temp_diff:
                if not diff_i in missing_ind_dict:
                    missing_ind_dict[diff_i] = 1
                else:
                    missing_ind_dict[diff_i] += 1
        self._missing_ind_dict = missing_ind_dict
        
        filterList = filterListLen + filterListRMSD + filterListZ + filterListIdentity
        filterDict = {'len': filterListLen, 'rmsd': filterListRMSD, 'Z': filterListZ, 'identity': filterListIdentity}
        self._filterList = filterList
        self._filterDict = filterDict
        self._pdbList = [self._pdbListAll[0]] + [item for item in self._pdbListAll[1:] if not item in filterList]
        LOGGER.info(str(len(filterList)) + ' PDBs have been filtered out from '+str(len(pdbListAll))+' Dali hits (remaining: '+str(len(pdbListAll)-len(filterList))+').')
        
        filterRMSD = []
        diverseRMSD = []
        for item in RMSDs:
            if item < cutoff_rmsd:
                filterRMSD.append(item)
            if item > 1.0:
                diverseRMSD.append(item)
        
        print ('RMSD less than ', cutoff_rmsd, mean(filterRMSD), std(filterRMSD))
        print ('RMSD greater than 1A ', mean(diverseRMSD), std(diverseRMSD))
        
        return self._pdbList
    
    def getTitle(self):
        """Return the title of the record"""

        return self._title

def daliFilterMultimer(atoms, dali_rec, n_chains=None):
    """
    Filters multimers to only include chains with Dali mappings.

    :arg atoms: the multimer to be filtered
    :type atoms: :class:`.Atomic`

    :arg dali_rec: the DaliRecord object with which to filter chains
    :type dali_rec: :class:`.DaliRecord`
    """
    if not isinstance(atoms, Atomic):
        raise TypeError("atoms should be an Atomic object")

    if not isinstance(dali_rec, DaliRecord):
        raise TypeError("dali_rec should be a DaliRecord")
    try:
        keys = dali_rec._alignPDB
    except:
        raise AttributeError("Dali Record does not have any data yet. Please run fetch.")

    numChains = 0
    atommap = None
    for i, chain in enumerate(atoms.iterChains()):
        m = dali_rec.getMapping(chain.getTitle()[:4] + chain.getChid())
        if m is not None:
            numChains += 1
            if atommap is None:
                atommap = chain
            else:
                atommap += chain

    if n_chains is None or numChains == n_chains:
        return atommap
    else:
        return None

def daliFilterMultimers(structures, dali_rec, n_chains=None):
    """A wrapper for daliFilterMultimer to apply to multiple structures.
    """
    dali_ags = []
    for entry in structures:
        result = daliFilterMultimer(entry, dali_rec, n_chains)
        if result is not None:
            dali_ags.append(result)
    return dali_ags

# %%
from numpy import *
from matplotlib.pyplot import *
# import os
ion()

# find hinges
def splitHinge(vals, sites, block):
    # split hinges
    currBlock = 1
    index = 0
    isStart = False
    newSites = []
    newVals = []

    for val in vals:
        if block[index] == currBlock and not isStart:
            isStart = True
            currSites = [sites[index]]
            currValLists = [vals[index]]
        elif block[index] == currBlock and isStart:
            currSites.append(sites[index])
            currValLists.append(vals[index])
        else:
            currBlock += 1
            isStart = True
            newSites.append(currSites)
            newVals.append(currValLists)
            currSites = [sites[index]]
            currValLists = [vals[index]]
        if currBlock == block[-1] and index == len(vals) - 1:
            newSites.append(currSites)
            newVals.append(currValLists)
        index += 1
    # print newSites, newVals
    return newSites, newVals


def mini(a, b):
    if a > b:
        return a
    else:
        return b


def checkIfCrossBase(currVal, currSite, currEigenVec):
    identify = sort(currVal)
    ifRemain = True
    if identify[0] < 0 and identify[-1] > 0:
        ifRemain = True
    else:
        maxSite = max(currSite)
        minSite = min(currSite)
        # print (identify)
        if identify[0] >= 0 and identify[-1] >= 0:
            if currEigenVec[max(0, minSite - 1)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 1)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 2)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 3)] < 0:
                ifRemain = True
            else:
                ifRemain = False
        elif identify[0] <= 0 and identify[-1] <= 0:
            # print (len(currEigenVec))
            # print (currEigenVec[239])

            if currEigenVec[max(0, minSite - 1)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 1))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 2))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 3))] > 0:
                ifRemain = True
            else:
                ifRemain = False

        else:
            print(identify[0], identify[-1])
            print("Check!")
    return ifRemain


def oneModeHinge(currEigenVec, thereshold=20):
    range = ((1 / float(len(currEigenVec))) ** 0.5) / thereshold
    # print (range)
    # print range
    sites = []
    vals = []
    block = []

    index = 0
    blockID = 1
    for item in currEigenVec:
        if item <= range and item >= -range:
            vals.append(item)
            if len(sites) >= 1 and abs(sites[-1] - index) > 1:
                blockID += 1
            sites.append(index)
            block.append(blockID)
        index += 1

    newSites, newVals = splitHinge(vals, sites, block)

    filtSites = []
    filtVals = []

    index = 0
    for item in newSites:
        currSite = newSites[index]
        currVal = newVals[index]
        if checkIfCrossBase(currVal, currSite, currEigenVec):
            filtSites.append(currSite)
            filtVals.append(currVal)
        index += 1

    return filtSites, filtVals



def getValue(currList):
    newList = []
    for item in currList:
        newList.append(float(item))
    return newList


def readModes(fileName):
    allModes = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.strip()
            line = line.split('\t')
            currMode = line[0]
            currVal = line[1:]
            allModes[currMode] = getValue(currVal)
    return allModes


def flattenData(arrayTwoD):
    flat = []
    for item in arrayTwoD:
        for each in item:
            flat.append(each)
    return flat

def cleanStr(currStr):
    return currStr.strip('\'')

def readFile(fileName):
    data = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.replace('\n', '')
            line = line.strip()
            line = line.split('\t')
            currPDB = line[0]
            currDrug = line[1]
            currChain = line[2:]
            if currPDB not in data.keys():
                data[currPDB] = {}
            if currDrug not in data[currPDB].keys():
                data[currPDB][currDrug] = []
            for each in currChain:
                data[currPDB][currDrug].append(cleanStr(each))
    return data

# contribution of mode of motions
def getContribution(eigenVals, mode):
    allContribution = np.sqrt(np.sum(1 / eigenVals))
    currModeContribution = eigenVals[:mode]
    currContribution = np.sqrt(np.sum(1 / currModeContribution))
    return currContribution / allContribution

def getModesGivenThreshold(eigenVals, thereshold):
    contribution = 0
    mode = 0
    while contribution <= thereshold:
        mode += 1
        contribution = getContribution(eigenVals, mode)
    return mode

def writeBinding(fileName, pdb_ids):
    with open(fileName, 'w') as wf:
        for item in pdb_ids:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')


from prody import *
def getModes(currPDB, eachChain, length = 0.7, rmsd = 1.0, Z = 10):    
    # if not os.path.exists('./Results/' + currPath):
    #     os.mkdir('./Results/' + currPath)
    dali_rec = searchDal(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len = length, cutoff_rmsd = rmsd, cutoff_Z = Z)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    
    ags = parsePDB(pdb_ids, subset='ca')
    dali_ens = buildPDBEnsemble(ags, mapping=mappings, seqid=20)
    gnms = calcEnsembleENMs(dali_ens, model='GNM', trim='reduce', n_modes=None)
    eigVals = gnms.getEigvals()
    averageEigVals = eigVals[0]

    eigVects = gnms.getEigvecs()
    averageEigVects = mean(eigVects, axis=0)
    return averageEigVals, averageEigVects, pdb_ids, gnms, averageEigVects

            
def getDali_info(currPDB, eachChain, rmsd = 2.5, length = 0.9):
    dali_rec = searchDali(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len=length, cutoff_rmsd=rmsd)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    return pdb_ids, mappings

def getHinges(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

def getHinges2(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

def getHinges_modes(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def getHinges_modes2(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge


def get3Hinges_bandwidth(averageEigVects, bandWidths = [15, 16, 17]):
    currHinge = []
    for i in range(3):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidths[i])
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
# Experiment to evaluate performance of hypergeometric p values
from scipy.stats import hypergeom
def ORA(M, N, n, k):
    total = 0
    totalLength = N
    binding = M
    hinge = n
    overlap = k
    
    for i in range(overlap):
        total += hypergeom.pmf(i, totalLength, binding, hinge)
    return 1 - total

import os
def writeIDs(path, idList):
    # Check whether the specified path exists or not
    isExist = os.path.exists(path)
    if not isExist:

       # Create a new directory because it does not exist
       os.makedirs(path)
       print("The new directory is created!")
    
    with open(path + '/ids.txt', 'w') as wf:
        for item in idList:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')

# %%
def screenIDs(ids):
    newIDs = []
    for item in ids:
        newIDs.append(item[:4])
    return newIDs

# filter transmembrane protein
def filterHinges(Hinges_2, ContinueThreshold = 50, HingeCutoff = 10):
    newHinges = []
    currItem = []
    for item in Hinges_2:
        if currItem == [] or currItem[-1] == item - 1:
            currItem.append(item)
        else:
            newHinges.append(currItem)
            currItem = []

    filteredItem = []
    for item in newHinges:
        if len(item) <= ContinueThreshold:
            filteredItem += item
        else:
            filteredItem += item[:HingeCutoff]
            filteredItem += item[-HingeCutoff:]
    return filteredItem

# %%
def writeNumbers(path, numbers):
    with open(path, 'w') as wf:
        for item in numbers:
            wf.write(str(item) + '\n')

def merge_overlapping_lists(lists):
    sorted_lists = sorted(lists, key=lambda x: x[0])  # Sort lists based on the first element
    merged_lists = [sorted_lists[0]]
    
    for current in sorted_lists[1:]:
        previous = merged_lists[-1]
        # Check if the current list overlaps with the previous one
        if current[0] <= previous[-1]:
            # Merge overlapping lists by updating the last list in merged_lists
            merged_lists[-1] = list(range(min(previous[0], current[0]), max(previous[-1], current[-1])+1))
        else:
            merged_lists.append(current)
    return merged_lists

# %%
def trimEnds(values, lists, Number):
    begining = Number
    ends = len(values) - Number
    isInclude = True
    for item in lists:
        if item < begining or item > ends:
            isInclude = False
    return isInclude

def splitRegions(currlist):
    sortList = sort(currlist)
    
    region_list = []
    currRegion = []
    previous = -1
    for item in sortList:
        if item - previous == 1:
            currRegion.append(item)
            previous = item
        else:
            if currRegion != []:
                region_list.append(currRegion)
            currRegion = [item]
            previous = item
    
    if currRegion not in region_list:
        region_list.append(currRegion)
    return region_list
        
def extendRegions(crossovers, values, thereshold):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    return regions

# %%
def mergeRegions(lists, max_gap=2, min_length=5):
    merged = [lists[0]]  # Start with the first list

    for next_list in lists[1:]:
        # Check if the next list starts within max_gap+1 of the last element of the current last list in 'merged'
        if next_list[0] - merged[-1][-1] <= max_gap + 1:
            # Merge the lists by extending the last list in 'merged' with the elements of 'next_list'
            merged[-1].extend(next_list)
        else:
            # If it doesn't meet the merge criteria, just append the list as a new one
            merged.append(next_list)

    # Filter merged lists to ensure they meet the min_length requirement after removing duplicates and sort them
    # Keep unmerged lists as they are
    final_list = []
    for sublist in merged:
        unique_sublist = sorted(set(sublist))  # Remove duplicates and sort
        if len(unique_sublist) >= min_length or unique_sublist == sublist:  # Check length or unchanged list
            final_list.append(unique_sublist)
        else:
            # For lists that were attempted to merge but didn't meet the length requirement,
            # revert to individual elements as separate lists
            final_list.extend([[item] for item in unique_sublist])

    # print (final_list)
    finals = []
    for item in final_list:
        if len(item) < min_length:
            finals += splitRegions(item)
        else:
            finals.append(item)
    
    return finals

# %%
# Function to trim similar sign values from start
def trim_start(lst, index):
    if len(lst) == 1:
        return lst, index
    if not lst:
        return [], []
    start_sign = lst[0] >= 0
    for i in range(1, len(lst)):
        if (lst[i] >= 0) != start_sign:
            return lst[i-1:], index[i-1:]
    return [], []

# Function to trim similar sign values from end
def trim_end(lst, index):
    if len(lst) == 1:
        return lst, index
    
    if not lst:
        return [], []
    lst = lst[::-1]  # Reverse the list for ease of use
    index = index[::-1]
    end_sign = lst[0] >= 0
    for i in range(1, len(lst)):
        if (lst[i] >= 0) != end_sign:
            return lst[i-1:][::-1], index[i-1:][::-1]  # Reverse the list again to restore original order
    return [], []

def trimRegions(region, values):
    newRegion = []
    for eachIndex in region:
        currValues = [values[x] for x in eachIndex]
        # print (eachIndex, currValues)
        # Apply the trimming functions
        trimmed_start, trimmed_index = trim_start(currValues, eachIndex)
        # print (trimmed_index)
        trimmed_end, trimmed_index = trim_end(trimmed_start, trimmed_index)
        newRegion.append(trimmed_index)
    return newRegion

# %%
def findSmallestPairs(index_list, value_list):
    # Initialize variables to store the smallest sum and corresponding indices
    smallest_sum = float('inf')  # Set it to infinity initially
    smallest_pair = None

    # Iterate through the value list to find adjacent index pairs with the smallest sum of absolute values
    for i in range(len(value_list) - 1):  # -1 because we are looking at pairs
        current_sum = abs(value_list[i]) + abs(value_list[i + 1])
        if current_sum < smallest_sum:
            smallest_sum = current_sum
            smallest_pair = [index_list[i], index_list[i + 1]]
    return smallest_pair

def find_cross_points(Final_test, crossovers, values):
    crossoverPoints_pairs = []
    for item in Final_test:
        if item in crossovers and item - 1 in Final_test:
            crossoverPoints_pairs.append([item - 1, item])
    
    # print ('cross_pairs', crossoverPoints_pairs)
    # filtering_pairs = mergeRegions(crossoverPoints_pairs, max_gap=0, min_length=3)
    # currNumber = len(filtering_pairs) * 2
    # print ('filtering_pairs', crossoverPoints_pairs)
    
    bestPairs = crossoverPoints_pairs[0]
    bestScore = abs(values[bestPairs[0]]) + abs(values[bestPairs[1]])
    if len(crossoverPoints_pairs) <= 1:
        return bestPairs
    else:
        for item in crossoverPoints_pairs[1:]:
            currScore = abs(values[item[0]]) + abs(values[item[1]])
            # print ('item, score', item, currScore)
            if currScore <= bestScore:
                bestPairs = item
                bestScore = currScore
    
    # print ('filtered', bestPairs)
    return bestPairs

# %%
def filteringCriteria(Final, values, crossovers):
    FinalRegions = []
    for region in Final:
        # print ('before filtering', region)
        if len(region) >= 3:
            allPairs = find_cross_points(region, crossovers, values)
            currRegion = allPairs
            
            # print ('allPairs', allPairs)
            pos = [index for index in region if values[index] > 0]
            neg = [index for index in region if values[index] < 0]
            pos.sort(key=lambda x: values[x])
            neg.sort(key=lambda x: values[x], reverse=True)
            extra = round((len(region) - 2) / 4 + 0.00001)
            
            # rest = pos[1:] + neg[1:]
            # restValues = [values[res] for res in rest]
            # combined_list = sorted(zip(rest, restValues), key=lambda x: abs(x[1]))
            rest = []
            for item in region:
                if item not in currRegion:
                    rest.append(item)
            restValues = [values[res] for res in rest]   
            combined_list = sorted(zip(rest, restValues), key=lambda x: abs(x[1]))
            
            # Extract the sorted indexes from the combined list
            sorted_indexes = [index for index, value in combined_list]
            
            region = currRegion + sorted_indexes[:extra]
            # print (region)
            
        # elif 3 <= len(region) == 4:
            # region = find_cross_points(region, crossovers, values)
            # print (region)
            # if values[region[0]-1] * values[region[-1]+1] > 0:
            #     continue  # Skip this region if adjacent values outside the band have the same sign
        # print ('after filtering',region)      
            
        
        # print ('after filtering',region)      
        elif len(region) == 1:
            continue
            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    return FinalRegions

# %%
def oneModeHinge_update2(values, hinges, thereshold=20):
    # band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    regions = extendRegions(crossovers, values, thereshold)
    # print ('extend Regions', regions)
    # print ('debug regions, hinges', regions, hinges)
    
    # merge regions and hinges
    flat = sort(list(set(flattenData(regions) + hinges)))
    Final = splitRegions(flat)
    # print ('before merging', Final)
    Final = mergeRegions(Final, max_gap=2, min_length=5)
    # print ('Final is', Final)
    # trim Regions
    trimmedFinal = trimRegions(Final, values)
    # rint ('after trimming', trimmedFinal)
    
    FinalRegions = filteringCriteria(trimmedFinal, values, crossovers)
    # print ('after filtering', FinalRegions)
    
    # remove frist and last several residues as hinges
    updateRegions = []
    for currReg in FinalRegions:
        if trimEnds(values, currReg, 15):
            updateRegions.append(currReg)
    
    # print ('trim tails', updateRegions)
        
    flat = flattenData(updateRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return updateRegions, final_values

# %%
def getHinges_modes3(averageEigVects, mode, hinges, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update2(averageEigVects[:, mode], hinges, thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def getHinges3(averageEigVects, currNumModes, hinges, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update2(averageEigVects[:, i], hinges[i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
# remove first and last hinges for each chain
def filterTwoEnds(hinges, chainLength = [[0, 551], [552, 956]], trimmingLength = 15):
    FilteringIndex = []
    for item in chainLength:
        # print (item)
        FilteringIndex += list(range(item[0], item[0] + trimmingLength))
        FilteringIndex += list(range(item[1] - trimmingLength + 1, item[1] + 1))  
    updateHinges = []
    for item in hinges:
        if item not in FilteringIndex:
            updateHinges.append(item)
    
    return updateHinges

# %% [markdown]
# ## method 2

# %%
def oneModeHinge_update(values, thereshold=20):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    # print (regions)
    
    FinalRegions = []
    for region in regions:
        # print ('before filtering', region)
        if len(region) >= 4:
            if len(region) == 4:
                if values[region[0]-1] * values[region[-1]+1] > 0:
                    continue  
            # print ('previous region', region)
            pos = [index for index in region if values[index] > 0]
            neg = [index for index in region if values[index] < 0]
            pos.sort(key=lambda x: values[x])
            neg.sort(key=lambda x: values[x], reverse=True)
            n = int(len(region) / 4) + 1
            region = pos[:n] + neg[:n]
            # print (region, neg, pos)
        elif  len(region) == 3:  
            if values[region[0]-1] * values[region[-1]+1] > 0:
                continue  # Skip this region if adjacent values outside the band have the same sign
            else:
                region = find_cross_points(region, crossovers, values)

        # print ('after filtering',region)      
            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    # print ('Final regions', FinalRegions)
    # remove frist and last several residues as hinges
    updateRegions = []
    for currReg in FinalRegions:
        if trimEnds(values, currReg, 15):
            updateRegions.append(currReg)
    
    flat = flattenData(updateRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return updateRegions, final_values

# %% [markdown]
# # Similar ensemble

# %%
currPDB = '6f78'
eachChain = 'A'

# pdb_ids, mappings = getDali_info(currPDB, eachChain, cutoff_len=0.7, cutoff_rmsd=1.0, cutoff_Z=10)
EigVals, averageEigVects, ids, gnms, averageEigVects = getModes(currPDB, eachChain, length=0.8, rmsd=2, Z=10)
# Out:
# @> Submitted Dali search for PDB "6f78A".
# @> http://ekhidna2.biocenter.helsinki.fi/barcosel/tmp//6f78A/
# @> Dali results were fetched in 0.2s.
# @> Obtained 5026 PDB chains from Dali for 6f78A.
# @> 4481 PDBs have been filtered out from 5026 Dali hits (remaining: 545).
# @> Retrieving 6f78A... [  0%]
# RMSD less than  2.0 1.1265682 0.40224788
# RMSD greater than 1A  3.3715906 0.81577677
# # of similar structures is found from Dali 545
# @> Retrieving 2pznA... [ 37%] 87s @> WARNING SEQADV for chain A: database sequence reference not found (2PZN:321)
# @> Retrieving 3t42A... [ 38%] 86s@> WARNING SEQADV for chain A: database sequence reference not found (3T42:303)
# @> Retrieving 1t41A... [ 46%] 74s@> WARNING SEQADV for chain A: database sequence reference not found (1T41:290)
# @> 545 PDBs were parsed in 138.47s.
# @> Mapping 3ln3A_ca to the reference... [ 29%] 10s@> WARNING
# the number of residues in the map_dict (319 residues) is inconsistent with Chain A from 3ln3A_ca (291 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 1ah3A_ca to the reference... [ 56%] 7s @> WARNING
# the number of residues in the map_dict (315 residues) is inconsistent with Chain A from 1ah3A_ca (314 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 1ah4A_ca to the reference... [ 62%] 6s@> WARNING
# the number of residues in the map_dict (315 residues) is inconsistent with Chain A from 1ah4A_ca (314 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 1ekoA_ca to the reference... [ 63%] 6s@> WARNING
# the number of residues in the map_dict (315 residues) is inconsistent with Chain A from 1ekoA_ca (314 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4wevX_ca to the reference... [ 64%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 4wevX_ca (301 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 2pf8A_ca to the reference... [ 65%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain A from 2pf8A_ca (313 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4xzlX_ca to the reference... [ 65%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 4xzlX_ca (302 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5liuX_ca to the reference... [ 66%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5liuX_ca (302 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4iccX_ca to the reference... [ 67%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 4iccX_ca (301 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5liyX_ca to the reference... [ 67%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5liyX_ca (307 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5lixX_ca to the reference... [ 68%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5lixX_ca (301 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5liwX_ca to the reference... [ 68%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5liwX_ca (307 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5likX_ca to the reference... [ 68%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5likX_ca (302 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 5m2fX_ca to the reference... [ 68%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 5m2fX_ca (299 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4xzmX_ca to the reference... [ 69%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 4xzmX_ca (298 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4xznX_ca to the reference... [ 69%] 5s@> WARNING
# the number of residues in the map_dict (316 residues) is inconsistent with Chain X from 4xznX_ca (299 residues)
# @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Starting iterative superposition:
# @> Step #1: RMSD difference = 6.8830e-01
# @> Step #2: RMSD difference = 3.6893e-03
# @> Step #3: RMSD difference = 1.1930e-04
# @> Step #4: RMSD difference = 4.9100e-06
# @> Iterative superposition completed in 0.49s.
# @> Final superposition to calculate transformations.
# @> Superposition completed in 0.12 seconds.
# @> Ensemble (529 conformations) were built in 14.73s.
# @> WARNING 16 structures cannot be mapped.
# @> WARNING last 64 modes for 253 modes from MaskedGNM 6f78A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 6gxkB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 6f78B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 1ry0B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4dbsB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4dbwB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 1ry8B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 1ry0A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 6gxkA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 1ry8A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4dbuB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2f38A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4yvvB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4zfcB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4famA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 7wqsB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 7wqmA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 5hntA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 8i0cB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 5hnuA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 7c7hB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 62 modes for 253 modes from MaskedGNM 5jm5A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 7c7gA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4dbwA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4zfcA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4dbsA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 7c7hA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4yvvA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 6a7bA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 7x3lB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 8bbsB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4famB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 7wqsA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 8bbsA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 7c7gB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 7wqmB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 7c7fB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 7c7fA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4xveA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 6ijxA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 6a7aA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 7x3mB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 7x3lA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3c3uA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 7wqrA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 56 modes for 253 modes from MaskedGNM 3r43A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4xo7B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 7wqrB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 1s2cA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 7x3mA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4dbuA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4l1wB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4xo6A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4yvpB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4yvxB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4wdtA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1zq5A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2ipjB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3gugA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 1s1pA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 62 modes for 253 modes from MaskedGNM 4wrhA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 62 modes for 253 modes from MaskedGNM 1s1rA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4l1xB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 58 modes for 253 modes from MaskedGNM 3uweA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2ipjA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 1xjbB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 56 modes for 253 modes from MaskedGNM 5jm5B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4xo7A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2hdjB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3ntyA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4l1wA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4wduA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 1xjbA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4xvdA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 56 modes for 253 modes from MaskedGNM 7x3oB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4xo6B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 8i0cA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 1s2aA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 1mrqA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 1xf0A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4l1xA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2hdjA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4yvxA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 4yvpA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 6f2uB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2fvlB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2fvlC_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 6f2uA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2fvlA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 1j96A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4jtqB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4jqaB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4jq3B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1j96B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 5hnuC_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 1q5mA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 63 modes for 253 modes from MaskedGNM 1ihiB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 63 modes for 253 modes from MaskedGNM 1ihiA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4jtrB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4jq1A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 4jq2B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 53 modes for 253 modes from MaskedGNM 2fgbA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 1q5mB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4jq3A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 49 modes for 253 modes from MaskedGNM 5hntC_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4jqaA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 57 modes for 253 modes from MaskedGNM 4xvdB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4jtrA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 51 modes for 253 modes from MaskedGNM 4falA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4jtqA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4jq2A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4jq4A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 49 modes for 253 modes from MaskedGNM 3r6iA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 51 modes for 253 modes from MaskedGNM 4h7cA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 49 modes for 253 modes from MaskedGNM 3r7mA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 49 modes for 253 modes from MaskedGNM 3r8gA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 49 modes for 253 modes from MaskedGNM 4dz5A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 50 modes for 253 modes from MaskedGNM 3r58A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 49 modes for 253 modes from MaskedGNM 3ufyA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 49 modes for 253 modes from MaskedGNM 3r8hA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4jq1B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 49 modes for 253 modes from MaskedGNM 3ug8A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 49 modes for 253 modes from MaskedGNM 3r94A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 54 modes for 253 modes from MaskedGNM 3ugrA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2ipgA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 52 modes for 253 modes from MaskedGNM 4hmnA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 51 modes for 253 modes from MaskedGNM 7x3oA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 48 modes for 253 modes from MaskedGNM 6a7bB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2ipfA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 1q13A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 57 modes for 253 modes from MaskedGNM 4jq4B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2hejB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2hejA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2ipfB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 51 modes for 253 modes from MaskedGNM 4fa3A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1q13B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2p5nB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 2p5nA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3buvB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3buvA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 48 modes for 253 modes from MaskedGNM 4wdxB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3burA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3uzxB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3bv7B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 63 modes for 253 modes from MaskedGNM 2ipgB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3burB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3bv7A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3cv6B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3uzwA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3uzyB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3cv6A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3cmfB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 47 modes for 253 modes from MaskedGNM 4wdwB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3g1rA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3g1rB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3cotA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3cmfA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3uzzB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3uzwB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3dopB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3cotB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3uzxA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3uzyA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3dopA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3uzzA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 44 modes for 253 modes from MaskedGNM 4wdxA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3caqB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 44 modes for 253 modes from MaskedGNM 4wdwA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3caqA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3casB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3casA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 2he8B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3cavA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 64 modes for 253 modes from MaskedGNM 3cavB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 57 modes for 253 modes from MaskedGNM 2he8A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 3fjnB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 2he5B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 61 modes for 253 modes from MaskedGNM 2he5A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 1afsA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 1afsB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 57 modes for 253 modes from MaskedGNM 2he5D_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 56 modes for 253 modes from MaskedGNM 3fjnA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 57 modes for 253 modes from MaskedGNM 2he5C_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 54 modes for 253 modes from MaskedGNM 5uxfA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4rpqA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 8fh6A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4qx4A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4xzhA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2hv5A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 58 modes for 253 modes from MaskedGNM 6m7kA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2pdlA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 8b3nA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 5ou0A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 4ys1A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2pdfA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4q7bA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 3bcjA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4igsA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 5oujA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 3u2cA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2pdhA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2j8tA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2fzbA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2dv0A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2pdqA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2pznA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 4puuA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 6t5gA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1pwlA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 3t42A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2pdpA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 4nkcA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4prtA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 5oukA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2pdkA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2pdjA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4prrA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1x98A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2pduA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2pdnA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2pdgA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 6t27A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 6tufA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 3q67B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2acqA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 3q67A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2agtA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 3mc5A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 8auuA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1x97A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1pwmA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 6xumA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2pd5A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2nvcA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 8b34A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 3rx2A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2nvdA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 3m0iA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2ikhA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2pdmA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2f2kA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 4puwA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 3lenA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 8aqpA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2pd9A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1x96A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 8fh9A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2ikgA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2fz9A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 8fh5A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4qbxA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 3m64A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1t41A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 5ha7B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2pdcA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 3dn5A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 4pr4A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 3mb9A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 5ha7A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1z8aA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 3v35A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 6y1pA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4lb4A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2ikjA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 8fh7A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 3q65B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 4yu1A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 6txpA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2ineA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 6sywA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 6td8A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 3rx3A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 3q65A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 3s3gA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 6f81A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2pevA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 3p2vA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1z89A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2pdyA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 3rx4A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4gcaA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2pdwA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 2pdbA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2hvoA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4lb3A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 8bjlA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2fz8A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 8ae9A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 1el3A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 6f82A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 4qr6A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4lbsA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 2duxA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 4lbrA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 4jirA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 6t7qA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 60 modes for 253 modes from MaskedGNM 3v36A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 59 modes for 253 modes from MaskedGNM 8fh8A_ca reduced has been discarded because at least one conformation has only 253 modes
# ...
# @> WARNING last 46 modes for 253 modes from MaskedGNM 7f7lB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 51 modes for 253 modes from MaskedGNM 1mi3B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 46 modes for 253 modes from MaskedGNM 7w1xA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 52 modes for 253 modes from MaskedGNM 1z9aA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 47 modes for 253 modes from MaskedGNM 7f7kB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 51 modes for 253 modes from MaskedGNM 1ye6B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 51 modes for 253 modes from MaskedGNM 5z6tA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 53 modes for 253 modes from MaskedGNM 1z9aC_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 52 modes for 253 modes from MaskedGNM 1z9aB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 51 modes for 253 modes from MaskedGNM 1z9aD_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 49 modes for 253 modes from MaskedGNM 3h7uA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 51 modes for 253 modes from MaskedGNM 1mi3C_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 46 modes for 253 modes from MaskedGNM 7f7mB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 47 modes for 253 modes from MaskedGNM 7w1xB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 53 modes for 253 modes from MaskedGNM 1ye4B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 52 modes for 253 modes from MaskedGNM 1ye4D_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 52 modes for 253 modes from MaskedGNM 1ye4A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 52 modes for 253 modes from MaskedGNM 1ye4C_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 43 modes for 253 modes from MaskedGNM 7f7jB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 46 modes for 253 modes from MaskedGNM 1ralA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 50 modes for 253 modes from MaskedGNM 5z6uA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 40 modes for 253 modes from MaskedGNM 7f7jA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 44 modes for 253 modes from MaskedGNM 3h7rA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 47 modes for 253 modes from MaskedGNM 6kblA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 38 modes for 253 modes from MaskedGNM 7s5iB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 46 modes for 253 modes from MaskedGNM 5z6tB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 40 modes for 253 modes from MaskedGNM 7s5iA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 44 modes for 253 modes from MaskedGNM 1zgdB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 44 modes for 253 modes from MaskedGNM 1zgdA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 38 modes for 253 modes from MaskedGNM 1qwkA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 51 modes for 253 modes from MaskedGNM 5zciB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 45 modes for 253 modes from MaskedGNM 5az1A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 36 modes for 253 modes from MaskedGNM 5jgyA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 44 modes for 253 modes from MaskedGNM 5az0A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 36 modes for 253 modes from MaskedGNM 5jgwD_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 37 modes for 253 modes from MaskedGNM 5jgwB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 36 modes for 253 modes from MaskedGNM 5jgyB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 36 modes for 253 modes from MaskedGNM 2vdgA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 50 modes for 253 modes from MaskedGNM 5z6uB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 36 modes for 253 modes from MaskedGNM 5jgwC_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 36 modes for 253 modes from MaskedGNM 5jgwA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 36 modes for 253 modes from MaskedGNM 2bgsA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 45 modes for 253 modes from MaskedGNM 7mbfA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 46 modes for 253 modes from MaskedGNM 7mbfB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 41 modes for 253 modes from MaskedGNM 4ijrC_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 46 modes for 253 modes from MaskedGNM 7mbfD_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 41 modes for 253 modes from MaskedGNM 4ijrA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 41 modes for 253 modes from MaskedGNM 4ijcB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 44 modes for 253 modes from MaskedGNM 7mbfE_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 41 modes for 253 modes from MaskedGNM 4ijcA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 43 modes for 253 modes from MaskedGNM 7mbfC_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 41 modes for 253 modes from MaskedGNM 3krbA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 41 modes for 253 modes from MaskedGNM 3krbB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 20 modes for 253 modes from MaskedGNM 1vp5A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 20 modes for 253 modes from MaskedGNM 1vp5B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 35 modes for 253 modes from MaskedGNM 1jezB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 42 modes for 253 modes from MaskedGNM 7mbfF_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 37 modes for 253 modes from MaskedGNM 1jezA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 31 modes for 253 modes from MaskedGNM 2bgqA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 13 modes for 253 modes from MaskedGNM 1vbjA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 13 modes for 253 modes from MaskedGNM 1vbjB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 14 modes for 253 modes from MaskedGNM 4q3mA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 14 modes for 253 modes from MaskedGNM 4q3mC_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 14 modes for 253 modes from MaskedGNM 4q3mD_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 13 modes for 253 modes from MaskedGNM 4q3mE_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 17 modes for 253 modes from MaskedGNM 4mhbA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 17 modes for 253 modes from MaskedGNM 4mhbC_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 17 modes for 253 modes from MaskedGNM 4mhbB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 12 modes for 253 modes from MaskedGNM 4q3mB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 16 modes for 253 modes from MaskedGNM 4g5dB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 16 modes for 253 modes from MaskedGNM 4mhbE_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 16 modes for 253 modes from MaskedGNM 4mhbD_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 16 modes for 253 modes from MaskedGNM 4g5dA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 13 modes for 253 modes from MaskedGNM 3d3fA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 13 modes for 253 modes from MaskedGNM 3f7jB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 16 modes for 253 modes from MaskedGNM 4mhbF_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 14 modes for 253 modes from MaskedGNM 2wzmA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 13 modes for 253 modes from MaskedGNM 2wzmB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 13 modes for 253 modes from MaskedGNM 3d3fB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 14 modes for 253 modes from MaskedGNM 4f40B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 16 modes for 253 modes from MaskedGNM 4gieA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 12 modes for 253 modes from MaskedGNM 3f7jA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 14 modes for 253 modes from MaskedGNM 4f40A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 11 modes for 253 modes from MaskedGNM 4fziB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 13 modes for 253 modes from MaskedGNM 4otkA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 17 modes for 253 modes from MaskedGNM 3b3dB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 9 modes for 253 modes from MaskedGNM 4q3mF_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 16 modes for 253 modes from MaskedGNM 1m9hA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 13 modes for 253 modes from MaskedGNM 1mzrA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 16 modes for 253 modes from MaskedGNM 1a80A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 16 modes for 253 modes from MaskedGNM 3b3dC_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 13 modes for 253 modes from MaskedGNM 1mzrB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 15 modes for 253 modes from MaskedGNM 4fziA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 16 modes for 253 modes from MaskedGNM 3b3dA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 3 modes for 253 modes from MaskedGNM 2wztA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 17 modes for 253 modes from MaskedGNM 3up8A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 17 modes for 253 modes from MaskedGNM 3up8B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 1 modes for 253 modes from MaskedGNM 2wztB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 9 modes for 253 modes from MaskedGNM 3wbwA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 9 modes for 253 modes from MaskedGNM 3wbwB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 9 modes for 253 modes from MaskedGNM 3wbxA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 9 modes for 253 modes from MaskedGNM 3wbxB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 4 modes for 253 modes from MaskedGNM 5jh1A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 1 modes for 253 modes from MaskedGNM 5jh2A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 9 modes for 253 modes from MaskedGNM 3wbyB_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 9 modes for 253 modes from MaskedGNM 3wbyA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 2 modes for 253 modes from MaskedGNM 5danA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 1 modes for 253 modes from MaskedGNM 6ky6A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 2 modes for 253 modes from MaskedGNM 6ky6B_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 1 modes for 253 modes from MaskedGNM 6kiyA_ca reduced has been discarded because at least one conformation has only 253 modes
# @> WARNING last 1 modes for 253 modes from MaskedGNM 1pz0A_ca reduced has been discarded because at least one conformation has only 253 modes
# @> all GNM modes were calculated for each of the 529 conformations in 33.21s.
# @> 253 modes across 529 modesets were matched in 7.86s.

# %%
writeIDs('./Binding', ids)

# %%
currNumModes = getModesGivenThreshold(EigVals, 0.33)
currNumModes
# Out:
# 3

# %%
bindings =  ['14', '15', '16', '19', '107', '143', '194', '195', '196', '197', '198', '199', '200', '246', '247', '250', '251', '254', '257', '258', '259', '285']

binding = ['18', '21', '25', '48', '49', '50', '52', '53', '80', '112', '113', '114', '210', '211', '221', '300', '301', '305', '307', '312']

# binding = ['18', '21', '48', '49', '50', '52', '53', '80', '112', '113', '114', '221', '223', '300', '305', '307', '309', '312']

binding = [int(x) for x in binding]

# %%
Hinges_2 = getHinges(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges(averageEigVects, 3, 20)

Hinges_4 = getHinges(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges(averageEigVects, 3, 15)

# %%
Hinges_2 = filterTwoEnds(Hinges_2, chainLength = [[0, 317]])
Hinges_3 = filterTwoEnds(Hinges_3, chainLength = [[0, 317]])
Hinges_4 = filterTwoEnds(Hinges_4, chainLength = [[0, 317]])
Hinges_5 = filterTwoEnds(Hinges_5, chainLength = [[0, 317]])

# %%
protein_length = 318

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 20
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 38 2 0.7180509165705307
# # of hinge sites for first 3 modes, overlap, hyper score 38 2 0.7180509165705307
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 56 2 0.8980785397514173
# # of hinge sites for first 3 modes, overlap, hyper score 56 2 0.8980785397514173

# %%
glucor = parsePDB('6f78', subset='calpha')
calphas = glucor.select('calpha and chain A')
gnm = GNM('glu')
gnm.buildKirchhoff(calphas)
gnm.calcModes(n_modes=None)
Hinge0 = calcHinges(gnm[0])
Hinge1 = calcHinges(gnm[1])
Hinge2 = calcHinges(gnm[2])
# Out:
# @> Connecting wwPDB FTP server RCSB PDB (USA).
# @> 6f78 downloaded (6f78.pdb.gz)
# @> PDB download via FTP completed (1 downloaded, 0 failed).
# @> 636 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> Secondary structures were assigned to 406 residues.
# @> Kirchhoff was built in 0.02s.
# @> 317 modes were calculated in 0.04s.

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

Hinges_sep2 = filterTwoEnds(Hinges_sep2, chainLength = [[0, 303]])
Hinges_sep3 = filterTwoEnds(Hinges_sep3, chainLength = [[0, 303]])
Hinges_sep4 = filterTwoEnds(Hinges_sep4, chainLength = [[0, 303]])
Hinges_sep5 = filterTwoEnds(Hinges_sep5, chainLength = [[0, 303]])

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 20
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 60 5 0.318458881734488
# # of hinge sites for 3 modes, overlap, hyper score 60 5 0.318458881734488
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 76 5 0.5434216986012115
# # of hinge sites for 3 modes, overlap, hyper score 76 5 0.5434216986012115

# %% [markdown]
# ### write hinges

# %%
averageEigVects.shape
# Out:
# (247, 196)

# %%
# write MSFs
averageEigVals
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)
len(MSF)
# Out:
# 247

# %%
values_array = np.array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = np.argsort(values_array)

if not os.path.exists('./Data'):
    os.mkdir('./Data')

writeNumbers('./Data/RMSF_minimum.txt', indices)

# %%
includeModes = 3
size = includeModes * 2 + 1 + 2 

curr = zeros((len(MSF), size))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]
curr[:, 5] = averageEigVects[:, 2]

for each in binding:
    curr[each, 0] = each

# %%
modes = [0, 1, 2]
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    currList = sort(list(set(list(currHinge)))) # + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
curr = list(curr)
def writeAllData(path, curr):
    with open(path, 'w') as wf:
        for row in curr:
            for col in row:
                if col == 0.0:
                    wf.write('' + '\t')
                else:
                    wf.write(str(col) + '\t')
            wf.write('\n')
                
# writeAllData('./Data/GR_Method1.txt', curr)

# %% [markdown]
# ## method 2

# %%
binding = ['18', '21', '25', '48', '49', '50', '52', '53', '80', '112', '113', '114', '210', '211', '300', '301', '305', '307', '312']

# %%
binding = ['18', '21', '48', '49', '50', '52', '80', '111', '112', '113', '114', '161', '210', '211', '300', '301', '305', '313']

binding = [int(x) for x in binding]

# %%
Hinges_2 = getHinges2(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges2(averageEigVects, 3, 20)

Hinges_4 = getHinges2(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges2(averageEigVects, 3, 15)

# %%
sort(Hinges_4)
# Out:
# array([ 44,  45,  61,  62,  63,  68,  69,  73,  74,  79,  80,  85,  86,
#         89,  90,  94,  96,  97, 102, 103, 109, 110, 113, 114, 136, 137,
#        144, 145, 157, 158, 184, 185, 195, 196, 197, 198, 206, 207, 210,
#        211, 212, 213, 252, 253, 259, 260, 262, 263, 276, 277, 282, 283,
#        284, 285, 286, 289, 298, 299, 300, 301])

# %%
Hinges_2 = filterTwoEnds(Hinges_2, [[0, 318]], 15)
Hinges_3 = filterTwoEnds(Hinges_3, [[0, 318]], 15)
Hinges_4 = filterTwoEnds(Hinges_4, [[0, 318]], 15)
Hinges_5 = filterTwoEnds(Hinges_5, [[0, 318]], 15)

# %%
protein_length = 318

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 18
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 57 7 0.02603341516142299
# # of hinge sites for first 3 modes, overlap, hyper score 57 7 0.02603341516142299
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 60 7 0.03419560487237627
# # of hinge sites for first 3 modes, overlap, hyper score 60 7 0.03419560487237627

# %%
ORA(18, 318, 58, 7)
# Out:
# 0.028578678826915893

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

Hinges_2 = filterTwoEnds(Hinges_2, chainLength = [[0, 318]])
Hinges_3 = filterTwoEnds(Hinges_3, chainLength = [[0, 318]])
Hinges_4 = filterTwoEnds(Hinges_4, chainLength = [[0, 318]])
Hinges_5 = filterTwoEnds(Hinges_5, chainLength = [[0, 318]])

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 18
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 76 7 0.10855163712919957
# # of hinge sites for 3 modes, overlap, hyper score 76 7 0.10855163712919957
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 79 7 0.12886242923888136
# # of hinge sites for 3 modes, overlap, hyper score 79 7 0.12886242923888136

# %%
AverageEigVals1 = gnms.getEigvals()[0]
AverageEigVals2 = mean(gnms.getEigvals(), axis=0)
proteinLength = 318

# %%
currHinge = Hinges_3

# %%
Segment = int(proteinLength / 5)
print ('mark Index are', 0, Segment, Segment*2, Segment*3, Segment*4, proteinLength - 1)
# Out:
# mark Index are 0 63 126 189 252 317

# %%
Labels = ['6', '69', '132', '195', '258', '323']

# %%
fig, ax = plt.subplots(figsize=(20, 10))   # Adjust size as per requirement
plt.sca(ax)  # Set current axis to 'ax'
    
# Increase font sizes
plt.rc('xtick', labelsize=55)
plt.rc('ytick', labelsize=50)
plt.rcParams.update({'font.size': 70})

# calcMSF
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row): # 279
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / AverageEigVals1[mode]
    MSF.append(currMSF)

# plt.plot(MSF, color='#3B9EFF', linewidth=3, alpha=0.7)
plt.plot(MSF, color='black', linewidth=4, alpha=0.88)

HingeY = [MSF[item] for item in currHinge]
plt.plot(currHinge, HingeY, color=(0.2, 1, 0.1), marker='o', linestyle='', markersize=25)
print ('# of hinges', len(HingeY))

# plot binding sites
bindingY = [MSF[item] for item in binding]
plt.plot(binding, bindingY, 'r*', markersize=30)
print ('# of bindings sites', len(binding))

# plot overlaps
allHinge = currHinge
overlaps = [item for item in binding if item in allHinge]
overlapsY = [MSF[item] for item in overlaps]
plt.plot(overlaps, overlapsY, 'mD', markersize=25)

print ('# of hits are', len(overlaps))

# Hide y labels
plt.gca().yaxis.set_visible(False)

# Hide top, right, and left spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)


# Set x-axis labels and title with Arial font
# plt.title('Aldo-keto Reductase \nFamily 1 Member C3')
plt.xticks([0, Segment, Segment*2, Segment*3, Segment*4, proteinLength - 1], Labels)

plt.savefig('./AKR1C3_MSF.png', dpi=500)
# Out:
# # of hinges 57
# # of bindings sites 18
# # of hits are 7

# %%
AverageEigVals1
# Out:
# sdarray([ 0.78425281,  1.11832355,  1.63549065,  1.94984503,  2.7934631 ,
#           2.93946523,  3.06896609,  3.53209136,  3.65679448,  4.12394838,
#           4.31121822,  4.49888556,  5.30152412,  5.80560939,  5.87632097,
#           6.18966181,  6.26362557,  6.50297479,  7.        ,  7.16474091,
#           7.28396598,  7.51548149,  7.60615984,  7.79357253,  7.93702101,
#           8.10342448,  8.38705471,  8.46478572,  8.85350288,  9.19488895,
#           9.27771507,  9.31457986,  9.43153712,  9.68977098,  9.7555031 ,
#           9.87683207,  9.88544878, 10.        , 10.13370381, 10.15466467,
#          10.19927031, 10.27114308, 10.42578201, 10.50297176, 10.67200209,
#          10.79980866, 10.84859367, 10.87661468, 10.92335985, 11.02733621,
#          11.15774581, 11.25933526, 11.29749018, 11.33549733, 11.37136789,
#          11.43820358, 11.57348252, 11.70067354, 11.77060395, 11.79891289,
#          11.96474077, 12.03922209, 12.11175074, 12.28525482, 12.35993942,
#          12.38553331, 12.41539125, 12.48036325, 12.52656053, 12.59054496,
#          12.76219295, 12.77113208, 12.80401952, 12.94917068, 13.09573921,
#          13.17769663, 13.22230432, 13.28545067, 13.37370298, 13.4511797 ,
#          13.47409515, 13.5542041 , 13.63177669, 13.64422337, 13.72506007,
#          13.83163153, 13.85336936, 13.86163557, 13.90721649, 14.04408031,
#          14.08631932, 14.15081278, 14.16154342, 14.24107832, 14.28098579,
#          14.33537283, 14.46822377, 14.55734249, 14.60055997, 14.6150724 ,
#          14.69219504, 14.74718013, 14.77332568, 14.88945079, 14.94732675,
#          14.97299971, 15.1099221 , 15.13623023, 15.19808839, 15.21697119,
#          15.29843706, 15.35739073, 15.37643856, 15.42767101, 15.46139536,
#          15.46953078, 15.72465043, 15.79582987, 15.80072389, 15.89565532,
#          16.01177999, 16.05965048, 16.12806476, 16.24110671, 16.31329429,
#          16.42906336, 16.45082019, 16.48489948, 16.57622665, 16.68429743,
#          16.71841962, 16.75143262, 16.76373894, 16.91199799, 16.94270235,
#          17.02935989, 17.13243201, 17.1633005 , 17.21066811, 17.26564172,
#          17.28888648, 17.35567779, 17.42472186, 17.48477548, 17.52341836,
#          17.53191581, 17.62125784, 17.66289822, 17.72446521, 17.77607819,
#          17.82736315, 17.87685071, 17.92866716, 18.05148313, 18.05721765,
#          18.10911089, 18.18237771, 18.22797397, 18.26836195, 18.34119004,
#          18.36826917, 18.43621789, 18.50248088, 18.52434018, 18.63364771,
#          18.69231146, 18.78684083, 18.88499381, 18.8992774 , 19.00921705,
#          19.09039082, 19.12500438, 19.18432803, 19.32957138, 19.37750193,
#          19.40312586, 19.47690922, 19.49017643, 19.58641807, 19.67740979,
#          19.7186575 , 19.7912242 , 19.95105159, 20.00954341, 20.07215131,
#          20.09998787, 20.1596717 , 20.2520578 , 20.32950845, 20.35228697,
#          20.44327624, 20.50412265, 20.57313224, 20.66295549, 20.73942911,
#          20.7704176 , 20.84585541, 20.92172524, 20.95354715, 21.01576301,
#          21.12682219, 21.21085301, 21.25364485, 21.39629115, 21.42980985,
#          21.45577652, 21.56817364, 21.61321011, 21.69498943, 21.80324284,
#          21.86966958, 21.87792524, 21.94415986, 21.99015373, 22.12251732,
#          22.18183104, 22.2022914 , 22.24472155, 22.25593082, 22.36057826,
#          22.39118616, 22.50000943, 22.51123671, 22.63255648, 22.6545921 ,
#          22.6955117 , 22.81535188, 22.88823248, 22.95532301, 23.01290239,
#          23.08651876, 23.11534418, 23.15062135, 23.26388123, 23.31784974,
#          23.38480622, 23.38734107, 23.45890613, 23.53389754, 23.58306223,
#          23.68900439, 23.72493752, 23.759384  , 23.92294119, 24.03039016,
#          24.16555373, 24.2189239 , 24.23932664, 24.34302637, 24.46484913,
#          24.51025465, 24.60183766, 24.62348231])

# %% [markdown]
# ## write Hinges

# %%
EigVals.shape
# Out:
# (253,)

# %%
averageEigVects.shape
# Out:
# (318, 253)

# %%
# write MSFs
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / EigVals[mode]
    MSF.append(currMSF)
len(MSF)
# Out:
# 318

# %%
values_array = np.array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = np.argsort(values_array)

if not os.path.exists('./Data'):
    os.mkdir('./Data')

writeNumbers('./Data/RMSF_minimum.txt', indices)

# %%
includeModes = 3
size = includeModes * 2 + 1 + 2 

curr = zeros((len(MSF), size))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]
curr[:, 5] = averageEigVects[:, 2]

for each in binding:
    curr[each, 0] = each

# %%
modes = [0, 1, 2]
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=15)
    currHinge = filterTwoEnds(currHinge, [[0, 318]], 15)
    currList = sort(list(set(list(currHinge)))) # + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
writeAllData('./Data/AKR1C3_Method2_similar_update.txt', curr)

# %% [markdown]
# # method3

# %%
currNumModes = 3

# %%
Hinges_2 = getHinges3(averageEigVects, currNumModes, [[], [], []], 20)
Hinges_3 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 20)

Hinges_4 = getHinges3(averageEigVects, currNumModes, [[], [], []], 15)
Hinges_5 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 15)

# %%
Hinges_2 = filterTwoEnds(Hinges_2, chainLength = [[0, 318]])
Hinges_3 = filterTwoEnds(Hinges_3, chainLength = [[0, 318]])
Hinges_4 = filterTwoEnds(Hinges_4, chainLength = [[0, 318]])
Hinges_5 = filterTwoEnds(Hinges_5, chainLength = [[0, 318]])

# %%
protein_length = 318

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 20
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 57 7 0.04689911279209702
# # of hinge sites for first 3 modes, overlap, hyper score 54 7 0.03556518389993091
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 56 7 0.042879960080688284
# # of hinge sites for first 3 modes, overlap, hyper score 54 7 0.03556518389993091

# %%
print(sort(Hinges_5))
# Out:
# [ 30  31  32  33  34  43  44  62  63  70  72  73  74  75  76 110 113 114
#  116 118 119 125 126 136 137 139 141 142 149 150 163 164 167 168 194 195
#  196 199 200 201]

# %% [markdown]
# ### write hinges

# %%
# write MSFs
averageEigVals
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)

# %%
includeModes = 3
size = includeModes * 2 + 1 + 2 

curr = zeros((len(MSF), size))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]
curr[:, 5] = averageEigVects[:, 2]

for each in binding:
    curr[each, 0] = each

# %%
currHinge = getHinges_modes3(averageEigVects, 1, hinges[1], bandWidth=15)
currHinge
# Out:
# crossovers [1, 3, 4, 15, 31, 32, 34, 75, 137, 164, 196, 197, 199, 201, 203, 243]
# extend Regions [[0, 1], [2, 3, 4], [14, 15], [30, 31, 32, 33, 34], [74, 75], [136, 137], [163, 164], [195, 196, 197], [198, 199, 200, 201, 202, 203], [242, 243]]
# before merging [[0, 1, 2, 3, 4], [6, 7], [14, 15], [30, 31, 32, 33, 34], [74, 75], [136, 137], [139], [163, 164], [195, 196, 197, 198, 199, 200, 201, 202, 203], [242, 243]]
# Final is [[0, 1, 2, 3, 4, 6, 7], [14, 15], [30, 31, 32, 33, 34], [74, 75], [136, 137], [139], [163, 164], [195, 196, 197, 198, 199, 200, 201, 202, 203], [242, 243]]
# after trimming [[0, 1, 2, 3, 4], [14, 15], [30, 31, 32, 33, 34], [74, 75], [136, 137], [139], [163, 164], [195, 196, 197, 198, 199, 200, 201, 202, 203], [242, 243]]
# after filtering [[2, 3, 1], [14, 15], [31, 32, 33], [74, 75], [136, 137], [163, 164], [200, 201, 196, 199], [242, 243]]
# [32, 33, 163, 164, 196, 199, 136, 137, 74, 75, 200, 201, 14, 15, 31]

# %%
row, col = averageEigVects.shape
hinges = [Hinge0, Hinge1, Hinge2]
for mode in modes:
    currHinge = getHinges_modes3(averageEigVects, mode, hinges[mode], bandWidth=15)
    currList = sort(list(set(list(currHinge)))) # + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

writeAllData('./Data/GR_Method3.txt', curr)
# Out:
# crossovers [12, 44, 70, 73, 74, 126, 195, 236]
# extend Regions [[11, 12], [43, 44], [69, 70], [72, 73, 74], [125, 126], [194, 195, 196], [233, 234, 235, 236]]
# before merging [[11, 12], [43, 44], [69, 70], [72, 73, 74], [123], [125, 126], [194, 195, 196, 197], [232, 233, 234, 235, 236]]
# Final is [[11, 12], [43, 44], [69, 70, 72, 73, 74], [123], [125, 126], [194, 195, 196, 197], [232, 233, 234, 235, 236]]
# after trimming [[11, 12], [43, 44], [69, 70, 72, 73, 74], [123], [125, 126], [194, 195], [235, 236]]
# after filtering [[11, 12], [43, 44], [72, 73, 70], [125, 126], [194, 195], [235, 236]]
# crossovers [1, 3, 4, 15, 31, 32, 34, 75, 137, 164, 196, 197, 199, 201, 203, 243]
# extend Regions [[0, 1], [2, 3, 4], [14, 15], [30, 31, 32, 33, 34], [74, 75], [136, 137], [163, 164], [195, 196, 197], [198, 199, 200, 201, 202, 203], [242, 243]]
# before merging [[0, 1, 2, 3, 4], [6, 7], [14, 15], [30, 31, 32, 33, 34], [74, 75], [136, 137], [139], [163, 164], [195, 196, 197, 198, 199, 200, 201, 202, 203], [242, 243]]
# Final is [[0, 1, 2, 3, 4, 6, 7], [14, 15], [30, 31, 32, 33, 34], [74, 75], [136, 137], [139], [163, 164], [195, 196, 197, 198, 199, 200, 201, 202, 203], [242, 243]]
# after trimming [[0, 1, 2, 3, 4], [14, 15], [30, 31, 32, 33, 34], [74, 75], [136, 137], [139], [163, 164], [195, 196, 197, 198, 199, 200, 201, 202, 203], [242, 243]]
# after filtering [[2, 3, 1], [14, 15], [31, 32, 33], [74, 75], [136, 137], [163, 164], [200, 201, 196, 199], [242, 243]]
# crossovers [30, 31, 34, 35, 63, 74, 75, 77, 107, 110, 111, 113, 115, 117, 119, 120, 126, 127, 140, 142, 143, 150, 168]
# extend Regions [[29, 30, 31], [33, 34, 35], [62, 63], [73, 74, 75, 76, 77], [106, 107], [109, 110, 111], [112, 113, 114, 115, 116, 117, 118, 119, 120], [125, 126, 127], [139, 140, 141, 142, 143], [149, 150], [167, 168]]
# before merging [[27], [29, 30, 31, 32, 33, 34, 35], [38], [62, 63], [66], [73, 74, 75, 76, 77], [106, 107], [109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121], [123], [125, 126, 127], [129], [139, 140, 141, 142, 143], [149, 150], [167, 168]]
# Final is [[27, 29, 30, 31, 32, 33, 34, 35, 38], [62, 63], [66], [73, 74, 75, 76, 77], [106, 107, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 123, 125, 126, 127, 129], [139, 140, 141, 142, 143], [149, 150], [167, 168]]
# after trimming [[29, 30, 31, 32, 33, 34, 35], [62, 63], [66], [73, 74, 75, 76, 77], [106, 107, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 123, 125, 126, 127], [139, 140, 141, 142, 143], [149, 150], [167, 168]]
# after filtering [[30, 31, 34], [62, 63], [73, 74, 76], [118, 119, 113, 110, 114, 116], [141, 142, 139], [149, 150], [167, 168]]

# %% [markdown]
# # Plot graph

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import math
import numpy as np

def format_significant(value, pos):
    if abs(value) <= 0.01:
        return "0.00"
    else:
        order_of_magnitude = math.floor(math.log10(abs(value)))
        round_digits = -order_of_magnitude + 1
        formatted_number = round(value, round_digits)
        str_format = "{:." + str(round_digits) + "f}"
        return str_format.format(formatted_number)

# %% [markdown]
# # Plot single graph

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import math
import numpy as np

def format_significant(value, pos):
    if abs(value) <= 0.01:
        return "0.00"
    else:
        order_of_magnitude = math.floor(math.log10(abs(value)))
        round_digits = -order_of_magnitude + 1
        formatted_number = round(value, round_digits)
        str_format = "{:." + str(round_digits) + "f}"
        return str_format.format(formatted_number)

# %%
def plotSingleGraph(mode, averageEigVects, gnms, binding, Hinge):
    fig, ax = plt.subplots(figsize=(20, 10))   # Adjust size as per requirement
    
    plt.sca(ax)  # Set current axis to 'ax'
    
    # Increase font sizes
    plt.rc('xtick', labelsize=40)
    plt.rc('ytick', labelsize=50)
    plt.rcParams.update({'font.size': 50})

    # plot mode of motion
    showSignatureMode(gnms[:, mode], linewidth=3)

    # Hinges within band
    # method1
    # currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    # method2
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=15)
    currHinge = filterTwoEnds(currHinge, [[0, 318]], 15)
    
    currHinge = [x for x in currHinge if x != 285]
    currHinge = [x for x in currHinge if x != 289]
    
    
    HingeY = [averageEigVects[item, mode] for item in currHinge]
    print ('Hinge residue with wide bands', currHinge)
    plt.plot(currHinge, HingeY, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # extraHinges for local loops
    updateHinge = [item for item in Hinge if item not in currHinge]
    HingeY_local = [averageEigVects[item, mode] for item in updateHinge]
    print ('local loop motion', updateHinge)
    plt.plot(updateHinge, HingeY_local, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # plot binding sites
    bindingY = [averageEigVects[item, mode] for item in binding]
    plt.plot(binding, bindingY, 'r*', markersize=18)
    print ('current bindings are', binding)
    plt.title('Mode ' + str(mode + 1), fontweight="bold")

    # plot overlaps
    allHinge = updateHinge + currHinge
    overlaps = [item for item in binding if item in allHinge]
    overlapsY = [averageEigVects[item, mode] for item in overlaps]
    print ('current hits are', overlaps)
    plt.plot(overlaps, overlapsY, 'mD', markersize=18)

    print('# of overlaps finding from current mode is', len(overlaps))
    
    # Set y-ticks to have 4-5 values with equal spacing
    y_min, y_max = ax.get_ylim()
    ax.set_yticks(np.linspace(y_min * 0.9, y_max, 5))  # Adjust the number 5 if you want a different number of y-ticks
    ax.yaxis.set_major_formatter(FuncFormatter(format_significant)) 
    
    plt.tight_layout()
    plt.savefig('./AKR1C3_method1_similarUpdate_mode' + str(mode + 1) + '.png', dpi=500)

# %%
modes = 0 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [195, 68, 69, 198, 196, 197, 44, 45, 206, 207, 300, 301, 184, 185, 61, 62, 63]
# local loop motion []
# current bindings are [18, 21, 48, 49, 50, 52, 80, 111, 112, 113, 114, 161, 210, 211, 300, 301, 305, 313]
# current hits are [300, 301]
# # of overlaps finding from current mode is 2

# %%
modes = 1 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [259, 260, 109, 110, 79, 80, 144, 145, 276, 277, 89, 90, 157, 158]
# local loop motion []
# current bindings are [18, 21, 48, 49, 50, 52, 80, 111, 112, 113, 114, 161, 210, 211, 300, 301, 305, 313]
# current hits are [80]
# # of overlaps finding from current mode is 1

# %%
modes = 2 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [262, 263, 136, 137, 282, 283, 284, 286, 298, 299, 73, 74, 79, 80, 210, 211, 212, 85, 86, 213, 94, 96, 97, 102, 103, 113, 114, 252, 253]
# local loop motion []
# current bindings are [18, 21, 48, 49, 50, 52, 80, 111, 112, 113, 114, 161, 210, 211, 300, 301, 305, 313]
# current hits are [80, 113, 114, 210, 211]
# # of overlaps finding from current mode is 5

# %%
def plotSingleGraph_method3(mode, averageEigVects, gnms, binding, Hinge):
    fig, ax = plt.subplots(figsize=(15, 10))   # Adjust size as per requirement
    
    plt.sca(ax)  # Set current axis to 'ax'
    
    # Increase font sizes
    plt.rc('xtick', labelsize=40)
    plt.rc('ytick', labelsize=50)
    plt.rcParams.update({'font.size': 50})

    # plot mode of motion
    showSignatureMode(gnms[:, mode], linewidth=3)

    # Hinges within band
    # method3
    currHinge = getHinges_modes3(averageEigVects, mode, Hinge, bandWidth = 15)
    
    
    HingeY = [averageEigVects[item, mode] for item in currHinge]
    print ('Hinge residue with wide bands', currHinge)
    plt.plot(currHinge, HingeY, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # extraHinges for local loops
    # updateHinge = [item for item in Hinge if item not in currHinge]
    # HingeY_local = [averageEigVects[item, mode] for item in updateHinge]
    # print ('local loop motion', updateHinge)
    # plt.plot(updateHinge, HingeY_local, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # plot binding sites
    bindingY = [averageEigVects[item, mode] for item in binding]
    plt.plot(binding, bindingY, 'r*', markersize=18)
    print ('current bindings are', binding)
    plt.title('Mode ' + str(mode + 1), fontweight="bold")

    # plot overlaps
    allHinge = currHinge
    overlaps = [item for item in binding if item in allHinge]
    overlapsY = [averageEigVects[item, mode] for item in overlaps]
    print ('current hits are', overlaps)
    plt.plot(overlaps, overlapsY, 'mD', markersize=18)

    print('# of overlaps finding from current mode is', len(overlaps))
    
    # Set y-ticks to have 4-5 values with equal spacing
    y_min, y_max = ax.get_ylim()
    ax.set_yticks(np.linspace(y_min * 0.9, y_max, 5))  # Adjust the number 5 if you want a different number of y-ticks
    ax.yaxis.set_major_formatter(FuncFormatter(format_significant)) 
    
    plt.tight_layout()
    plt.savefig('./GR_method3_mode' + str(mode + 1) + '.png', dpi=500)

# %%
Hinge0
# Out:
# [11, 44, 70, 72, 73, 123, 125, 197, 232]

# %%
modes = 0 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, Hinge0)
# Out:
# debug regions, hinges [[11, 12], [43, 44], [69, 70], [72, 73, 74], [125, 126], [194, 195, 196], [233, 234, 235, 236]] [11, 44, 70, 72, 73, 123, 125, 197, 232]
# Hinge residue with wide bands [194, 195, 70, 72, 73, 43, 11, 12, 44, 235, 236, 125, 126]
# current bindings are [30, 210, 206, 209, 31, 34, 37, 38, 41, 75, 79, 82, 76, 72, 117, 35, 207, 220, 71, 116, 119, 40, 44, 78, 74, 81, 77, 83, 39, 42, 80, 36, 33, 73, 208, 93]
# current hits are [72, 44, 73]
# # of overlaps finding from current mode is 3

# %%
modes = 1 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, Hinge1)
# Out:
# debug regions, hinges [[0, 1], [2, 3, 4], [14, 15], [30, 31, 32, 33, 34], [74, 75], [136, 137], [163, 164], [195, 196, 197], [198, 199, 200, 201, 202, 203], [242, 243]] [6, 7, 14, 30, 74, 139, 163, 196, 200, 202, 243]
# Hinge residue with wide bands [32, 33, 163, 164, 196, 199, 136, 137, 74, 75, 200, 201, 14, 15, 31]
# current bindings are [30, 210, 206, 209, 31, 34, 37, 38, 41, 75, 79, 82, 76, 72, 117, 35, 207, 220, 71, 116, 119, 40, 44, 78, 74, 81, 77, 83, 39, 42, 80, 36, 33, 73, 208, 93]
# current hits are [31, 75, 74, 33]
# # of overlaps finding from current mode is 4

# %%
modes = 2 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, Hinge2)
# Out:
# debug regions, hinges [[29, 30, 31], [33, 34, 35], [62, 63], [73, 74, 75, 76, 77], [106, 107], [109, 110, 111], [112, 113, 114, 115, 116, 117, 118, 119, 120], [125, 126, 127], [139, 140, 141, 142, 143], [149, 150], [167, 168]] [27, 32, 33, 35, 38, 66, 73, 76, 110, 113, 117, 119, 121, 123, 125, 127, 129, 140, 143, 149, 167]
# Hinge residue with wide bands [139, 141, 142, 149, 150, 30, 31, 34, 167, 168, 62, 63, 73, 74, 76, 110, 113, 114, 116, 118, 119]
# current bindings are [30, 210, 206, 209, 31, 34, 37, 38, 41, 75, 79, 82, 76, 72, 117, 35, 207, 220, 71, 116, 119, 40, 44, 78, 74, 81, 77, 83, 39, 42, 80, 36, 33, 73, 208, 93]
# current hits are [30, 31, 34, 76, 116, 119, 74, 73]
# # of overlaps finding from current mode is 8

# %%
ORA(36, 247, 45, 14)
# Out:
# 0.0012366703910227095

# %% [markdown]
# # Write Modes

# %%
len(averageEigVects[:, 0])
# Out:
# 318

# %%
mode = 2

# %%
residue = []
new_b_factor = []

for item in averageEigVects[:, mode]:
    new_b_factor.append(item)

# %%
resiIndex = [x for x in range(6, 324)]
chain = ['A' for x in range(6, 324)]

# %%
with open('./structure_demo/AKR1C3_b_mode' + str(mode + 1) + '.txt', 'w') as wf:
    for i in range(len(resiIndex)):
        # print (chain[i])
        wf.write(chain[i] + ', ' + str(resiIndex[i]) + ', ' + str(new_b_factor[i]) + '\n')

# %%
# !pwd
# Out:
# /data/frank/Desktop/Hinges_Figures_all/Aldo-keto_reductase

# %%
len(resiIndex)
# Out:
# 318
