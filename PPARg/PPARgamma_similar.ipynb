# %%
# -*- coding: utf-8 -*-
"""This module defines functions for Dali searching Protein Data Bank."""

import re
import numpy as np
from prody.atomic import Atomic, AtomGroup, AtomMap
from prody.proteins.pdbfile import _getPDBid
from prody.measure import getRMSD, getTransformation
from prody.utilities import checkCoords, checkWeights, createStringIO
from prody import LOGGER, PY3K
from prody import parsePDB, writePDBStream
# if PY3K:
    # import urllib.parse as urllib
    # import urllib.request as urllib2
# else:
    # import urllib
    # import urllib2
from prody.ensemble import Ensemble
from prody.ensemble import PDBEnsemble
import os

__all__ = ['DaliRecord', 'searchDali', 
           'daliFilterMultimer', 'daliFilterMultimers']

def searchDal(pdb, chain=None, subset='fullPDB', daliURL=None, **kwargs):
    """Search Dali server with input of PDB ID (or local PDB file) and chain ID.
    Dali server: http://ekhidna2.biocenter.helsinki.fi/dali/
    
    :arg pdb: PDB code or local PDB file for the protein to be searched

    :arg chain: chain identifier (only one chain can be assigned for PDB)
    :type chain: str

    :arg subset: fullPDB, PDB25, PDB50, PDB90
    :type subset: str
    """
    
    import requests
    
    LOGGER.timeit('_dali')
    # timeout = 120
    timeout = kwargs.pop('timeout', 120)
    
    if daliURL is None:
        daliURL = "http://ekhidna2.biocenter.helsinki.fi/cgi-bin/sans/dump.cgi"
    
    if isinstance(pdb, Atomic):
        atoms = pdb
        chain_set = set(atoms.getChids())
        if chain and not chain in chain_set:
            raise ValueError('input structure (%s) does not have chain %s'%(atoms.getTitle(), chain))
        
        if len(chain_set) > 1:
            if not chain:
                raise TypeError('the structure (%s) contains more than one chain, therefore a chain identifier '
                                'needs to be specified'%pdb.getTitle())
            atoms = atoms.select('chain '+chain)
        else:
            chain = chain_set.pop()
            
        stream = createStringIO()
        writePDBStream(stream, atoms)
        data = stream.getvalue()
        stream.close()
        files = {"file1" : data}

        pdbId = atoms.getTitle()
        pdb_chain = ''
        dali_title = 'Title_'+pdbId+chain
    elif isinstance(pdb, str):
        if os.path.isfile(pdb):
            atoms = parsePDB(pdb)
            chain_set = set(atoms.getChids())
            # pdbId = "s001"
            filename = os.path.basename(pdb)
            filename, ext = os.path.splitext(filename)
            if ext.lower() == '.gz':
                filename2, ext2 = os.path.splitext(filename)
                if ext2.lower() == '.pdb':
                    filename = filename2
            pdbId = filename
            if chain and not chain in chain_set:
                raise ValueError('input PDB file does not have chain ' + chain)
            
            if len(chain_set) > 1:
                if not chain:
                    raise TypeError('PDB file (%s) contains more than one chain, therefore a chain identifier '
                                    'needs to be specified'%pdb)
                atoms = atoms.select('chain '+chain)
                #local_temp_pdb = pdbId+chain+'.pdb'
                #local_temp_pdb = 's001'+chain+'.pdb'
                stream = createStringIO()
                writePDBStream(stream, atoms)
                data = stream.getvalue()
                stream.close()
            else:
                data = open(pdb, "rb")
                chain = chain_set.pop()
            files = {"file1" : data}
            # case: multiple chains.             apply fetch ? multiple times?
            pdb_chain = ''
            dali_title = 'Title_' + pdbId + chain
        else:
            pdbId, ch = _getPDBid(pdb)
            if not chain:
                chain = ch
            if not chain:
                raise TypeError('a chain identifier is needed for the search')
            pdb_chain = pdbId + chain
            dali_title = 'Title_' + pdb_chain
            files = ''
    parameters = { 'cd1' : pdb_chain, 'method': 'search', 'title': dali_title, 'address': '' }
    # enc_params = urllib.urlencode(parameters).encode('utf-8')
    # request = urllib2.Request(daliURL, enc_params)
    request = requests.post(daliURL, parameters, files=files)
    try_error = 3
    while try_error >= 0:
        try:
            # url = urllib2.urlopen(request).url
            url = request.url
            break
        except:
            try_error -= 1
            if try_error >= 0:
                LOGGER.sleep(2, '. Connection error happened. Trying to reconnect...')
                continue
            else:
                # url = urllib2.urlopen(request).url
                url = request.url
                break
    if url.split('.')[-1].lower() in ['html', 'php']:
        # print('test -1: '+url)
        url = url.replace(url.split('/')[-1], '')
    LOGGER.debug('Submitted Dali search for PDB "{0}{1}".'.format(pdbId, chain))
    LOGGER.info(url)
    LOGGER.clear()
    
    return DaliRecor(url, pdbId, chain, subset=subset, timeout=timeout, **kwargs)
    

class DaliRecor(object):

    """A class to store results from Dali PDB search."""

    def __init__(self, url, pdbId, chain, subset='fullPDB', localFile=False, **kwargs):
        """Instantiate a DaliRecord object instance.

        :arg url: url of Dali results page or local dali results file
        :arg pdbId: PDB code for searched protein
        :arg chain: chain identifier (only one chain can be assigned for PDB)
        :arg subset: fullPDB, PDB25, PDB50, PDB90. Ignored if localFile=True (url is a local file)
        :arg localFile: whether provided url is a path for a local dali results file
        """

        self._url = url
        self._pdbId = pdbId
        self._chain = chain
        subset = subset.upper()
        if subset == "FULLPDB" or subset not in ["PDB25", "PDB50", "PDB90"]:
            self._subset = ""
        else:
            self._subset = "-"+subset[3:]
        timeout = kwargs.pop('timeout', 120)

        self._title = pdbId + '-' + chain
        self._alignPDB = None
        self._filterDict = None
        self._max_index = None
        self.fetch(self._url, localFile=localFile, timeout=timeout, **kwargs)

    def fetch(self, url=None, localFile=False, **kwargs):
        """Get Dali record from url or file.

        :arg url: url of Dali results page or local dali results file
            If None then the url already associated with the DaliRecord object is used.
        :type url: str

        :arg localFile: whether provided url is a path for a local dali results file
        :type localFile: bool

        :arg timeout: amount of time until the query times out in seconds
            default value is 120
        :type timeout: int

        :arg localfolder: folder in which to find the local file
            default is the current folder
        :type localfolder: str
        """
        if localFile:
            dali_file = open(url, 'r')
            data = dali_file.read()
            dali_file.close()
        else:
            import requests
            
            if url == None:
                url = self._url
            
            sleep = 2
            timeout = kwargs.pop('timeout', 120)
            LOGGER.timeit('_dali')
            log_message = ''
            try_error = 3
            while True:
                LOGGER.write('Connecting to Dali for search results...')
                LOGGER.clear()
                try:
                    # html = urllib2.urlopen(url).read()
                    html = requests.get(url).content
                except:
                    try_error -= 1
                    if try_error >= 0:
                        LOGGER.sleep(2, '. Connection error happened. Trying to reconnect...')
                        continue
                    else:
                        # html = urllib2.urlopen(url).read()
                        html = requests.get(url).content
                if PY3K:
                    html = html.decode()
                if html.find('Status: Queued') > -1:
                    log_message = '(Dali search is queued)...'
                elif html.find('Status: Running') > -1:
                    log_message = '(Dali search is running)...'
                elif html.find('Your job') == -1 and html.find('.txt') > -1:
                    break
                elif html.find('ERROR:') > -1:
                    LOGGER.warn(': Dali search reported an ERROR!')
                    self.isSuccess = False
                    return False
                sleep = 20 if int(sleep * 1.5) >= 20 else int(sleep * 1.5)
                if LOGGER.timing('_dali') > timeout:
                    LOGGER.warn(': Dali search has timed out. \nThe results can be obtained later using the fetch() method.')
                    self.isSuccess = False
                    return False
                LOGGER.sleep(int(sleep), 'to reconnect to Dali '+log_message)
                LOGGER.clear()
            LOGGER.clear()
            LOGGER.report('Dali results were fetched in %.1fs.', '_dali')
            lines = html.strip().split('\n')
            file_name = re.search('=.+-90\\.txt', html).group()[1:]
            file_name = file_name[:-7]
            # LOGGER.info(url+file_name+self._subset+'.txt')
            # data = urllib2.urlopen(url+file_name+self._subset+'.txt').read()
            data = requests.get(url+file_name+self._subset+'.txt').content
            if PY3K:
                data = data.decode()
            localfolder = kwargs.pop('localfolder', '.')

            if file_name.lower().startswith('s001'):
                temp_name = self._pdbId + self._chain
            else:
                temp_name = file_name
            temp_name += self._subset + '_dali.txt'
            if localfolder != '.' and not os.path.exists(localfolder):
                os.mkdir(localfolder)
            with open(localfolder+os.sep+temp_name, "w") as file_temp: file_temp.write(html + '\n' + url+file_name+self._subset+'.txt' + '\n' + data)
            # with open(temp_name, "a+") as file_temp: file_temp.write(url+file_name + '\n' + data)
        data_list = data.strip().split('# ')
        # No:  Chain   Z    rmsd lali nres  %id PDB  Description -> data_list[3]
        # Structural equivalences -> data_list[4]
        # Translation-rotation matrices -> data_list[5]
        map_temp_dict = dict()
        lines = data_list[4].strip().split('\n')
        self._lines_4 = lines
        mapping_temp = np.genfromtxt(lines[1:], delimiter = (4,1,14,6,2,4,4,5,2,4,4,3,5,4,3,5,6,3,5,4,3,5,28), 
                                     usecols = [0,3,5,7,9,12,15,15,18,21], dtype='|i4')
        # [0,3,5,7,9,12,15,15,18,21] -> [index, residue_a, residue_b, residue_i_a, residue_i_b, resid_a, resid_b, resid_i_a, resid_i_b]
        for map_i in mapping_temp:
            if not map_i[0] in map_temp_dict:
                map_temp_dict[map_i[0]] = [[map_i[1], map_i[2], map_i[3], map_i[4]]]
            else:
                map_temp_dict[map_i[0]].append([map_i[1], map_i[2], map_i[3], map_i[4]])
        self._max_index = max(mapping_temp[:,2])
        self._mapping = map_temp_dict
        self._data = data_list[3]
        lines = data_list[3].strip().split('\n')
        # daliInfo = np.genfromtxt(lines[1:], delimiter = (4,3,6,5,5,5,6,5,57), usecols = [0,2,3,4,5,6,7,8], 
                                # dtype=[('id', '<i4'), ('pdb_chain', '|S6'), ('Z', '<f4'), ('rmsd', '<f4'), 
                                # ('len_align', '<i4'), ('nres', '<i4'), ('identity', '<i4'), ('title', '|S70')])
        daliInfo = np.genfromtxt(lines[1:], delimiter = (4,3,6,5,5,5,6,5,57), usecols = [0,2,3,4,5,6,7,8], 
                                dtype=[('id', '<i4'), ('pdb_chain', '|U6'), ('Z', '<f4'), ('rmsd', '<f4'), 
                                ('len_align', '<i4'), ('nres', '<i4'), ('identity', '<i4'), ('title', '|U70')])
        if daliInfo.ndim == 0:
            daliInfo = np.array([daliInfo])
        pdbListAll = []
        self._daliInfo = daliInfo
        dali_temp_dict = dict()
        for temp in self._daliInfo:
            temp_dict = dict()
            pdb_chain = temp[1].strip()[0:6]
            # U6 and U70 were used as the dtype for np.genfromtext -> unicode string were used in daliInfo 
            # if PY3K:
                # pdb_chain = pdb_chain.decode()
            pdb_chain = str(pdb_chain)
            temp_dict['pdbId'] = pdbid = pdb_chain[0:4].lower()
            temp_dict['chainId'] = chid = pdb_chain[5:6]
            temp_dict['pdb_chain'] = pdb_chain = pdbid + chid
            temp_dict['Z'] = temp[2]
            temp_dict['rmsd'] = temp[3]
            temp_dict['len_align'] = temp[4]
            temp_dict['nres'] = temp[5]
            temp_dict['identity'] = temp[6]
            temp_dict['mapping'] = (np.array(map_temp_dict[temp[0]])-1).tolist()
            temp_dict['map_ref'] = [x for map_i in (np.array(map_temp_dict[temp[0]])-1).tolist() for x in range(map_i[0], map_i[1]+1)]
            temp_dict['map_sel'] = [x for map_i in (np.array(map_temp_dict[temp[0]])-1).tolist() for x in range(map_i[2], map_i[3]+1)]
            dali_temp_dict[pdb_chain] = temp_dict
            pdbListAll.append(pdb_chain)
        self._pdbListAll = tuple(pdbListAll)
        self._pdbList = self._pdbListAll
        self._alignPDB = dali_temp_dict
        LOGGER.info('Obtained ' + str(len(pdbListAll)) + ' PDB chains from Dali for '+self._pdbId+self._chain+'.')
        self.isSuccess = True
        return True
        
    def getPDBs(self, filtered=True):
        """Returns PDB list (filters may be applied)"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')
        
        if filtered:
            return self._pdbList
        return self._pdbListAll
        
    def getHits(self):
        """Returns the dictionary associated with the DaliRecord"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')

        return self._alignPDB
        
    def getFilterList(self):
        """Returns a list of PDB IDs and chains for the entries that were filtered out"""
        
        filterDict = self._filterDict
        if filterDict is None:
            raise ValueError('You cannot obtain the list of filtered out entries before doing any filtering.')

        temp_str = ', '.join([str(len(filterDict['len'])), str(len(filterDict['rmsd'])), 
                            str(len(filterDict['Z'])), str(len(filterDict['identity']))])
        LOGGER.info('Filtered out [' + temp_str + '] for [length, RMSD, Z, identity]')
        return self._filterList

    
    def getMapping(self, key):
        """Get mapping for a particular entry in the DaliRecord"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')
            return None
        
        try:
            info = self._alignPDB[key]
            mapping = [info['map_ref'], info['map_sel']]
        except KeyError:
            return None
        return mapping

    def getMappings(self):
        """Get all mappings in the DaliRecord"""

        if self._alignPDB is None:
            LOGGER.warn('Dali Record does not have any data yet. Please run fetch.')
            return None

        map_dict = {}
        for key in self._alignPDB:
            info = self._alignPDB[key]
            mapping = [info['map_ref'], info['map_sel']]
            map_dict[key] = mapping
        return map_dict

    mappings = property(getMappings)

    def filter(self, cutoff_len=None, cutoff_rmsd=None, cutoff_Z=None, cutoff_identity=None):
        """Filters out PDBs from the PDBList and returns the PDB list.
        PDBs that satisfy any of the following criterion will be filtered out.
        (1) Length of aligned residues < cutoff_len (must be an integer or a float between 0 and 1);
        (2) RMSD < cutoff_rmsd (must be a positive number);
        (3) Z score < cutoff_Z (must be a positive number);
        (4) Identity > cutoff_identity (must be an integer or a float between 0 and 1).
        """
        if self._max_index is None:
            LOGGER.warn('DaliRecord has no data. Please use the fetch() method.')
            return None

        if cutoff_len == None:
            # cutoff_len = int(0.8*self._max_index)
            cutoff_len = 0.00000001
        elif not isinstance(cutoff_len, (float, int)):
            raise TypeError('cutoff_len must be a float or an integer')
        elif cutoff_len <= 1 and cutoff_len > 0:
            cutoff_len = int(cutoff_len*self._max_index)
        elif cutoff_len <= self._max_index and cutoff_len > 0:
            cutoff_len = int(cutoff_len)
        else:
            raise ValueError('cutoff_len must be a float between 0 and 1, or an int not greater than the max length')
            
        if cutoff_rmsd == None:
            cutoff_rmsd = 1000
        elif not isinstance(cutoff_rmsd, (float, int)):
            raise TypeError('cutoff_rmsd must be a float or an integer')
        elif cutoff_rmsd >= 0:
            cutoff_rmsd = float(cutoff_rmsd)
        else:
            raise ValueError('cutoff_rmsd must be a number not less than 0')
            
        if cutoff_Z == None:
            cutoff_Z = 0
        elif not isinstance(cutoff_Z, (float, int)):
            raise TypeError('cutoff_Z must be a float or an integer')
        elif cutoff_Z >= 0:
            cutoff_Z = float(cutoff_Z)
        else:
            raise ValueError('cutoff_Z must be a number not less than 0')
            
        if cutoff_identity == None or cutoff_identity == 0:
            cutoff_identity = 0
        elif not isinstance(cutoff_identity, (float, int)):
            raise TypeError('cutoff_identity must be a float or an integer')
        elif cutoff_identity <= 1 and cutoff_identity > 0:
            cutoff_identity = float(cutoff_identity*100)
        elif cutoff_identity <= 100 and cutoff_identity > 0:
            cutoff_identity = float(cutoff_identity)
        else:
            raise ValueError('cutoff_identity must be a float between 0 and 1, or a number between 0 and 100')
            
        # debug:
        # print('cutoff_len: ' + str(cutoff_len) + ', ' + 'cutoff_rmsd: ' + str(cutoff_rmsd) + ', ' + 'cutoff_Z: ' + str(cutoff_Z) + ', ' + 'cutoff_identity: ' + str(cutoff_identity))
        
        daliInfo = self._alignPDB
        if daliInfo is None:
            raise ValueError("Dali Record does not have any data yet. Please run fetch.")

        pdbListAll = self._pdbListAll
        missing_ind_dict = dict()
        ref_indices_set = set(range(self._max_index))
        filterListLen = []
        filterListRMSD = []
        filterListZ = []
        filterListIdentity = []
        
        RMSDs = []
        
        # keep the first PDB (query PDB)
        for pdb_chain in pdbListAll[1:]:
            temp_dict = daliInfo[pdb_chain]
            # print ('currRMSD', temp_dict['rmsd'])
            # filter: len_align, identity, rmsd, Z
            RMSDs.append(temp_dict['rmsd'])
            if temp_dict['len_align'] < cutoff_len:
                # print('Filter out ' + pdb_chain + ', len_align: ' + str(temp_dict['len_align']))
                filterListLen.append(pdb_chain)
                continue
            if temp_dict['rmsd'] > cutoff_rmsd:
                # print('Filter out ' + pdb_chain + ', rmsd: ' + str(temp_dict['rmsd']))
                filterListRMSD.append(pdb_chain)
                # print ('currRMSD', temp_dict['rmsd'])
                # print(pdb_chain)
                continue
            if temp_dict['Z'] < cutoff_Z:
                # print('Filter out ' + pdb_chain + ', Z: ' + str(temp_dict['Z']))
                filterListZ.append(pdb_chain)
                continue
            if temp_dict['identity'] < cutoff_identity:
                # print('Filter out ' + pdb_chain + ', identity: ' + str(temp_dict['identity']))
                filterListIdentity.append(pdb_chain)
                continue
            temp_diff = list(ref_indices_set - set(temp_dict['map_ref']))
            for diff_i in temp_diff:
                if not diff_i in missing_ind_dict:
                    missing_ind_dict[diff_i] = 1
                else:
                    missing_ind_dict[diff_i] += 1
        self._missing_ind_dict = missing_ind_dict
        
        filterList = filterListLen + filterListRMSD + filterListZ + filterListIdentity
        filterDict = {'len': filterListLen, 'rmsd': filterListRMSD, 'Z': filterListZ, 'identity': filterListIdentity}
        self._filterList = filterList
        self._filterDict = filterDict
        self._pdbList = [self._pdbListAll[0]] + [item for item in self._pdbListAll[1:] if not item in filterList]
        LOGGER.info(str(len(filterList)) + ' PDBs have been filtered out from '+str(len(pdbListAll))+' Dali hits (remaining: '+str(len(pdbListAll)-len(filterList))+').')
        
        filterRMSD = []
        diverseRMSD = []
        for item in RMSDs:
            if item < cutoff_rmsd:
                filterRMSD.append(item)
            if item > 1.0:
                diverseRMSD.append(item)
        
        print ('RMSD less than ', cutoff_rmsd, mean(filterRMSD), std(filterRMSD))
        print ('RMSD greater than 1A ', mean(diverseRMSD), std(diverseRMSD))
        
        return self._pdbList
    
    def getTitle(self):
        """Return the title of the record"""

        return self._title

def daliFilterMultimer(atoms, dali_rec, n_chains=None):
    """
    Filters multimers to only include chains with Dali mappings.

    :arg atoms: the multimer to be filtered
    :type atoms: :class:`.Atomic`

    :arg dali_rec: the DaliRecord object with which to filter chains
    :type dali_rec: :class:`.DaliRecord`
    """
    if not isinstance(atoms, Atomic):
        raise TypeError("atoms should be an Atomic object")

    if not isinstance(dali_rec, DaliRecord):
        raise TypeError("dali_rec should be a DaliRecord")
    try:
        keys = dali_rec._alignPDB
    except:
        raise AttributeError("Dali Record does not have any data yet. Please run fetch.")

    numChains = 0
    atommap = None
    for i, chain in enumerate(atoms.iterChains()):
        m = dali_rec.getMapping(chain.getTitle()[:4] + chain.getChid())
        if m is not None:
            numChains += 1
            if atommap is None:
                atommap = chain
            else:
                atommap += chain

    if n_chains is None or numChains == n_chains:
        return atommap
    else:
        return None

def daliFilterMultimers(structures, dali_rec, n_chains=None):
    """A wrapper for daliFilterMultimer to apply to multiple structures.
    """
    dali_ags = []
    for entry in structures:
        result = daliFilterMultimer(entry, dali_rec, n_chains)
        if result is not None:
            dali_ags.append(result)
    return dali_ags

# %%
from numpy import *
from matplotlib.pyplot import *
# import os
ion()

# find hinges
def splitHinge(vals, sites, block):
    # split hinges
    currBlock = 1
    index = 0
    isStart = False
    newSites = []
    newVals = []

    for val in vals:
        if block[index] == currBlock and not isStart:
            isStart = True
            currSites = [sites[index]]
            currValLists = [vals[index]]
        elif block[index] == currBlock and isStart:
            currSites.append(sites[index])
            currValLists.append(vals[index])
        else:
            currBlock += 1
            isStart = True
            newSites.append(currSites)
            newVals.append(currValLists)
            currSites = [sites[index]]
            currValLists = [vals[index]]
        if currBlock == block[-1] and index == len(vals) - 1:
            newSites.append(currSites)
            newVals.append(currValLists)
        index += 1
    # print newSites, newVals
    return newSites, newVals


def mini(a, b):
    if a > b:
        return a
    else:
        return b


def checkIfCrossBase(currVal, currSite, currEigenVec):
    identify = sort(currVal)
    ifRemain = True
    if identify[0] < 0 and identify[-1] > 0:
        ifRemain = True
    else:
        maxSite = max(currSite)
        minSite = min(currSite)
        # print (identify)
        if identify[0] >= 0 and identify[-1] >= 0:
            if currEigenVec[max(0, minSite - 1)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 1)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 2)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 3)] < 0:
                ifRemain = True
            else:
                ifRemain = False
        elif identify[0] <= 0 and identify[-1] <= 0:
            # print (len(currEigenVec))
            # print (currEigenVec[239])

            if currEigenVec[max(0, minSite - 1)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 1))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 2))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 3))] > 0:
                ifRemain = True
            else:
                ifRemain = False

        else:
            print(identify[0], identify[-1])
            print("Check!")
    return ifRemain


def oneModeHinge(currEigenVec, thereshold=20):
    range = ((1 / float(len(currEigenVec))) ** 0.5) / thereshold
    # print (range)
    # print range
    sites = []
    vals = []
    block = []

    index = 0
    blockID = 1
    for item in currEigenVec:
        if item <= range and item >= -range:
            vals.append(item)
            if len(sites) >= 1 and abs(sites[-1] - index) > 1:
                blockID += 1
            sites.append(index)
            block.append(blockID)
        index += 1

    newSites, newVals = splitHinge(vals, sites, block)

    filtSites = []
    filtVals = []

    index = 0
    for item in newSites:
        currSite = newSites[index]
        currVal = newVals[index]
        if checkIfCrossBase(currVal, currSite, currEigenVec):
            filtSites.append(currSite)
            filtVals.append(currVal)
        index += 1

    return filtSites, filtVals

def oneModeHinge_update(values, thereshold=20):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    # print (regions)
    
    FinalRegions = []
    for region in regions:
        # print ('before filtering', region)
        if len(region) >= 5:
            # print ('previous region', region)
            pos = [index for index in region if values[index] > 0]
            neg = [index for index in region if values[index] < 0]
            pos.sort(key=lambda x: values[x])
            neg.sort(key=lambda x: values[x], reverse=True)
            n = int(len(region) / 4) + 1
            region = pos[:n] + neg[:n]
            # print (region, neg, pos)
        elif 3 <= len(region) <= 4:
            if values[region[0]-1] * values[region[-1]+1] > 0:
                continue  # Skip this region if adjacent values outside the band have the same sign
        # print ('after filtering',region)      
            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    # print ('Final regions', FinalRegions)
    
    flat = flattenData(FinalRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return FinalRegions, final_values

def getValue(currList):
    newList = []
    for item in currList:
        newList.append(float(item))
    return newList


def readModes(fileName):
    allModes = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.strip()
            line = line.split('\t')
            currMode = line[0]
            currVal = line[1:]
            allModes[currMode] = getValue(currVal)
    return allModes


def flattenData(arrayTwoD):
    flat = []
    for item in arrayTwoD:
        for each in item:
            flat.append(each)
    return flat

def cleanStr(currStr):
    return currStr.strip('\'')

def readFile(fileName):
    data = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.replace('\n', '')
            line = line.strip()
            line = line.split('\t')
            currPDB = line[0]
            currDrug = line[1]
            currChain = line[2:]
            if currPDB not in data.keys():
                data[currPDB] = {}
            if currDrug not in data[currPDB].keys():
                data[currPDB][currDrug] = []
            for each in currChain:
                data[currPDB][currDrug].append(cleanStr(each))
    return data

# contribution of mode of motions
def getContribution(eigenVals, mode):
    allContribution = np.sqrt(np.sum(1 / eigenVals))
    currModeContribution = eigenVals[:mode]
    currContribution = np.sqrt(np.sum(1 / currModeContribution))
    return currContribution / allContribution

def getModesGivenThreshold(eigenVals, thereshold):
    contribution = 0
    mode = 0
    while contribution <= thereshold:
        mode += 1
        contribution = getContribution(eigenVals, mode)
    return mode

def writeBinding(fileName, pdb_ids):
    with open(fileName, 'w') as wf:
        for item in pdb_ids:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')


from prody import *
def getModes(currPDB, eachChain, length = 0.7, rmsd = 1.0, Z = 10):    
    # if not os.path.exists('./Results/' + currPath):
    #     os.mkdir('./Results/' + currPath)
    dali_rec = searchDal(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len = length, cutoff_rmsd = rmsd, cutoff_Z = Z)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    
    ags = parsePDB(pdb_ids, subset='ca')
    dali_ens = buildPDBEnsemble(ags, mapping=mappings, seqid=20)
    gnms = calcEnsembleENMs(dali_ens, model='GNM', trim='reduce', n_modes=None)
    eigVals = gnms.getEigvals()
    averageEigVals = mean(eigVals, axis=0)

    eigVects = gnms.getEigvecs()
    averageEigVects = mean(eigVects, axis=0)
    return averageEigVals, averageEigVects, pdb_ids, gnms, averageEigVects

            
def getDali_info(currPDB, eachChain, rmsd = 2.5, length = 0.9):
    dali_rec = searchDali(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len=length, cutoff_rmsd=rmsd)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    return pdb_ids, mappings

def getHinges(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

def getHinges2(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

def getHinges_modes(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def getHinges_modes2(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge


def get3Hinges_bandwidth(averageEigVects, bandWidths = [15, 16, 17]):
    currHinge = []
    for i in range(3):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidths[i])
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
# Experiment to evaluate performance of hypergeometric p values
from scipy.stats import hypergeom
def ORA(M, N, n, k):
    total = 0
    totalLength = N
    binding = M
    hinge = n
    overlap = k
    
    for i in range(overlap):
        total += hypergeom.pmf(i, totalLength, binding, hinge)
    return 1 - total

import os
def writeIDs(path, idList, chains):
    # Check whether the specified path exists or not
    isExist = os.path.exists(path)
    if not isExist:

       # Create a new directory because it does not exist
       os.makedirs(path)
       print("The new directory is created!")
    
    with open(path + '/ids.txt', 'w') as wf:
        i = 0
        for item in idList:
            wf.write(item[:4] + '\t' + chains[i])
            wf.write('\n')
            i += 1

# %%
def screenIDs(ids):
    newIDs = []
    for item in ids:
        newIDs.append(item[:4])
    return newIDs

# filter transmembrane protein
def filterHinges(Hinges_2, ContinueThreshold = 50, HingeCutoff = 10):
    newHinges = []
    currItem = []
    for item in Hinges_2:
        if currItem == [] or currItem[-1] == item - 1:
            currItem.append(item)
        else:
            newHinges.append(currItem)
            currItem = []

    filteredItem = []
    for item in newHinges:
        if len(item) <= ContinueThreshold:
            filteredItem += item
        else:
            filteredItem += item[:HingeCutoff]
            filteredItem += item[-HingeCutoff:]
    return filteredItem

# %%
def writeNumbers(path, numbers):
    with open(path, 'w') as wf:
        for item in numbers:
            wf.write(str(item) + '\n')

def merge_overlapping_lists(lists):
    sorted_lists = sorted(lists, key=lambda x: x[0])  # Sort lists based on the first element
    merged_lists = [sorted_lists[0]]
    
    for current in sorted_lists[1:]:
        previous = merged_lists[-1]
        # Check if the current list overlaps with the previous one
        if current[0] <= previous[-1]:
            # Merge overlapping lists by updating the last list in merged_lists
            merged_lists[-1] = list(range(min(previous[0], current[0]), max(previous[-1], current[-1])+1))
        else:
            merged_lists.append(current)
    return merged_lists

# %%
def trimEnds(values, lists):
    begining = 14
    ends = len(values) - 15
    isInclude = True
    for item in lists:
        if item < begining or item > ends:
            isInclude = False
    return isInclude

def splitRegions(currlist):
    sortList = sort(currlist)
    
    region_list = []
    currRegion = []
    previous = -1
    for item in sortList:
        if item - previous == 1:
            currRegion.append(item)
            previous = item
        else:
            if currRegion != []:
                region_list.append(currRegion)
            currRegion = [item]
            previous = item
    
    if currRegion not in region_list:
        region_list.append(currRegion)
    return region_list
        
def extendRegions(crossovers, values, thereshold):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    return regions

# %%
def mergeRegions(lists, max_gap=2, min_length=5):
    merged = [lists[0]]  # Start with the first list

    for next_list in lists[1:]:
        # Check if the next list starts within max_gap+1 of the last element of the current last list in 'merged'
        if next_list[0] - merged[-1][-1] <= max_gap + 1:
            # Merge the lists by extending the last list in 'merged' with the elements of 'next_list'
            merged[-1].extend(next_list)
        else:
            # If it doesn't meet the merge criteria, just append the list as a new one
            merged.append(next_list)

    # Filter merged lists to ensure they meet the min_length requirement after removing duplicates and sort them
    # Keep unmerged lists as they are
    final_list = []
    for sublist in merged:
        unique_sublist = sorted(set(sublist))  # Remove duplicates and sort
        if len(unique_sublist) >= min_length or unique_sublist == sublist:  # Check length or unchanged list
            final_list.append(unique_sublist)
        else:
            # For lists that were attempted to merge but didn't meet the length requirement,
            # revert to individual elements as separate lists
            final_list.extend([[item] for item in unique_sublist])

    # print (final_list)
    finals = []
    for item in final_list:
        if len(item) < min_length:
            finals += splitRegions(item)
        else:
            finals.append(item)
    
    return finals

# Function to trim similar sign values from start
def trim_start(lst, index):
    if len(lst) == 1:
        return lst, index
    if not lst:
        return [], []
    start_sign = lst[0] >= 0
    for i in range(1, len(lst)):
        if (lst[i] >= 0) != start_sign:
            return lst[i-1:], index[i-1:]
    return [], []

# Function to trim similar sign values from end
def trim_end(lst, index):
    if len(lst) == 1:
        return lst, index
    
    if not lst:
        return [], []
    lst = lst[::-1]  # Reverse the list for ease of use
    index = index[::-1]
    end_sign = lst[0] >= 0
    for i in range(1, len(lst)):
        if (lst[i] >= 0) != end_sign:
            return lst[i-1:][::-1], index[i-1:][::-1]  # Reverse the list again to restore original order
    return [], []

def trimRegions(region, values):
    newRegion = []
    for eachIndex in region:
        currValues = [values[x] for x in eachIndex]
        # print (eachIndex, currValues)
        # Apply the trimming functions
        trimmed_start, trimmed_index = trim_start(currValues, eachIndex)
        # print (trimmed_index)
        trimmed_end, trimmed_index = trim_end(trimmed_start, trimmed_index)
        newRegion.append(trimmed_index)
    return newRegion

def findSmallestPairs(index_list, value_list):
    # Initialize variables to store the smallest sum and corresponding indices
    smallest_sum = float('inf')  # Set it to infinity initially
    smallest_pair = None

    # Iterate through the value list to find adjacent index pairs with the smallest sum of absolute values
    for i in range(len(value_list) - 1):  # -1 because we are looking at pairs
        current_sum = abs(value_list[i]) + abs(value_list[i + 1])
        if current_sum < smallest_sum:
            smallest_sum = current_sum
            smallest_pair = [index_list[i], index_list[i + 1]]
    return smallest_pair

def find_cross_points(Final_test, crossovers, values):
    crossoverPoints_pairs = []
    for item in Final_test:
        if item in crossovers and item - 1 in Final_test:
            crossoverPoints_pairs.append([item - 1, item])
    
    # print ('cross_pairs', crossoverPoints_pairs)
    # filtering_pairs = mergeRegions(crossoverPoints_pairs, max_gap=0, min_length=3)
    # currNumber = len(filtering_pairs) * 2
    # print ('filtering_pairs', crossoverPoints_pairs)
    
    bestPairs = crossoverPoints_pairs[0]
    bestScore = abs(values[bestPairs[0]]) + abs(values[bestPairs[1]])
    if len(crossoverPoints_pairs) <= 1:
        return bestPairs
    else:
        for item in crossoverPoints_pairs[1:]:
            currScore = abs(values[item[0]]) + abs(values[item[1]])
            # print ('item, score', item, currScore)
            if currScore <= bestScore:
                bestPairs = item
                bestScore = currScore
    
    # print ('filtered', bestPairs)
    return bestPairs

def filteringCriteria(Final, values, crossovers, beforeTrimming):
    FinalRegions = []
    i = 0
    for region in Final:
        # print ('before filtering', region)
        currLength = len(beforeTrimming[i])
        i += 1
        if currLength >= 3:
            allPairs = find_cross_points(region, crossovers, values)
            currRegion = allPairs
            
            # print ('allPairs', allPairs)
            pos = [index for index in region if values[index] > 0]
            neg = [index for index in region if values[index] < 0]
            pos.sort(key=lambda x: values[x])
            neg.sort(key=lambda x: values[x], reverse=True)
            extra = round((len(region) - 2) / 4 + 0.00001)
            
            # rest = pos[1:] + neg[1:]
            # restValues = [values[res] for res in rest]
            # combined_list = sorted(zip(rest, restValues), key=lambda x: abs(x[1]))
            rest = []
            for item in region:
                if item not in currRegion:
                    rest.append(item)
            restValues = [values[res] for res in rest]   
            combined_list = sorted(zip(rest, restValues), key=lambda x: abs(x[1]))
            
            # Extract the sorted indexes from the combined list
            sorted_indexes = [index for index, value in combined_list]
            
            region = currRegion + sorted_indexes[:extra]
            # print (region)
            
        # elif currLength == 3:
            # region = find_cross_points(region, crossovers, values)
            # print (region)
            # if values[region[0]-1] * values[region[-1]+1] > 0:
            #     continue  # Skip this region if adjacent values outside the band have the same sign
        # print ('after filtering',region)      
            
        
        # print ('after filtering',region)      
        elif currLength == 1:
            continue
            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    return FinalRegions

def oneModeHinge_update2(values, hinges, thereshold=20):
    # band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    regions = extendRegions(crossovers, values, thereshold)
    # print ('extend Regions', regions)
    
    # merge regions and hinges
    flat = sort(list(set(flattenData(regions) + hinges)))
    Final = splitRegions(flat)
    # print ('before merging', Final)
    Final = mergeRegions(Final, max_gap=2, min_length=5)
    # print ('Final is', Final)
    # trim Regions
    trimmedFinal = trimRegions(Final, values)
    # print ('after trimming', trimmedFinal)
    
    FinalRegions = filteringCriteria(trimmedFinal, values, crossovers, Final)
    # print ('after filtering', FinalRegions)
    
    # remove frist and last several residues as hinges
    updateRegions = []
    for currReg in FinalRegions:
        if trimEnds(values, currReg):
            updateRegions.append(currReg)
    
    # print (updateRegions)
        
    flat = flattenData(updateRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return updateRegions, final_values

def getHinges_modes3(averageEigVects, mode, hinges, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update2(averageEigVects[:, mode], hinges, thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def getHinges3(averageEigVects, currNumModes, hinges, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update2(averageEigVects[:, i], hinges[i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
def writeAllData(path, curr):
    with open(path, 'w') as wf:
        for row in curr:
            for col in row:
                if col == 0.0:
                    wf.write('' + '\t')
                else:
                    wf.write(str(col) + '\t')
            wf.write('\n')

# %%
# remove first and last hinges for each chain
def filterTwoEnds(hinges, chainLength = [[0, 551], [552, 956]], trimmingLength = 15):
    FilteringIndex = []
    for item in chainLength:
        # print (item)
        FilteringIndex += list(range(item[0], item[0] + trimmingLength))
        FilteringIndex += list(range(item[1] - trimmingLength + 1, item[1] + 1))  
    updateHinges = []
    for item in hinges:
        if item not in FilteringIndex:
            updateHinges.append(item)
    
    return updateHinges

# %% [markdown]
# # Similar ensemble

# %%
currPDB = '6f2l'
eachChain = 'A'

# pdb_ids, mappings = getDali_info(currPDB, eachChain, cutoff_len=0.7, cutoff_rmsd=1.0, cutoff_Z=10)
averageEigVals_A, averageEigVects_A, ids_A, gnms_A, averageEigVects_A = getModes(currPDB, eachChain, length=0.8, rmsd=2, Z=10)
# Out:
# @> Submitted Dali search for PDB "6f2lA".
# @> http://ekhidna2.biocenter.helsinki.fi/barcosel/tmp//6f2lA//
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> Dali results were fetched in 3.5s.
# @> Obtained 1995 PDB chains from Dali for 6f2lA.
# @> 1266 PDBs have been filtered out from 1995 Dali hits (remaining: 729).
# @> Retrieving 6f2lA... [  0%]
# RMSD less than  2.0 1.0323572 0.3046129
# RMSD greater than 1A  2.2770286 1.0478884
# # of similar structures is found from Dali 729
# @> 729 PDBs were parsed in 169.68s.
# @> Mapping 5u3qB_ca to the reference... [ 55%] 7s @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4ci4A_ca to the reference... [ 78%] 4s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4nqaB_ca to the reference... [ 99%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Starting iterative superposition:
# @> Step #1: RMSD difference = 8.5074e-01
# @> Step #2: RMSD difference = 8.3741e-03
# @> Step #3: RMSD difference = 2.2677e-04
# @> Step #4: RMSD difference = 6.7798e-06
# @> Iterative superposition completed in 0.59s.
# @> Final superposition to calculate transformations.
# @> Superposition completed in 0.15 seconds.
# @> Ensemble (726 conformations) were built in 15.86s.
# @> WARNING 3 structures cannot be mapped.
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6f2lA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6dglA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6md4A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 6md1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6c1iA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3hodA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2i4jA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2i4pA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 5lsgA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6dgrA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 6md2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3b3kA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2i4zA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3wmhA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3cdpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6vzoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 5wqxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 6mczA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6dgoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3cdsA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 6aviA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4e4qA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 6jeyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 6vzlA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 8bf2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 2vsrA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 5f9bA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3d6dA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4jl4A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 1i7iA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 5wr1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 4yt1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 6o67A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3adsA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 6md0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 3an4A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 7cxeA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6l8bA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 5wr0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3adwA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3r8iA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 1prgA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 7lotA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 8hhqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 4xumA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 6l89A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 3vsoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2zk0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3x1hA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 2yfeA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 6vzmA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6o68A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 7woxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 5hzcA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 6e5aA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 6vznA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 3vspA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2zk2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3advA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 6zlyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3an3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 5ttoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4e4kA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 1knuA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6augA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3vjhA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 5u5lA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 7efqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 4pvuA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 2vstA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3po9A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 6dh9A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 8wfeA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4xuhA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3adxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3et0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 3ia6A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2zk6A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 6dhaA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 4a4vA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 6an1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 7jqgA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 6dgqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3sz1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3x1iA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2zvtA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 2q8sA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 2vv1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3b0rA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3pbaA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 4a4wA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3oswA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 4r6sA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 6qj5A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 2vv3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 6jf0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 5azvA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 4em9A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2zk5A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 2q5pA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 2vv2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3osiA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 2xkwA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 2vv0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2zk4A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3ho0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3b0qA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 7ahjA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 2q6sA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4jazA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 6d3eA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 3aduA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 6jq7A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 8c0cA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 2vv4A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 1zeoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 5gtpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 4ci5A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 6ijsA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 6t9cA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 7cxjA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 6enqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 7cxgA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2zk3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 3adtA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2zk1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 8adfA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 2znoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 1nyxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3vjiA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 7cxiA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 4r06A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 2pobA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3r8iB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 6dgpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 7rleA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 8dszA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3vn2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 6dgpB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3fejA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 4pwlA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 5ycpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3et3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 5y2oA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3k8sB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 3wj5A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 2hwqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 7rleC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 2q59A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 7cxkA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 5gtoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 7e2oA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 7cxlA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 6ktmA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 2gtkA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 8humA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 5ycnA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 3wj4A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 5dv6A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 6fzpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3g9eA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6dbhA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6fzjB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3u9qA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 4y29A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 7wgoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6izmA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 4r2uA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 5z6sA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 5gtnA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6ms7A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 2q61A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 8hupA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 3kmgD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3cwdB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 5z5sA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 5y2tA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 2q5sA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 2fvjA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2f4bA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 5twoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 8bf1A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6iznA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 4emaA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2g0gA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3ty0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3noaA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 7e0aA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6ktnA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 2hwrA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6d94A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 5ugmB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 8dk4A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 7cxfA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3gbkA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 3cwdA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2athA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 3kmgA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 7awdA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 7wgqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2om9C_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 3bc5A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2om9A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 3h0aD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 6fzjA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 6onjA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 5ugmA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 5ji0D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 3r5nA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 5dv3A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 40 modes for 208 modes from MaskedGNM 1rdtD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 6tsgA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6fzfA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6fzgA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 1fm9D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 8cpiA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6fzfB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 1wm0X_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 6t6bA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 7awcA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 7cxhA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 8atzA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 4f9mA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 4xldA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2prgA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 3s9sA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 3r8aA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 3v9yA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3b1mA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 6t1vA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 1zgyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 5dwlA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 5dshA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 1k74D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 5dvcA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 8dsyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 2om9D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 2om9B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 1fm6D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 6t1sA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 6y3uA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6d8xA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 3lmpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3t03A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3v9vA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 8bffC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2g0hA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 5dv8A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2g0gB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 6fzyB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3qt0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 1fm6X_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 3furA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 8bffA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3gbkB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 6c1iB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4prgC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 3v9tA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 40 modes for 208 modes from MaskedGNM 4heeX_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 40 modes for 208 modes from MaskedGNM 7a7hA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 8bffB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 6fzyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2f4bB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3prgA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 8atyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 6aviB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2athB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 8bf2B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 3kduA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3ia6B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 6md1B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6dhaB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 3sz1B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4prgA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 6dglB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 40 modes for 208 modes from MaskedGNM 7p4eA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 6icjA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2g0hB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 8dsyB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 44 modes for 208 modes from MaskedGNM 2q8sB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 1knuB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 2yfeB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 30 modes for 208 modes from MaskedGNM 2p4yA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 39 modes for 208 modes from MaskedGNM 4xtaA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 3e00D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3noaB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 6d3eB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4a4wB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 6o68B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6ijrA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6a6pA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 37 modes for 208 modes from MaskedGNM 3t03B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 4yt1B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 8hhpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4a4vB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 36 modes for 208 modes from MaskedGNM 6ilqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6ijrC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3wmhB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 3et2A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 6md0B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 1prgB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 3cs8A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 7wgpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 40 modes for 208 modes from MaskedGNM 7jqgB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 4r6sB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 6md2B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 6augB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 2hfpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 2q61B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 6mczB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 40 modes for 208 modes from MaskedGNM 2hwqB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 7bq0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 3kduB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 6vzoB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 47 modes for 208 modes from MaskedGNM 1i7iB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 2vsrB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 40 modes for 208 modes from MaskedGNM 5u5lB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 45 modes for 208 modes from MaskedGNM 6dh9B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 7efqB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 3tkmA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 40 modes for 208 modes from MaskedGNM 6md4B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 2q5sB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 7lotB_ca reduced has been discarded because at least one conformation has only 208 modes
# ...
# @> WARNING last 39 modes for 208 modes from MaskedGNM 6qj5B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 2xyxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 21 modes for 208 modes from MaskedGNM 8b90B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 39 modes for 208 modes from MaskedGNM 5u3xB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 40 modes for 208 modes from MaskedGNM 2znnA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 8b94A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 26 modes for 208 modes from MaskedGNM 8b92B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 34 modes for 208 modes from MaskedGNM 3feiA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 30 modes for 208 modes from MaskedGNM 2vv1B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 7vweA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 4jazB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 30 modes for 208 modes from MaskedGNM 8cphB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 3sp9B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 38 modes for 208 modes from MaskedGNM 2j14B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4e4kB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 38 modes for 208 modes from MaskedGNM 3d5fA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 39 modes for 208 modes from MaskedGNM 6t9cB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 4pwlB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 43 modes for 208 modes from MaskedGNM 2znpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 5u40A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 5aztB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 26 modes for 208 modes from MaskedGNM 8b95B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 35 modes for 208 modes from MaskedGNM 4emaB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 28 modes for 208 modes from MaskedGNM 3x1iB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 24 modes for 208 modes from MaskedGNM 2q6rA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 28 modes for 208 modes from MaskedGNM 3r8aB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 5u41A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 46 modes for 208 modes from MaskedGNM 4l98B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 18 modes for 208 modes from MaskedGNM 8c0cB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 36 modes for 208 modes from MaskedGNM 3oz0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 18 modes for 208 modes from MaskedGNM 8adfB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 32 modes for 208 modes from MaskedGNM 8b93A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 3dzuD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 6c5qA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4prgD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 48 modes for 208 modes from MaskedGNM 4l96A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 49 modes for 208 modes from MaskedGNM 6c5tA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 41 modes for 208 modes from MaskedGNM 5aztA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 4prgB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 32 modes for 208 modes from MaskedGNM 4l98A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 50 modes for 208 modes from MaskedGNM 7sqbA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 16 modes for 208 modes from MaskedGNM 2p4yB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 33 modes for 208 modes from MaskedGNM 6tdcA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 28 modes for 208 modes from MaskedGNM 2q5gA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 6pdzA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 23 modes for 208 modes from MaskedGNM 2q5gB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 38 modes for 208 modes from MaskedGNM 1kkqC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 38 modes for 208 modes from MaskedGNM 1kkqD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 40 modes for 208 modes from MaskedGNM 8aqmB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 38 modes for 208 modes from MaskedGNM 1kkqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 38 modes for 208 modes from MaskedGNM 1kkqB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 39 modes for 208 modes from MaskedGNM 8aqnB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 38 modes for 208 modes from MaskedGNM 8aqmA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 42 modes for 208 modes from MaskedGNM 6dcuA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 37 modes for 208 modes from MaskedGNM 6dcuB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 17 modes for 208 modes from MaskedGNM 6fx0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 16 modes for 208 modes from MaskedGNM 1fcyA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 16 modes for 208 modes from MaskedGNM 1exxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 15 modes for 208 modes from MaskedGNM 1fcxA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 15 modes for 208 modes from MaskedGNM 1fd0A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 17 modes for 208 modes from MaskedGNM 1exaA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 16 modes for 208 modes from MaskedGNM 3lbdA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 16 modes for 208 modes from MaskedGNM 4dm6A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 11 modes for 208 modes from MaskedGNM 7wqqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 15 modes for 208 modes from MaskedGNM 1fczA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 12 modes for 208 modes from MaskedGNM 7apoA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 13 modes for 208 modes from MaskedGNM 4dm8A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 1pqcC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 1uhlB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6s4nC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 3fc6D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 4dk8A_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 3ipuA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 11 modes for 208 modes from MaskedGNM 6s4nA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 4dk8C_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 3fc6B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 6s4nB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 3falD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 3ipqA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 6s4nD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 6s5kA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 2aclB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 6 modes for 208 modes from MaskedGNM 6k9gB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 4 modes for 208 modes from MaskedGNM 3ipsB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 5kyaA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 3ipsA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 6s4tA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 5i4vE_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 2aclD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 2aclF_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 3falB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 3l0eA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 5jy3B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 4rakB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 6k9gC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 5kyaE_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 10 modes for 208 modes from MaskedGNM 5kyjE_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 5avlA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 5 modes for 208 modes from MaskedGNM 5aviC_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 1pq9D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 6 modes for 208 modes from MaskedGNM 1pq6D_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 1pq9B_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 11 modes for 208 modes from MaskedGNM 6k9gA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 4oztE_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 2nxxG_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 2 modes for 208 modes from MaskedGNM 1pqcD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 8 modes for 208 modes from MaskedGNM 5hjpD_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 5hjpB_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7c7wA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 9 modes for 208 modes from MaskedGNM 5i4vA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> WARNING last 3 modes for 208 modes from MaskedGNM 7vqpA_ca reduced has been discarded because at least one conformation has only 208 modes
# @> all GNM modes were calculated for each of the 726 conformations in 30.72s.
# @> 208 modes across 726 modesets were matched in 8.06s.

# %%
currPDB = '6f2l'
eachChain = 'B'

# pdb_ids, mappings = getDali_info(currPDB, eachChain, cutoff_len=0.7, cutoff_rmsd=1.0, cutoff_Z=10)
averageEigVals_B, averageEigVects_B, ids_B, gnms_B, averageEigVects_B = getModes(currPDB, eachChain, length=0.8, rmsd=2, Z=10)
# Out:
# @> Submitted Dali search for PDB "6f2lB".
# @> http://ekhidna2.biocenter.helsinki.fi/barcosel/tmp//6f2lB//
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> Dali results were fetched in 116.6s.
# @> Obtained 1990 PDB chains from Dali for 6f2lB.
# @> 1281 PDBs have been filtered out from 1990 Dali hits (remaining: 709).
# @> Retrieving 6f2lB... [  0%]
# RMSD less than  2.0 1.0823009 0.32859674
# RMSD greater than 1A  2.1923442 0.57283264
# # of similar structures is found from Dali 709
# @> 709 PDBs were parsed in 160.81s.
# @> Mapping 5u3qB_ca to the reference... [ 66%] 5s @> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4ci4A_ca to the reference... [ 89%] 2s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Mapping 4nqaI_ca to the reference... [ 97%] 1s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Starting iterative superposition:
# @> Step #1: RMSD difference = 1.1355e+00
# @> Step #2: RMSD difference = 9.9440e-03
# @> Step #3: RMSD difference = 2.4288e-04
# @> Step #4: RMSD difference = 7.2981e-06
# @> Iterative superposition completed in 0.57s.
# @> Final superposition to calculate transformations.
# @> Superposition completed in 0.14 seconds.
# @> Ensemble (706 conformations) were built in 14.41s.
# @> WARNING 3 structures cannot be mapped.
# @> Calculating all GNM modes for 706 conformations... [ 93%] 2s @> WARNING More than 1 (2) zero eigenvalues were calculated.
# @> Calculating all GNM modes for 706 conformations... [ 93%] 2s@> WARNING More than 1 (2) zero eigenvalues were calculated.
# @> Calculating all GNM modes for 706 conformations... [ 94%] 2s@> WARNING More than 1 (2) zero eigenvalues were calculated.
# @> WARNING last 51 modes for 203 modes from MaskedGNM 6f2lB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 6md1B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 6dh9B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2yfeB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 2vsrB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 6dglB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 1knuB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 6md0B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 6c1iB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 6dhaB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 6aviB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 6md2B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 5lsgB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 6o67B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 3x1hB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 6mczB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 6vzoB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 2xkwB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 3advB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 2zk0B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 6md4B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 6d3eB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 8bf2B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 7lotB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 1i7iB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 4a4wB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 4a4vB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 3ia6B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 2q8sB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zk2B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2i4jB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 7efqB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 6o68B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 6vzmB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3adsB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3d6dB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 6an1B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3adxB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 5u5lB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 6augB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 4r6sB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3hodB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 3sz1B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2i4zB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 1prgB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 4yt1B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 2vv2B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3cdpB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 2q6sB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 4e4qB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 5y2oB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 1nyxB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zk5B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 5ttoB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 7jqgB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 3wmhB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 3pbaB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 3adwB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3b3kB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 3adtB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 8wfeB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 4r2uD_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3cdsB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 4jl4B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 2zk6B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zk3B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 3vspB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 6dgoB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 4r06B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 2q61B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 6vznB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2i4pB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 6dgrB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 3vjhB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 8dszB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 2q59B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zk1B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zk4B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 3an3B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 5wqxB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 3an4B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 6l8bB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 3aduB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 3vsoB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 6e5aB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 6jeyB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 4xumB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zvtB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 5wr1B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 6dbhB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 2vv0B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 3wj5B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 3b0qB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 2znoB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 8hhqB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 2q5sB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 8dsyB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 6dgqB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 4xuhB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 3wj4B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 3oswB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 2q6rB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 7cxeB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 5y2tB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 3k8sA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 39 modes for 203 modes from MaskedGNM 3osiB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 2vstB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 2vv4B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 5wr0B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 6vzlB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 3vjiB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 3b0rB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 7woxB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 4e4kB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 4jazB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 5f9bB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 38 modes for 203 modes from MaskedGNM 6zlyB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 7ahjB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 1zeoB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 5azvB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 6l89B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 3po9B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 36 modes for 203 modes from MaskedGNM 4em9B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3ho0B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 5hzcB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 2q5pB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 2vv3B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 38 modes for 203 modes from MaskedGNM 6qj5B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 4ci5B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3et0B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 34 modes for 203 modes from MaskedGNM 2vv1B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 36 modes for 203 modes from MaskedGNM 6enqB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 4pvuB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 6jf0B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 38 modes for 203 modes from MaskedGNM 6t9cB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 39 modes for 203 modes from MaskedGNM 2hwqB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 4pwlB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 3wmhA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2g0gB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 36 modes for 203 modes from MaskedGNM 2pobB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 6md4A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 6c1iA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2f4bB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 32 modes for 203 modes from MaskedGNM 3x1iB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 6dglA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 4pvuA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3r8iB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3ty0B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 6f2lA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 6vzmA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 34 modes for 203 modes from MaskedGNM 4xtaB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 6dgoA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 5lsgA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2athB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2g0hB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 4xuhA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 7e2oB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 34 modes for 203 modes from MaskedGNM 8b8zB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 6md2A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 5ttoA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 39 modes for 203 modes from MaskedGNM 2hwrB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2i4pA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3sz1A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 5y2oA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 5wqxA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 6dgrA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3gbkB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 7woxA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 6md0A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 6aviA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 8hhqA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3noaB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 7efqA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 6jeyA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 5wr0A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 4yt1A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 6md1A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 7cxgB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 5wr1A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 6jq7A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 6mczA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 3vsoA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 6vzoA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 8b8xB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 8b92A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2i4zA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 5gtpA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2i4jA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3adwA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 8b8zA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 34 modes for 203 modes from MaskedGNM 4emaB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 1knuA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 8bf2A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 35 modes for 203 modes from MaskedGNM 8b8wB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zk0A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 8wfeA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 32 modes for 203 modes from MaskedGNM 8b91B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 3vspA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3adxA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 8b95A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 7cxgA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 7cxjA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 3an4A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3x1hA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zk2A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 7lotA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3vn2A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 6o67A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 5gtoA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 2yfeA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 3wj4A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3r8iA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 1prgA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zvtA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 1i7iA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 6vznA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 6l8bA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 24 modes for 203 modes from MaskedGNM 8c0cB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3hodA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 6izmA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 2vsrA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 4e4qA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 34 modes for 203 modes from MaskedGNM 8b8yB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 5y2tA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 49 modes for 203 modes from MaskedGNM 7e0aA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 6vzlA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3d6dA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 7cxiA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zk6A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 4jl4A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 7cxeA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 4xumA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3oswA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 5f9bA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 3r5nA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 3wj5A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 6augA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 3bc5A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 2vv3A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 6an1A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 8b91A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 31 modes for 203 modes from MaskedGNM 3r8aB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 6zlyA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3cdpA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 5ycpA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 6o68A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 2hwqA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 24 modes for 203 modes from MaskedGNM 8adfB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3an3A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 4a4vA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 7jqgA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 6dhaA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3advA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 7wgoA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 50 modes for 203 modes from MaskedGNM 6iznA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 5u5lA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 2vstA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3cdsA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 6l89A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zk5A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 8humA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 6dh9A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 6dbhA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 7cxkA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 31 modes for 203 modes from MaskedGNM 8b94B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 4e4kA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 6e5aA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3adsA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 8b94A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 6ijsA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2f4bA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 8b8yA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 3kmgD_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3po9A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zk4A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 3h0aD_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 4em9A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 2znoA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 3b0rA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 5z6sA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2athA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 48 modes for 203 modes from MaskedGNM 7cxlA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 8cphA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 4prgD_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2zk3A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 3vjhA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 8bf1A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3b3kA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2g0gA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 4r6sA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 3r8aA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 8atzA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 5azvA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 5z5sA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 4y29A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3cwdB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 6jf0A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 2q6sA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 8dk4A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 6ktmA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 5ji0D_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 5hzcA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 3ia6A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 2prgA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 8dszA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 7wgqA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 30 modes for 203 modes from MaskedGNM 8b92B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 8hupA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 3gbkA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 5twoA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3et0A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 4a4wA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 2xkwA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 2vv2A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 5ycnA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 2q8sA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3pbaA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 51 modes for 203 modes from MaskedGNM 4prgB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 2vv1A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 7sqaB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 4oj4A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 4ci5A_ca reduced has been discarded because at least one conformation has only 203 modes
# ...
# @> WARNING last 45 modes for 203 modes from MaskedGNM 6l37B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 7bpyC_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 2awhA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 39 modes for 203 modes from MaskedGNM 3peqB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 6kb9A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 36 modes for 203 modes from MaskedGNM 2bawA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 3d5fB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 2znpB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 6l96B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 6kb8A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 7bq4A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 5u41B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 6l37A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 6lx6A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 1k7lE_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 6l36A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 32 modes for 203 modes from MaskedGNM 5xmxB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 2p54A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 6kxyA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 27 modes for 203 modes from MaskedGNM 2q6rA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 39 modes for 203 modes from MaskedGNM 6kb7A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 34 modes for 203 modes from MaskedGNM 2awhB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 6kb4A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 6lxaA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 6kb5A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 29 modes for 203 modes from MaskedGNM 5zxiB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 39 modes for 203 modes from MaskedGNM 2xyxA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 38 modes for 203 modes from MaskedGNM 6lxbA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 39 modes for 203 modes from MaskedGNM 5u3yB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 6lx8A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 39 modes for 203 modes from MaskedGNM 6kazA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 3vi8A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 5u40B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 38 modes for 203 modes from MaskedGNM 5u3xB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 6kb6A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 6kb0A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 44 modes for 203 modes from MaskedGNM 6lx9A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 7c6qA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 3sp9A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 4bcrB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 2j14A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 7vweA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 39 modes for 203 modes from MaskedGNM 6lxcA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 4bcrA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 2znnA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 6lx7A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 1k7lA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 1k7lC_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 45 modes for 203 modes from MaskedGNM 3sp9B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 39 modes for 203 modes from MaskedGNM 5u41A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 33 modes for 203 modes from MaskedGNM 2bawB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 1k7lG_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 30 modes for 203 modes from MaskedGNM 4l98A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 6pdzA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 3d5fA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 5u40A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 40 modes for 203 modes from MaskedGNM 6kxxA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 2j14B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 2znpA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 29 modes for 203 modes from MaskedGNM 2q5gA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 29 modes for 203 modes from MaskedGNM 3feiA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 46 modes for 203 modes from MaskedGNM 3dzuD_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 28 modes for 203 modes from MaskedGNM 2q5gB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 39 modes for 203 modes from MaskedGNM 5aztA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 5aztB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 47 modes for 203 modes from MaskedGNM 1kkqA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 42 modes for 203 modes from MaskedGNM 8aqmB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 1kkqD_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 1kkqB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 32 modes for 203 modes from MaskedGNM 3oz0A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 43 modes for 203 modes from MaskedGNM 1kkqC_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 37 modes for 203 modes from MaskedGNM 8aqnB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 41 modes for 203 modes from MaskedGNM 6dcuA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 38 modes for 203 modes from MaskedGNM 8aqmA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 35 modes for 203 modes from MaskedGNM 6dcuB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 7 modes for 203 modes from MaskedGNM 4dk7C_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 1pqcC_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 1pq9C_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 9 modes for 203 modes from MaskedGNM 3falD_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 4dk7A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 4dk8C_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 9 modes for 203 modes from MaskedGNM 4rakB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 6s4tA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 9 modes for 203 modes from MaskedGNM 3fc6D_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 9 modes for 203 modes from MaskedGNM 1pq6A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 9 modes for 203 modes from MaskedGNM 3fc6B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 4dk8A_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 6s4nD_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 1pq9B_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 4 modes for 203 modes from MaskedGNM 3ipsB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 6s4nA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 9 modes for 203 modes from MaskedGNM 3falB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 1pqcB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 2aclB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 2 modes for 203 modes from MaskedGNM 6s4nC_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 5kyaA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 3 modes for 203 modes from MaskedGNM 3ipsA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 1 modes for 203 modes from MaskedGNM 6s5kA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 2aclD_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 5hjpB_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 2aclH_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 3 modes for 203 modes from MaskedGNM 3ipqA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 5i4vE_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 1p8dA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 4 modes for 203 modes from MaskedGNM 5hjsA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 5 modes for 203 modes from MaskedGNM 1pq6D_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 3 modes for 203 modes from MaskedGNM 5aviC_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 8 modes for 203 modes from MaskedGNM 5kyaE_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 3 modes for 203 modes from MaskedGNM 5avlA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 3 modes for 203 modes from MaskedGNM 5aviA_ca reduced has been discarded because at least one conformation has only 203 modes
# @> WARNING last 1 modes for 203 modes from MaskedGNM 6k9gC_ca reduced has been discarded because at least one conformation has only 203 modes
# @> all GNM modes were calculated for each of the 706 conformations in 30.22s.
# @> 203 modes across 706 modesets were matched in 6.42s.

# %%
mergeIDs = []
mergeChains = []
usedStruct = []

for item_A in ids_A:
    for item_B in ids_B:
        if item_A[:4] == item_B[:4] and item_A[-1] != item_B[-1]:
            if item_A[:4] not in usedStruct:
                # print (item_A, item_B)
                usedStruct.append(item_A[:4])
                mergeIDs.append(item_A[:4])
                mergeChains.append(item_A[-1] + item_B[-1])

mergeIDs = list(set(mergeIDs))

# %%
writeIDs('./Binding', mergeIDs, mergeChains)

# %%
len(mergeIDs)
# Out:
# 272

# %%
update_mergeIDs = []
update_mergeChains = []
for i in range(len(mergeIDs)):
    if mergeIDs[i] not in ['8huk', '6k0t', '3kmg', '1k7l', '7bpy', '1fm6', '8b8y', '6ijr', \
                           '2npa', '7bpz', '4dk8', '7bq0', '5avi', '3t03']:
        update_mergeIDs.append(mergeIDs[i])
        update_mergeChains.append(mergeChains[i])
    elif mergeIDs[i] in ['8b8y', '3t03']:
        update_mergeIDs.append(mergeIDs[i])
        update_mergeChains.append('AB')
    else:
        update_mergeIDs.append(mergeIDs[i])
        update_mergeChains.append('AC')

# %%
ags = parsePDB(update_mergeIDs, subset='ca', chain=update_mergeChains)
dali_ens = buildPDBEnsemble(ags)
gnms = calcEnsembleENMs(dali_ens, model='GNM', trim='reduce', n_modes=None)
eigVals = gnms.getEigvals()
averageEigVals = eigVals[0]
eigVects = gnms.getEigvecs()
averageEigVects = mean(eigVects, axis=0)
# Out:
# @> Retrieving 6d3eDX... [ 59%] 29s@> WARNING Atomic data could not be parsed, please check the input file.
# @> Retrieving 5u3vCD... [ 94%] 4s @> WARNING Atomic data could not be parsed, please check the input file.
# @> Solving for 3-best solution...ence... [  2%]@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [  2%]@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [  4%] 29s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [  5%] 30s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [  7%] 27s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [  8%] 29s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [  8%] 30s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 10%] 27s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 11%] 28s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 12%] 29s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 13%] 27s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 15%] 25s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 20%] 24s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 3kmgAC_ca to the reference... [ 22%] 23s@> WARNING 3kmgAC_ca has fewer chains than 6f2lAB_ca
# @> Solving for 3-best solution...ence... [ 25%] 21s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 26%] 21s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 27%] 21s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 28%] 21s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 7rleAB_ca to the reference... [ 29%] 20s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 30%] 20s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 32%] 19s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 32%] 19s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 33%] 19s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 33%] 19s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 35%] 18s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 37%] 17s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 39%] 17s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 40%] 16s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 42%] 15s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 43%] 15s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 46%] 15s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 4bcrAC_ca to the reference... [ 47%] 14s@> WARNING 4bcrAC_ca has fewer chains than 6f2lAB_ca
# @> Solving for 3-best solution...ence... [ 49%] 14s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 50%] 14s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 51%] 14s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 2zk1AD_ca to the reference... [ 51%] 14s@> WARNING 2zk1AD_ca has fewer chains than 6f2lAB_ca
# @> Mapping 1nyxDA_ca to the reference... [ 52%] 13s@> WARNING 1nyxDA_ca has fewer chains than 6f2lAB_ca
# @> Solving for 3-best solution...ence... [ 52%] 13s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 53%] 13s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 54%] 13s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 55%] 13s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 56%] 13s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 56%] 13s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 3d6dCA_ca to the reference... [ 57%] 13s@> WARNING 3d6dCA_ca has fewer chains than 6f2lAB_ca
# @> Solving for 3-best solution...ence... [ 58%] 12s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 58%] 12s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 58%] 12s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 1fm6AC_ca to the reference... [ 59%] 12s@> WARNING 1fm6AC_ca has fewer chains than 6f2lAB_ca
# @> Solving for 3-best solution...ence... [ 60%] 12s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 60%] 11s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 61%] 11s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 61%] 11s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 62%] 11s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 3pbaAC_ca to the reference... [ 62%] 11s@> WARNING 3pbaAC_ca has fewer chains than 6f2lAB_ca
# @> Solving for 3-best solution...ence... [ 62%] 11s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 4pwlAC_ca to the reference... [ 63%] 11s@> WARNING 4pwlAC_ca has fewer chains than 6f2lAB_ca
# @> Solving for 3-best solution...ence... [ 63%] 11s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 2yfeAC_ca to the reference... [ 64%] 11s@> WARNING 2yfeAC_ca has fewer chains than 6f2lAB_ca
# @> Solving for 3-best solution...ence... [ 64%] 10s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 65%] 10s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 65%] 10s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 66%] 10s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 4r2uAC_ca to the reference... [ 67%] 10s@> WARNING 4r2uAC_ca has fewer chains than 6f2lAB_ca
# @> Mapping 6an1CA_ca to the reference... [ 68%] 10s@> WARNING 6an1CA_ca has fewer chains than 6f2lAB_ca
# @> Mapping 5u5lAC_ca to the reference... [ 69%] 9s @> WARNING 5u5lAC_ca has fewer chains than 6f2lAB_ca
# @> Solving for 3-best solution...ence... [ 69%] 9s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 70%] 9s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 70%] 9s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 70%] 9s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 72%] 8s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 72%] 8s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 7ahjAC_ca to the reference... [ 73%] 8s@> WARNING 7ahjAC_ca has fewer chains than 6f2lAB_ca
# @> Mapping 4nqaBA_ca to the reference... [ 74%] 8s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 75%] 8s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 76%] 7s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 77%] 7s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 78%] 7s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 78%] 7s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 79%] 7s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 79%] 7s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 79%] 6s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 80%] 6s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 80%] 6s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 81%] 6s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 84%] 5s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 84%] 5s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 85%] 5s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 85%] 5s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 4r06EA_ca to the reference... [ 86%] 5s@> WARNING 4r06EA_ca has fewer chains than 6f2lAB_ca
# @> Solving for 3-best solution...ence... [ 87%] 5s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 87%] 5s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 90%] 4s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 90%] 4s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 91%] 3s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 92%] 3s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Solving for 3-best solution...ence... [ 92%] 3s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 2vv3CA_ca to the reference... [ 93%] 3s@> WARNING 2vv3CA_ca has fewer chains than 6f2lAB_ca
# @> Mapping 2xkwCB_ca to the reference... [ 94%] 2s@> WARNING 2xkwCB_ca has fewer chains than 6f2lAB_ca
# @> Mapping 6fzyDB_ca to the reference... [ 95%] 2s@> WARNING 6fzyDB_ca has fewer chains than 6f2lAB_ca
# @> Mapping 2znqAC_ca to the reference... [ 95%] 2s@> WARNING 2znqAC_ca has fewer chains than 6f2lAB_ca
# @> Mapping 8hhqBD_ca to the reference... [ 96%] 2s@> WARNING 8hhqBD_ca has fewer chains than 6f2lAB_ca
# @> Mapping 7vwgBC_ca to the reference... [ 96%] 2s@> WARNING 7vwgBC_ca has fewer chains than 6f2lAB_ca
# @> Mapping 3ipsAE_ca to the reference... [ 97%] 1s@> WARNING 3ipsAE_ca has fewer chains than 6f2lAB_ca
# @> Mapping 3et0CA_ca to the reference... [ 97%] 1s@> WARNING 3et0CA_ca has fewer chains than 6f2lAB_ca
# @> Mapping 8bffDA_ca to the reference... [ 98%] 1s@> WARNING 8bffDA_ca has fewer chains than 6f2lAB_ca
# @> Mapping 8dszDB_ca to the reference... [ 98%] 1s@> WARNING 8dszDB_ca has fewer chains than 6f2lAB_ca
# @> Solving for 3-best solution...ence... [ 99%] 1s@> WARNING no atommaps were found. Consider inceasing rmsd_reject or drmsd
# @> Mapping 8c0cAE_ca to the reference... [ 99%] 1s@> WARNING 8c0cAE_ca has fewer chains than 6f2lAB_ca
# @> WARNING 110 structures cannot be mapped.
# @> Calculating all GNM modes for 162 conformations... [ 99%] 1s @> WARNING last 146 modes for 367 modes from MaskedGNM 6f2lAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 5ttoAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 140 modes for 367 modes from MaskedGNM 6vzoAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 123 modes for 367 modes from MaskedGNM 8b8wAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 129 modes for 367 modes from MaskedGNM 8cphAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 128 modes for 367 modes from MaskedGNM 8dsyAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 140 modes for 367 modes from MaskedGNM 3adxAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 138 modes for 367 modes from MaskedGNM 7lotAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 142 modes for 367 modes from MaskedGNM 3vsoAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 123 modes for 367 modes from MaskedGNM 8b8zAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 133 modes for 367 modes from MaskedGNM 6vznAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 4prgAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 1prgAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 142 modes for 367 modes from MaskedGNM 1i7iAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 6dhaAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 144 modes for 367 modes from MaskedGNM 6c1iAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 5ugmAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 129 modes for 367 modes from MaskedGNM 7jqgAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 142 modes for 367 modes from MaskedGNM 5lsgAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 113 modes for 367 modes from MaskedGNM 8b92AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 99 modes for 367 modes from MaskedGNM 8adfAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 131 modes for 367 modes from MaskedGNM 3osiAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 87 modes for 367 modes from MaskedGNM 2p4yAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 24 modes for 367 modes from MaskedGNM 2aclAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 127 modes for 367 modes from MaskedGNM 2vv4AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 130 modes for 367 modes from MaskedGNM 7e2oAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 3cdpAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 6dgpAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 125 modes for 367 modes from MaskedGNM 8aqmAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 142 modes for 367 modes from MaskedGNM 6aviAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 137 modes for 367 modes from MaskedGNM 3adsAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 24 modes for 367 modes from MaskedGNM 1pq9AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 130 modes for 367 modes from MaskedGNM 5f9bAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 131 modes for 367 modes from MaskedGNM 3b0rAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 124 modes for 367 modes from MaskedGNM 6enqAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 135 modes for 367 modes from MaskedGNM 2q5sAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 64 modes for 367 modes from MaskedGNM 1pq6AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 2zvtAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 124 modes for 367 modes from MaskedGNM 2vv1AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 132 modes for 367 modes from MaskedGNM 6jf0AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 117 modes for 367 modes from MaskedGNM 2q6rAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 32 modes for 367 modes from MaskedGNM 3falAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 132 modes for 367 modes from MaskedGNM 3po9AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 128 modes for 367 modes from MaskedGNM 2prgAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 6mczAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 137 modes for 367 modes from MaskedGNM 4ci5AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 24 modes for 367 modes from MaskedGNM 5i4vAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 125 modes for 367 modes from MaskedGNM 7sqaAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 138 modes for 367 modes from MaskedGNM 6dgrAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 117 modes for 367 modes from MaskedGNM 3r8aAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 6md0AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 135 modes for 367 modes from MaskedGNM 3adtAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 3x1hAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 135 modes for 367 modes from MaskedGNM 8b8xAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 118 modes for 367 modes from MaskedGNM 8b95AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 134 modes for 367 modes from MaskedGNM 2vstAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 140 modes for 367 modes from MaskedGNM 2vsrAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 135 modes for 367 modes from MaskedGNM 3wj4AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 135 modes for 367 modes from MaskedGNM 6l89AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 140 modes for 367 modes from MaskedGNM 3advAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 136 modes for 367 modes from MaskedGNM 6dgqAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 143 modes for 367 modes from MaskedGNM 6o68AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 143 modes for 367 modes from MaskedGNM 6dglAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 143 modes for 367 modes from MaskedGNM 2zk6AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 5y2tAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 125 modes for 367 modes from MaskedGNM 6qj5AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 143 modes for 367 modes from MaskedGNM 4a4vAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 133 modes for 367 modes from MaskedGNM 1zeoAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 137 modes for 367 modes from MaskedGNM 6vzmAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 136 modes for 367 modes from MaskedGNM 2znoAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 3b3kAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 140 modes for 367 modes from MaskedGNM 2vv2AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 138 modes for 367 modes from MaskedGNM 3an3AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 135 modes for 367 modes from MaskedGNM 2q8sAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 142 modes for 367 modes from MaskedGNM 6l8bAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 138 modes for 367 modes from MaskedGNM 4xumAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 132 modes for 367 modes from MaskedGNM 3vjhAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 121 modes for 367 modes from MaskedGNM 8b91AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 143 modes for 367 modes from MaskedGNM 3adwAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 143 modes for 367 modes from MaskedGNM 6dh9AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 109 modes for 367 modes from MaskedGNM 8b93AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 2zk3AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 135 modes for 367 modes from MaskedGNM 3wj5AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 137 modes for 367 modes from MaskedGNM 2q61AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 4r6sAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 2zk5AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 142 modes for 367 modes from MaskedGNM 8bf2AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 1knuAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 123 modes for 367 modes from MaskedGNM 4emaAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 135 modes for 367 modes from MaskedGNM 4pvuAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 32 modes for 367 modes from MaskedGNM 3fc6AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 107 modes for 367 modes from MaskedGNM 8b90AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 128 modes for 367 modes from MaskedGNM 8wfeAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 143 modes for 367 modes from MaskedGNM 6dgoAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 127 modes for 367 modes from MaskedGNM 4em9AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 3an4AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 4jazAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 134 modes for 367 modes from MaskedGNM 7woxAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 4yt1AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 5y2oAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 134 modes for 367 modes from MaskedGNM 3cwdBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 132 modes for 367 modes from MaskedGNM 5wqxAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 141 modes for 367 modes from MaskedGNM 6md1AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 123 modes for 367 modes from MaskedGNM 3x1iAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 2zk4BA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 3sz1AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 4jl4AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 142 modes for 367 modes from MaskedGNM 3vspAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 24 modes for 367 modes from MaskedGNM 5kyaAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 132 modes for 367 modes from MaskedGNM 6jeyAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 3r8iAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 137 modes for 367 modes from MaskedGNM 7cxeAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 134 modes for 367 modes from MaskedGNM 3oswAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 140 modes for 367 modes from MaskedGNM 7cxgAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 117 modes for 367 modes from MaskedGNM 8b8yAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 136 modes for 367 modes from MaskedGNM 6e5aAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 136 modes for 367 modes from MaskedGNM 3sp9AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 145 modes for 367 modes from MaskedGNM 6dbhBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 143 modes for 367 modes from MaskedGNM 3ty0BA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 7efqBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 145 modes for 367 modes from MaskedGNM 6augAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 131 modes for 367 modes from MaskedGNM 3vjiBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 118 modes for 367 modes from MaskedGNM 4xtaAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 126 modes for 367 modes from MaskedGNM 6zlyBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 2i4jAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 142 modes for 367 modes from MaskedGNM 4a4wBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 139 modes for 367 modes from MaskedGNM 6md2AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 136 modes for 367 modes from MaskedGNM 6fzfBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 129 modes for 367 modes from MaskedGNM 6vzlAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 132 modes for 367 modes from MaskedGNM 5wr1BA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 141 modes for 367 modes from MaskedGNM 3wmhAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 142 modes for 367 modes from MaskedGNM 4xuhBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 125 modes for 367 modes from MaskedGNM 6t9cBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 136 modes for 367 modes from MaskedGNM 3aduAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 32 modes for 367 modes from MaskedGNM 1pqcAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 119 modes for 367 modes from MaskedGNM 8b94BA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 145 modes for 367 modes from MaskedGNM 2zk0BA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 138 modes for 367 modes from MaskedGNM 6md4AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 141 modes for 367 modes from MaskedGNM 3k8sBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 136 modes for 367 modes from MaskedGNM 2q59BA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 4e4qBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 138 modes for 367 modes from MaskedGNM 3ia6BA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 131 modes for 367 modes from MaskedGNM 3b0qBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 3ho0BA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 136 modes for 367 modes from MaskedGNM 2q6sAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 3cdsAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 136 modes for 367 modes from MaskedGNM 6fzjBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 133 modes for 367 modes from MaskedGNM 2vv0AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 127 modes for 367 modes from MaskedGNM 5hzcAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 132 modes for 367 modes from MaskedGNM 5wr0AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 127 modes for 367 modes from MaskedGNM 2q5pBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 4e4kBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 2i4pAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 64 modes for 367 modes from MaskedGNM 4dk8AC_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 2zk2BA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 141 modes for 367 modes from MaskedGNM 6o67AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 132 modes for 367 modes from MaskedGNM 5azvBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 3hodAB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 40 modes for 367 modes from MaskedGNM 5aviAC_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 146 modes for 367 modes from MaskedGNM 2i4zBA_ca reduced has been discarded because at least one conformation has only 367 modes
# @> WARNING last 120 modes for 367 modes from MaskedGNM 3t03AB_ca reduced has been discarded because at least one conformation has only 367 modes
# @> Matching 367 modes across 162 modesets... [ 99%] 1s

# %%
currNumModes = getModesGivenThreshold(averageEigVals, 0.33)
currNumModes
# Out:
# 1

# %%
bindings = ['64', '65', '66', '68', '69', '70', '72', '73', '107', '110', '111', '114', '117', '123', '124', '125', '126', '132', '137', '147', '148', '151', '233', '237', '253', '257', '325', '326', '327', '329', '330', '331', '333', '334', '368', '371', '372', '375', '378', '384', '385', '386', '387', '393', '398', '408', '409', '412', '494', '498', '509', '513']

binding = [int(x) for x in bindings]

# %%
Hinges_2 = getHinges(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges(averageEigVects, 3, 20)

Hinges_4 = getHinges(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges(averageEigVects, 3, 15)

# %%
protein_length = 528

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 52
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 4 0 1
# # of hinge sites for first 3 modes, overlap, hyper score 38 4 0.5279187356308926
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 5 0 1
# # of hinge sites for first 3 modes, overlap, hyper score 46 5 0.48272757830841817

# %%
hivPR = parsePDB('6f2l')
calphas = hivPR.select('calpha and chain A B')
gnm = GNM('hivPR')
gnm.buildKirchhoff(calphas)
gnm.calcModes(n_modes=None)
eigenVals = gnm.getEigvals()
eigenVects = gnm.getEigvecs()
Hinge0 = calcHinges(gnm[0])
Hinge1 = calcHinges(gnm[1])
Hinge2 = calcHinges(gnm[2])

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0 + Hinge1))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0 + Hinge1))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 52
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 24 2 0.7059953933161602
# # of hinge sites for 3 modes, overlap, hyper score 59 8 0.2110702954170156
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 25 2 0.7278228958196048
# # of hinge sites for 3 modes, overlap, hyper score 64 8 0.2851224221349957

# %% [markdown]
# ### write hinges

# %%
averageEigVects.shape
# Out:
# (198, 167)

# %%
# write MSFs
averageEigVals
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)

# %%
includeModes = 3
size = includeModes * 2 + 1 + 2 

curr = zeros((len(MSF), size))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]
curr[:, 5] = averageEigVects[:, 2]

for each in binding:
    curr[each, 0] = each

# %%
row, col = averageEigVects.shape
hinges = [Hinge0, Hinge1, Hinge2]
for mode in modes:
    currHinge = getHinges_modes3(averageEigVects, mode, hinges[mode], bandWidth=15)
    currList = sort(list(set(list(currHinge)))) # + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

writeAllData('./Data/HIV-PR_Method1_similar.txt', curr)
# Out:
# [50, 51]
# [101, 102]
# [149, 150]
# [14, 15]
# [50, 51]

# %% [markdown]
# ## method 2

# %%
bindings = ['59', '60', '64', '65', '66', '68', '69', '72', '73', '110', '111', '114', '117', '123', '124', '125', '126', '132', '147', '148', '233', '320', '321', '325', '326', '327', '329', '330', '333', '334', '371', '372', '375', '378', '384', '385', '386', '387', '393', '408', '409', '494']

binding = [int(x) for x in bindings]

# %%
bindings = ['59', '65', '66', '68', '69', '72', '76', '110', '111', '114', '117', '123', '125', '126', '148', '320', '326', '327', '329', '330', '333', '337', '371', '372', '375', '378', '384', '386', '387', '409']

binding = [int(x) for x in bindings]

# %%
Hinges_2 = getHinges2(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges2(averageEigVects, 3, 20)

Hinges_4 = getHinges2(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges2(averageEigVects, 3, 15)

# %%
Hinges_2
# Out:
# [258, 259]

# %%
len(Hinges_5)
# Out:
# 58

# %%
Hinges_2 = filterTwoEnds(Hinges_2, [[0, 258], [259, 513]], 15)
Hinges_3 = filterTwoEnds(Hinges_3, [[0, 258], [259, 513]], 15)
Hinges_4 = filterTwoEnds(Hinges_4, [[0, 258], [259, 513]], 15)
Hinges_5 = filterTwoEnds(Hinges_5, [[0, 258], [259, 513]], 15)

# %%
sort (Hinges_5)
# Out:
# array([ 19,  20,  21,  22,  23,  74,  75,  76,  77,  78,  79, 109, 110,
#        113, 114, 156, 157, 158, 159, 160, 225, 226, 227, 228, 279, 280,
#        288, 289, 291, 292, 330, 331, 332, 333, 337, 338, 371, 372, 379,
#        380, 381, 411, 412, 413, 421, 422, 486, 487, 488, 493, 494, 495])

# %%
protein_length = 514

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 30
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 0 0 1
# # of hinge sites for first 3 modes, overlap, hyper score 51 8 0.005721332624574971
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 0 0 1
# # of hinge sites for first 3 modes, overlap, hyper score 52 8 0.006486801693134092

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

Hinges_sep2 = filterTwoEnds(Hinges_sep2, [[0, 258], [259, 513]], 15)
Hinges_sep3 = filterTwoEnds(Hinges_sep3, [[0, 258], [259, 513]], 15)
Hinges_sep4 = filterTwoEnds(Hinges_sep4, [[0, 258], [259, 513]], 15)
Hinges_sep5 = filterTwoEnds(Hinges_sep5, [[0, 258], [259, 513]], 15)

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 30
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 5 0 1
# # of hinge sites for 3 modes, overlap, hyper score 62 8 0.0192033585452398
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 5 0 1
# # of hinge sites for 3 modes, overlap, hyper score 63 8 0.021093043352196528

# %%
AverageEigVals1 = gnms.getEigvals()[0]
AverageEigVals2 = mean(gnms.getEigvals(), axis=0)
proteinLength = 514
Segment = int(proteinLength / 5)
print ('mark Index are', 0, Segment, Segment*2, Segment*3, Segment*4, proteinLength - 1)
# Out:
# mark Index are 0 102 204 306 408 513

# %%
Labels = ['A:207', 'A:318', 'A:420', 'B:255', 'B:363', 'B:473']
SplitLabel = 258

# %%
currHinge = Hinges_5

# %%
import matplotlib.patches as patches
fig, ax = plt.subplots(figsize=(20, 10))   # Adjust size as per requirement
plt.sca(ax)  # Set current axis to 'ax'
    
# Increase font sizes
plt.rc('xtick', labelsize=55)
plt.rc('ytick', labelsize=50)
plt.rcParams.update({'font.size': 70})

# calcMSF
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row-8):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / AverageEigVals1[mode]
    MSF.append(currMSF)

plt.plot(MSF, color='black', linewidth=4, alpha=0.88)    

HingeY = [MSF[item] for item in currHinge]
plt.plot(currHinge, HingeY, color=(0.2, 1, 0.1), marker='o', linestyle='', markersize=25)
print ('# of hinges', len(HingeY))

# plot binding sites
bindingY = [MSF[item] for item in binding]
plt.plot(binding, bindingY, 'r*', markersize=30)
print ('# of bindings sites', len(binding))

# plot overlaps
allHinge = currHinge
overlaps = [item for item in binding if item in allHinge]
overlapsY = [MSF[item] for item in overlaps]
plt.plot(overlaps, overlapsY, 'mD', markersize=25)

print ('# of hits are', len(overlaps))

# Hide y labels
plt.gca().yaxis.set_visible(False)

# Hide top, right, and left spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

y = MSF
# Determine the lower y-limit for bands and labels
lower_y_limit = min(y) * 0.1
upper_y_limit = min(y) * 0.5

# Add narrow bands below the plot
ax.add_patch(patches.Rectangle((0, lower_y_limit), SplitLabel, upper_y_limit - lower_y_limit, color='purple', alpha=0.9))
ax.add_patch(patches.Rectangle((SplitLabel, lower_y_limit), proteinLength - SplitLabel, upper_y_limit - lower_y_limit, color='orange',alpha=0.9))
# Add labels just above the bands
ax.text(SplitLabel / 2, upper_y_limit, 'A', color='black', ha='center', va='bottom')
ax.text((SplitLabel + proteinLength) / 2, upper_y_limit, 'B', color='black', ha='center', va='bottom')

# Set x-axis labels and title with Arial font
# plt.title('Peroxisome Proliferator-activated \nReceptor gamma')
plt.xticks([0, Segment, Segment*2, Segment*3, Segment*4, proteinLength - 1], Labels)

plt.savefig('./PPARg_MSF.png', dpi=500)
# Out:
# # of hinges 52
# # of bindings sites 30
# # of hits are 8

# %%
AverageEigVals1
# Out:
# sdarray([ 0.19108978,  0.58242401,  0.70377338,  0.82148101,  1.10886961,
#           1.20829941,  1.79408945,  1.90760233,  2.11875951,  2.23694006,
#           2.44502643,  2.63999203,  2.72014404,  2.85635134,  3.02494603,
#           3.24792435,  3.35806931,  3.46725223,  3.66915226,  3.92731388,
#           4.27254828,  4.36927496,  4.4683385 ,  4.78222185,  5.0589335 ,
#           5.35999297,  5.44331977,  5.62941794,  5.75782971,  5.89198686,
#           5.93909934,  6.0188174 ,  6.19111224,  6.29632686,  6.41399602,
#           6.46282666,  6.64001724,  6.71703318,  6.90322583,  6.92429323,
#           6.98296972,  7.14622359,  7.3792104 ,  7.47475022,  7.52619855,
#           7.73958047,  7.88630371,  7.93186954,  8.        ,  8.        ,
#           8.        ,  8.09780819,  8.16961433,  8.18554797,  8.25960755,
#           8.32280355,  8.52371016,  8.5390158 ,  8.55142277,  8.59860432,
#           8.65879217,  8.72703866,  8.86404978,  8.94930933,  9.04902942,
#           9.09248856,  9.2732181 ,  9.28103995,  9.34885095,  9.41154352,
#           9.50208837,  9.56806351,  9.69193959,  9.71368074,  9.75475197,
#           9.86208962,  9.95664248,  9.96372337,  9.99458037, 10.14643785,
#          10.23997892, 10.28372847, 10.33984241, 10.38206413, 10.45934175,
#          10.47880615, 10.54077765, 10.56951366, 10.63498415, 10.67969728,
#          10.68813439, 10.75176399, 10.77537642, 10.79708918, 10.86052836,
#          10.89073496, 10.91048691, 10.9275585 , 10.95297608, 10.99507451,
#          11.03545358, 11.06463362, 11.06578291, 11.12743898, 11.14188897,
#          11.23959178, 11.26573193, 11.29414913, 11.32827916, 11.34197697,
#          11.3959883 , 11.42481639, 11.49739225, 11.51508978, 11.60199065,
#          11.63891369, 11.68061054, 11.68805802, 11.748095  , 11.83431531,
#          11.85785718, 11.88934905, 11.91248117, 11.99182993, 11.99967177,
#          12.04775107, 12.18249554, 12.25903867, 12.29817813, 12.31343836,
#          12.36578167, 12.39622294, 12.56205761, 12.59628902, 12.65430674,
#          12.6696108 , 12.69290671, 12.73724049, 12.74669971, 12.79796097,
#          12.81247455, 12.84919949, 12.86646135, 12.89931635, 12.90099697,
#          12.92812909, 12.96375984, 13.02115653, 13.07596337, 13.12302434,
#          13.16872206, 13.22522859, 13.28553979, 13.35362354, 13.36209185,
#          13.42357121, 13.51753315, 13.55641735, 13.56757838, 13.5904807 ,
#          13.60366982, 13.64406358, 13.70062839, 13.73258448, 13.77573178,
#          13.82870146, 13.84097776, 13.87397956, 13.88211532, 13.95431191,
#          13.97642978, 13.99316363, 14.01046096, 14.04748862, 14.08205862,
#          14.16287746, 14.19838195, 14.23025534, 14.25247518, 14.2621671 ,
#          14.3271028 , 14.33235002, 14.37125446, 14.39577284, 14.45464741,
#          14.46791901, 14.49679999, 14.58963655, 14.61112903, 14.61864968,
#          14.68774545, 14.74525809, 14.77179733, 14.8032836 , 14.85801958,
#          14.89164795, 14.91641789, 14.9526919 , 14.96265268, 14.98432618,
#          15.03653996, 15.09298754, 15.0993368 , 15.11694162, 15.18046859,
#          15.20539378, 15.21951392, 15.27518693, 15.28117565, 15.32135339,
#          15.34078635, 15.3690622 , 15.40434372, 15.43221418, 15.46089682,
#          15.48470174, 15.55719572, 15.57031781, 15.61729101, 15.64084818,
#          15.68421285, 15.70334599, 15.74927157, 15.79109054, 15.82486281,
#          15.85170812, 15.89938996, 15.92068698, 15.94182195, 15.9859247 ,
#          16.01863236, 16.03082131, 16.06567839, 16.11196508, 16.13345835,
#          16.16082678, 16.16966056, 16.2056248 , 16.22818935, 16.23408595,
#          16.27946451, 16.29781891, 16.30613635, 16.34305348, 16.35033215,
#          16.39458707, 16.42997029, 16.49485817, 16.50909952, 16.54473856,
#          16.56520311, 16.57710957, 16.60699414, 16.62671634, 16.64351006,
#          16.69302242, 16.74850886, 16.76817108, 16.78131108, 16.85570416,
#          16.90164649, 16.91134042, 16.9155579 , 16.93861143, 17.00802249,
#          17.03846399, 17.05571704, 17.07697122, 17.13652346, 17.1956641 ,
#          17.20933882, 17.22594487, 17.26931648, 17.28662666, 17.29262961,
#          17.32185264, 17.34298985, 17.36945777, 17.41900698, 17.45582749,
#          17.46662655, 17.47886973, 17.53055676, 17.55175695, 17.59061669,
#          17.60882295, 17.65910352, 17.67460081, 17.71030497, 17.747677  ,
#          17.7855432 , 17.83332515, 17.8614929 , 17.90944807, 17.92662048,
#          17.94451666, 17.96539543, 17.97922387, 18.04865589, 18.06860242,
#          18.0841051 , 18.12483971, 18.14398281, 18.16110269, 18.2004778 ,
#          18.21546028, 18.21946178, 18.26287952, 18.28228202, 18.31114231,
#          18.36797426, 18.38112284, 18.41488399, 18.43973346, 18.44578085,
#          18.49865052, 18.51111543, 18.5164921 , 18.53738227, 18.61172453,
#          18.62256903, 18.65292887, 18.66314315, 18.7101515 , 18.71958122,
#          18.80168162, 18.81041506, 18.84970312, 18.91572844, 18.95235235,
#          19.01048069, 19.02466337, 19.04580736, 19.05477941, 19.07384289,
#          19.09844475, 19.11964383, 19.18178097, 19.21879881, 19.23640276,
#          19.30576035, 19.31903051, 19.36321657, 19.40143072, 19.43741529,
#          19.48864514, 19.50956061, 19.58694544, 19.63959625, 19.6837787 ,
#          19.70472358, 19.73470189, 19.76269192, 19.78284247, 19.79650107,
#          19.80092943, 19.84481047, 19.92347624, 19.96356902, 19.9774481 ,
#          20.02974707, 20.03381887, 20.07105944, 20.10495169, 20.14856466,
#          20.17521284, 20.21478673])

# %% [markdown]
# ### write hinges

# %%
averageEigVects.shape
# Out:
# (514, 367)

# %%
# write MSFs
averageEigVals
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)
len(MSF)
# Out:
# 514

# %%
values_array = np.array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = np.argsort(values_array)

if not os.path.exists('./Data'):
    os.mkdir('./Data')

writeNumbers('./Data/RMSF_minimum.txt', indices)

# %%
includeModes = 3
size = includeModes * 2 + 1 + 2 

curr = zeros((len(MSF), size))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]
curr[:, 5] = averageEigVects[:, 2]

for each in binding:
    curr[each, 0] = each

# %%
modes = [0, 1, 2]
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=15)
    currHinge = filterTwoEnds(currHinge, [[0, 258], [259, 513]], 15)
    currList = sort(list(set(list(currHinge)))) # + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
writeAllData('./Data/PPARg_Method2_similar.txt', curr)

# %% [markdown]
# # Method 3

# %%
Hinges_2 = getHinges3(averageEigVects, currNumModes, [Hinge0, Hinge1], 20)
Hinges_3 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 20)

Hinges_4 = getHinges3(averageEigVects, currNumModes, [Hinge0, Hinge1], 15)
Hinges_5 = getHinges3(averageEigVects, 3, [Hinge0, Hinge1, Hinge2], 15)

# %%
protein_length = 514

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 28
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 6 0 1
# # of hinge sites for first 3 modes, overlap, hyper score 49 5 0.11663245597579841
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 6 0 1
# # of hinge sites for first 3 modes, overlap, hyper score 49 5 0.11663245597579841

# %%
Hinges_2 = getHinges3(averageEigVects, currNumModes, [[]], 20)
Hinges_3 = getHinges3(averageEigVects, 3, [[], [], []], 20)

Hinges_4 = getHinges3(averageEigVects, currNumModes, [[]], 15)
Hinges_5 = getHinges3(averageEigVects, 3, [[], [], []], 15)

# %%
protein_length = 514

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 28
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 6 0 1
# # of hinge sites for first 3 modes, overlap, hyper score 49 5 0.11663245597579841
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 6 0 1
# # of hinge sites for first 3 modes, overlap, hyper score 49 5 0.11663245597579841

# %%
includeModes = 3
size = includeModes * 2 + 1 + 2 

curr = zeros((len(MSF), size))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]
curr[:, 5] = averageEigVects[:, 2]

for each in binding:
    curr[each, 0] = each

# %%
modes = [0, 1, 2]
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes3(averageEigVects, mode, [], bandWidth=15)
    currList = sort(list(set(list(currHinge)))) # + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
writeAllData('./Data/PR_Method3_update.txt', curr)

# %% [markdown]
# # StoreData

# %%
# write modes
writeNumbers('./Data/mode1.txt', averageEigVects[:, 0])
writeNumbers('./Data/mode2.txt', averageEigVects[:, 1])
writeNumbers('./Data/mode3.txt', averageEigVects[:, 2])

# %%
# write MSFs
averageEigVals
modes = [0, 1, 2]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)
           
writeNumbers('./Data/MSF_mode123.txt', MSF)
writeNumbers('./Data/RMSF_mode123.txt', sqrt(MSF))

# %%
# RMSF minimum
values_array = np.array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = np.argsort(values_array)

writeNumbers('./Data/RMSF_minimum.txt', indices)

# %% [markdown]
# # Plot graph

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import math
import numpy as np

def format_significant(value, pos):
    if abs(value) <= 0.01:
        return "0.00"
    else:
        order_of_magnitude = math.floor(math.log10(abs(value)))
        round_digits = -order_of_magnitude + 1
        formatted_number = round(value, round_digits)
        str_format = "{:." + str(round_digits) + "f}"
        return str_format.format(formatted_number)

# %% [markdown]
# # Plot single graph

# %%
def plotSingleGraph(mode, averageEigVects, gnms, binding, Hinge):
    fig, ax = plt.subplots(figsize=(15, 10))   # Adjust size as per requirement
    
    plt.sca(ax)  # Set current axis to 'ax'
    
    # Increase font sizes
    plt.rc('xtick', labelsize=40)
    plt.rc('ytick', labelsize=50)
    plt.rcParams.update({'font.size': 50})

    # plot mode of motion
    showSignatureMode(gnms[:, mode], linewidth=3)

    # Hinges within band
    # method1
    # currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    # method2
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=15)
    currHinge = filterTwoEnds(currHinge, [[0, 258], [259, 513]], 15)
    
    HingeY = [averageEigVects[item, mode] for item in currHinge]
    print ('Hinge residue with wide bands', currHinge, len(currHinge))
    plt.plot(currHinge, HingeY, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # extraHinges for local loops
    updateHinge = [item for item in Hinge if item not in currHinge]
    HingeY_local = [averageEigVects[item, mode] for item in updateHinge]
    print ('local loop motion', updateHinge)
    plt.plot(updateHinge, HingeY_local, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # plot binding sites
    bindingY = [averageEigVects[item, mode] for item in binding]
    plt.plot(binding, bindingY, 'r*', markersize=18)
    print ('current bindings are', binding)
    plt.title('Mode ' + str(mode + 1), fontweight="bold")

    # plot overlaps
    allHinge = updateHinge + currHinge
    overlaps = [item for item in binding if item in allHinge]
    overlapsY = [averageEigVects[item, mode] for item in overlaps]
    print ('current hits are', overlaps)
    plt.plot(overlaps, overlapsY, 'mD', markersize=18)

    print('# of overlaps finding from current mode is', len(overlaps))
    
    # Set y-ticks to have 4-5 values with equal spacing
    y_min, y_max = ax.get_ylim()
    ax.set_yticks(np.linspace(y_min * 0.9, y_max, 5))  # Adjust the number 5 if you want a different number of y-ticks
    ax.yaxis.set_major_formatter(FuncFormatter(format_significant)) 
    
    plt.tight_layout()
    plt.savefig('./PPARg_method2_mode' + str(mode + 1) + '.png', dpi=500)

# %%
modes = 0 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [] 0
# local loop motion []
# current bindings are [59, 65, 66, 68, 69, 72, 76, 110, 111, 114, 117, 123, 125, 126, 148, 320, 326, 327, 329, 330, 333, 337, 371, 372, 375, 378, 384, 386, 387, 409]
# current hits are []
# # of overlaps finding from current mode is 0

# %%
modes = 1 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [19, 20, 411, 412, 157, 158, 159, 160, 288, 289, 291, 292, 413, 76, 77, 78, 79, 337, 338, 226, 227, 228, 109, 110, 493, 494, 495, 379, 380, 381] 30
# local loop motion []
# current bindings are [59, 65, 66, 68, 69, 72, 76, 110, 111, 114, 117, 123, 125, 126, 148, 320, 326, 327, 329, 330, 333, 337, 371, 372, 375, 378, 384, 386, 387, 409]
# current hits are [76, 110, 337]
# # of overlaps finding from current mode is 3

# %%
modes = 2 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [20, 21, 22, 279, 23, 280, 156, 157, 421, 422, 74, 75, 330, 333, 331, 332, 225, 226, 227, 228, 486, 487, 488, 113, 114, 371, 372] 27
# local loop motion []
# current bindings are [59, 65, 66, 68, 69, 72, 76, 110, 111, 114, 117, 123, 125, 126, 148, 320, 326, 327, 329, 330, 333, 337, 371, 372, 375, 378, 384, 386, 387, 409]
# current hits are [114, 330, 333, 371, 372]
# # of overlaps finding from current mode is 5

# %%
ORA(30, 514, 42, 8)
# Out:
# 0.0015374435368183947

# %%
def plotSingleGraph_method3(mode, averageEigVects, gnms, binding, Hinge):
    fig, ax = plt.subplots(figsize=(15, 10))   # Adjust size as per requirement
    
    plt.sca(ax)  # Set current axis to 'ax'
    
    # Increase font sizes
    plt.rc('xtick', labelsize=40)
    plt.rc('ytick', labelsize=50)
    plt.rcParams.update({'font.size': 50})

    # plot mode of motion
    showSignatureMode(gnms[:, mode], linewidth=3)

    # Hinges within band
    # method3
    currHinge = getHinges_modes3(averageEigVects, mode, Hinge, bandWidth = 15)
    
    
    HingeY = [averageEigVects[item, mode] for item in currHinge]
    print ('Hinge residue with wide bands', currHinge)
    plt.plot(currHinge, HingeY, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # extraHinges for local loops
    # updateHinge = [item for item in Hinge if item not in currHinge]
    # HingeY_local = [averageEigVects[item, mode] for item in updateHinge]
    # print ('local loop motion', updateHinge)
    # plt.plot(updateHinge, HingeY_local, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # plot binding sites
    bindingY = [averageEigVects[item, mode] for item in binding]
    plt.plot(binding, bindingY, 'r*', markersize=18)
    print ('current bindings are', binding)
    plt.title('Mode ' + str(mode + 1), fontweight="bold")

    # plot overlaps
    allHinge = currHinge
    overlaps = [item for item in binding if item in allHinge]
    overlapsY = [averageEigVects[item, mode] for item in overlaps]
    print ('current hits are', overlaps)
    plt.plot(overlaps, overlapsY, 'mD', markersize=18)

    print('# of overlaps finding from current mode is', len(overlaps))
    
    # Set y-ticks to have 4-5 values with equal spacing
    y_min, y_max = ax.get_ylim()
    ax.set_yticks(np.linspace(y_min * 0.9, y_max, 5))  # Adjust the number 5 if you want a different number of y-ticks
    ax.yaxis.set_major_formatter(FuncFormatter(format_significant)) 
    
    plt.tight_layout()
    plt.savefig('./HIV1-PR_method3_mode' + str(mode + 1) + '.png', dpi=500)

# %%
modes = 0 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, Hinge0)
# Out:
# [50, 51]
# [101, 102]
# [149, 150]
# Hinge residue with wide bands [96, 101, 102, 50, 51, 149, 150, 95]
# current bindings are [23, 25, 27, 28, 29, 30, 32, 47, 48, 49, 50, 83, 84, 86, 124, 126, 128, 129, 130, 131, 133, 149, 150, 151, 152, 183, 184, 185, 187]
# current hits are [50, 149, 150]
# # of overlaps finding from current mode is 3

# %%
modes = 1 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, Hinge1)
# Out:
# [14, 15]
# Hinge residue with wide bands [160, 129, 130, 161, 72, 73, 171, 172, 14, 15, 82, 83, 181, 182, 62, 61, 30, 31]
# current bindings are [23, 25, 27, 28, 29, 30, 32, 47, 48, 49, 50, 83, 84, 86, 124, 126, 128, 129, 130, 131, 133, 149, 150, 151, 152, 183, 184, 185, 187]
# current hits are [30, 83, 129, 130]
# # of overlaps finding from current mode is 4

# %%
modes = 2 # Example modes
plotSingleGraph_method3(modes, averageEigVects, gnms, binding, Hinge2)
# Out:
# [50, 51]
# Hinge residue with wide bands [128, 129, 147, 148, 150, 151, 30, 31, 160, 161, 171, 172, 50, 51, 181, 182, 61, 62, 72, 73, 82, 83, 96, 101, 102, 106, 125]
# current bindings are [23, 25, 27, 28, 29, 30, 32, 47, 48, 49, 50, 83, 84, 86, 124, 126, 128, 129, 130, 131, 133, 149, 150, 151, 152, 183, 184, 185, 187]
# current hits are [30, 50, 83, 128, 129, 150, 151]
# # of overlaps finding from current mode is 7

# %% [markdown]
# # Write Modes

# %%
len(averageEigVects[:, 0])
# Out:
# 514

# %%
mode = 2

# %%
residue = []
new_b_factor = []

for item in averageEigVects[:, mode]:
    new_b_factor.append(item)

# %%
resiIndex = [x for x in range(207, 266)]
chain = ['A' for x in range(207, 266)]

resiIndex += [x for x in range(275, 475)]
chain += ['A' for x in range(275, 475)]


resiIndex += [x for x in range(207, 239)]
chain += ['B' for x in range(207, 239)]

resiIndex += [x for x in range(240, 269)]
chain += ['B' for x in range(240, 269)]

resiIndex += [x for x in range(275, 461)]
chain += ['B' for x in range(275, 461)]

resiIndex += [x for x in range(466, 474)]
chain += ['B' for x in range(466, 474)]

# %%
len(resiIndex)
# Out:
# 514

# %%
len(chain)
# Out:
# 514

# %%
with open('./structure_demo/PPARg_b_mode' + str(mode + 1) + '.txt', 'w') as wf:
    for i in range(len(resiIndex)):
        # print (chain[i])
        wf.write(chain[i] + ', ' + str(resiIndex[i]) + ', ' + str(new_b_factor[i]) + '\n')

# %%
# !pwd
# Out:
# /data/frank/Desktop/Hinges_Figures_all/HIV-PR
