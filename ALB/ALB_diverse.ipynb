# %%
from numpy import *
# from matplotlib.pyplot import *
# import os
# ion()

# find hinges
def splitHinge(vals, sites, block):
    # split hinges
    currBlock = 1
    index = 0
    isStart = False
    newSites = []
    newVals = []

    for val in vals:
        if block[index] == currBlock and not isStart:
            isStart = True
            currSites = [sites[index]]
            currValLists = [vals[index]]
        elif block[index] == currBlock and isStart:
            currSites.append(sites[index])
            currValLists.append(vals[index])
        else:
            currBlock += 1
            isStart = True
            newSites.append(currSites)
            newVals.append(currValLists)
            currSites = [sites[index]]
            currValLists = [vals[index]]
        if currBlock == block[-1] and index == len(vals) - 1:
            newSites.append(currSites)
            newVals.append(currValLists)
        index += 1
    # print newSites, newVals
    return newSites, newVals


def mini(a, b):
    if a > b:
        return a
    else:
        return b


def checkIfCrossBase(currVal, currSite, currEigenVec):
    identify = sort(currVal)
    ifRemain = True
    if identify[0] < 0 and identify[-1] > 0:
        ifRemain = True
    else:
        maxSite = max(currSite)
        minSite = min(currSite)
        # print (identify)
        if identify[0] >= 0 and identify[-1] >= 0:
            if currEigenVec[max(0, minSite - 1)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 1)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 2)] < 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] < 0 or currEigenVec[min(len(currEigenVec) - 1, maxSite + 3)] < 0:
                ifRemain = True
            else:
                ifRemain = False
        elif identify[0] <= 0 and identify[-1] <= 0:
            # print (len(currEigenVec))
            # print (currEigenVec[239])

            if currEigenVec[max(0, minSite - 1)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 1))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 2)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 2))] > 0:
                ifRemain = True
            elif currEigenVec[max(0, minSite - 3)] > 0 or currEigenVec[min(len(currEigenVec) - 1, (maxSite + 3))] > 0:
                ifRemain = True
            else:
                ifRemain = False

        else:
            print(identify[0], identify[-1])
            print("Check!")
    return ifRemain


def oneModeHinge(currEigenVec, thereshold=20):
    range = ((1 / float(len(currEigenVec))) ** 0.5) / thereshold
    # print (range)
    # print range
    sites = []
    vals = []
    block = []

    index = 0
    blockID = 1
    for item in currEigenVec:
        if item <= range and item >= -range:
            vals.append(item)
            if len(sites) >= 1 and abs(sites[-1] - index) > 1:
                blockID += 1
            sites.append(index)
            block.append(blockID)
        index += 1

    newSites, newVals = splitHinge(vals, sites, block)

    filtSites = []
    filtVals = []

    index = 0
    for item in newSites:
        currSite = newSites[index]
        currVal = newVals[index]
        if checkIfCrossBase(currVal, currSite, currEigenVec):
            filtSites.append(currSite)
            filtVals.append(currVal)
        index += 1

    return filtSites, filtVals


def getValue(currList):
    newList = []
    for item in currList:
        newList.append(float(item))
    return newList


def readModes(fileName):
    allModes = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.strip()
            line = line.split('\t')
            currMode = line[0]
            currVal = line[1:]
            allModes[currMode] = getValue(currVal)
    return allModes


def flattenData(arrayTwoD):
    flat = []
    for item in arrayTwoD:
        for each in item:
            flat.append(each)
    return flat

def cleanStr(currStr):
    return currStr.strip('\'')

def readFile(fileName):
    data = {}
    with open(fileName, 'r') as rf:
        for line in rf.readlines():
            line = line.replace('\n', '')
            line = line.strip()
            line = line.split('\t')
            currPDB = line[0]
            currDrug = line[1]
            currChain = line[2:]
            if currPDB not in data.keys():
                data[currPDB] = {}
            if currDrug not in data[currPDB].keys():
                data[currPDB][currDrug] = []
            for each in currChain:
                data[currPDB][currDrug].append(cleanStr(each))
    return data

# contribution of mode of motions
def getContribution(eigenVals, mode):
    allContribution = sqrt(sum(1 / eigenVals))
    currModeContribution = eigenVals[:mode]
    currContribution = sqrt(sum(1 / currModeContribution))
    return currContribution / allContribution

def getModesGivenThreshold(eigenVals, thereshold):
    contribution = 0
    mode = 0
    while contribution <= thereshold:
        mode += 1
        contribution = getContribution(eigenVals, mode)
    return mode

def writeBinding(fileName, pdb_ids):
    with open(fileName, 'w') as wf:
        for item in pdb_ids:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')


from prody import *
def getModes(currPDB, eachChain, length = 0.7, rmsd = 1.0, Z = 10):    
    # if not os.path.exists('./Results/' + currPath):
    #     os.mkdir('./Results/' + currPath)
    dali_rec = searchDali(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len = length, cutoff_rmsd = rmsd, cutoff_Z = Z)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    
    ags = parsePDB(pdb_ids, subset='ca')
    dali_ens = buildPDBEnsemble(ags, mapping=mappings, seqid=20)
    gnms = calcEnsembleENMs(dali_ens, model='GNM', trim='reduce', n_modes=None)
    eigVals = gnms.getEigvals()
    averageEigVals = mean(eigVals, axis=0)

    eigVects = gnms.getEigvecs()
    averageEigVects = mean(eigVects, axis=0)
    return averageEigVals, averageEigVects, pdb_ids, gnms, averageEigVects

            
def getDali_info(currPDB, eachChain, rmsd = 2.5, length = 0.9):
    dali_rec = searchDali(currPDB, eachChain)
    while not dali_rec.isSuccess:
        dali_rec.fetch()

    pdb_ids = dali_rec.filter(cutoff_len=length, cutoff_rmsd=rmsd)
    # pdb_ids = dali_rec.filter(cutoff_identity=0.5)

    currNumber = len(pdb_ids) # this number should over 50 as cutoffs

    print ('# of similar structures is found from Dali', currNumber)
    mappings = dali_rec.getMappings()
    return pdb_ids, mappings

def getHinges(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge


def getHinges_modes(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

def get3Hinges_bandwidth(averageEigVects, bandWidths = [15, 16, 17]):
    currHinge = []
    for i in range(3):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge(averageEigVects[:, i], thereshold=bandWidths[i])
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

# %%
def oneModeHinge_update(values, thereshold=20):
    band = (-sqrt(1/len(values))/thereshold, sqrt(1/len(values))/thereshold)
    # print ('Band is', band)
    
    # Identify crossover points
    crossovers = [i for i in range(1, len(values)) if \
                  (values[i-1] < 0 and values[i] > 0) or \
                  (values[i-1] > 0 and values[i] < 0)]
    # print ('crossovers', crossovers)
    
    # Process each crossover to find the start and end of each region
    regions = []
    for i in crossovers:
        # Initialize region
        region = [i-1, i]
        # print (region)
        
        if (region[0] < band[0] and region[1] > band[1]) or \
        (region[0] < band[1] and region[1] > band[0]):
            regions.append(region)

        else:
            # Extend backwards
            j = i - 2
            while j >= 0 and (band[0] <= values[j] <= band[1]):
                region.insert(0, j)
                j -= 1
                # print (values[j])
                
            # Extend forwards
            j = i + 1
            while j < len(values) and (band[0] < values[j] < band[1]):
                region.append(j)
                j += 1
            regions.append(region)
            
        # print (region)
    regions = merge_overlapping_lists(regions)
    # print (regions)
    
    FinalRegions = []
    for region in regions:
        # print ('before filtering', region)
        if len(region) >= 5:
            # print ('previous region', region)
            pos = [index for index in region if values[index] > 0]
            neg = [index for index in region if values[index] < 0]
            pos.sort(key=lambda x: values[x])
            neg.sort(key=lambda x: values[x], reverse=True)
            n = int(len(region) / 4) + 1
            region = pos[:n] + neg[:n]
            # print (region, neg, pos)
        elif 3 <= len(region) <= 4:
            if values[region[0]-1] * values[region[-1]+1] > 0:
                continue  # Skip this region if adjacent values outside the band have the same sign
        # print ('after filtering',region)      
            
        if region not in FinalRegions:
            FinalRegions.append(region)
    
    # print ('Final regions', FinalRegions)
    
    flat = flattenData(FinalRegions)
    # print (len(flat))
    # Extract indices and values for the final list
    final_values = [values[index] for index in flat]
    
    return FinalRegions, final_values

def getHinges2(averageEigVects, currNumModes, bandWidth = 15):
    currHinge = []
    for i in range(currNumModes):
        # print (i, len(averageEigVects[:, i]))
        currPos, currVals = oneModeHinge_update(averageEigVects[:, i], thereshold=bandWidth)
        currPos = flattenData(currPos)
        # print (currPos)
        currHinge += currPos
        currHinge = list(set(currHinge))
    return currHinge

def getHinges_modes2(averageEigVects, mode, bandWidth = 15):
    currHinge = []
    # print (i, len(averageEigVects[:, i]))
    currPos, currVals = oneModeHinge_update(averageEigVects[:, mode], thereshold=bandWidth)
    currPos = flattenData(currPos)
        # print (currPos)
    currHinge += currPos
    currHinge = list(set(currHinge))
    return currHinge

# %%
# Experiment to evaluate performance of hypergeometric p values
from scipy.stats import hypergeom
def ORA(M, N, n, k):
    total = 0
    totalLength = N
    binding = M
    hinge = n
    overlap = k
    
    for i in range(overlap):
        total += hypergeom.pmf(i, totalLength, binding, hinge)
    return 1 - total


import os
def writeIDs(path, idList):
    # Check whether the specified path exists or not
    isExist = os.path.exists(path)
    if not isExist:

       # Create a new directory because it does not exist
       os.makedirs(path)
       print("The new directory is created!")
    
    with open(path + '/ids_diverse.txt', 'w') as wf:
        for item in idList:
            wf.write(item[:4] + '\t' + item[-1])
            wf.write('\n')

# %%
def writeNumbers(path, numbers):
    with open(path, 'w') as wf:
        for item in numbers:
            wf.write(str(item) + '\n')

def merge_overlapping_lists(lists):
    sorted_lists = sorted(lists, key=lambda x: x[0])  # Sort lists based on the first element
    merged_lists = [sorted_lists[0]]
    
    for current in sorted_lists[1:]:
        previous = merged_lists[-1]
        # Check if the current list overlaps with the previous one
        if current[0] <= previous[-1]:
            # Merge overlapping lists by updating the last list in merged_lists
            merged_lists[-1] = list(range(min(previous[0], current[0]), max(previous[-1], current[-1])+1))
        else:
            merged_lists.append(current)
    return merged_lists

# %% [markdown]
# # Serum Albumin (ALB)

# %%
currPDB = '2bxf'
eachChain = 'A'

# pdb_ids, mappings = getDali_info(currPDB, eachChain, cutoff_len=0.7, cutoff_rmsd=1.0, cutoff_Z=10)
averageEigVals, averageEigVects, ids, gnms, averageEigVects = getModes(currPDB, eachChain, length=0.95, rmsd=1, Z=10)
# Out:
# @> Submitted Dali search for PDB "2bxfA".
# @> http://ekhidna2.biocenter.helsinki.fi/barcosel/tmp//2bxfA//
# @> WARNING : Dali search has timed out.
# The results can be obtained later using the fetch() method.
# @> Dali results were fetched in 96.4s.
# @> Obtained 476 PDB chains from Dali for 2bxfA.
# @> 281 PDBs have been filtered out from 476 Dali hits (remaining: 195).
# @> Retrieving 2bxfA... [  0%]
# # of similar structures is found from Dali 195
# @> 195 PDBs were parsed in 61.98s.
# @> Mapping 6xk0A_ca to the reference... [ 44%] 5s@> WARNING no atommaps were available. Consider adjusting accepting criteria
# @> Starting iterative superposition:
# @> Step #1: RMSD difference = 1.8915e+00
# @> Step #2: RMSD difference = 3.0143e-03
# @> Step #3: RMSD difference = 1.5539e-05
# @> Iterative superposition completed in 0.16s.
# @> Final superposition to calculate transformations.
# @> Superposition completed in 0.05 seconds.
# @> Ensemble (194 conformations) were built in 8.84s.
# @> WARNING 1 structures cannot be mapped.
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2bxfA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1ao6B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1bm0A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1bm0B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4g03B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4g03A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4emxB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4l9kB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4g04B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4g04A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 24 modes for 548 modes from MaskedGNM 3lu8B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4emxA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 3lu7B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4lb2A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4lb2B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 21 modes for 548 modes from MaskedGNM 5ijfA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4la0B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4l9qB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 20 modes for 548 modes from MaskedGNM 5x52A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 3lu6B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 20 modes for 548 modes from MaskedGNM 5yoqA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 18 modes for 548 modes from MaskedGNM 5ujbA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4k2cA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4la0A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 15 modes for 548 modes from MaskedGNM 5ujbB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 1 modes for 548 modes from MaskedGNM 7x7xA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4k2cB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 14 modes for 548 modes from MaskedGNM 5x52B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4l9qA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 3lu6A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 12 modes for 548 modes from MaskedGNM 5yoqB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 5z0bB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 8 modes for 548 modes from MaskedGNM 7wokB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 26 modes for 548 modes from MaskedGNM 3jryB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 26 modes for 548 modes from MaskedGNM 3jryA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 6oclA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 23 modes for 548 modes from MaskedGNM 5yxeA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 6m5eA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 11 modes for 548 modes from MaskedGNM 7djnA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 7 modes for 548 modes from MaskedGNM 1tf0A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 16 modes for 548 modes from MaskedGNM 6m5dA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 5z0bA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 3v09A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 9 modes for 548 modes from MaskedGNM 7wokA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 6m5eC_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 5fuoA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 15 modes for 548 modes from MaskedGNM 7djnB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 6m5eB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 4ot2A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 5dbyA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 4zbrA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 5id9A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 12 modes for 548 modes from MaskedGNM 6m58A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 4zbqA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 1 modes for 548 modes from MaskedGNM 6m58B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 6ociA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 5iihA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 7q4xA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 5dqfA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 26 modes for 548 modes from MaskedGNM 6mdqA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 6ockA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 6u5aA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 18 modes for 548 modes from MaskedGNM 5hozA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 24 modes for 548 modes from MaskedGNM 5iixA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 5iiuA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 6u4xA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 4jk4B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 26 modes for 548 modes from MaskedGNM 4f5vA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 26 modes for 548 modes from MaskedGNM 3v03B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 4jk4A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 10 modes for 548 modes from MaskedGNM 6a7pA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 7 modes for 548 modes from MaskedGNM 7wkzB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 3v03A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 5otbC_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 6rjvB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 5ij5A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 6rjvA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 6qs9A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 7 modes for 548 modes from MaskedGNM 7d6jA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 6hn0A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 5v0vA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 5ijeA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 5otbB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 7mblA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 6ci6A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 4lufA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 4luhA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 4po0A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 26 modes for 548 modes from MaskedGNM 5otbD_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 5oswA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 5otbA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 5oriA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 3v08A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 3jqzA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 6ocjA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 26 modes for 548 modes from MaskedGNM 8bsgA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 4f5tA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 5orfC_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 11 modes for 548 modes from MaskedGNM 6ezqA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 4f5sA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 5orfD_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 23 modes for 548 modes from MaskedGNM 6qs9B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 9 modes for 548 modes from MaskedGNM 5ghkA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 5orfB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 6qioA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4n0uD_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 4or0A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 6qipA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 6u4rA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4k71A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 4f5sB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 4or0B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 5orfA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 6hn1A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4n0fG_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4n0fD_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 24 modes for 548 modes from MaskedGNM 4k71D_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4n0fM_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4n0fJ_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 3 modes for 548 modes from MaskedGNM 6zl1A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1uorA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 5 modes for 548 modes from MaskedGNM 4e99A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 3jqzB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 8a9qA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2bxiA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 7y2dA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 7ov5A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 6wuwB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 8ew7A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 8a9qB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1ha2A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2xvvA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 27 modes for 548 modes from MaskedGNM 7vr9B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2xvwA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2bxlA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2i30A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1hk4A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 26 modes for 548 modes from MaskedGNM 7vr9A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 9 modes for 548 modes from MaskedGNM 6fakA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 7ov1A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1gnjA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 3sqjA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 4j2vA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 7wz9A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 4f5uA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 5yb1A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 23 modes for 548 modes from MaskedGNM 2vdbA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4lb9A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 7eekA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 16 modes for 548 modes from MaskedGNM 7wojA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1e7hA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 5yb1B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1o9xA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 6je7A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 6hscB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 5id7A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2bxkA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2xsiA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 5id7B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 7ov5B_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2bxmA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2bxoA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 6hscA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 7ov6A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1e7fA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1gniA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1h9zA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1e7eA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 8ew4A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 28 modes for 548 modes from MaskedGNM 2i2zA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2bxnA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4bkeA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2bxpA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 7jwnA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 6wuwA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 8cksA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 7wlfA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4l8uA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 7eekB_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 7dl4A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 3cx9A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 2bxqA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 8 modes for 548 modes from MaskedGNM 7yimA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 3b9mA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 25 modes for 548 modes from MaskedGNM 3tdlA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 5ifoA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 8ey5A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 1e7gA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 8itrA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4z69A_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 4z69I_ca reduced has been discarded because at least one conformation has only 548 modes
# @> WARNING last 29 modes for 548 modes from MaskedGNM 8q3fA_ca reduced has been discarded because at least one conformation has only 548 modes
# @> all GNM modes were calculated for each of the 194 conformations in 32.27s.
# @> 548 modes across 194 modesets were matched in 12.71s.

# %%
writeIDs('./Binding', ids)

# %%
len(ids)
# Out:
# 195

# %%
currNumModes = getModesGivenThreshold(averageEigVals, 0.33)
currNumModes

# %%
bindings = ['203', '204', '207', '208', '318', '321', '322', '325', '341', '344', '345', '381', '382', '383', '385', '386', '387', '396', '397', '398', '399', '400', '401', '402', '403', '404', '405', '406', '408', '424', '425', '427', '428', '429', '432', '433', '443', '444', '445', '447', '448', '451', '474', '475', '476', '477', '479', '480', '482', '483', '484', '523', '536', '538', '539', '542']

binding = list(set([int(x) for x in bindings]))

# %%
Hinges_2 = getHinges(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges(averageEigVects, 3, 20)

Hinges_4 = getHinges(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges(averageEigVects, 3, 15)

# %%
protein_length = 578

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 56
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 14 2 0.4004572153553545
# # of hinge sites for first 3 modes, overlap, hyper score 75 4 0.9518869323302681
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 19 4 0.10186313226669319
# # of hinge sites for first 3 modes, overlap, hyper score 105 12 0.3059160634356165

# %%
Badren = parsePDB('2bxf', subset='calpha')
calphas = Badren.select('calpha and chain A')
gnm = GNM('b-adren')
gnm.buildKirchhoff(calphas)
gnm.calcModes(n_modes=None)
eigenVals = gnm.getEigvals()
eigenVects = gnm.getEigvecs()
Hinge0 = calcHinges(gnm[0])
Hinge1 = calcHinges(gnm[1])
Hinge2 = calcHinges(gnm[2])

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0 + Hinge1))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0 + Hinge1))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 56
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 27 5 0.10948111788404435
# # of hinge sites for 3 modes, overlap, hyper score 95 9 0.5925411011488728
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 32 7 0.026872350729655325
# # of hinge sites for 3 modes, overlap, hyper score 122 16 0.10469417965223715

# %% [markdown]
# ## writeResults

# %%
# write MSFs
averageEigVals
modes = [0, 1]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)
len(MSF)
# Out:
# 578

# %%
values_array = np.array(sqrt(MSF))

# Get indices of the 5 smallest values
indices = np.argsort(values_array)

if not os.path.exists('./Data'):
    os.mkdir('./Data')

writeNumbers('./Data/RMSF_minimum.txt', indices)

# %%
curr = zeros((len(MSF), 7))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]

for each in binding:
    curr[each, 0] = each

# %%
modes = [0, 1]
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    currList = sort(list(set(list(currHinge) + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
curr = list(curr)
def writeAllData(path, curr):
    with open(path, 'w') as wf:
        for row in curr:
            for col in row:
                if col == 0.0:
                    wf.write('' + '\t')
                else:
                    wf.write(str(col) + '\t')
            wf.write('\n')
                
writeAllData('./Data/ALB_Method1.txt', curr)

# %% [markdown]
# ## Method 2

# %%
Hinges_2 = getHinges2(averageEigVects, currNumModes, 20)
Hinges_3 = getHinges2(averageEigVects, 3, 20)

Hinges_4 = getHinges2(averageEigVects, currNumModes, 15)
Hinges_5 = getHinges2(averageEigVects, 3, 15)

# %%
Hinges_4 = list(set([x for x in Hinges_4 + [338, 341, 344, 195, 237, 279, 402, 421, 459, 460]\
                     if x not in [279, 371]]))

# %%
protein_length = 578

overlaps_2 = len(binding) + len(Hinges_2) - len(set(binding + Hinges_2))
overlaps_3 = len(binding) + len(Hinges_3) - len(set(binding + Hinges_3))
overlaps_4 = len(binding) + len(Hinges_4) - len(set(binding + Hinges_4))
overlaps_5 = len(binding) + len(Hinges_5) - len(set(binding + Hinges_5))

HyperScore_2 = ORA(len(binding), protein_length, len(Hinges_2), overlaps_2)
HyperScore_3 = ORA(len(binding), protein_length, len(Hinges_3), overlaps_3)
HyperScore_4 = ORA(len(binding), protein_length, len(Hinges_4), overlaps_4)
HyperScore_5 = ORA(len(binding), protein_length, len(Hinges_5), overlaps_5)

print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_2), overlaps_2, HyperScore_2)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_3), overlaps_3, HyperScore_3)

print ('Hinge allocated zeta = 15')
print ('# of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_4), overlaps_4, HyperScore_4)
print ('# of hinge sites for first 3 modes, overlap, hyper score', len(Hinges_5), overlaps_5, HyperScore_5)
# Out:
# # of binding sites is 56
# Hinge allocated zeta = 20
# # of hinge sites for threshold 0.35, overlap, hyper score 24 5 0.07216317065967992
# # of hinge sites for first 3 modes, overlap, hyper score 60 5 0.7162301388380922
# Hinge allocated zeta = 15
# # of hinge sites for threshold 0.35, overlap, hyper score 34 8 0.011472322475327257
# # of hinge sites for first 3 modes, overlap, hyper score 68 7 0.49705478776657763

# %%
Hinges_sep2 = list(set(Hinges_2 + Hinge0 + Hinge1))
Hinges_sep3 = list(set(Hinges_3 + Hinge0 + Hinge1 + Hinge2))
Hinges_sep4 = list(set(Hinges_4 + Hinge0 + Hinge1))
Hinges_sep5 = list(set(Hinges_5 + Hinge0 + Hinge1 + Hinge2))

overlaps_sep2 = len(binding) + len(Hinges_sep2) - len(set(binding + Hinges_sep2))
overlaps_sep3 = len(binding) + len(Hinges_sep3) - len(set(binding + Hinges_sep3))
overlaps_sep4 = len(binding) + len(Hinges_sep4) - len(set(binding + Hinges_sep4))
overlaps_sep5 = len(binding) + len(Hinges_sep5) - len(set(binding + Hinges_sep5))


HyperScore_sep2 = ORA(len(binding), protein_length, len(Hinges_sep2), overlaps_sep2)
HyperScore_sep3 = ORA(len(binding), protein_length, len(Hinges_sep3), overlaps_sep3)
HyperScore_sep4 = ORA(len(binding), protein_length, len(Hinges_sep4), overlaps_sep4)
HyperScore_sep5 = ORA(len(binding), protein_length, len(Hinges_sep5), overlaps_sep5)


print ('# of binding sites is', len(binding))
print ('Hinge allocated zeta = 20')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep2), overlaps_sep2, HyperScore_sep2)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep3), overlaps_sep3, HyperScore_sep3)

print ('Hinge allocated zeta = 15')
print ('# of of hinge sites for threshold 0.35, overlap, hyper score', len(Hinges_sep4), overlaps_sep4, HyperScore_sep4)  
print ('# of hinge sites for 3 modes, overlap, hyper score', len(Hinges_sep5), overlaps_sep5, HyperScore_sep5)
# Out:
# # of binding sites is 56
# Hinge allocated zeta = 20
# # of of hinge sites for threshold 0.35, overlap, hyper score 35 8 0.013749945992516999
# # of hinge sites for 3 modes, overlap, hyper score 80 9 0.36665995268934803
# Hinge allocated zeta = 15
# # of of hinge sites for threshold 0.35, overlap, hyper score 36 8 0.016345304282132878
# # of hinge sites for 3 modes, overlap, hyper score 88 11 0.2154270661983514

# %%
AverageEigVals1 = gnms.getEigvals()[0]
AverageEigVals2 = mean(gnms.getEigvals(), axis=0)
proteinLength = 578

# %%
currHinge = Hinges_4

# %%
Segment = int(proteinLength / 5)
print ('mark Index are', 0, Segment, Segment*2, Segment*3, Segment*4, proteinLength - 1)
# Out:
# mark Index are 0 115 230 345 460 577

# %%
Labels = ['5', '120', '235', '350', '465', '582']

# %%
import matplotlib.patches as patches
fig, ax = plt.subplots(figsize=(20, 10))   # Adjust size as per requirement
plt.sca(ax)  # Set current axis to 'ax'
    
# Increase font sizes
plt.rc('xtick', labelsize=55)
plt.rc('ytick', labelsize=50)
plt.rcParams.update({'font.size': 70})

# calcMSF
modes = [0, 1]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / AverageEigVals2[mode]
    MSF.append(currMSF)

plt.plot(MSF, color='black', linewidth=4, alpha=0.88)    

HingeY = [MSF[item] for item in currHinge]
plt.plot(currHinge, HingeY, color=(0.2, 1, 0.1), marker='o', linestyle='', markersize=25)
print ('# of hinges', len(HingeY))

# plot binding sites
bindingY = [MSF[item] for item in binding]
plt.plot(binding, bindingY, 'r*', markersize=30)
print ('# of bindings sites', len(binding))

# plot overlaps
allHinge = currHinge
overlaps = [item for item in binding if item in allHinge]
overlapsY = [MSF[item] for item in overlaps]
plt.plot(overlaps, overlapsY, 'mD', markersize=25)

print ('# of hits are', len(overlaps))

# Hide y labels
plt.gca().yaxis.set_visible(False)

# Hide top, right, and left spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)


# Set x-axis labels and title with Arial font
# plt.title('Serum Albumin')
plt.xticks([0, Segment, Segment*2, Segment*3, Segment*4, proteinLength - 1], Labels)

plt.savefig('./ALB_MSF.png', dpi=500)
# Out:
# # of hinges 34
# # of bindings sites 56
# # of hits are 8

# %%
AverageEigVals2
# Out:
# array([ 0.17935933,  0.32811392,  0.63195479,  0.83812052,  0.99969581,
#         1.34739654,  1.60803751,  2.50746863,  1.99804179,  2.35512845,
#         2.38041992,  2.93123626,  2.97542544,  3.34990768,  3.33115845,
#         3.23390522,  3.5691857 ,  3.82269649,  3.97774035,  4.03669675,
#         4.79910812,  4.36887892,  4.76038922,  5.91668381,  4.75170884,
#         5.03966131,  4.98450272,  5.25208942,  5.61560138,  5.72699127,
#         5.68763491,  6.07476167,  6.13097547,  6.26153145,  6.85434408,
#         6.32641285,  6.65894208,  6.84137348,  8.02063553,  6.98701893,
#         7.43353946,  7.1703455 ,  7.44447943,  7.36084775,  7.47586585,
#         7.68177411,  7.83901727,  7.84181515,  8.11602817,  8.35988942,
#         8.25014477,  8.66226325,  8.88082789,  8.9109834 ,  8.78879678,
#         8.83331476,  8.53983231,  9.25893398,  9.11278309,  9.07915032,
#         9.83546077, 10.92329929,  9.46910008,  9.98627704,  9.31146128,
#         9.79215349,  9.54812205,  9.91308029, 10.22059137,  9.53962154,
#        10.21933442, 10.38139557,  9.8370496 , 12.35654154, 10.06269472,
#        10.18663108, 10.91237246, 11.34530223, 10.44856371, 10.67795597,
#        10.45398887, 10.95230765, 11.02544328, 10.95575042, 10.54017569,
#        12.50128769, 11.22320234, 10.87288958, 10.84600734, 10.98164282,
#        10.93028349, 11.17168308, 10.96199725, 11.01769458, 11.15894546,
#        11.18435823, 11.49599551, 11.40378171, 11.26845713, 11.92102613,
#        11.82483119, 12.11572417, 11.75617968, 11.53066993, 11.46265909,
#        11.66833282, 11.91803853, 11.81370956, 12.94045038, 11.53574124,
#        11.72390201, 11.7066292 , 11.94033517, 11.7749228 , 12.08825842,
#        12.2757633 , 11.96009886, 11.65397138, 11.99846025, 11.43922044,
#        12.67547047, 12.12949902, 12.90512258, 12.29105125, 12.24724141,
#        12.32969484, 12.69715945, 12.34055829, 12.96068788, 12.53090977,
#        12.28218048, 12.89375207, 12.43752939, 12.60697895, 12.42836228,
#        12.50668533, 13.22493913, 13.27194989, 12.84710225, 12.75326318,
#        13.33309042, 12.47122163, 12.9025145 , 12.70180968, 12.84545191,
#        12.9799424 , 12.78708952, 13.45844577, 12.79871009, 13.31954879,
#        13.285676  , 13.18770323, 12.93989484, 13.40094685, 12.90466157,
#        13.68986099, 13.09817594, 13.36712272, 12.96239654, 13.29053608,
#        13.25387289, 13.19229673, 13.13644782, 13.41163128, 12.88501322,
#        13.34390419, 12.93936334, 13.46112161, 14.02785112, 13.68295631,
#        13.38326904, 13.54618664, 13.71022027, 13.54387886, 13.72313084,
#        13.497633  , 13.73024518, 13.08835626, 13.78445042, 13.53164601,
#        13.61055302, 13.43070064, 15.18544313, 13.80925268, 14.02418168,
#        13.83071987, 13.91471389, 13.87797287, 14.27412513, 13.96642642,
#        13.423202  , 13.92239149, 14.294123  , 14.44575412, 14.41355619,
#        14.12108097, 14.33720203, 14.59978201, 14.08490985, 14.47251288,
#        14.04453772, 14.44716235, 15.86670402, 14.64641108, 14.35730129,
#        14.61081011, 14.61425396, 14.74936569, 14.77450952, 15.11514341,
#        14.73018784, 15.13780377, 14.97380926, 14.78085018, 14.7081483 ,
#        15.13880059, 15.07538373, 14.89897508, 15.12417225, 15.0177995 ,
#        15.01649634, 15.36501102, 15.52623089, 15.01621647, 16.27383471,
#        14.97239771, 14.77934759, 15.1899996 , 14.63392056, 15.43583763,
#        15.37621627, 15.37389124, 15.32208065, 15.51077353, 15.74195489,
#        15.48409544, 15.35648936, 15.39835966, 15.67155562, 15.63689565,
#        15.42941816, 15.84516129, 15.72758938, 15.51913091, 15.50961273,
#        15.7896112 , 15.81983838, 15.89997471, 15.77707266, 15.7149665 ,
#        15.83968155, 15.76605853, 16.15053318, 15.86946227, 15.68663638,
#        16.0870118 , 16.09366843, 16.38322109, 16.41104521, 16.18972225,
#        16.4773541 , 16.02653678, 16.34435487, 16.15606659, 16.67466017,
#        16.22775511, 17.02317853, 17.32261432, 16.42258311, 16.75167294,
#        16.38376358, 16.50031814, 16.41994936, 16.63539212, 16.48703249,
#        17.70249677, 17.49045777, 16.68669064, 16.58300559, 16.60651129,
#        16.52916676, 16.82656785, 16.68695726, 16.74433799, 16.97244688,
#        16.85636895, 17.18182881, 16.81662829, 16.61892315, 16.77386871,
#        17.45840764, 17.36955903, 17.56947701, 17.1529845 , 17.65446598,
#        17.30339355, 17.20123342, 17.24220577, 17.14362913, 17.44189738,
#        17.3930144 , 17.38301614, 17.9931206 , 17.58315028, 17.43228871,
#        17.41671487, 17.45846823, 17.65107026, 17.94892684, 18.87674398,
#        17.61360555, 17.84620832, 17.8250169 , 17.94588757, 18.13875226,
#        17.98662294, 18.20252158, 17.99248454, 17.95043557, 17.83193392,
#        17.9151386 , 17.88246044, 18.32384647, 17.72438077, 17.16515119,
#        17.79964641, 18.42282279, 18.10680985, 18.40152976, 18.33297687,
#        18.47815201, 18.86377029, 18.53731475, 18.01273199, 18.02742689,
#        18.49249326, 18.70303157, 18.77077486, 18.21699667, 18.9776346 ,
#        18.5620782 , 18.44400775, 18.36175909, 18.43009287, 18.58304793,
#        18.63162722, 18.88922435, 17.70983565, 18.82026273, 18.84883923,
#        18.78776142, 19.04104197, 19.12505864, 18.66581293, 18.98457482,
#        18.97062712, 18.71695705, 19.05563491, 18.84238484, 19.16717753,
#        19.20560343, 19.19406814, 19.3035577 , 19.21808262, 18.48895122,
#        19.15883467, 19.31148845, 19.24612282, 19.43400171, 19.29913799,
#        19.5703229 , 19.14227614, 19.80824372, 19.86227135, 19.41577025,
#        19.55755324, 19.77022878, 19.55345917, 19.69425287, 19.89850735,
#        19.82704153, 20.14505278, 19.76158841, 19.65756202, 19.84581115,
#        20.1872565 , 20.25562613, 19.96734862, 20.25377327, 20.12635465,
#        20.46981442, 20.23152043, 20.30946799, 20.59402566, 20.142321  ,
#        20.03358424, 21.04488204, 20.21742283, 20.67364931, 20.65285338,
#        20.10742453, 20.1116798 , 20.73208523, 20.46671529, 21.53736277,
#        20.73102679, 20.72414229, 20.82421051, 20.66126003, 20.63661259,
#        20.66858073, 20.68387249, 21.09461174, 21.13487164, 20.74300354,
#        20.68042536, 21.14948859, 20.91840134, 21.1987967 , 21.73533641,
#        20.95775178, 21.45619641, 21.07663625, 21.15169853, 21.21301483,
#        21.26651545, 21.51603524, 21.52208106, 21.57807876, 21.25307316,
#        21.21033149, 21.31597264, 21.06696011, 20.78537426, 21.54735874,
#        21.69843288, 21.85947598, 21.26581515, 21.43571107, 21.59620882,
#        21.57082071, 21.83457144, 22.09339725, 21.84927735, 22.17462277,
#        21.80803022, 22.16301422, 21.55724735, 22.09685266, 22.37514182,
#        22.33673662, 22.07080973, 22.03045124, 22.14782397, 22.04560725,
#        22.23418597, 22.35216651, 21.99769324, 22.00369001, 22.92879405,
#        22.30185279, 22.85648324, 22.37990834, 22.33690513, 22.83903465,
#        22.64439705, 22.2464999 , 22.68560265, 22.99390132, 22.26056203,
#        22.85821489, 22.75890384, 22.51006389, 22.4552038 , 22.3732645 ,
#        23.93134283, 23.13895756, 23.1695314 , 23.06964336, 23.26391863,
#        23.52255693, 23.03090147, 23.0303205 , 23.35054602, 23.25551738,
#        23.57349423, 23.20343752, 23.32357285, 23.45628432, 23.43469482,
#        23.3116556 , 23.70688056, 23.42514323, 23.46938841, 23.64727007,
#        23.88193191, 23.4067276 , 23.43457272, 23.6980175 , 23.53963193,
#        23.7047428 , 23.52067553, 24.14539903, 23.71469902, 23.60751261,
#        23.34496213, 23.59631639, 24.08769833, 24.45980951, 24.07656093,
#        24.57925586, 24.46849243, 24.67683535, 24.13396268, 24.59043065,
#        24.0772479 , 24.98913219, 23.87588679, 24.37308215, 25.25882806,
#        24.11607917, 25.28295128, 24.91047233, 24.80285982, 25.17199285,
#        25.30284524, 25.42830406, 24.94731177, 25.2848637 , 25.52614317,
#        25.47493181, 25.44591191, 25.34779446, 24.874398  , 24.49264796,
#        25.1654032 , 25.63316196, 25.62073112, 25.45773407, 25.377293  ,
#        25.72102862, 25.51522665, 25.69156199, 24.56869385, 25.25576363,
#        26.25987373, 25.11414516, 23.70006927])

# %% [markdown]
# ## writeResults

# %%
# write MSFs
averageEigVals
modes = [0, 1]
MSF = []

row, col = averageEigVects.shape
for i in range(row):
    currMSF = 0
    for mode in modes:
        currMSF += averageEigVects[i, mode] ** 2 / averageEigVals[mode]
    MSF.append(currMSF)

# %%
curr = zeros((len(MSF), 7))
# write MSF and RMSF
curr[:, -1] = sqrt(MSF)
curr[:, -2] = MSF

# write modes
curr[:, 1] = averageEigVects[:, 0]
curr[:, 3] = averageEigVects[:, 1]

for each in binding:
    curr[each, 0] = each

# %%
row, col = averageEigVects.shape

for mode in modes:
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=15)
    currList = sort(list(set(list(currHinge) + list(calcHinges(gnm[mode])))))
    for item in currList:
        curr[item, mode*2 + 2] = curr[item, mode*2 + 1]

# %%
writeAllData('./Data/ALB_Method2.txt', curr)

# %% [markdown]
# # Write Modes

# %%
def writeModesAsBfactors(mode, eigenVects):
    residue = []
    new_b_factor = []
    chain = 'A'

    resiIndex = 4
    for item in eigenVects[:, mode]:
        resiIndex += 1
        residue.append(resiIndex)
        new_b_factor.append(item)

    with open('./Structure_demo/ALB_b_mode' + str(mode + 1) + '.txt', 'w') as wf:
        for i in range(len(residue)):
            wf.write(chain + ', ' + str(residue[i]) + ', ' + str(new_b_factor[i]) + '\n')

# %%
writeModesAsBfactors(0, eigenVects)
writeModesAsBfactors(1, eigenVects)

# %% [markdown]
# # Plot graphs

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import math
import numpy as np

def format_significant(value, pos):
    if abs(value) <= 0.01:
        return "0.00"
    else:
        order_of_magnitude = math.floor(math.log10(abs(value)))
        round_digits = -order_of_magnitude + 1
        formatted_number = round(value, round_digits)
        str_format = "{:." + str(round_digits) + "f}"
        return str_format.format(formatted_number)

# %%
def plotSingleGraph(mode, averageEigVects, gnms, binding, Hinge):
    fig, ax = plt.subplots(figsize=(20, 10))   # Adjust size as per requirement
    
    plt.sca(ax)  # Set current axis to 'ax'
    
    # Increase font sizes
    plt.rc('xtick', labelsize=40)
    plt.rc('ytick', labelsize=50)
    plt.rcParams.update({'font.size': 50})

    # plot mode of motion
    showSignatureMode(gnms[:, mode], linewidth=3)

    # Hinges within band
    # method1
    # currHinge = getHinges_modes(averageEigVects, mode, bandWidth=15)
    # method2
    currHinge = getHinges_modes2(averageEigVects, mode, bandWidth=15)
    
    if mode == 0:
        currHinge = [x for x in currHinge + [338, 341, 344] if x not in [371]]
    elif mode == 1:
        currHinge = [x for x in currHinge + [195, 237, 279, 402, 421, 459, 460] \
                     if x not in [279]]
    
    
    HingeY = [averageEigVects[item, mode] for item in currHinge]
    print ('Hinge residue with wide bands', currHinge)
    plt.plot(currHinge, HingeY, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # extraHinges for local loops
    # updateHinge = [item for item in Hinge if item not in currHinge]
    # HingeY_local = [averageEigVects[item, mode] for item in updateHinge]
    # print ('local loop motion', updateHinge)
    # plt.plot(updateHinge, HingeY_local, color=(0.5, 1, 0), marker='o', linestyle='', markersize=15)

    # plot binding sites
    bindingY = [averageEigVects[item, mode] for item in binding]
    plt.plot(binding, bindingY, 'r*', markersize=18)
    print ('current bindings are', binding)
    plt.title('Mode ' + str(mode + 1), fontweight="bold")

    # plot overlaps
    allHinge = currHinge
    overlaps = [item for item in binding if item in allHinge]
    overlapsY = [averageEigVects[item, mode] for item in overlaps]
    print ('current hits are', overlaps)
    plt.plot(overlaps, overlapsY, 'mD', markersize=18)

    print('# of overlaps finding from current mode is', len(overlaps))
    
    # Set y-ticks to have 4-5 values with equal spacing
    y_min, y_max = ax.get_ylim()
    ax.set_yticks(np.linspace(y_min * 0.9, y_max, 5))  # Adjust the number 5 if you want a different number of y-ticks
    ax.yaxis.set_major_formatter(FuncFormatter(format_significant)) 
    
    plt.tight_layout()
    plt.savefig('./ALB_method2Merging_mode' + str(mode + 1) + '.png', dpi=500)

# %%
modes = 0 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [333, 334, 335, 338, 341, 344]
# current bindings are [385, 386, 387, 523, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 408, 536, 538, 539, 542, 424, 425, 427, 428, 429, 432, 433, 443, 444, 445, 318, 447, 448, 321, 322, 451, 325, 203, 204, 207, 208, 341, 344, 345, 474, 475, 476, 477, 479, 480, 482, 483, 484, 381, 382, 383]
# current hits are [341, 344]
# # of overlaps finding from current mode is 2

# %%
modes = 1 # Example modes
plotSingleGraph(modes, averageEigVects, gnms, binding, [])
# Out:
# Hinge residue with wide bands [396, 397, 398, 399, 423, 424, 192, 193, 454, 455, 456, 457, 465, 466, 467, 468, 486, 487, 238, 239, 250, 251, 195, 237, 402, 421, 459, 460]
# current bindings are [385, 386, 387, 523, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 408, 536, 538, 539, 542, 424, 425, 427, 428, 429, 432, 433, 443, 444, 445, 318, 447, 448, 321, 322, 451, 325, 203, 204, 207, 208, 341, 344, 345, 474, 475, 476, 477, 479, 480, 482, 483, 484, 381, 382, 383]
# current hits are [396, 397, 398, 399, 402, 424]
# # of overlaps finding from current mode is 6
